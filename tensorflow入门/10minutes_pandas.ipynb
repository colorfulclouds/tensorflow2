# %%
#http://www.cnblogs.com/chaosimple/p/4153083.html
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,2,3,4.2,'f',np.nan])

# %%
s
# Out:
# 0      1
# 1      2
# 2      3
# 3    4.2
# 4      f
# 5    NaN
# dtype: object

# %%
dates = pd.date_range('20171031' , periods = 6)
dates
# Out:
# DatetimeIndex(['2017-10-31', '2017-11-01', '2017-11-02', '2017-11-03',
#                '2017-11-04', '2017-11-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4) , index=dates , columns=list('ABCD'))

# %%
print(df.dtypes)
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df2 = pd.DataFrame({'A':1.,
                   'B':pd.Timestamp('20171031'),
                   'C':pd.Series(1 , index=list(range(4)) , dtype='float32'),
                   'D':np.array([3]*4 , dtype='int32'),
                   'E':pd.Categorical(['test' , 'train' , 'test' , 'train']),
                   'F':'foo'})
#df2中的这些属性列 都可以被tab访问到

# %%
df2
#上下两种效果不一样 上面的像是一个图片 下面的像是控制台的输出
print(df2)
print(df2.dtypes)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2017-10-31  1.0  3   test  foo
# 1  1.0 2017-10-31  1.0  3  train  foo
# 2  1.0 2017-10-31  1.0  3   test  foo
# 3  1.0 2017-10-31  1.0  3  train  foo
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()#默认显示前5行 可以指定df.head(3)
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945

# %%
df.tail()#默认显示后5行 可以指定 df.tail(3)
# Out:
#                    A         B         C         D
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699

# %%
df
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699

# %%
df.index
# Out:
# DatetimeIndex(['2017-10-31', '2017-11-01', '2017-11-02', '2017-11-03',
#                '2017-11-04', '2017-11-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.1050273 ,  0.17586672, -0.12334467, -0.1979002 ],
#        [ 0.30725139, -0.51081474,  0.2486227 , -1.52138135],
#        [ 0.34825999,  0.64660299,  1.19134583, -0.37769014],
#        [ 0.81133255, -0.59427794,  1.5057626 , -1.25742834],
#        [-1.06225285,  0.61523939,  0.51010605, -1.88994516],
#        [ 0.18084039, -0.57527366, -2.42611573, -1.06269884]])

# %%
df.describe()#快速统计一下
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.115076 -0.040443  0.151063 -1.051174
# std    0.627154  0.593762  1.398069  0.655586
# min   -1.062253 -0.594278 -2.426116 -1.889945
# 25%    0.123981 -0.559159 -0.030353 -1.455393
# 50%    0.244046 -0.167474  0.379364 -1.160064
# 75%    0.338008  0.505396  1.021036 -0.548942
# max    0.811333  0.646603  1.505763 -0.197900

# %%
df.T
# Out:
#    2017-10-31  2017-11-01  2017-11-02  2017-11-03  2017-11-04  2017-11-05
# A    0.105027    0.307251    0.348260    0.811333   -1.062253    0.180840
# B    0.175867   -0.510815    0.646603   -0.594278    0.615239   -0.575274
# C   -0.123345    0.248623    1.191346    1.505763    0.510106   -2.426116
# D   -0.197900   -1.521381   -0.377690   -1.257428   -1.889945   -1.062699

# %%
df
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699

# %%
#按轴进行排序
df.sort_index(axis=1 ,ascending=False)#True升序
# Out:
#                    D         C         B         A
# 2017-10-31 -0.197900 -0.123345  0.175867  0.105027
# 2017-11-01 -1.521381  0.248623 -0.510815  0.307251
# 2017-11-02 -0.377690  1.191346  0.646603  0.348260
# 2017-11-03 -1.257428  1.505763 -0.594278  0.811333
# 2017-11-04 -1.889945  0.510106  0.615239 -1.062253
# 2017-11-05 -1.062699 -2.426116 -0.575274  0.180840

# %%
df.sort_values(by='B')#按哪一列的value进行排序
# Out:
#                    A         B         C         D
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690

# %%
df
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699

# %%
df.A
# Out:
# 2017-10-31    0.105027
# 2017-11-01    0.307251
# 2017-11-02    0.348260
# 2017-11-03    0.811333
# 2017-11-04   -1.062253
# 2017-11-05    0.180840
# Freq: D, Name: A, dtype: float64

# %%
df['A']
# Out:
# 2017-10-31    0.105027
# 2017-11-01    0.307251
# 2017-11-02    0.348260
# 2017-11-03    0.811333
# 2017-11-04   -1.062253
# 2017-11-05    0.180840
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]#也可以进行切片
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690

# %%
df['20171031':'20171102']
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690

# %%
print(dates)
# Out:
# DatetimeIndex(['2017-10-31', '2017-11-01', '2017-11-02', '2017-11-03',
#                '2017-11-04', '2017-11-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
#loc方法通过标签进行选择 数据
#iloc通过索引进行选择数据（index loc）

# %%
df.loc[dates[0]]
#使用标签来获取一个交叉的区域
# Out:
# A    0.105027
# B    0.175867
# C   -0.123345
# D   -0.197900
# Name: 2017-10-31 00:00:00, dtype: float64

# %%
#通过标签来在多个轴上进行选择
df.loc[: , ['A','B']]
# Out:
#                    A         B
# 2017-10-31  0.105027  0.175867
# 2017-11-01  0.307251 -0.510815
# 2017-11-02  0.348260  0.646603
# 2017-11-03  0.811333 -0.594278
# 2017-11-04 -1.062253  0.615239
# 2017-11-05  0.180840 -0.575274

# %%
#标签的切片
df.loc['20171031':'20171102' , ['A','B']]
# Out:
#                    A         B
# 2017-10-31  0.105027  0.175867
# 2017-11-01  0.307251 -0.510815
# 2017-11-02  0.348260  0.646603

# %%
#返回的对象进行维度缩减
df.loc['20171102' , ['A','B']]
# Out:
# A    0.348260
# B    0.646603
# Name: 2017-11-02 00:00:00, dtype: float64

# %%
df.loc[dates[0] , 'A'] #获取一个标量 直接确定了具体的位置
# Out:
# 0.10502729827861898

# %%
df.at[dates[0] , 'A']#与上一个方法相同
# Out:
# 0.10502729827861898

# %%
df
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699

# %%
#iloc (index loc)
#下标从0开始
#通过位置进行选择数据 （索引）
#3 4 , 0 1
df.iloc[3:5 , 0:2]
# Out:
#                    A         B
# 2017-11-03  0.811333 -0.594278
# 2017-11-04 -1.062253  0.615239

# %%
df.iloc[3]
# Out:
# A    0.811333
# B   -0.594278
# C    1.505763
# D   -1.257428
# Name: 2017-11-03 00:00:00, dtype: float64

# %%
df
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699

# %%
#指定一个位置的列表
df.iloc[[1,2,4] , [0,2]]
# Out:
#                    A         C
# 2017-11-01  0.307251  0.248623
# 2017-11-02  0.348260  1.191346
# 2017-11-04 -1.062253  0.510106

# %%
#对行进行切片
df.iloc[1:3 , :]
# Out:
#                    A         B         C         D
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690

# %%
#对列进行切片
df.iloc[: , 1:3]
# Out:
#                    B         C
# 2017-10-31  0.175867 -0.123345
# 2017-11-01 -0.510815  0.248623
# 2017-11-02  0.646603  1.191346
# 2017-11-03 -0.594278  1.505763
# 2017-11-04  0.615239  0.510106
# 2017-11-05 -0.575274 -2.426116

# %%
df
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699

# %%
#获取特定位置的值
df.iloc[1,1]
# Out:
# -0.51081473523918519

# %%
#和上面的功能一样
df.iat[1,1]
# Out:
# -0.51081473523918519

# %%
df
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699

# %%
#使用布尔索引 进行选择数据
df[df.A>0]
# Out:
#                    A         B         C         D
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699

# %%
df[df>0]
# Out:
#                    A         B         C   D
# 2017-10-31  0.105027  0.175867       NaN NaN
# 2017-11-01  0.307251       NaN  0.248623 NaN
# 2017-11-02  0.348260  0.646603  1.191346 NaN
# 2017-11-03  0.811333       NaN  1.505763 NaN
# 2017-11-04       NaN  0.615239  0.510106 NaN
# 2017-11-05  0.180840       NaN       NaN NaN

# %%
df3 = df.copy()

# %%
#在后面新增加了一列
df3['E'] = ['one', 'two', 'one', 'one', 'one', 'one']

# %%
df3
# Out:
#                    A         B         C         D    E
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900  one
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381  two
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690  one
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428  one
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945  one
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699  one

# %%
#对dataframe的设置相关
s1 = pd.Series([1,2,3,4,5,6] , index=pd.date_range('20171031' , periods=6))

# %%
s1
# Out:
# 2017-10-31    1
# 2017-11-01    2
# 2017-11-02    3
# 2017-11-03    4
# 2017-11-04    5
# 2017-11-05    6
# Freq: D, dtype: int64

# %%
df['F'] =s1
#新增加了一列

# %%
df
# Out:
#                    A         B         C         D  F
# 2017-10-31  0.105027  0.175867 -0.123345 -0.197900  1
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381  2
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690  3
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428  4
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945  5
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699  6

# %%
df.at[dates[0] , 'A']= 0

# %%
df
# Out:
#                    A         B         C         D  F
# 2017-10-31  0.000000  0.175867 -0.123345 -0.197900  1
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381  2
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690  3
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428  4
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945  5
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699  6

# %%
df.iat[0,1]=0

# %%
df
# Out:
#                    A         B         C         D  F
# 2017-10-31  0.000000  0.000000 -0.123345 -0.197900  1
# 2017-11-01  0.307251 -0.510815  0.248623 -1.521381  2
# 2017-11-02  0.348260  0.646603  1.191346 -0.377690  3
# 2017-11-03  0.811333 -0.594278  1.505763 -1.257428  4
# 2017-11-04 -1.062253  0.615239  0.510106 -1.889945  5
# 2017-11-05  0.180840 -0.575274 -2.426116 -1.062699  6

# %%
df.loc[: , 'D'] = np.array([5] * len(df))#进行设置

# %%
df
# Out:
#                    A         B         C  D  F
# 2017-10-31  0.000000  0.000000 -0.123345  5  1
# 2017-11-01  0.307251 -0.510815  0.248623  5  2
# 2017-11-02  0.348260  0.646603  1.191346  5  3
# 2017-11-03  0.811333 -0.594278  1.505763  5  4
# 2017-11-04 -1.062253  0.615239  0.510106  5  5
# 2017-11-05  0.180840 -0.575274 -2.426116  5  6

# %%
len(df)#6行
# Out:
# 6

# %%
df4 = df.copy()

# %%
df4
# Out:
#                    A         B         C  D  F
# 2017-10-31  0.000000  0.000000 -0.123345  5  1
# 2017-11-01  0.307251 -0.510815  0.248623  5  2
# 2017-11-02  0.348260  0.646603  1.191346  5  3
# 2017-11-03  0.811333 -0.594278  1.505763  5  4
# 2017-11-04 -1.062253  0.615239  0.510106  5  5
# 2017-11-05  0.180840 -0.575274 -2.426116  5  6

# %%
df4[df4>0] = -df4
#将正数变为相反数d

# %%
df4
# Out:
#                    A         B         C  D  F
# 2017-10-31  0.000000  0.000000 -0.123345 -5 -1
# 2017-11-01 -0.307251 -0.510815 -0.248623 -5 -2
# 2017-11-02 -0.348260 -0.646603 -1.191346 -5 -3
# 2017-11-03 -0.811333 -0.594278 -1.505763 -5 -4
# 2017-11-04 -1.062253 -0.615239 -0.510106 -5 -5
# 2017-11-05 -0.180840 -0.575274 -2.426116 -5 -6

# %%
#对样本中的缺失值的处理
#在pandas中缺失值使用np.nan代替 并且这些值默认不会参与计算
#reindex()方法可以对指定轴上的索引进行改变/增加/删除操作，这将返回原始数据的一个拷贝
#0 1 2 3 4行
#加一个E列 新增加的列没有指定具体值 则用nan代替
df1 = df.reindex(index = dates[0:4] , columns=list(df.columns) + ['E'])

# %%
df1
# Out:
#                    A         B         C  D  F   E
# 2017-10-31  0.000000  0.000000 -0.123345  5  1 NaN
# 2017-11-01  0.307251 -0.510815  0.248623  5  2 NaN
# 2017-11-02  0.348260  0.646603  1.191346  5  3 NaN
# 2017-11-03  0.811333 -0.594278  1.505763  5  4 NaN

# %%
df1.loc[dates[0] : dates[1] , 'E'] = 1
#设置一些指定的值

# %%
df1
# Out:
#                    A         B         C  D  F    E
# 2017-10-31  0.000000  0.000000 -0.123345  5  1  1.0
# 2017-11-01  0.307251 -0.510815  0.248623  5  2  1.0
# 2017-11-02  0.348260  0.646603  1.191346  5  3  NaN
# 2017-11-03  0.811333 -0.594278  1.505763  5  4  NaN

# %%
#去掉包含缺失值的行
df1.dropna(how = 'any')
#any模式 只要含有nan就去掉该行
#all模式 一行全部为nan采取掉该行
# Out:
#                    A         B         C  D  F    E
# 2017-10-31  0.000000  0.000000 -0.123345  5  1  1.0
# 2017-11-01  0.307251 -0.510815  0.248623  5  2  1.0

# %%
df1
# Out:
#                    A         B         C  D  F    E
# 2017-10-31  0.000000  0.000000 -0.123345  5  1  1.0
# 2017-11-01  0.307251 -0.510815  0.248623  5  2  1.0
# 2017-11-02  0.348260  0.646603  1.191346  5  3  NaN
# 2017-11-03  0.811333 -0.594278  1.505763  5  4  NaN

# %%
#对缺失值进行填充
df1.fillna(value = 5)
# Out:
#                    A         B         C  D  F    E
# 2017-10-31  0.000000  0.000000 -0.123345  5  1  1.0
# 2017-11-01  0.307251 -0.510815  0.248623  5  2  1.0
# 2017-11-02  0.348260  0.646603  1.191346  5  3  5.0
# 2017-11-03  0.811333 -0.594278  1.505763  5  4  5.0

# %%
#进行布尔填充
pd.isnull(df1)
# Out:
#                 A      B      C      D      F      E
# 2017-10-31  False  False  False  False  False  False
# 2017-11-01  False  False  False  False  False  False
# 2017-11-02  False  False  False  False  False   True
# 2017-11-03  False  False  False  False  False   True

# %%
#统计方面的相关操作
df
# Out:
#                    A         B         C  D  F
# 2017-10-31  0.000000  0.000000 -0.123345  5  1
# 2017-11-01  0.307251 -0.510815  0.248623  5  2
# 2017-11-02  0.348260  0.646603  1.191346  5  3
# 2017-11-03  0.811333 -0.594278  1.505763  5  4
# 2017-11-04 -1.062253  0.615239  0.510106  5  5
# 2017-11-05  0.180840 -0.575274 -2.426116  5  6

# %%
df.mean(0)#0可以省略不写
# Out:
# A    0.097572
# B   -0.069754
# C    0.151063
# D    5.000000
# F    3.500000
# dtype: float64

# %%
df.mean(1)#其他轴上的相同操作
# Out:
# 2017-10-31    1.175331
# 2017-11-01    1.409012
# 2017-11-02    2.037242
# 2017-11-03    2.144563
# 2017-11-04    2.012619
# 2017-11-05    1.635890
# Freq: D, dtype: float64

# %%
dates
# Out:
# DatetimeIndex(['2017-10-31', '2017-11-01', '2017-11-02', '2017-11-03',
#                '2017-11-04', '2017-11-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
s = pd.Series([1,3,5,np.nan,6,8] , index = dates).shift(2)
#shift向后移动
#对于拥有不同维度，需要对齐的对象进行操作。Pandas会自动的沿着指定的维度进行广播

# %%
s
# Out:
# 2017-10-31    NaN
# 2017-11-01    NaN
# 2017-11-02    1.0
# 2017-11-03    3.0
# 2017-11-04    5.0
# 2017-11-05    NaN
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C  D  F
# 2017-10-31  0.000000  0.000000 -0.123345  5  1
# 2017-11-01  0.307251 -0.510815  0.248623  5  2
# 2017-11-02  0.348260  0.646603  1.191346  5  3
# 2017-11-03  0.811333 -0.594278  1.505763  5  4
# 2017-11-04 -1.062253  0.615239  0.510106  5  5
# 2017-11-05  0.180840 -0.575274 -2.426116  5  6

# %%
df.sub(s , axis = 'index')
#每列进行减法操作
# Out:
#                    A         B         C    D    F
# 2017-10-31       NaN       NaN       NaN  NaN  NaN
# 2017-11-01       NaN       NaN       NaN  NaN  NaN
# 2017-11-02 -0.651740 -0.353397  0.191346  4.0  2.0
# 2017-11-03 -2.188667 -3.594278 -1.494237  2.0  1.0
# 2017-11-04 -6.062253 -4.384761 -4.489894  0.0  0.0
# 2017-11-05       NaN       NaN       NaN  NaN  NaN

# %%
df
# Out:
#                    A         B         C  D  F
# 2017-10-31  0.000000  0.000000 -0.123345  5  1
# 2017-11-01  0.307251 -0.510815  0.248623  5  2
# 2017-11-02  0.348260  0.646603  1.191346  5  3
# 2017-11-03  0.811333 -0.594278  1.505763  5  4
# 2017-11-04 -1.062253  0.615239  0.510106  5  5
# 2017-11-05  0.180840 -0.575274 -2.426116  5  6

# %%
#对数据应用函数操作
df.apply(np.cumsum)
#每一行都是本行与上一行的加和
# Out:
#                    A         B         C   D   F
# 2017-10-31  0.000000  0.000000 -0.123345   5   1
# 2017-11-01  0.307251 -0.510815  0.125278  10   3
# 2017-11-02  0.655511  0.135788  1.316624  15   6
# 2017-11-03  1.466844 -0.458490  2.822386  20  10
# 2017-11-04  0.404591  0.156750  3.332493  25  15
# 2017-11-05  0.585431 -0.418524  0.906377  30  21

# %%
df.apply(lambda x:x.max() - x.min())
# Out:
# A    1.873585
# B    1.240881
# C    3.931878
# D    0.000000
# F    5.000000
# dtype: float64

# %%
#直方图
s = pd.Series(np.random.randint(0 , 7 , size = 10))

# %%
s
# Out:
# 0    6
# 1    1
# 2    5
# 3    6
# 4    0
# 5    3
# 6    3
# 7    0
# 8    0
# 9    6
# dtype: int32

# %%
#统计每个数字出现的次数
s.value_counts()
# Out:
# 6    3
# 0    3
# 3    2
# 5    1
# 1    1
# dtype: int64

# %%
#字符串方法
s = pd.Series(['A' , 'B' , 'C' , 'Aaaa' , np.nan , 'cbda' , 'cat' , 'dog'])

# %%
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaaa
# 4     NaN
# 5    cbda
# 6     cat
# 7     dog
# dtype: object

# %%
#全部变为小写
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaaa
# 4     NaN
# 5    cbda
# 6     cat
# 7     dog
# dtype: object

# %%
#对series dataframe panel进行各种逻辑关系的合并
df = pd.DataFrame(np.random.randn(10 , 4))

# %%
df
# Out:
#           0         1         2         3
# 0 -1.547730 -1.373560 -0.035541  0.532975
# 1 -0.174814  0.437748  1.203901  1.378942
# 2  0.410641 -1.474074 -0.827281 -0.087326
# 3  0.518450  0.416547 -1.153498  0.622732
# 4 -0.297233  0.646295 -1.452204 -1.707959
# 5 -0.704038  0.913492  0.255460  1.743004
# 6 -0.560110  1.223270  0.228054 -0.526734
# 7 -0.572087 -1.695989 -1.415499  0.901036
# 8  0.253589 -1.120872 -1.334076 -0.396982
# 9  1.538716 -0.634290  0.791311  0.479205

# %%
pieces = [df[:3] , df[3:7] , df[7:]]

# %%
pieces[2]
# Out:
#           0         1         2         3
# 7 -0.572087 -1.695989 -1.415499  0.901036
# 8  0.253589 -1.120872 -1.334076 -0.396982
# 9  1.538716 -0.634290  0.791311  0.479205

# %%
pd.concat(pieces)
#将pieces连接起来成为一个dataframe
# Out:
#           0         1         2         3
# 0 -1.547730 -1.373560 -0.035541  0.532975
# 1 -0.174814  0.437748  1.203901  1.378942
# 2  0.410641 -1.474074 -0.827281 -0.087326
# 3  0.518450  0.416547 -1.153498  0.622732
# 4 -0.297233  0.646295 -1.452204 -1.707959
# 5 -0.704038  0.913492  0.255460  1.743004
# 6 -0.560110  1.223270  0.228054 -0.526734
# 7 -0.572087 -1.695989 -1.415499  0.901036
# 8  0.253589 -1.120872 -1.334076 -0.396982
# 9  1.538716 -0.634290  0.791311  0.479205

# %%
left = pd.DataFrame({'key':['foo','foo'],
                    'lval':[1,2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right = pd.DataFrame({'key':['foo' , 'foo'],
                     'rval':[4,5]})
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left , right , on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
#append将一行连接到一个dataframe上
df = pd.DataFrame(np.random.randn(8,4) , columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0  0.413265 -1.898906  0.391930 -1.371091
# 1  0.717109 -2.270769  0.106151 -1.065875
# 2  0.787347  2.197607 -0.368131 -0.314276
# 3  0.868694 -0.788398  1.552670 -0.797263
# 4  0.221607 -1.200793 -0.293121 -0.445470
# 5  1.182252 -0.180799 -0.296746 -1.163255
# 6  0.489850  1.840432 -0.139121  0.470454
# 7  0.766606  0.183423 -2.038669  1.567045

# %%
s = df.iloc[3]
#取出第三行

# %%
s
# Out:
# A    0.868694
# B   -0.788398
# C    1.552670
# D   -0.797263
# Name: 3, dtype: float64

# %%
df.append(s , ignore_index=False)
#如果为True 则最后一行最前面为8
# Out:
#           A         B         C         D
# 0  0.413265 -1.898906  0.391930 -1.371091
# 1  0.717109 -2.270769  0.106151 -1.065875
# 2  0.787347  2.197607 -0.368131 -0.314276
# 3  0.868694 -0.788398  1.552670 -0.797263
# 4  0.221607 -1.200793 -0.293121 -0.445470
# 5  1.182252 -0.180799 -0.296746 -1.163255
# 6  0.489850  1.840432 -0.139121  0.470454
# 7  0.766606  0.183423 -2.038669  1.567045
# 3  0.868694 -0.788398  1.552670 -0.797263

# %%
#分组 groupby方法
df = pd.DataFrame({'A':['foo','bar','foo','bar',
                       'foo','bar','foo','foo',],
                  'B':['one','one','one','one',
                       'one','one','one','two'],
                  'C':np.random.randn(8),
                  'D':np.random.randn(8)})

# %%
df
# Out:
#      A    B         C         D
# 0  foo  one  0.811548  0.364094
# 1  bar  one -0.745675  1.217032
# 2  foo  one  1.011057 -0.539807
# 3  bar  one -0.318415 -1.164545
# 4  foo  one  1.414004 -1.178962
# 5  bar  one -0.664279  0.368953
# 6  foo  one  0.657968  0.103559
# 7  foo  two  2.340783 -0.568734

# %%
df.groupby('A').sum()
#对每个分组执行sum函数 以A来进行组合
# Out:
#             C         D
# A
# bar -1.728369  0.421441
# foo  6.235361 -1.819850

# %%
#通过多个列进行分组形成一个层次索引
df.groupby(['A','B']).sum()
# Out:
#                 C         D
# A   B
# bar one -1.728369  0.421441
# foo one  3.894578 -1.251116
#     two  2.340783 -0.568734

# %%
#变换形状 reshape
tuples = list(zip(*[['bar','bar','bar','bar',
                    'foo','foo','qux','qux'],
                    ['one','two','one','two',
                    'one','two','one','two']]))

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('bar', 'one'),
#  ('bar', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples , names=['first' , 'second'])

# %%
index
# Out:
# MultiIndex(levels=[['bar', 'foo', 'qux'], ['one', 'two']],
#            labels=[[0, 0, 0, 0, 1, 1, 2, 2], [0, 1, 0, 1, 0, 1, 0, 1]],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8,2) , index=index ,columns=['A','B'])

# %%
df
# Out:
#                      A         B
# first second
# bar   one     0.308706  0.188210
#       two    -1.918814  1.041199
#       one    -0.333533 -0.291182
#       two     0.552911  0.498050
# foo   one    -0.773468  0.384140
#       two     0.833224 -1.510110
# qux   one    -0.683848  1.062289
#       two     1.008840  0.624457

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one     0.308706  0.188210
#       two    -1.918814  1.041199
#       one    -0.333533 -0.291182
#       two     0.552911  0.498050

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A    0.308706
#                B    0.188210
#        two     A   -1.918814
#                B    1.041199
#        one     A   -0.333533
#                B   -0.291182
#        two     A    0.552911
#                B    0.498050
# dtype: float64

# %%
stacked.unstack()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-80854a09d3ed> in <module>()
# ----> 1 stacked.unstack()
#
# I:\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    2026         """
#    2027         from pandas.core.reshape.reshape import unstack
# -> 2028         return unstack(self, level, fill_value)
#    2029
#    2030     # ----------------------------------------------------------------------
#
# I:\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     456     else:
#     457         unstacker = _Unstacker(obj.values, obj.index, level=level,
# --> 458                                fill_value=fill_value)
#     459         return unstacker.get_result()
#     460
#
# ...

# %%
stacked.unstack(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-117c305e7235> in <module>()
# ----> 1 stacked.unstack(0)
#
# I:\Anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    2026         """
#    2027         from pandas.core.reshape.reshape import unstack
# -> 2028         return unstack(self, level, fill_value)
#    2029
#    2030     # ----------------------------------------------------------------------
#
# I:\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     456     else:
#     457         unstacker = _Unstacker(obj.values, obj.index, level=level,
# --> 458                                fill_value=fill_value)
#     459         return unstacker.get_result()
#     460
#
# ...

# %%
#上述和下面的都是生成 数据透视表
df = pd.DataFrame({'A':['one','one','two','three']*3,
                  'B':['A','B','C']*4,
                  'C':['foo','foo','foo','bar','bar','bar']*2,
                  'D':np.random.randn(12),
                  'E':np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.189142 -0.340025
# 1     one  B  foo  1.186376  0.040604
# 2     two  C  foo -0.585003  1.395587
# 3   three  A  bar  0.062073 -1.184125
# 4     one  B  bar -1.408911  0.425746
# 5     one  C  bar  1.003930  0.326884
# 6     two  A  foo  0.590566  0.566371
# 7   three  B  foo  0.698506  0.013807
# 8     one  C  foo -0.031665  0.501932
# 9     one  A  bar -1.095029 -0.668728
# 10    two  B  bar -1.356031  1.045089
# 11  three  C  bar -0.574305 -2.352108

# %%
#生成数据透视表
pd.pivot_table(df , values='D' , index=['A' , 'B'] , columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -1.095029 -0.189142
#       B -1.408911  1.186376
#       C  1.003930 -0.031665
# three A  0.062073       NaN
#       B       NaN  0.698506
#       C -0.574305       NaN
# two   A       NaN  0.590566
#       B -1.356031       NaN
#       C       NaN -0.585003

# %%
#时间序列
rng = pd.date_range('3/6/2012 00:00' , periods = 5 , freq='D')

# %%
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)) , rng)

# %%
ts
# Out:
# 2012-03-06    2.855756
# 2012-03-07    1.046145
# 2012-03-08   -1.591908
# 2012-03-09   -0.106210
# 2012-03-10   -0.632687
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    2.855756
# 2012-03-07 00:00:00+00:00    1.046145
# 2012-03-08 00:00:00+00:00   -1.591908
# 2012-03-09 00:00:00+00:00   -0.106210
# 2012-03-10 00:00:00+00:00   -0.632687
# Freq: D, dtype: float64

# %%
#时区转换
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    2.855756
# 2012-03-06 19:00:00-05:00    1.046145
# 2012-03-07 19:00:00-05:00   -1.591908
# 2012-03-08 19:00:00-05:00   -0.106210
# 2012-03-09 19:00:00-05:00   -0.632687
# Freq: D, dtype: float64

# %%
#时间跨度转换
rng = pd.date_range('1/1/2012', periods = 5 , freq='M')

# %%
rng
# Out:
# DatetimeIndex(['2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)) , index=rng)

# %%
ts
# Out:
# 2012-01-31    0.562894
# 2012-02-29   -1.119457
# 2012-03-31   -1.405112
# 2012-04-30    0.631980
# 2012-05-31   -0.850207
# Freq: M, dtype: float64

# %%
ps =ts.to_period()

# %%
ps
# Out:
# 2012-01    0.562894
# 2012-02   -1.119457
# 2012-03   -1.405112
# 2012-04    0.631980
# 2012-05   -0.850207
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.562894
# 2012-02-01   -1.119457
# 2012-03-01   -1.405112
# 2012-04-01    0.631980
# 2012-05-01   -0.850207
# Freq: MS, dtype: float64

# %%
#时期和时间戳之间的转换
prng = pd.period_range('1990Q1' , '2000Q4' , freq='Q-NOV')

# %%
prng
# Out:
# PeriodIndex(['1990Q1', '1990Q2', '1990Q3', '1990Q4', '1991Q1', '1991Q2',
#              '1991Q3', '1991Q4', '1992Q1', '1992Q2', '1992Q3', '1992Q4',
#              '1993Q1', '1993Q2', '1993Q3', '1993Q4', '1994Q1', '1994Q2',
#              '1994Q3', '1994Q4', '1995Q1', '1995Q2', '1995Q3', '1995Q4',
#              '1996Q1', '1996Q2', '1996Q3', '1996Q4', '1997Q1', '1997Q2',
#              '1997Q3', '1997Q4', '1998Q1', '1998Q2', '1998Q3', '1998Q4',
#              '1999Q1', '1999Q2', '1999Q3', '1999Q4', '2000Q1', '2000Q2',
#              '2000Q3', '2000Q4'],
#             dtype='period[Q-NOV]', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)) , prng)

# %%
ts
# Out:
# 1990Q1    1.072778
# 1990Q2    0.947528
# 1990Q3   -0.314332
# 1990Q4   -0.000733
# 1991Q1   -0.674988
# 1991Q2    0.565423
# 1991Q3   -0.115551
# 1991Q4    0.094314
# 1992Q1   -1.106820
# 1992Q2   -0.146162
# 1992Q3   -0.456137
# 1992Q4    0.880308
# 1993Q1    0.816227
# 1993Q2   -0.195331
# 1993Q3    0.333141
# 1993Q4   -1.370458
# 1994Q1    1.131236
# 1994Q2   -0.479771
# 1994Q3    1.369580
# 1994Q4   -1.180380
# 1995Q1   -1.390236
# 1995Q2    0.074947
# 1995Q3    0.710218
# 1995Q4    0.714869
# 1996Q1   -0.440411
# 1996Q2    1.270527
# 1996Q3    1.920130
# 1996Q4   -0.242315
# 1997Q1    1.982427
# 1997Q2   -1.375486
# 1997Q3    0.201325
# 1997Q4   -0.592641
# 1998Q1    0.164070
# 1998Q2    1.393572
# 1998Q3    0.324988
# 1998Q4    1.690337
# 1999Q1   -0.478726
# 1999Q2   -1.171777
# 1999Q3   -0.404118
# 1999Q4   -0.364557
# 2000Q1   -0.626933
# 2000Q2   -0.622622
# 2000Q3    0.121412
# 2000Q4   -0.026268
# Freq: Q-NOV, dtype: float64

# %%
ts.index = (prng.asfreq('M','e') + 1).asfreq('H','s')+9

# %%
ts.head()
# Out:
# 1990-03-01 09:00    1.072778
# 1990-06-01 09:00    0.947528
# 1990-09-01 09:00   -0.314332
# 1990-12-01 09:00   -0.000733
# 1991-03-01 09:00   -0.674988
# Freq: H, dtype: float64

# %%
#Categorical
df = pd.DataFrame({'id':[1,2,3,4,5,6],
                  'raw_grade':['a','b','b','a','a','e']})

# %%
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df['grade'] = df['raw_grade'].astype('category')

# %%
df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df['grade'].cat.categories = ['very good' , 'good' , 'very bad']

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
#df['grade'] = df['grade'].cat.set_categories(["very bad","bad","medium","good","very good"])

# %%
df.sort_values('grade')
# Out:
#    id raw_grade     grade
# 1   2         b       bad
# 4   5         a       bad
# 3   4         a      good
# 2   3         b    medium
# 0   1         a  very bad
# 5   6         e  very bad

# %%
df.groupby('grade').size()
# Out:
# grade
# bad         2
# good        1
# medium      1
# very bad    2
# dtype: int64

# %%
#用来画图了
ts = pd.Series(np.random.randn(1000) , index=pd.date_range('1/1/2000' , periods=1000))

# %%
ts
# Out:
# 2000-01-01   -1.530670
# 2000-01-02    0.456194
# 2000-01-03    0.016290
# 2000-01-04   -2.277781
# 2000-01-05    0.662277
# 2000-01-06    0.887007
# 2000-01-07    0.517430
# 2000-01-08   -0.399803
# 2000-01-09    0.589875
# 2000-01-10   -0.703584
# 2000-01-11    1.450816
# 2000-01-12    1.717583
# 2000-01-13   -0.150780
# 2000-01-14    2.001763
# 2000-01-15   -0.850609
# 2000-01-16    2.557444
# 2000-01-17    1.989463
# 2000-01-18    0.818842
# 2000-01-19    0.248273
# 2000-01-20   -1.095959
# 2000-01-21    0.107200
# 2000-01-22   -0.029558
# 2000-01-23   -1.121314
# 2000-01-24   -0.627485
# 2000-01-25   -0.695102
# 2000-01-26    1.312030
# 2000-01-27    0.264641
# 2000-01-28   -0.014830
# 2000-01-29   -0.098848
# 2000-01-30    0.850374
#                 ...
# 2002-08-28   -1.319544
# 2002-08-29    0.504286
# 2002-08-30    1.244090
# 2002-08-31    0.241611
# 2002-09-01   -0.032088
# 2002-09-02   -0.696278
# 2002-09-03   -1.008160
# 2002-09-04    0.647831
# 2002-09-05   -1.883373
# ...

# %%
ts = ts.cumsum()

# %%
ts
# Out:
# 2000-01-01    -1.530670
# 2000-01-02    -1.074476
# 2000-01-03    -1.058186
# 2000-01-04    -3.335967
# 2000-01-05    -2.673690
# 2000-01-06    -1.786684
# 2000-01-07    -1.269254
# 2000-01-08    -1.669057
# 2000-01-09    -1.079182
# 2000-01-10    -1.782766
# 2000-01-11    -0.331950
# 2000-01-12     1.385633
# 2000-01-13     1.234854
# 2000-01-14     3.236617
# 2000-01-15     2.386008
# 2000-01-16     4.943451
# 2000-01-17     6.932914
# 2000-01-18     7.751756
# 2000-01-19     8.000030
# 2000-01-20     6.904070
# 2000-01-21     7.011271
# 2000-01-22     6.981713
# 2000-01-23     5.860399
# 2000-01-24     5.232914
# 2000-01-25     4.537812
# 2000-01-26     5.849841
# 2000-01-27     6.114483
# 2000-01-28     6.099653
# 2000-01-29     6.000804
# 2000-01-30     6.851179
#                 ...
# 2002-08-28    12.715506
# 2002-08-29    13.219792
# 2002-08-30    14.463882
# 2002-08-31    14.705493
# 2002-09-01    14.673405
# 2002-09-02    13.977127
# 2002-09-03    12.968966
# ...

# %%
ts.plot()
plt.show()

# %%
df = pd.DataFrame(np.random.randn(1000,4) , index = ts.index , columns=['A','B','C','D'])

# %%
df = df.cumsum()

# %%
df
# Out:
#                     A          B          C          D
# 2000-01-01   0.351134  -0.460810   0.553903  -1.491959
# 2000-01-02  -0.390032  -0.207376   2.354127  -0.581965
# 2000-01-03  -0.612207   0.267703   1.864081  -0.801164
# 2000-01-04  -1.196623   0.808166   1.495259  -3.217301
# 2000-01-05   0.582955  -0.584577   1.017694  -1.696754
# 2000-01-06  -0.818958  -1.330783   2.352015  -1.048774
# 2000-01-07   1.038430  -1.182236   0.365445  -1.159122
# 2000-01-08   2.235333  -0.278269   1.127836  -0.851772
# 2000-01-09  -0.087953  -0.462495   1.078838  -1.226958
# 2000-01-10   0.412439   0.839165   2.472528  -0.340936
# 2000-01-11   0.579823   1.194893   0.980351   1.070649
# 2000-01-12   1.581831   0.897420   0.512240   0.888560
# 2000-01-13   0.239305   1.956252   0.823132   1.164497
# 2000-01-14  -0.092229  -0.094505   1.131758   0.662804
# 2000-01-15  -1.211347  -1.002815   1.986584   1.768650
# 2000-01-16  -1.053692  -0.006189   1.179572  -0.739339
# ...

# %%
df.plot()
plt.show()

# %%
#导入数据 保存数据

# %%
#写入csv文件
df.to_csv('foo.csv')

# %%
#读出csv文件
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-01-01   0.351134  -0.460810   0.553903  -1.491959
# 1    2000-01-02  -0.390032  -0.207376   2.354127  -0.581965
# 2    2000-01-03  -0.612207   0.267703   1.864081  -0.801164
# 3    2000-01-04  -1.196623   0.808166   1.495259  -3.217301
# 4    2000-01-05   0.582955  -0.584577   1.017694  -1.696754
# 5    2000-01-06  -0.818958  -1.330783   2.352015  -1.048774
# 6    2000-01-07   1.038430  -1.182236   0.365445  -1.159122
# 7    2000-01-08   2.235333  -0.278269   1.127836  -0.851772
# 8    2000-01-09  -0.087953  -0.462495   1.078838  -1.226958
# 9    2000-01-10   0.412439   0.839165   2.472528  -0.340936
# 10   2000-01-11   0.579823   1.194893   0.980351   1.070649
# 11   2000-01-12   1.581831   0.897420   0.512240   0.888560
# 12   2000-01-13   0.239305   1.956252   0.823132   1.164497
# 13   2000-01-14  -0.092229  -0.094505   1.131758   0.662804
# 14   2000-01-15  -1.211347  -1.002815   1.986584   1.768650
# ...

# %%
#写入hdf5文件
df.to_hdf('foo.h5' , 'df')

# %%
#读出h5文件
pd.read_hdf('foo.h5' , 'df')
# Out:
#                     A          B          C          D
# 2000-01-01   0.351134  -0.460810   0.553903  -1.491959
# 2000-01-02  -0.390032  -0.207376   2.354127  -0.581965
# 2000-01-03  -0.612207   0.267703   1.864081  -0.801164
# 2000-01-04  -1.196623   0.808166   1.495259  -3.217301
# 2000-01-05   0.582955  -0.584577   1.017694  -1.696754
# 2000-01-06  -0.818958  -1.330783   2.352015  -1.048774
# 2000-01-07   1.038430  -1.182236   0.365445  -1.159122
# 2000-01-08   2.235333  -0.278269   1.127836  -0.851772
# 2000-01-09  -0.087953  -0.462495   1.078838  -1.226958
# 2000-01-10   0.412439   0.839165   2.472528  -0.340936
# 2000-01-11   0.579823   1.194893   0.980351   1.070649
# 2000-01-12   1.581831   0.897420   0.512240   0.888560
# 2000-01-13   0.239305   1.956252   0.823132   1.164497
# 2000-01-14  -0.092229  -0.094505   1.131758   0.662804
# 2000-01-15  -1.211347  -1.002815   1.986584   1.768650
# 2000-01-16  -1.053692  -0.006189   1.179572  -0.739339
# ...

# %%
#写入excel文件
df.to_excel('foo.xlsx' , sheet_name='Sheet1')

# %%
#读出excel文件
pd.read_excel('foo.xlsx' , 'Sheet1' , index_col=None , na_values=['NA'])
# Out:
#                     A          B          C          D
# 2000-01-01   0.351134  -0.460810   0.553903  -1.491959
# 2000-01-02  -0.390032  -0.207376   2.354127  -0.581965
# 2000-01-03  -0.612207   0.267703   1.864081  -0.801164
# 2000-01-04  -1.196623   0.808166   1.495259  -3.217301
# 2000-01-05   0.582955  -0.584577   1.017694  -1.696754
# 2000-01-06  -0.818958  -1.330783   2.352015  -1.048774
# 2000-01-07   1.038430  -1.182236   0.365445  -1.159122
# 2000-01-08   2.235333  -0.278269   1.127836  -0.851772
# 2000-01-09  -0.087953  -0.462495   1.078838  -1.226958
# 2000-01-10   0.412439   0.839165   2.472528  -0.340936
# 2000-01-11   0.579823   1.194893   0.980351   1.070649
# 2000-01-12   1.581831   0.897420   0.512240   0.888560
# 2000-01-13   0.239305   1.956252   0.823132   1.164497
# 2000-01-14  -0.092229  -0.094505   1.131758   0.662804
# 2000-01-15  -1.211347  -1.002815   1.986584   1.768650
# 2000-01-16  -1.053692  -0.006189   1.179572  -0.739339
# ...
