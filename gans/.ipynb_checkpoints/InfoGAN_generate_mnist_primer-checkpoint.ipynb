# %%
from keras.models import Sequential , Model
from keras.layers import Dense ,  BatchNormalization , Reshape , Input , Flatten
from keras.layers import Conv2D , MaxPool2D , Conv2DTranspose , UpSampling2D , ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU , PReLU
from keras.layers import Activation
from keras.layers import Dropout

from keras.layers import Concatenate

#addin cycleGAN 使用instance-norm
from keras_contrib.layers.normalization import InstanceNormalization

from keras.initializers import truncated_normal , constant , random_normal

from keras.optimizers import Adam , RMSprop

from keras.datasets import mnist

from keras.utils import to_categorical
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import os

import matplotlib as plt
import numpy as np

import gc

from glob import glob

import keras.backend as K

import scipy

# %matplotlib inline

# %%
WIDTH = 28
HEIGHT = 28
CHANNEL = 1

SHAPE = (WIDTH , HEIGHT , CHANNEL)

BATCH_SIZE = 64
EPOCHS = 10

#生成多少个图像 长*宽
ROW = 2
COL = 2

LATENT_DIM = 72 #infogan中变为72维
CLASSES_NUM = 10 #mnist一共10中类别

# %%
(X_train , y_train),(_ , _) = mnist.load_data()
X_train = X_train/127.5-1
X_train = np.expand_dims(X_train , 3)
y_train = y_train.reshape(-1 , 1)
y_train = to_categorical(y_train , num_classes=CLASSES_NUM)

# %%
def load_mnist(batch_size = BATCH_SIZE):
    idx = np.random.randint(0 , X_train.shape[0] ,batch_size)
    return X_train[idx] , y_train[idx]
    
def write_image_mnist(epoch):
    
    z = np.random.normal(0 , 1 , size=(ROW * COL , LATENT_DIM-CLASSES_NUM))
    c = np.random.randint(0 , high=CLASSES_NUM , size=(ROW*COL , 1))
    c_one_hot = to_categorical(c , num_classes=CLASSES_NUM)
    
    G_input = np.concatenate((z , c_one_hot) , axis = 1)
    
    imgs = generator_i.predict(G_input)
    
    imgs = imgs*0.5+0.5
    
    fig , axes = plt.pyplot.subplots(ROW , COL)
    
    axes[0][0].imshow(imgs[0,:,:,0] , cmap='gray')
    axes[0][0].set_title('%d' % (c[0]))
    axes[0][0].axis('off')

    axes[0][1].imshow(imgs[1,:,:,0] , cmap='gray')
    axes[0][1].set_title('%d' % (c[1]))
    axes[0][1].axis('off')
    
    axes[1][0].imshow(imgs[2,:,:,0] , cmap='gray')
    axes[1][0].set_title('%d' % (c[2]))
    axes[1][0].axis('off')

    axes[1][1].imshow(imgs[3,:,:,0] , cmap='gray')
    axes[1][1].set_title('%d' % (c[3]))
    axes[1][1].axis('off')

    fig.savefig('mnist_infogan/No.%d.png' % epoch)
    plt.pyplot.close()

# %%
def generator():
    z = Input(shape=(LATENT_DIM , )) #输入一个风格的图像 生成另一个风格的图像
    
    model = Sequential()

    model.add(Dense(128 * 7 * 7, activation="relu", input_shape=(LATENT_DIM , )))
    model.add(Reshape((7, 7, 128)))
    model.add(BatchNormalization(momentum=0.8))
    model.add(UpSampling2D())
    model.add(Conv2D(128, kernel_size=3, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(UpSampling2D())
    model.add(Conv2D(64, kernel_size=3, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(CHANNEL, kernel_size=3, padding="same"))
    model.add(Activation("tanh"))
    
    img = model(z)
    
    return Model(z , img)

# %%
def discriminator():
    img = Input(shape=SHAPE)
    
    model = Sequential()

    model.add(Conv2D(64, kernel_size=3, strides=2, input_shape=SHAPE , padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(256, kernel_size=3, strides=2, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(512, kernel_size=3, strides=2, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Flatten())
    
    feature = model(img)
   
    validity = Dense(1 , activation='sigmoid')(feature)
    
    q_net = Dense(units=128 , activation='relu')(feature)
    labels = Dense(CLASSES_NUM , activation='softmax')(q_net) #加1 因为多出来一个不存在的label 来代替fake的label
        
    return Model(img , validity) , Model(img , labels)

# %%
#给Q-NET使用的互信息损失
def mutual_info_loss(c , c_x):
    epsilon = 1e-8
    
    x_entropy = K.mean(-K.sum(c*K.log(c_x+epsilon) , axis=1 ))
    entropy = K.mean(-K.sum(c*K.log(c+epsilon) , axis=1))
    
    return x_entropy + entropy

# %%
adam = Adam(lr = 0.0002 , beta_1=0.5)
#构建计算图
D , Q = discriminator()

D.compile(optimizer = adam , loss='binary_crossentropy' , metrics=['accuracy'])
Q.compile(optimizer = adam , loss=mutual_info_loss , metrics=['accuracy'])

generator_i = generator()

z = Input(shape=(LATENT_DIM , ))
img = generator_i(z)

#freeze D
D.trainable = False

validity = D(img)
labels = Q(img)

combined = Model(z , [validity , labels])
combined.compile(optimizer=adam , loss=['binary_crossentropy' , mutual_info_loss])

# %%
def train():
    real_labels = np.ones(shape=(BATCH_SIZE , 1))
    fake_labels = np.zeros(shape=(BATCH_SIZE , 1))

    for i in range(1001):
        X_train , y_train = load_mnist()
        
        z = np.random.normal(0 , 1 , (BATCH_SIZE , LATENT_DIM-CLASSES_NUM)) #一定要减去 变为62 因为后面需要和隐藏编码c concatenate 一下
        c = np.random.randint(0 , CLASSES_NUM , size=(BATCH_SIZE , 1)) #隐藏编码c
        c = to_categorical(c , num_classes=CLASSES_NUM)
        
        G_input = np.concatenate((z , c) , axis = 1)

        img = generator_i.predict(G_input)
        #训练判别器
        real_loss = D.train_on_batch(X_train , real_labels  )
        fake_loss = D.train_on_batch(img , fake_labels )
        
        loss = np.add(real_loss , fake_loss)/2

        #训练生成器
        generator_loss = combined.train_on_batch(G_input , [real_labels , c])

        print('epoch:%d loss:%f accu:%f |xentropy_loss:%f mutual_info_loss:%f' % (i , loss[0] , loss[1] , generator_loss[0] , generator_loss[1]))

        if i % 50 == 0:
            write_image_mnist(i)

    write_image_mnist(999)

# %%
train()
# Out:
# C:\Anaconda3\lib\site-packages\keras\engine\training.py:479: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# epoch:0 loss:1.660878 accu:0.226562 |xentropy_loss:3.648218 mutual_info_loss:0.594777
# epoch:1 loss:0.911609 accu:0.562500 |xentropy_loss:4.090487 mutual_info_loss:0.999379
# epoch:2 loss:0.618219 accu:0.710938 |xentropy_loss:4.333584 mutual_info_loss:1.589423
# epoch:3 loss:0.779388 accu:0.609375 |xentropy_loss:4.422917 mutual_info_loss:1.266415
# epoch:4 loss:0.752575 accu:0.554688 |xentropy_loss:4.040728 mutual_info_loss:1.315180
# epoch:5 loss:0.683502 accu:0.648438 |xentropy_loss:4.074518 mutual_info_loss:1.417691
# epoch:6 loss:0.559876 accu:0.679688 |xentropy_loss:4.184185 mutual_info_loss:1.552115
# epoch:7 loss:0.635173 accu:0.664062 |xentropy_loss:4.393694 mutual_info_loss:1.529202
# epoch:8 loss:0.700243 accu:0.632812 |xentropy_loss:4.335485 mutual_info_loss:1.660262
# epoch:9 loss:0.669257 accu:0.648438 |xentropy_loss:4.362889 mutual_info_loss:1.771099
# epoch:10 loss:0.652122 accu:0.687500 |xentropy_loss:4.666224 mutual_info_loss:1.774040
# epoch:11 loss:0.629556 accu:0.671875 |xentropy_loss:4.367477 mutual_info_loss:1.788367
# epoch:12 loss:0.507376 accu:0.710938 |xentropy_loss:4.669192 mutual_info_loss:1.842104
# epoch:13 loss:0.667003 accu:0.656250 |xentropy_loss:3.881811 mutual_info_loss:1.503252
# epoch:14 loss:0.595606 accu:0.664062 |xentropy_loss:4.316622 mutual_info_loss:1.552879
# epoch:15 loss:0.616542 accu:0.679688 |xentropy_loss:4.508068 mutual_info_loss:1.897843
# epoch:16 loss:0.469159 accu:0.734375 |xentropy_loss:4.136272 mutual_info_loss:1.502074
# epoch:17 loss:0.516286 accu:0.695312 |xentropy_loss:4.135451 mutual_info_loss:1.638104
# epoch:18 loss:0.452353 accu:0.734375 |xentropy_loss:4.202996 mutual_info_loss:1.596088
# epoch:19 loss:0.563495 accu:0.710938 |xentropy_loss:4.091672 mutual_info_loss:1.727564
# epoch:20 loss:0.600487 accu:0.679688 |xentropy_loss:4.021361 mutual_info_loss:1.485156
# epoch:21 loss:0.424563 accu:0.734375 |xentropy_loss:4.433604 mutual_info_loss:1.799214
# epoch:22 loss:0.478127 accu:0.750000 |xentropy_loss:4.120888 mutual_info_loss:1.709492
# epoch:23 loss:0.438384 accu:0.710938 |xentropy_loss:3.865072 mutual_info_loss:1.470424
# epoch:24 loss:0.431233 accu:0.718750 |xentropy_loss:4.162937 mutual_info_loss:1.663092
# epoch:25 loss:0.550081 accu:0.695312 |xentropy_loss:4.010897 mutual_info_loss:1.413476
# epoch:26 loss:0.367432 accu:0.781250 |xentropy_loss:4.141359 mutual_info_loss:1.683937
# epoch:27 loss:0.378951 accu:0.781250 |xentropy_loss:4.029217 mutual_info_loss:1.555309
# epoch:28 loss:0.370077 accu:0.820312 |xentropy_loss:4.195301 mutual_info_loss:1.673956
# epoch:29 loss:0.487459 accu:0.742188 |xentropy_loss:4.155642 mutual_info_loss:1.801059
# epoch:30 loss:0.455354 accu:0.757812 |xentropy_loss:3.999253 mutual_info_loss:1.591023
# epoch:31 loss:0.504540 accu:0.703125 |xentropy_loss:4.397788 mutual_info_loss:1.945956
# epoch:32 loss:0.379190 accu:0.804688 |xentropy_loss:4.184121 mutual_info_loss:1.803000
# epoch:33 loss:0.444691 accu:0.757812 |xentropy_loss:3.914865 mutual_info_loss:1.648268
# epoch:34 loss:0.382146 accu:0.765625 |xentropy_loss:3.930721 mutual_info_loss:1.712412
# epoch:35 loss:0.422204 accu:0.750000 |xentropy_loss:4.125422 mutual_info_loss:1.715506
# epoch:36 loss:0.417341 accu:0.773438 |xentropy_loss:4.261938 mutual_info_loss:1.775504
# epoch:37 loss:0.427463 accu:0.773438 |xentropy_loss:4.392474 mutual_info_loss:2.007897
# epoch:38 loss:0.422258 accu:0.757812 |xentropy_loss:4.240799 mutual_info_loss:1.905994
# epoch:39 loss:0.453746 accu:0.726562 |xentropy_loss:4.279831 mutual_info_loss:2.032109
# epoch:40 loss:0.376121 accu:0.765625 |xentropy_loss:4.065706 mutual_info_loss:1.951629
# epoch:41 loss:0.387936 accu:0.820312 |xentropy_loss:4.268660 mutual_info_loss:2.048405
# epoch:42 loss:0.402967 accu:0.765625 |xentropy_loss:4.189783 mutual_info_loss:1.802993
# epoch:43 loss:0.409685 accu:0.773438 |xentropy_loss:4.040339 mutual_info_loss:1.662171
# epoch:44 loss:0.457789 accu:0.773438 |xentropy_loss:4.144247 mutual_info_loss:1.960425
# epoch:45 loss:0.384474 accu:0.773438 |xentropy_loss:4.545106 mutual_info_loss:2.185501
# epoch:46 loss:0.439158 accu:0.750000 |xentropy_loss:4.134375 mutual_info_loss:1.900575
# epoch:47 loss:0.428389 accu:0.773438 |xentropy_loss:4.202935 mutual_info_loss:2.062992
# epoch:48 loss:0.467793 accu:0.726562 |xentropy_loss:4.293427 mutual_info_loss:2.141461
# epoch:49 loss:0.335369 accu:0.804688 |xentropy_loss:3.981775 mutual_info_loss:1.873978
# epoch:50 loss:0.393348 accu:0.828125 |xentropy_loss:4.003401 mutual_info_loss:1.902094
# epoch:51 loss:0.377686 accu:0.781250 |xentropy_loss:4.012350 mutual_info_loss:1.879526
# epoch:52 loss:0.440911 accu:0.742188 |xentropy_loss:4.263896 mutual_info_loss:2.201334
# epoch:53 loss:0.397443 accu:0.804688 |xentropy_loss:3.942692 mutual_info_loss:1.959606
# epoch:54 loss:0.455771 accu:0.750000 |xentropy_loss:4.303279 mutual_info_loss:2.162305
# epoch:55 loss:0.416799 accu:0.781250 |xentropy_loss:4.212107 mutual_info_loss:2.078720
# epoch:56 loss:0.375549 accu:0.789062 |xentropy_loss:3.923493 mutual_info_loss:1.950376
# epoch:57 loss:0.394808 accu:0.765625 |xentropy_loss:4.114304 mutual_info_loss:2.089349
# epoch:58 loss:0.356308 accu:0.835938 |xentropy_loss:4.086834 mutual_info_loss:2.196289
# epoch:59 loss:0.365997 accu:0.796875 |xentropy_loss:4.019367 mutual_info_loss:2.012499
# epoch:60 loss:0.349622 accu:0.796875 |xentropy_loss:4.028538 mutual_info_loss:2.090851
# epoch:61 loss:0.411762 accu:0.789062 |xentropy_loss:3.856814 mutual_info_loss:1.929803
# epoch:62 loss:0.384497 accu:0.804688 |xentropy_loss:4.070621 mutual_info_loss:2.221332
# epoch:63 loss:0.418687 accu:0.765625 |xentropy_loss:4.021023 mutual_info_loss:2.121571
# epoch:64 loss:0.380405 accu:0.812500 |xentropy_loss:4.128017 mutual_info_loss:2.182199
# epoch:65 loss:0.349896 accu:0.828125 |xentropy_loss:3.666516 mutual_info_loss:1.810526
# epoch:66 loss:0.412631 accu:0.765625 |xentropy_loss:3.578440 mutual_info_loss:2.022148
# epoch:67 loss:0.386394 accu:0.828125 |xentropy_loss:3.632775 mutual_info_loss:2.045779
# epoch:68 loss:0.353417 accu:0.812500 |xentropy_loss:3.779817 mutual_info_loss:2.155463
# epoch:69 loss:0.380005 accu:0.804688 |xentropy_loss:3.764339 mutual_info_loss:2.073375
# epoch:70 loss:0.349916 accu:0.812500 |xentropy_loss:3.572607 mutual_info_loss:1.949765
# epoch:71 loss:0.411103 accu:0.765625 |xentropy_loss:3.467869 mutual_info_loss:1.874363
# epoch:72 loss:0.393756 accu:0.789062 |xentropy_loss:3.615749 mutual_info_loss:2.087104
# epoch:73 loss:0.293389 accu:0.867188 |xentropy_loss:3.421130 mutual_info_loss:1.875312
# epoch:74 loss:0.414881 accu:0.812500 |xentropy_loss:3.482782 mutual_info_loss:1.836643
# epoch:75 loss:0.328616 accu:0.835938 |xentropy_loss:3.462761 mutual_info_loss:1.949216
# epoch:76 loss:0.371227 accu:0.773438 |xentropy_loss:3.851652 mutual_info_loss:2.342903
# epoch:77 loss:0.340074 accu:0.851562 |xentropy_loss:3.503240 mutual_info_loss:2.049070
# epoch:78 loss:0.315257 accu:0.851562 |xentropy_loss:3.404512 mutual_info_loss:1.963840
# epoch:79 loss:0.362776 accu:0.781250 |xentropy_loss:3.208530 mutual_info_loss:2.062977
# epoch:80 loss:0.353269 accu:0.781250 |xentropy_loss:3.546624 mutual_info_loss:2.366461
# epoch:81 loss:0.360410 accu:0.781250 |xentropy_loss:3.706479 mutual_info_loss:2.421928
# epoch:82 loss:0.314599 accu:0.843750 |xentropy_loss:3.291560 mutual_info_loss:2.223540
# epoch:83 loss:0.291895 accu:0.828125 |xentropy_loss:2.944503 mutual_info_loss:1.894536
# epoch:84 loss:0.482945 accu:0.742188 |xentropy_loss:3.303080 mutual_info_loss:2.243441
# epoch:85 loss:0.318285 accu:0.851562 |xentropy_loss:3.375974 mutual_info_loss:2.339598
# epoch:86 loss:0.323831 accu:0.820312 |xentropy_loss:3.150411 mutual_info_loss:2.157670
# epoch:87 loss:0.307581 accu:0.859375 |xentropy_loss:3.004767 mutual_info_loss:2.044970
# epoch:88 loss:0.337858 accu:0.828125 |xentropy_loss:2.703236 mutual_info_loss:2.003267
# epoch:89 loss:0.418974 accu:0.742188 |xentropy_loss:3.292921 mutual_info_loss:2.418269
# epoch:90 loss:0.304444 accu:0.867188 |xentropy_loss:2.847436 mutual_info_loss:2.177138
# epoch:91 loss:0.358011 accu:0.820312 |xentropy_loss:3.268580 mutual_info_loss:2.277024
# epoch:92 loss:0.367825 accu:0.773438 |xentropy_loss:3.245129 mutual_info_loss:2.338802
# epoch:93 loss:0.261302 accu:0.867188 |xentropy_loss:2.667521 mutual_info_loss:1.894920
# epoch:94 loss:0.370645 accu:0.796875 |xentropy_loss:2.910518 mutual_info_loss:2.246049
# epoch:95 loss:0.307582 accu:0.859375 |xentropy_loss:2.870283 mutual_info_loss:2.155754
# epoch:96 loss:0.402413 accu:0.742188 |xentropy_loss:3.068396 mutual_info_loss:2.302006
# epoch:97 loss:0.334315 accu:0.804688 |xentropy_loss:3.343876 mutual_info_loss:2.567426
# epoch:98 loss:0.389465 accu:0.812500 |xentropy_loss:2.887975 mutual_info_loss:2.350244
# epoch:99 loss:0.316252 accu:0.851562 |xentropy_loss:2.755519 mutual_info_loss:2.194165
# epoch:100 loss:0.385331 accu:0.773438 |xentropy_loss:2.763360 mutual_info_loss:2.291650
# epoch:101 loss:0.345982 accu:0.804688 |xentropy_loss:2.856683 mutual_info_loss:2.341326
# epoch:102 loss:0.452049 accu:0.742188 |xentropy_loss:3.040648 mutual_info_loss:2.456188
# epoch:103 loss:0.413295 accu:0.781250 |xentropy_loss:3.192911 mutual_info_loss:2.518758
# epoch:104 loss:0.389390 accu:0.789062 |xentropy_loss:2.665974 mutual_info_loss:2.282107
# epoch:105 loss:0.421258 accu:0.773438 |xentropy_loss:2.981126 mutual_info_loss:2.289420
# epoch:106 loss:0.356698 accu:0.812500 |xentropy_loss:2.577420 mutual_info_loss:2.066567
# epoch:107 loss:0.391509 accu:0.773438 |xentropy_loss:2.737763 mutual_info_loss:2.117985
# epoch:108 loss:0.373404 accu:0.789062 |xentropy_loss:2.868880 mutual_info_loss:2.280797
# epoch:109 loss:0.439548 accu:0.757812 |xentropy_loss:3.091618 mutual_info_loss:2.523081
# epoch:110 loss:0.414262 accu:0.757812 |xentropy_loss:2.791557 mutual_info_loss:2.289698
# epoch:111 loss:0.393685 accu:0.781250 |xentropy_loss:2.823067 mutual_info_loss:2.400775
# epoch:112 loss:0.443032 accu:0.765625 |xentropy_loss:2.842606 mutual_info_loss:2.185651
# epoch:113 loss:0.389962 accu:0.796875 |xentropy_loss:3.023234 mutual_info_loss:2.403096
# epoch:114 loss:0.395540 accu:0.804688 |xentropy_loss:2.920266 mutual_info_loss:2.347633
# epoch:115 loss:0.352283 accu:0.820312 |xentropy_loss:2.719091 mutual_info_loss:2.278898
# epoch:116 loss:0.478739 accu:0.750000 |xentropy_loss:2.408157 mutual_info_loss:2.115744
# epoch:117 loss:0.425025 accu:0.773438 |xentropy_loss:2.625207 mutual_info_loss:2.275858
# epoch:118 loss:0.509669 accu:0.742188 |xentropy_loss:2.814108 mutual_info_loss:2.307198
# epoch:119 loss:0.435218 accu:0.765625 |xentropy_loss:2.709024 mutual_info_loss:2.279624
# epoch:120 loss:0.358103 accu:0.828125 |xentropy_loss:2.563080 mutual_info_loss:2.116720
# epoch:121 loss:0.406682 accu:0.757812 |xentropy_loss:2.710348 mutual_info_loss:2.227778
# epoch:122 loss:0.417714 accu:0.796875 |xentropy_loss:2.388622 mutual_info_loss:2.003141
# epoch:123 loss:0.416649 accu:0.773438 |xentropy_loss:2.524251 mutual_info_loss:2.057822
# epoch:124 loss:0.419242 accu:0.757812 |xentropy_loss:2.396086 mutual_info_loss:2.063852
# epoch:125 loss:0.435285 accu:0.750000 |xentropy_loss:2.574539 mutual_info_loss:2.021924
# epoch:126 loss:0.552831 accu:0.687500 |xentropy_loss:2.764728 mutual_info_loss:2.307961
# epoch:127 loss:0.426033 accu:0.820312 |xentropy_loss:2.656439 mutual_info_loss:2.187647
# epoch:128 loss:0.541716 accu:0.679688 |xentropy_loss:2.317822 mutual_info_loss:1.916104
# epoch:129 loss:0.552415 accu:0.671875 |xentropy_loss:2.747341 mutual_info_loss:2.354163
# epoch:130 loss:0.515962 accu:0.703125 |xentropy_loss:3.062578 mutual_info_loss:2.251483
# epoch:131 loss:0.544688 accu:0.710938 |xentropy_loss:2.912501 mutual_info_loss:2.423220
# epoch:132 loss:0.452015 accu:0.804688 |xentropy_loss:2.404688 mutual_info_loss:1.993246
# epoch:133 loss:0.497212 accu:0.757812 |xentropy_loss:2.386363 mutual_info_loss:1.969517
# epoch:134 loss:0.570477 accu:0.687500 |xentropy_loss:2.371415 mutual_info_loss:2.002563
# epoch:135 loss:0.525157 accu:0.679688 |xentropy_loss:2.557682 mutual_info_loss:2.229360
# epoch:136 loss:0.406201 accu:0.804688 |xentropy_loss:2.379071 mutual_info_loss:2.114885
# epoch:137 loss:0.601525 accu:0.656250 |xentropy_loss:2.279727 mutual_info_loss:1.869823
# epoch:138 loss:0.599733 accu:0.648438 |xentropy_loss:2.488323 mutual_info_loss:2.054865
# epoch:139 loss:0.505047 accu:0.765625 |xentropy_loss:2.483969 mutual_info_loss:1.907722
# epoch:140 loss:0.484834 accu:0.742188 |xentropy_loss:2.353361 mutual_info_loss:1.959365
# epoch:141 loss:0.595557 accu:0.664062 |xentropy_loss:2.234305 mutual_info_loss:1.919931
# epoch:142 loss:0.510270 accu:0.718750 |xentropy_loss:2.383516 mutual_info_loss:2.082121
# epoch:143 loss:0.586075 accu:0.703125 |xentropy_loss:2.270076 mutual_info_loss:1.882547
# epoch:144 loss:0.614657 accu:0.703125 |xentropy_loss:2.202349 mutual_info_loss:1.887061
# epoch:145 loss:0.495815 accu:0.710938 |xentropy_loss:2.358495 mutual_info_loss:1.968759
# epoch:146 loss:0.574914 accu:0.703125 |xentropy_loss:2.364916 mutual_info_loss:1.777838
# epoch:147 loss:0.524635 accu:0.710938 |xentropy_loss:2.056704 mutual_info_loss:1.852075
# epoch:148 loss:0.680511 accu:0.609375 |xentropy_loss:2.005986 mutual_info_loss:1.584181
# epoch:149 loss:0.546924 accu:0.664062 |xentropy_loss:2.234454 mutual_info_loss:1.931629
# epoch:150 loss:0.550187 accu:0.742188 |xentropy_loss:1.923475 mutual_info_loss:1.583173
# epoch:151 loss:0.559204 accu:0.687500 |xentropy_loss:1.980927 mutual_info_loss:1.644945
# epoch:152 loss:0.643709 accu:0.664062 |xentropy_loss:2.065953 mutual_info_loss:1.710055
# epoch:153 loss:0.652429 accu:0.625000 |xentropy_loss:2.332506 mutual_info_loss:1.862151
# epoch:154 loss:0.537235 accu:0.734375 |xentropy_loss:1.934222 mutual_info_loss:1.591625
# epoch:155 loss:0.635041 accu:0.640625 |xentropy_loss:1.984368 mutual_info_loss:1.678617
# epoch:156 loss:0.561378 accu:0.718750 |xentropy_loss:2.024086 mutual_info_loss:1.812925
# epoch:157 loss:0.538928 accu:0.710938 |xentropy_loss:1.896869 mutual_info_loss:1.753361
# epoch:158 loss:0.552547 accu:0.648438 |xentropy_loss:2.091310 mutual_info_loss:1.756992
# epoch:159 loss:0.536702 accu:0.695312 |xentropy_loss:2.076471 mutual_info_loss:1.762128
# epoch:160 loss:0.531211 accu:0.703125 |xentropy_loss:1.988799 mutual_info_loss:1.691401
# epoch:161 loss:0.676170 accu:0.609375 |xentropy_loss:2.132482 mutual_info_loss:1.570921
# epoch:162 loss:0.708440 accu:0.609375 |xentropy_loss:2.006153 mutual_info_loss:1.517440
# epoch:163 loss:0.547070 accu:0.695312 |xentropy_loss:1.969942 mutual_info_loss:1.630675
# epoch:164 loss:0.546029 accu:0.710938 |xentropy_loss:1.921292 mutual_info_loss:1.668834
# epoch:165 loss:0.478445 accu:0.742188 |xentropy_loss:1.887041 mutual_info_loss:1.745007
# epoch:166 loss:0.577935 accu:0.687500 |xentropy_loss:1.857896 mutual_info_loss:1.629903
# epoch:167 loss:0.578669 accu:0.679688 |xentropy_loss:1.937505 mutual_info_loss:1.850178
# epoch:168 loss:0.607301 accu:0.671875 |xentropy_loss:1.875813 mutual_info_loss:1.586726
# epoch:169 loss:0.763571 accu:0.562500 |xentropy_loss:1.972126 mutual_info_loss:1.620747
# epoch:170 loss:0.617326 accu:0.671875 |xentropy_loss:2.235880 mutual_info_loss:1.774738
# epoch:171 loss:0.581701 accu:0.734375 |xentropy_loss:2.030191 mutual_info_loss:1.723185
# epoch:172 loss:0.585643 accu:0.648438 |xentropy_loss:1.829834 mutual_info_loss:1.593656
# epoch:173 loss:0.608483 accu:0.648438 |xentropy_loss:1.915912 mutual_info_loss:1.595806
# epoch:174 loss:0.552482 accu:0.734375 |xentropy_loss:1.917432 mutual_info_loss:1.720309
# epoch:175 loss:0.559870 accu:0.703125 |xentropy_loss:1.791293 mutual_info_loss:1.605404
# epoch:176 loss:0.782942 accu:0.531250 |xentropy_loss:1.965606 mutual_info_loss:1.481141
# epoch:177 loss:0.611297 accu:0.734375 |xentropy_loss:2.133335 mutual_info_loss:1.701908
# epoch:178 loss:0.598640 accu:0.648438 |xentropy_loss:1.758329 mutual_info_loss:1.564612
# epoch:179 loss:0.644028 accu:0.632812 |xentropy_loss:1.731643 mutual_info_loss:1.618673
# epoch:180 loss:0.631336 accu:0.648438 |xentropy_loss:1.532138 mutual_info_loss:1.320110
# epoch:181 loss:0.644164 accu:0.664062 |xentropy_loss:1.638008 mutual_info_loss:1.425917
# epoch:182 loss:0.588087 accu:0.640625 |xentropy_loss:1.707716 mutual_info_loss:1.599696
# epoch:183 loss:0.708773 accu:0.570312 |xentropy_loss:1.830341 mutual_info_loss:1.578437
# epoch:184 loss:0.639023 accu:0.679688 |xentropy_loss:1.556816 mutual_info_loss:1.375352
# epoch:185 loss:0.665220 accu:0.632812 |xentropy_loss:1.957480 mutual_info_loss:1.536137
# epoch:186 loss:0.610552 accu:0.609375 |xentropy_loss:1.863249 mutual_info_loss:1.709363
# epoch:187 loss:0.680099 accu:0.609375 |xentropy_loss:1.804302 mutual_info_loss:1.637519
# epoch:188 loss:0.701317 accu:0.609375 |xentropy_loss:1.929519 mutual_info_loss:1.606723
# epoch:189 loss:0.543313 accu:0.734375 |xentropy_loss:1.639246 mutual_info_loss:1.483225
# epoch:190 loss:0.615601 accu:0.632812 |xentropy_loss:1.643982 mutual_info_loss:1.486883
# epoch:191 loss:0.638192 accu:0.671875 |xentropy_loss:1.571407 mutual_info_loss:1.353924
# epoch:192 loss:0.578277 accu:0.687500 |xentropy_loss:1.678254 mutual_info_loss:1.477727
# epoch:193 loss:0.615297 accu:0.671875 |xentropy_loss:1.693237 mutual_info_loss:1.532899
# epoch:194 loss:0.563646 accu:0.656250 |xentropy_loss:1.599572 mutual_info_loss:1.484494
# epoch:195 loss:0.638589 accu:0.593750 |xentropy_loss:1.865933 mutual_info_loss:1.475002
# epoch:196 loss:0.629383 accu:0.640625 |xentropy_loss:1.738513 mutual_info_loss:1.554832
# epoch:197 loss:0.611387 accu:0.695312 |xentropy_loss:1.525856 mutual_info_loss:1.458127
# epoch:198 loss:0.713695 accu:0.562500 |xentropy_loss:1.609466 mutual_info_loss:1.452669
# epoch:199 loss:0.574359 accu:0.664062 |xentropy_loss:1.475876 mutual_info_loss:1.339059
# epoch:200 loss:0.678301 accu:0.593750 |xentropy_loss:1.466098 mutual_info_loss:1.341454
# epoch:201 loss:0.644947 accu:0.648438 |xentropy_loss:1.487879 mutual_info_loss:1.392446
# epoch:202 loss:0.646572 accu:0.632812 |xentropy_loss:1.505814 mutual_info_loss:1.348114
# epoch:203 loss:0.634999 accu:0.648438 |xentropy_loss:1.561567 mutual_info_loss:1.425564
# epoch:204 loss:0.678648 accu:0.617188 |xentropy_loss:1.522363 mutual_info_loss:1.412086
# epoch:205 loss:0.574114 accu:0.687500 |xentropy_loss:1.502492 mutual_info_loss:1.363494
# epoch:206 loss:0.682489 accu:0.585938 |xentropy_loss:1.701931 mutual_info_loss:1.557118
# epoch:207 loss:0.654794 accu:0.625000 |xentropy_loss:1.782432 mutual_info_loss:1.617926
# epoch:208 loss:0.653882 accu:0.578125 |xentropy_loss:1.791524 mutual_info_loss:1.529479
# epoch:209 loss:0.586239 accu:0.687500 |xentropy_loss:1.516927 mutual_info_loss:1.453000
# epoch:210 loss:0.623155 accu:0.617188 |xentropy_loss:1.499508 mutual_info_loss:1.438138
# epoch:211 loss:0.584536 accu:0.671875 |xentropy_loss:1.611467 mutual_info_loss:1.437560
# epoch:212 loss:0.592215 accu:0.656250 |xentropy_loss:1.590819 mutual_info_loss:1.410498
# epoch:213 loss:0.611861 accu:0.601562 |xentropy_loss:1.678712 mutual_info_loss:1.514297
# epoch:214 loss:0.645863 accu:0.640625 |xentropy_loss:1.565766 mutual_info_loss:1.394715
# epoch:215 loss:0.773705 accu:0.539062 |xentropy_loss:1.698177 mutual_info_loss:1.446005
# epoch:216 loss:0.583732 accu:0.640625 |xentropy_loss:1.694934 mutual_info_loss:1.514371
# epoch:217 loss:0.632242 accu:0.632812 |xentropy_loss:1.724081 mutual_info_loss:1.476029
# epoch:218 loss:0.698989 accu:0.601562 |xentropy_loss:1.623678 mutual_info_loss:1.555561
# epoch:219 loss:0.658101 accu:0.671875 |xentropy_loss:1.553996 mutual_info_loss:1.413482
# epoch:220 loss:0.663894 accu:0.640625 |xentropy_loss:1.594922 mutual_info_loss:1.437451
# epoch:221 loss:0.716510 accu:0.554688 |xentropy_loss:1.473347 mutual_info_loss:1.281852
# epoch:222 loss:0.620328 accu:0.656250 |xentropy_loss:1.520656 mutual_info_loss:1.397969
# epoch:223 loss:0.665112 accu:0.632812 |xentropy_loss:1.442919 mutual_info_loss:1.377443
# epoch:224 loss:0.685783 accu:0.609375 |xentropy_loss:1.327933 mutual_info_loss:1.251422
# epoch:225 loss:0.711001 accu:0.648438 |xentropy_loss:1.446054 mutual_info_loss:1.335288
# epoch:226 loss:0.613909 accu:0.679688 |xentropy_loss:1.397208 mutual_info_loss:1.286205
# epoch:227 loss:0.720971 accu:0.585938 |xentropy_loss:1.333213 mutual_info_loss:1.209901
# epoch:228 loss:0.605479 accu:0.648438 |xentropy_loss:1.512386 mutual_info_loss:1.401931
# epoch:229 loss:0.632540 accu:0.625000 |xentropy_loss:1.337935 mutual_info_loss:1.243758
# epoch:230 loss:0.697401 accu:0.609375 |xentropy_loss:1.516873 mutual_info_loss:1.395034
# epoch:231 loss:0.589848 accu:0.648438 |xentropy_loss:1.477717 mutual_info_loss:1.438231
# epoch:232 loss:0.626191 accu:0.671875 |xentropy_loss:1.651714 mutual_info_loss:1.519486
# epoch:233 loss:0.716430 accu:0.601562 |xentropy_loss:1.435255 mutual_info_loss:1.276393
# epoch:234 loss:0.677251 accu:0.648438 |xentropy_loss:1.402291 mutual_info_loss:1.296782
# epoch:235 loss:0.649708 accu:0.593750 |xentropy_loss:1.427063 mutual_info_loss:1.289117
# epoch:236 loss:0.667045 accu:0.625000 |xentropy_loss:1.533613 mutual_info_loss:1.442116
# epoch:237 loss:0.689552 accu:0.593750 |xentropy_loss:1.444512 mutual_info_loss:1.328339
# epoch:238 loss:0.633487 accu:0.648438 |xentropy_loss:1.313321 mutual_info_loss:1.259241
# epoch:239 loss:0.678278 accu:0.625000 |xentropy_loss:1.369222 mutual_info_loss:1.301801
# epoch:240 loss:0.640751 accu:0.617188 |xentropy_loss:1.584372 mutual_info_loss:1.445050
# epoch:241 loss:0.721982 accu:0.648438 |xentropy_loss:1.473673 mutual_info_loss:1.302333
# epoch:242 loss:0.651964 accu:0.687500 |xentropy_loss:1.321624 mutual_info_loss:1.229772
# epoch:243 loss:0.738577 accu:0.617188 |xentropy_loss:1.546415 mutual_info_loss:1.474185
# epoch:244 loss:0.690965 accu:0.609375 |xentropy_loss:1.501658 mutual_info_loss:1.314740
# epoch:245 loss:0.651688 accu:0.609375 |xentropy_loss:1.514655 mutual_info_loss:1.373855
# epoch:246 loss:0.713066 accu:0.585938 |xentropy_loss:1.360056 mutual_info_loss:1.292626
# epoch:247 loss:0.676374 accu:0.593750 |xentropy_loss:1.473611 mutual_info_loss:1.397920
# epoch:248 loss:0.657201 accu:0.664062 |xentropy_loss:1.522759 mutual_info_loss:1.371315
# epoch:249 loss:0.689035 accu:0.609375 |xentropy_loss:1.508193 mutual_info_loss:1.375794
# epoch:250 loss:0.634704 accu:0.640625 |xentropy_loss:1.544849 mutual_info_loss:1.395592
# epoch:251 loss:0.735373 accu:0.593750 |xentropy_loss:1.443539 mutual_info_loss:1.336783
# epoch:252 loss:0.615168 accu:0.671875 |xentropy_loss:1.361048 mutual_info_loss:1.204485
# epoch:253 loss:0.719618 accu:0.617188 |xentropy_loss:1.449708 mutual_info_loss:1.379356
# epoch:254 loss:0.647084 accu:0.625000 |xentropy_loss:1.506756 mutual_info_loss:1.441169
# epoch:255 loss:0.623033 accu:0.648438 |xentropy_loss:1.511369 mutual_info_loss:1.396114
# epoch:256 loss:0.672122 accu:0.601562 |xentropy_loss:1.395655 mutual_info_loss:1.306244
# epoch:257 loss:0.705826 accu:0.601562 |xentropy_loss:1.415401 mutual_info_loss:1.314136
# epoch:258 loss:0.824464 accu:0.515625 |xentropy_loss:1.448040 mutual_info_loss:1.261573
# epoch:259 loss:0.644191 accu:0.648438 |xentropy_loss:1.530807 mutual_info_loss:1.350880
# epoch:260 loss:0.663537 accu:0.617188 |xentropy_loss:1.407445 mutual_info_loss:1.268500
# epoch:261 loss:0.786900 accu:0.546875 |xentropy_loss:1.279287 mutual_info_loss:1.152999
# epoch:262 loss:0.649259 accu:0.656250 |xentropy_loss:1.498133 mutual_info_loss:1.451257
# epoch:263 loss:0.632327 accu:0.625000 |xentropy_loss:1.241957 mutual_info_loss:1.172903
# epoch:264 loss:0.688442 accu:0.625000 |xentropy_loss:1.304562 mutual_info_loss:1.177181
# epoch:265 loss:0.686516 accu:0.601562 |xentropy_loss:1.375607 mutual_info_loss:1.175514
# epoch:266 loss:0.729474 accu:0.570312 |xentropy_loss:1.319064 mutual_info_loss:1.233040
# epoch:267 loss:0.656782 accu:0.593750 |xentropy_loss:1.370196 mutual_info_loss:1.300227
# epoch:268 loss:0.719761 accu:0.554688 |xentropy_loss:1.341426 mutual_info_loss:1.258805
# epoch:269 loss:0.690414 accu:0.617188 |xentropy_loss:1.469375 mutual_info_loss:1.306344
# epoch:270 loss:0.706111 accu:0.609375 |xentropy_loss:1.515366 mutual_info_loss:1.299190
# epoch:271 loss:0.642768 accu:0.671875 |xentropy_loss:1.352866 mutual_info_loss:1.299288
# epoch:272 loss:0.766073 accu:0.554688 |xentropy_loss:1.356978 mutual_info_loss:1.176705
# epoch:273 loss:0.652313 accu:0.617188 |xentropy_loss:1.236099 mutual_info_loss:1.182670
# epoch:274 loss:0.665183 accu:0.617188 |xentropy_loss:1.205572 mutual_info_loss:1.144587
# epoch:275 loss:0.649666 accu:0.601562 |xentropy_loss:1.225386 mutual_info_loss:1.169739
# epoch:276 loss:0.600804 accu:0.648438 |xentropy_loss:1.269384 mutual_info_loss:1.237849
# epoch:277 loss:0.633843 accu:0.640625 |xentropy_loss:1.250539 mutual_info_loss:1.141868
# epoch:278 loss:0.742815 accu:0.546875 |xentropy_loss:1.227314 mutual_info_loss:1.165784
# epoch:279 loss:0.724718 accu:0.593750 |xentropy_loss:1.246073 mutual_info_loss:1.179298
# epoch:280 loss:0.767580 accu:0.593750 |xentropy_loss:1.433370 mutual_info_loss:1.327262
# epoch:281 loss:0.788895 accu:0.562500 |xentropy_loss:1.372804 mutual_info_loss:1.240895
# epoch:282 loss:0.718694 accu:0.656250 |xentropy_loss:1.309246 mutual_info_loss:1.188672
# epoch:283 loss:0.670192 accu:0.671875 |xentropy_loss:1.279276 mutual_info_loss:1.215273
# epoch:284 loss:0.701110 accu:0.578125 |xentropy_loss:1.235927 mutual_info_loss:1.154473
# epoch:285 loss:0.723403 accu:0.562500 |xentropy_loss:1.527660 mutual_info_loss:1.357096
# epoch:286 loss:0.680079 accu:0.617188 |xentropy_loss:1.271445 mutual_info_loss:1.235235
# epoch:287 loss:0.620892 accu:0.656250 |xentropy_loss:1.453178 mutual_info_loss:1.350470
# epoch:288 loss:0.731081 accu:0.546875 |xentropy_loss:1.184799 mutual_info_loss:1.134002
# epoch:289 loss:0.690815 accu:0.593750 |xentropy_loss:1.271586 mutual_info_loss:1.175390
# epoch:290 loss:0.667259 accu:0.593750 |xentropy_loss:1.322805 mutual_info_loss:1.263490
# epoch:291 loss:0.679416 accu:0.585938 |xentropy_loss:1.216363 mutual_info_loss:1.169250
# epoch:292 loss:0.714773 accu:0.601562 |xentropy_loss:1.266116 mutual_info_loss:1.145254
# epoch:293 loss:0.732694 accu:0.539062 |xentropy_loss:1.299702 mutual_info_loss:1.172667
# epoch:294 loss:0.774685 accu:0.523438 |xentropy_loss:1.262094 mutual_info_loss:1.134813
# epoch:295 loss:0.665072 accu:0.632812 |xentropy_loss:1.231899 mutual_info_loss:1.087341
# epoch:296 loss:0.615283 accu:0.648438 |xentropy_loss:1.360377 mutual_info_loss:1.302390
# epoch:297 loss:0.717304 accu:0.593750 |xentropy_loss:1.330660 mutual_info_loss:1.156744
# epoch:298 loss:0.730128 accu:0.625000 |xentropy_loss:1.231045 mutual_info_loss:1.178897
# epoch:299 loss:0.711417 accu:0.562500 |xentropy_loss:1.324699 mutual_info_loss:1.148182
# epoch:300 loss:0.649286 accu:0.617188 |xentropy_loss:1.221634 mutual_info_loss:1.167207
# epoch:301 loss:0.646850 accu:0.609375 |xentropy_loss:1.221590 mutual_info_loss:1.154653
# epoch:302 loss:0.727216 accu:0.562500 |xentropy_loss:1.215869 mutual_info_loss:1.179496
# epoch:303 loss:0.723348 accu:0.617188 |xentropy_loss:1.352078 mutual_info_loss:1.267022
# epoch:304 loss:0.711690 accu:0.601562 |xentropy_loss:1.349746 mutual_info_loss:1.193937
# epoch:305 loss:0.671568 accu:0.625000 |xentropy_loss:1.285123 mutual_info_loss:1.228579
# epoch:306 loss:0.694506 accu:0.578125 |xentropy_loss:1.218343 mutual_info_loss:1.170911
# epoch:307 loss:0.766286 accu:0.601562 |xentropy_loss:1.222403 mutual_info_loss:1.136097
# epoch:308 loss:0.717379 accu:0.593750 |xentropy_loss:1.399146 mutual_info_loss:1.262623
# epoch:309 loss:0.700565 accu:0.609375 |xentropy_loss:1.174111 mutual_info_loss:1.089726
# epoch:310 loss:0.698893 accu:0.562500 |xentropy_loss:1.204403 mutual_info_loss:1.152719
# epoch:311 loss:0.676991 accu:0.617188 |xentropy_loss:1.243356 mutual_info_loss:1.163303
# epoch:312 loss:0.713857 accu:0.593750 |xentropy_loss:1.255785 mutual_info_loss:1.119751
# epoch:313 loss:0.761454 accu:0.570312 |xentropy_loss:1.046627 mutual_info_loss:0.933459
# epoch:314 loss:0.662508 accu:0.609375 |xentropy_loss:1.255689 mutual_info_loss:1.057983
# epoch:315 loss:0.687600 accu:0.578125 |xentropy_loss:1.117586 mutual_info_loss:1.054044
# epoch:316 loss:0.674899 accu:0.578125 |xentropy_loss:1.128128 mutual_info_loss:1.065798
# epoch:317 loss:0.689080 accu:0.601562 |xentropy_loss:1.195975 mutual_info_loss:1.101549
# epoch:318 loss:0.661670 accu:0.601562 |xentropy_loss:1.157787 mutual_info_loss:1.102964
# epoch:319 loss:0.744948 accu:0.593750 |xentropy_loss:1.245839 mutual_info_loss:1.167363
# epoch:320 loss:0.745719 accu:0.609375 |xentropy_loss:1.156831 mutual_info_loss:1.041626
# epoch:321 loss:0.685910 accu:0.625000 |xentropy_loss:1.112722 mutual_info_loss:1.035249
# epoch:322 loss:0.697678 accu:0.593750 |xentropy_loss:1.235666 mutual_info_loss:1.090700
# epoch:323 loss:0.638340 accu:0.640625 |xentropy_loss:1.183013 mutual_info_loss:1.136927
# epoch:324 loss:0.744298 accu:0.562500 |xentropy_loss:1.151894 mutual_info_loss:1.008694
# epoch:325 loss:0.646578 accu:0.593750 |xentropy_loss:1.170275 mutual_info_loss:1.103562
# epoch:326 loss:0.686382 accu:0.609375 |xentropy_loss:1.232500 mutual_info_loss:1.163958
# epoch:327 loss:0.681096 accu:0.593750 |xentropy_loss:1.056957 mutual_info_loss:1.030940
# epoch:328 loss:0.664859 accu:0.632812 |xentropy_loss:1.121952 mutual_info_loss:1.005244
# epoch:329 loss:0.694862 accu:0.640625 |xentropy_loss:1.276432 mutual_info_loss:1.246346
# epoch:330 loss:0.733697 accu:0.578125 |xentropy_loss:1.194060 mutual_info_loss:1.113785
# epoch:331 loss:0.690424 accu:0.554688 |xentropy_loss:1.156906 mutual_info_loss:1.065112
# epoch:332 loss:0.707995 accu:0.585938 |xentropy_loss:1.277783 mutual_info_loss:1.205515
# epoch:333 loss:0.726794 accu:0.585938 |xentropy_loss:1.113142 mutual_info_loss:1.037000
# epoch:334 loss:0.651500 accu:0.593750 |xentropy_loss:1.244307 mutual_info_loss:1.191692
# epoch:335 loss:0.711137 accu:0.562500 |xentropy_loss:1.074443 mutual_info_loss:1.011143
# epoch:336 loss:0.686084 accu:0.617188 |xentropy_loss:1.203881 mutual_info_loss:1.147069
# epoch:337 loss:0.632167 accu:0.617188 |xentropy_loss:1.186700 mutual_info_loss:1.161286
# epoch:338 loss:0.707318 accu:0.632812 |xentropy_loss:1.340817 mutual_info_loss:1.194150
# epoch:339 loss:0.700256 accu:0.578125 |xentropy_loss:1.067445 mutual_info_loss:1.022073
# epoch:340 loss:0.665570 accu:0.625000 |xentropy_loss:1.166229 mutual_info_loss:1.072255
# epoch:341 loss:0.659780 accu:0.601562 |xentropy_loss:1.247501 mutual_info_loss:1.208921
# epoch:342 loss:0.672007 accu:0.640625 |xentropy_loss:1.069420 mutual_info_loss:0.987182
# epoch:343 loss:0.670680 accu:0.593750 |xentropy_loss:1.172632 mutual_info_loss:1.065510
# epoch:344 loss:0.642651 accu:0.656250 |xentropy_loss:1.216888 mutual_info_loss:1.018891
# epoch:345 loss:0.636528 accu:0.593750 |xentropy_loss:1.218090 mutual_info_loss:1.144489
# epoch:346 loss:0.735653 accu:0.554688 |xentropy_loss:1.051079 mutual_info_loss:0.971711
# epoch:347 loss:0.741290 accu:0.585938 |xentropy_loss:1.089429 mutual_info_loss:1.029632
# epoch:348 loss:0.762341 accu:0.570312 |xentropy_loss:1.152544 mutual_info_loss:1.078488
# epoch:349 loss:0.635919 accu:0.625000 |xentropy_loss:1.246099 mutual_info_loss:1.177863
# epoch:350 loss:0.748622 accu:0.617188 |xentropy_loss:1.131279 mutual_info_loss:1.092948
# epoch:351 loss:0.712484 accu:0.578125 |xentropy_loss:1.084986 mutual_info_loss:1.055954
# epoch:352 loss:0.691714 accu:0.593750 |xentropy_loss:1.162928 mutual_info_loss:1.140004
# epoch:353 loss:0.666044 accu:0.625000 |xentropy_loss:1.326179 mutual_info_loss:1.200443
# epoch:354 loss:0.757180 accu:0.570312 |xentropy_loss:1.086160 mutual_info_loss:1.017525
# epoch:355 loss:0.697190 accu:0.585938 |xentropy_loss:1.202477 mutual_info_loss:1.110956
# epoch:356 loss:0.700845 accu:0.562500 |xentropy_loss:1.109876 mutual_info_loss:1.048337
# epoch:357 loss:0.715480 accu:0.578125 |xentropy_loss:1.148209 mutual_info_loss:1.019091
# epoch:358 loss:0.649907 accu:0.640625 |xentropy_loss:1.160983 mutual_info_loss:1.104536
# epoch:359 loss:0.699456 accu:0.562500 |xentropy_loss:1.078845 mutual_info_loss:0.999992
# epoch:360 loss:0.704270 accu:0.570312 |xentropy_loss:1.061418 mutual_info_loss:1.027251
# epoch:361 loss:0.691354 accu:0.578125 |xentropy_loss:1.231270 mutual_info_loss:1.151305
# epoch:362 loss:0.701796 accu:0.578125 |xentropy_loss:1.058037 mutual_info_loss:1.008946
# epoch:363 loss:0.685423 accu:0.648438 |xentropy_loss:1.044557 mutual_info_loss:1.006577
# epoch:364 loss:0.723721 accu:0.546875 |xentropy_loss:1.073795 mutual_info_loss:0.984739
# epoch:365 loss:0.646397 accu:0.640625 |xentropy_loss:1.277053 mutual_info_loss:1.212885
# epoch:366 loss:0.673391 accu:0.640625 |xentropy_loss:1.130085 mutual_info_loss:1.091917
# epoch:367 loss:0.796276 accu:0.546875 |xentropy_loss:1.068008 mutual_info_loss:0.944144
# epoch:368 loss:0.691568 accu:0.554688 |xentropy_loss:1.221239 mutual_info_loss:1.140601
# epoch:369 loss:0.686776 accu:0.640625 |xentropy_loss:1.228889 mutual_info_loss:1.158556
# epoch:370 loss:0.703951 accu:0.632812 |xentropy_loss:1.112665 mutual_info_loss:1.064615
# epoch:371 loss:0.687207 accu:0.578125 |xentropy_loss:1.135699 mutual_info_loss:1.092764
# epoch:372 loss:0.757986 accu:0.531250 |xentropy_loss:1.074640 mutual_info_loss:0.984046
# epoch:373 loss:0.676256 accu:0.648438 |xentropy_loss:1.247244 mutual_info_loss:1.090451
# epoch:374 loss:0.650480 accu:0.625000 |xentropy_loss:1.094710 mutual_info_loss:1.017805
# epoch:375 loss:0.676583 accu:0.609375 |xentropy_loss:1.056121 mutual_info_loss:0.985117
# epoch:376 loss:0.696987 accu:0.578125 |xentropy_loss:1.053100 mutual_info_loss:0.997872
# epoch:377 loss:0.725527 accu:0.593750 |xentropy_loss:1.217782 mutual_info_loss:1.057987
# epoch:378 loss:0.670625 accu:0.617188 |xentropy_loss:1.352646 mutual_info_loss:1.195592
# epoch:379 loss:0.667200 accu:0.593750 |xentropy_loss:1.257302 mutual_info_loss:1.107818
# epoch:380 loss:0.692977 accu:0.617188 |xentropy_loss:1.112444 mutual_info_loss:1.011591
# epoch:381 loss:0.729180 accu:0.570312 |xentropy_loss:1.167603 mutual_info_loss:1.100200
# epoch:382 loss:0.713743 accu:0.593750 |xentropy_loss:1.105091 mutual_info_loss:0.997902
# epoch:383 loss:0.699748 accu:0.625000 |xentropy_loss:1.154304 mutual_info_loss:1.091867
# epoch:384 loss:0.677144 accu:0.640625 |xentropy_loss:1.181804 mutual_info_loss:1.041301
# epoch:385 loss:0.754570 accu:0.523438 |xentropy_loss:1.050599 mutual_info_loss:0.944003
# epoch:386 loss:0.729730 accu:0.554688 |xentropy_loss:1.036150 mutual_info_loss:0.992433
# epoch:387 loss:0.658422 accu:0.625000 |xentropy_loss:1.269982 mutual_info_loss:1.227030
# epoch:388 loss:0.695041 accu:0.593750 |xentropy_loss:1.034812 mutual_info_loss:1.010012
# epoch:389 loss:0.648960 accu:0.617188 |xentropy_loss:1.078185 mutual_info_loss:1.030125
# epoch:390 loss:0.718177 accu:0.609375 |xentropy_loss:1.057424 mutual_info_loss:1.019134
# epoch:391 loss:0.650708 accu:0.625000 |xentropy_loss:1.175083 mutual_info_loss:1.126231
# epoch:392 loss:0.759200 accu:0.492188 |xentropy_loss:1.235879 mutual_info_loss:1.138701
# epoch:393 loss:0.641028 accu:0.585938 |xentropy_loss:1.196935 mutual_info_loss:1.113610
# epoch:394 loss:0.743396 accu:0.570312 |xentropy_loss:1.250824 mutual_info_loss:1.040468
# epoch:395 loss:0.634745 accu:0.617188 |xentropy_loss:1.181888 mutual_info_loss:1.099425
# epoch:396 loss:0.674312 accu:0.617188 |xentropy_loss:1.138276 mutual_info_loss:1.090812
# epoch:397 loss:0.723810 accu:0.593750 |xentropy_loss:1.116563 mutual_info_loss:1.094786
# epoch:398 loss:0.706749 accu:0.632812 |xentropy_loss:1.064836 mutual_info_loss:1.021634
# epoch:399 loss:0.780385 accu:0.523438 |xentropy_loss:1.105744 mutual_info_loss:0.982946
# epoch:400 loss:0.720614 accu:0.539062 |xentropy_loss:1.340038 mutual_info_loss:1.170964
# epoch:401 loss:0.698445 accu:0.640625 |xentropy_loss:1.117831 mutual_info_loss:1.058275
# epoch:402 loss:0.711951 accu:0.585938 |xentropy_loss:1.070713 mutual_info_loss:1.022589
# epoch:403 loss:0.707395 accu:0.578125 |xentropy_loss:1.020771 mutual_info_loss:0.956876
# epoch:404 loss:0.628927 accu:0.640625 |xentropy_loss:1.188969 mutual_info_loss:1.131105
# epoch:405 loss:0.640021 accu:0.632812 |xentropy_loss:1.154103 mutual_info_loss:1.103342
# epoch:406 loss:0.774103 accu:0.578125 |xentropy_loss:0.995555 mutual_info_loss:0.967260
# epoch:407 loss:0.733138 accu:0.554688 |xentropy_loss:1.028122 mutual_info_loss:0.957539
# epoch:408 loss:0.781659 accu:0.570312 |xentropy_loss:1.146665 mutual_info_loss:1.053932
# epoch:409 loss:0.626466 accu:0.648438 |xentropy_loss:1.210617 mutual_info_loss:1.128486
# epoch:410 loss:0.697783 accu:0.585938 |xentropy_loss:1.001306 mutual_info_loss:0.972516
# epoch:411 loss:0.746296 accu:0.570312 |xentropy_loss:1.086769 mutual_info_loss:1.044128
# epoch:412 loss:0.651490 accu:0.671875 |xentropy_loss:1.064574 mutual_info_loss:0.970973
# epoch:413 loss:0.740966 accu:0.562500 |xentropy_loss:1.104514 mutual_info_loss:0.994435
# epoch:414 loss:0.725782 accu:0.570312 |xentropy_loss:1.010793 mutual_info_loss:0.976729
# epoch:415 loss:0.677541 accu:0.585938 |xentropy_loss:1.073423 mutual_info_loss:1.044276
# epoch:416 loss:0.744718 accu:0.554688 |xentropy_loss:1.149623 mutual_info_loss:1.056285
# epoch:417 loss:0.723675 accu:0.562500 |xentropy_loss:1.084512 mutual_info_loss:1.017633
# epoch:418 loss:0.714714 accu:0.554688 |xentropy_loss:1.095700 mutual_info_loss:0.976615
# epoch:419 loss:0.751701 accu:0.562500 |xentropy_loss:1.069051 mutual_info_loss:1.042002
# epoch:420 loss:0.695812 accu:0.609375 |xentropy_loss:1.202832 mutual_info_loss:0.997154
# epoch:421 loss:0.747081 accu:0.546875 |xentropy_loss:1.076999 mutual_info_loss:1.024054
# epoch:422 loss:0.723040 accu:0.523438 |xentropy_loss:1.184018 mutual_info_loss:1.054026
# epoch:423 loss:0.699776 accu:0.609375 |xentropy_loss:1.048868 mutual_info_loss:0.932137
# epoch:424 loss:0.732781 accu:0.554688 |xentropy_loss:1.081154 mutual_info_loss:1.006226
# epoch:425 loss:0.701567 accu:0.585938 |xentropy_loss:1.079340 mutual_info_loss:0.992576
# epoch:426 loss:0.723670 accu:0.554688 |xentropy_loss:1.095476 mutual_info_loss:1.051809
# epoch:427 loss:0.673191 accu:0.625000 |xentropy_loss:1.084991 mutual_info_loss:1.046028
# epoch:428 loss:0.710657 accu:0.609375 |xentropy_loss:1.182986 mutual_info_loss:1.105581
# epoch:429 loss:0.616169 accu:0.656250 |xentropy_loss:1.088318 mutual_info_loss:1.063768
# epoch:430 loss:0.739305 accu:0.539062 |xentropy_loss:1.108452 mutual_info_loss:0.984543
# epoch:431 loss:0.678666 accu:0.632812 |xentropy_loss:1.047081 mutual_info_loss:0.943351
# epoch:432 loss:0.693644 accu:0.593750 |xentropy_loss:1.063097 mutual_info_loss:0.959639
# epoch:433 loss:0.672001 accu:0.578125 |xentropy_loss:1.036361 mutual_info_loss:0.960655
# epoch:434 loss:0.665539 accu:0.601562 |xentropy_loss:1.195371 mutual_info_loss:1.095684
# epoch:435 loss:0.737978 accu:0.539062 |xentropy_loss:1.116549 mutual_info_loss:1.061436
# epoch:436 loss:0.675551 accu:0.617188 |xentropy_loss:0.991221 mutual_info_loss:0.949207
# epoch:437 loss:0.695885 accu:0.593750 |xentropy_loss:1.073150 mutual_info_loss:1.002617
# epoch:438 loss:0.696185 accu:0.593750 |xentropy_loss:1.012912 mutual_info_loss:0.989430
# epoch:439 loss:0.690110 accu:0.601562 |xentropy_loss:1.169929 mutual_info_loss:1.090603
# epoch:440 loss:0.673954 accu:0.593750 |xentropy_loss:1.052840 mutual_info_loss:0.980977
# epoch:441 loss:0.732248 accu:0.539062 |xentropy_loss:1.104013 mutual_info_loss:1.078840
# epoch:442 loss:0.651563 accu:0.609375 |xentropy_loss:1.089602 mutual_info_loss:1.050242
# epoch:443 loss:0.698382 accu:0.578125 |xentropy_loss:1.061622 mutual_info_loss:1.034617
# epoch:444 loss:0.710771 accu:0.585938 |xentropy_loss:1.058881 mutual_info_loss:0.958142
# epoch:445 loss:0.745118 accu:0.523438 |xentropy_loss:1.166021 mutual_info_loss:1.083407
# epoch:446 loss:0.659730 accu:0.632812 |xentropy_loss:1.192390 mutual_info_loss:1.128153
# epoch:447 loss:0.660407 accu:0.648438 |xentropy_loss:1.097606 mutual_info_loss:1.025497
# epoch:448 loss:0.641407 accu:0.640625 |xentropy_loss:1.067314 mutual_info_loss:1.033203
# epoch:449 loss:0.781116 accu:0.554688 |xentropy_loss:0.944722 mutual_info_loss:0.903348
# epoch:450 loss:0.652198 accu:0.578125 |xentropy_loss:1.153169 mutual_info_loss:1.116465
# epoch:451 loss:0.715650 accu:0.492188 |xentropy_loss:1.154412 mutual_info_loss:1.069995
# epoch:452 loss:0.639034 accu:0.554688 |xentropy_loss:1.058180 mutual_info_loss:1.030085
# epoch:453 loss:0.707103 accu:0.640625 |xentropy_loss:1.235812 mutual_info_loss:1.130822
# epoch:454 loss:0.714020 accu:0.593750 |xentropy_loss:1.030673 mutual_info_loss:1.020092
# epoch:455 loss:0.646227 accu:0.585938 |xentropy_loss:1.077590 mutual_info_loss:0.981704
# epoch:456 loss:0.726609 accu:0.578125 |xentropy_loss:0.968927 mutual_info_loss:0.896474
# epoch:457 loss:0.766270 accu:0.570312 |xentropy_loss:1.056070 mutual_info_loss:1.011200
# epoch:458 loss:0.706145 accu:0.601562 |xentropy_loss:1.226999 mutual_info_loss:1.095747
# epoch:459 loss:0.742970 accu:0.593750 |xentropy_loss:1.142490 mutual_info_loss:1.106145
# epoch:460 loss:0.669122 accu:0.664062 |xentropy_loss:1.056219 mutual_info_loss:0.963343
# epoch:461 loss:0.707088 accu:0.578125 |xentropy_loss:1.055112 mutual_info_loss:1.032816
# epoch:462 loss:0.690372 accu:0.601562 |xentropy_loss:1.157054 mutual_info_loss:1.103776
# epoch:463 loss:0.715138 accu:0.585938 |xentropy_loss:1.087169 mutual_info_loss:1.039223
# epoch:464 loss:0.711969 accu:0.585938 |xentropy_loss:1.149480 mutual_info_loss:1.085448
# epoch:465 loss:0.694282 accu:0.617188 |xentropy_loss:1.118644 mutual_info_loss:1.082781
# epoch:466 loss:0.748472 accu:0.562500 |xentropy_loss:1.017543 mutual_info_loss:0.974379
# epoch:467 loss:0.751609 accu:0.531250 |xentropy_loss:0.989790 mutual_info_loss:0.942446
# epoch:468 loss:0.731532 accu:0.554688 |xentropy_loss:1.062139 mutual_info_loss:1.010946
# epoch:469 loss:0.761215 accu:0.546875 |xentropy_loss:1.081922 mutual_info_loss:1.008893
# epoch:470 loss:0.690066 accu:0.601562 |xentropy_loss:1.173295 mutual_info_loss:1.010595
# epoch:471 loss:0.676840 accu:0.609375 |xentropy_loss:1.104327 mutual_info_loss:1.061811
# epoch:472 loss:0.753387 accu:0.570312 |xentropy_loss:1.104338 mutual_info_loss:1.064758
# epoch:473 loss:0.761040 accu:0.593750 |xentropy_loss:0.973422 mutual_info_loss:0.940033
# epoch:474 loss:0.743722 accu:0.531250 |xentropy_loss:1.098574 mutual_info_loss:1.008796
# epoch:475 loss:0.680211 accu:0.625000 |xentropy_loss:1.123246 mutual_info_loss:1.047757
# epoch:476 loss:0.665243 accu:0.609375 |xentropy_loss:1.002207 mutual_info_loss:0.917816
# epoch:477 loss:0.708318 accu:0.593750 |xentropy_loss:1.084743 mutual_info_loss:0.952981
# epoch:478 loss:0.740846 accu:0.593750 |xentropy_loss:0.896158 mutual_info_loss:0.859506
# epoch:479 loss:0.701354 accu:0.593750 |xentropy_loss:1.089541 mutual_info_loss:1.006278
# epoch:480 loss:0.729935 accu:0.554688 |xentropy_loss:1.037200 mutual_info_loss:0.973509
# epoch:481 loss:0.696560 accu:0.601562 |xentropy_loss:1.122172 mutual_info_loss:1.027231
# epoch:482 loss:0.708138 accu:0.562500 |xentropy_loss:0.899121 mutual_info_loss:0.870273
# epoch:483 loss:0.636964 accu:0.640625 |xentropy_loss:1.029822 mutual_info_loss:0.987692
# epoch:484 loss:0.809377 accu:0.554688 |xentropy_loss:1.025080 mutual_info_loss:0.977939
# epoch:485 loss:0.634645 accu:0.617188 |xentropy_loss:1.190012 mutual_info_loss:1.081832
# epoch:486 loss:0.629673 accu:0.656250 |xentropy_loss:1.086764 mutual_info_loss:0.992936
# epoch:487 loss:0.670184 accu:0.601562 |xentropy_loss:0.929539 mutual_info_loss:0.895033
# epoch:488 loss:0.717870 accu:0.562500 |xentropy_loss:1.016366 mutual_info_loss:0.915789
# epoch:489 loss:0.752645 accu:0.531250 |xentropy_loss:1.048277 mutual_info_loss:0.951422
# epoch:490 loss:0.713922 accu:0.562500 |xentropy_loss:1.069461 mutual_info_loss:1.031621
# epoch:491 loss:0.683616 accu:0.585938 |xentropy_loss:1.122879 mutual_info_loss:1.003303
# epoch:492 loss:0.710510 accu:0.554688 |xentropy_loss:1.092770 mutual_info_loss:1.049928
# epoch:493 loss:0.693521 accu:0.617188 |xentropy_loss:0.941353 mutual_info_loss:0.889132
# epoch:494 loss:0.633970 accu:0.664062 |xentropy_loss:1.009430 mutual_info_loss:0.942724
# epoch:495 loss:0.761321 accu:0.570312 |xentropy_loss:1.022726 mutual_info_loss:0.964503
# epoch:496 loss:0.671671 accu:0.617188 |xentropy_loss:1.105349 mutual_info_loss:1.072116
# epoch:497 loss:0.692126 accu:0.640625 |xentropy_loss:1.072751 mutual_info_loss:1.050559
# epoch:498 loss:0.697648 accu:0.585938 |xentropy_loss:1.075463 mutual_info_loss:1.024291
# epoch:499 loss:0.717931 accu:0.562500 |xentropy_loss:0.995445 mutual_info_loss:0.963070
# epoch:500 loss:0.693054 accu:0.593750 |xentropy_loss:1.005352 mutual_info_loss:0.919498
# epoch:501 loss:0.689490 accu:0.640625 |xentropy_loss:0.920367 mutual_info_loss:0.835315
# epoch:502 loss:0.686561 accu:0.593750 |xentropy_loss:0.967625 mutual_info_loss:0.931724
# epoch:503 loss:0.720979 accu:0.601562 |xentropy_loss:1.034149 mutual_info_loss:0.988585
# epoch:504 loss:0.645988 accu:0.593750 |xentropy_loss:1.031387 mutual_info_loss:0.925383
# epoch:505 loss:0.780753 accu:0.531250 |xentropy_loss:1.108408 mutual_info_loss:1.023322
# epoch:506 loss:0.705737 accu:0.578125 |xentropy_loss:1.091215 mutual_info_loss:0.965224
# epoch:507 loss:0.624584 accu:0.671875 |xentropy_loss:1.082711 mutual_info_loss:0.943410
# epoch:508 loss:0.742743 accu:0.578125 |xentropy_loss:1.011334 mutual_info_loss:0.951305
# epoch:509 loss:0.700564 accu:0.546875 |xentropy_loss:1.103483 mutual_info_loss:0.977129
# epoch:510 loss:0.682359 accu:0.593750 |xentropy_loss:0.936217 mutual_info_loss:0.900861
# epoch:511 loss:0.659201 accu:0.601562 |xentropy_loss:1.023038 mutual_info_loss:0.969412
# epoch:512 loss:0.743534 accu:0.546875 |xentropy_loss:1.014980 mutual_info_loss:0.998579
# epoch:513 loss:0.708578 accu:0.593750 |xentropy_loss:1.118722 mutual_info_loss:1.004267
# epoch:514 loss:0.713002 accu:0.601562 |xentropy_loss:0.970546 mutual_info_loss:0.924933
# epoch:515 loss:0.699885 accu:0.523438 |xentropy_loss:0.987820 mutual_info_loss:0.952991
# epoch:516 loss:0.743586 accu:0.617188 |xentropy_loss:1.107258 mutual_info_loss:1.059182
# epoch:517 loss:0.754449 accu:0.601562 |xentropy_loss:1.054610 mutual_info_loss:0.946431
# epoch:518 loss:0.653403 accu:0.609375 |xentropy_loss:1.126512 mutual_info_loss:1.022516
# epoch:519 loss:0.697669 accu:0.617188 |xentropy_loss:0.894765 mutual_info_loss:0.881447
# epoch:520 loss:0.755049 accu:0.539062 |xentropy_loss:1.024327 mutual_info_loss:0.914172
# epoch:521 loss:0.720056 accu:0.578125 |xentropy_loss:1.071651 mutual_info_loss:0.975440
# epoch:522 loss:0.663918 accu:0.617188 |xentropy_loss:0.983424 mutual_info_loss:0.960662
# epoch:523 loss:0.689265 accu:0.593750 |xentropy_loss:1.040711 mutual_info_loss:1.010499
# epoch:524 loss:0.737658 accu:0.585938 |xentropy_loss:1.044138 mutual_info_loss:0.990809
# epoch:525 loss:0.767070 accu:0.562500 |xentropy_loss:1.068911 mutual_info_loss:0.993266
# epoch:526 loss:0.742309 accu:0.531250 |xentropy_loss:1.033122 mutual_info_loss:1.000153
# epoch:527 loss:0.709920 accu:0.578125 |xentropy_loss:1.016241 mutual_info_loss:0.914527
# epoch:528 loss:0.715467 accu:0.539062 |xentropy_loss:0.913378 mutual_info_loss:0.853203
# epoch:529 loss:0.778701 accu:0.609375 |xentropy_loss:0.949368 mutual_info_loss:0.899801
# epoch:530 loss:0.678896 accu:0.609375 |xentropy_loss:1.079138 mutual_info_loss:1.026116
# epoch:531 loss:0.763858 accu:0.593750 |xentropy_loss:0.963246 mutual_info_loss:0.927016
# epoch:532 loss:0.666689 accu:0.625000 |xentropy_loss:0.994258 mutual_info_loss:0.945609
# epoch:533 loss:0.748620 accu:0.585938 |xentropy_loss:0.969011 mutual_info_loss:0.939304
# epoch:534 loss:0.655845 accu:0.617188 |xentropy_loss:1.050774 mutual_info_loss:0.957326
# epoch:535 loss:0.722167 accu:0.601562 |xentropy_loss:0.987093 mutual_info_loss:0.940166
# epoch:536 loss:0.667161 accu:0.601562 |xentropy_loss:1.001024 mutual_info_loss:0.971737
# epoch:537 loss:0.792981 accu:0.523438 |xentropy_loss:0.947225 mutual_info_loss:0.908181
# epoch:538 loss:0.720161 accu:0.523438 |xentropy_loss:1.072956 mutual_info_loss:1.007714
# epoch:539 loss:0.712285 accu:0.578125 |xentropy_loss:0.965289 mutual_info_loss:0.937811
# epoch:540 loss:0.671551 accu:0.585938 |xentropy_loss:1.006835 mutual_info_loss:0.933747
# epoch:541 loss:0.767931 accu:0.570312 |xentropy_loss:0.947674 mutual_info_loss:0.920911
# epoch:542 loss:0.699237 accu:0.578125 |xentropy_loss:0.999721 mutual_info_loss:0.950010
# ...
# epoch:820 loss:0.687640 accu:0.601562 |xentropy_loss:1.059090 mutual_info_loss:0.930950
# epoch:821 loss:0.685839 accu:0.578125 |xentropy_loss:1.004468 mutual_info_loss:0.990456
# epoch:822 loss:0.674969 accu:0.593750 |xentropy_loss:0.999704 mutual_info_loss:0.987814
# epoch:823 loss:0.767349 accu:0.546875 |xentropy_loss:0.932086 mutual_info_loss:0.884122
# epoch:824 loss:0.648112 accu:0.593750 |xentropy_loss:0.961209 mutual_info_loss:0.929398
# epoch:825 loss:0.735125 accu:0.554688 |xentropy_loss:0.982114 mutual_info_loss:0.954757
# epoch:826 loss:0.687447 accu:0.609375 |xentropy_loss:0.936539 mutual_info_loss:0.917772
# epoch:827 loss:0.739259 accu:0.570312 |xentropy_loss:0.964038 mutual_info_loss:0.933587
# epoch:828 loss:0.642432 accu:0.609375 |xentropy_loss:1.007149 mutual_info_loss:0.968292
# epoch:829 loss:0.671252 accu:0.632812 |xentropy_loss:0.968108 mutual_info_loss:0.936416
# epoch:830 loss:0.652384 accu:0.648438 |xentropy_loss:1.011508 mutual_info_loss:0.987434
# epoch:831 loss:0.685273 accu:0.593750 |xentropy_loss:1.014276 mutual_info_loss:0.995101
# epoch:832 loss:0.761326 accu:0.562500 |xentropy_loss:0.970398 mutual_info_loss:0.935747
# epoch:833 loss:0.705689 accu:0.578125 |xentropy_loss:0.984886 mutual_info_loss:0.949131
# epoch:834 loss:0.725952 accu:0.546875 |xentropy_loss:0.946342 mutual_info_loss:0.883080
# epoch:835 loss:0.751883 accu:0.570312 |xentropy_loss:0.967582 mutual_info_loss:0.955024
# epoch:836 loss:0.729095 accu:0.578125 |xentropy_loss:0.926926 mutual_info_loss:0.830119
# epoch:837 loss:0.691936 accu:0.578125 |xentropy_loss:0.917649 mutual_info_loss:0.903616
# epoch:838 loss:0.709824 accu:0.578125 |xentropy_loss:0.884476 mutual_info_loss:0.839218
# epoch:839 loss:0.693242 accu:0.578125 |xentropy_loss:0.931168 mutual_info_loss:0.922699
# epoch:840 loss:0.690040 accu:0.593750 |xentropy_loss:0.911665 mutual_info_loss:0.850530
# epoch:841 loss:0.681989 accu:0.617188 |xentropy_loss:0.890256 mutual_info_loss:0.881938
# epoch:842 loss:0.742038 accu:0.570312 |xentropy_loss:0.897711 mutual_info_loss:0.875535
# epoch:843 loss:0.722559 accu:0.593750 |xentropy_loss:0.993642 mutual_info_loss:0.956386
# epoch:844 loss:0.712934 accu:0.609375 |xentropy_loss:0.904649 mutual_info_loss:0.864410
# epoch:845 loss:0.717655 accu:0.585938 |xentropy_loss:1.075999 mutual_info_loss:1.027675
# epoch:846 loss:0.727976 accu:0.609375 |xentropy_loss:0.992272 mutual_info_loss:0.935102
# epoch:847 loss:0.682421 accu:0.632812 |xentropy_loss:1.115723 mutual_info_loss:1.021457
# epoch:848 loss:0.678827 accu:0.570312 |xentropy_loss:0.950238 mutual_info_loss:0.919962
# epoch:849 loss:0.695940 accu:0.578125 |xentropy_loss:0.909034 mutual_info_loss:0.896389
# epoch:850 loss:0.723314 accu:0.554688 |xentropy_loss:0.927911 mutual_info_loss:0.868380
# epoch:851 loss:0.746197 accu:0.554688 |xentropy_loss:0.893912 mutual_info_loss:0.837788
# epoch:852 loss:0.658165 accu:0.632812 |xentropy_loss:0.916020 mutual_info_loss:0.906103
# epoch:853 loss:0.693792 accu:0.578125 |xentropy_loss:0.967958 mutual_info_loss:0.937479
# epoch:854 loss:0.711465 accu:0.546875 |xentropy_loss:1.014864 mutual_info_loss:0.964873
# epoch:855 loss:0.649125 accu:0.609375 |xentropy_loss:0.962643 mutual_info_loss:0.911488
# epoch:856 loss:0.729599 accu:0.546875 |xentropy_loss:0.890463 mutual_info_loss:0.878843
# epoch:857 loss:0.667247 accu:0.609375 |xentropy_loss:0.969900 mutual_info_loss:0.940785
# epoch:858 loss:0.780485 accu:0.515625 |xentropy_loss:0.935756 mutual_info_loss:0.865656
# epoch:859 loss:0.691624 accu:0.578125 |xentropy_loss:0.936216 mutual_info_loss:0.914015
# epoch:860 loss:0.746667 accu:0.570312 |xentropy_loss:0.920265 mutual_info_loss:0.864711
# epoch:861 loss:0.784272 accu:0.523438 |xentropy_loss:0.936168 mutual_info_loss:0.873224
# epoch:862 loss:0.756001 accu:0.507812 |xentropy_loss:0.944337 mutual_info_loss:0.926743
# epoch:863 loss:0.760964 accu:0.578125 |xentropy_loss:0.893099 mutual_info_loss:0.831851
# epoch:864 loss:0.681216 accu:0.625000 |xentropy_loss:1.035611 mutual_info_loss:0.953456
# epoch:865 loss:0.724130 accu:0.546875 |xentropy_loss:0.886798 mutual_info_loss:0.850879
# epoch:866 loss:0.727757 accu:0.554688 |xentropy_loss:0.882851 mutual_info_loss:0.827125
# epoch:867 loss:0.710210 accu:0.554688 |xentropy_loss:0.998720 mutual_info_loss:0.916342
# epoch:868 loss:0.695966 accu:0.625000 |xentropy_loss:0.971770 mutual_info_loss:0.961236
# epoch:869 loss:0.694463 accu:0.609375 |xentropy_loss:0.903429 mutual_info_loss:0.886037
# epoch:870 loss:0.758292 accu:0.562500 |xentropy_loss:0.869903 mutual_info_loss:0.827057
# epoch:871 loss:0.744589 accu:0.523438 |xentropy_loss:0.889442 mutual_info_loss:0.874733
# epoch:872 loss:0.682323 accu:0.593750 |xentropy_loss:0.901619 mutual_info_loss:0.827792
# epoch:873 loss:0.718307 accu:0.562500 |xentropy_loss:0.943072 mutual_info_loss:0.912404
# epoch:874 loss:0.639712 accu:0.671875 |xentropy_loss:0.972430 mutual_info_loss:0.926849
# epoch:875 loss:0.776454 accu:0.570312 |xentropy_loss:0.977138 mutual_info_loss:0.894565
# epoch:876 loss:0.805747 accu:0.570312 |xentropy_loss:0.867965 mutual_info_loss:0.829476
# epoch:877 loss:0.723069 accu:0.609375 |xentropy_loss:1.073315 mutual_info_loss:0.982637
# epoch:878 loss:0.679570 accu:0.593750 |xentropy_loss:1.036110 mutual_info_loss:0.979111
# epoch:879 loss:0.713560 accu:0.562500 |xentropy_loss:0.993025 mutual_info_loss:0.949699
# epoch:880 loss:0.654839 accu:0.632812 |xentropy_loss:0.907064 mutual_info_loss:0.898802
# epoch:881 loss:0.661559 accu:0.656250 |xentropy_loss:1.056483 mutual_info_loss:0.900003
# epoch:882 loss:0.714732 accu:0.570312 |xentropy_loss:0.961418 mutual_info_loss:0.950176
# epoch:883 loss:0.685062 accu:0.585938 |xentropy_loss:0.975587 mutual_info_loss:0.962392
# epoch:884 loss:0.659199 accu:0.593750 |xentropy_loss:1.057303 mutual_info_loss:1.012213
# epoch:885 loss:0.658898 accu:0.601562 |xentropy_loss:0.945703 mutual_info_loss:0.904502
# epoch:886 loss:0.706939 accu:0.601562 |xentropy_loss:1.100246 mutual_info_loss:0.947698
# epoch:887 loss:0.657210 accu:0.617188 |xentropy_loss:1.096029 mutual_info_loss:1.074733
# epoch:888 loss:0.704166 accu:0.585938 |xentropy_loss:0.980445 mutual_info_loss:0.918869
# epoch:889 loss:0.647527 accu:0.648438 |xentropy_loss:1.042303 mutual_info_loss:1.036335
# epoch:890 loss:0.707739 accu:0.617188 |xentropy_loss:0.925037 mutual_info_loss:0.898339
# epoch:891 loss:0.632035 accu:0.625000 |xentropy_loss:1.059317 mutual_info_loss:0.953068
# epoch:892 loss:0.719943 accu:0.531250 |xentropy_loss:1.045223 mutual_info_loss:1.017316
# epoch:893 loss:0.626273 accu:0.601562 |xentropy_loss:1.051668 mutual_info_loss:1.015766
# epoch:894 loss:0.707409 accu:0.632812 |xentropy_loss:1.058847 mutual_info_loss:1.015786
# epoch:895 loss:0.642148 accu:0.625000 |xentropy_loss:1.008322 mutual_info_loss:0.987768
# epoch:896 loss:0.659660 accu:0.585938 |xentropy_loss:0.971718 mutual_info_loss:0.932985
# epoch:897 loss:0.694209 accu:0.554688 |xentropy_loss:0.985566 mutual_info_loss:0.974683
# epoch:898 loss:0.715929 accu:0.570312 |xentropy_loss:0.863878 mutual_info_loss:0.853399
# epoch:899 loss:0.704335 accu:0.585938 |xentropy_loss:0.925526 mutual_info_loss:0.869387
# epoch:900 loss:0.669783 accu:0.625000 |xentropy_loss:0.960644 mutual_info_loss:0.895482
# epoch:901 loss:0.639805 accu:0.625000 |xentropy_loss:0.943403 mutual_info_loss:0.877073
# epoch:902 loss:0.655851 accu:0.648438 |xentropy_loss:0.918597 mutual_info_loss:0.907452
# epoch:903 loss:0.714642 accu:0.593750 |xentropy_loss:0.983862 mutual_info_loss:0.914523
# epoch:904 loss:0.728482 accu:0.585938 |xentropy_loss:1.000803 mutual_info_loss:0.979417
# epoch:905 loss:0.674104 accu:0.617188 |xentropy_loss:0.879241 mutual_info_loss:0.830121
# epoch:906 loss:0.662474 accu:0.625000 |xentropy_loss:0.913392 mutual_info_loss:0.901517
# epoch:907 loss:0.708138 accu:0.585938 |xentropy_loss:0.964412 mutual_info_loss:0.926818
# epoch:908 loss:0.675814 accu:0.593750 |xentropy_loss:0.993631 mutual_info_loss:0.977260
# epoch:909 loss:0.700765 accu:0.617188 |xentropy_loss:0.926235 mutual_info_loss:0.858764
# epoch:910 loss:0.725261 accu:0.546875 |xentropy_loss:1.086218 mutual_info_loss:1.019567
# epoch:911 loss:0.669535 accu:0.648438 |xentropy_loss:1.046761 mutual_info_loss:1.025132
# epoch:912 loss:0.671938 accu:0.617188 |xentropy_loss:0.941332 mutual_info_loss:0.924602
# epoch:913 loss:0.690376 accu:0.617188 |xentropy_loss:0.915767 mutual_info_loss:0.871251
# epoch:914 loss:0.660216 accu:0.601562 |xentropy_loss:0.961963 mutual_info_loss:0.900099
# epoch:915 loss:0.663672 accu:0.617188 |xentropy_loss:0.847472 mutual_info_loss:0.833117
# epoch:916 loss:0.669253 accu:0.640625 |xentropy_loss:0.886035 mutual_info_loss:0.845702
# epoch:917 loss:0.638066 accu:0.679688 |xentropy_loss:1.018493 mutual_info_loss:0.963229
# epoch:918 loss:0.735733 accu:0.578125 |xentropy_loss:0.897113 mutual_info_loss:0.860925
# epoch:919 loss:0.703960 accu:0.570312 |xentropy_loss:0.926984 mutual_info_loss:0.909649
# epoch:920 loss:0.640660 accu:0.671875 |xentropy_loss:0.957568 mutual_info_loss:0.893533
# epoch:921 loss:0.679811 accu:0.578125 |xentropy_loss:0.962073 mutual_info_loss:0.932117
# epoch:922 loss:0.693819 accu:0.554688 |xentropy_loss:1.052697 mutual_info_loss:0.906456
# epoch:923 loss:0.637347 accu:0.570312 |xentropy_loss:1.077266 mutual_info_loss:0.954376
# epoch:924 loss:0.698496 accu:0.539062 |xentropy_loss:0.941320 mutual_info_loss:0.873862
# epoch:925 loss:0.702494 accu:0.609375 |xentropy_loss:0.918113 mutual_info_loss:0.894505
# epoch:926 loss:0.691691 accu:0.585938 |xentropy_loss:0.914651 mutual_info_loss:0.883640
# epoch:927 loss:0.677914 accu:0.679688 |xentropy_loss:1.124135 mutual_info_loss:1.006548
# epoch:928 loss:0.659771 accu:0.632812 |xentropy_loss:0.941507 mutual_info_loss:0.892807
# epoch:929 loss:0.646487 accu:0.640625 |xentropy_loss:0.961075 mutual_info_loss:0.949405
# epoch:930 loss:0.724263 accu:0.585938 |xentropy_loss:0.920119 mutual_info_loss:0.903226
# epoch:931 loss:0.687530 accu:0.609375 |xentropy_loss:0.955311 mutual_info_loss:0.918535
# epoch:932 loss:0.722291 accu:0.578125 |xentropy_loss:0.987487 mutual_info_loss:0.912980
# epoch:933 loss:0.658279 accu:0.656250 |xentropy_loss:0.962109 mutual_info_loss:0.911996
# epoch:934 loss:0.646388 accu:0.625000 |xentropy_loss:0.969410 mutual_info_loss:0.899265
# epoch:935 loss:0.690495 accu:0.632812 |xentropy_loss:0.933176 mutual_info_loss:0.890757
# epoch:936 loss:0.672792 accu:0.625000 |xentropy_loss:0.994778 mutual_info_loss:0.979152
# epoch:937 loss:0.695262 accu:0.601562 |xentropy_loss:1.000382 mutual_info_loss:0.986848
# epoch:938 loss:0.658863 accu:0.609375 |xentropy_loss:1.000609 mutual_info_loss:0.950787
# epoch:939 loss:0.697609 accu:0.625000 |xentropy_loss:0.916763 mutual_info_loss:0.879104
# epoch:940 loss:0.683614 accu:0.578125 |xentropy_loss:0.927109 mutual_info_loss:0.882510
# epoch:941 loss:0.707134 accu:0.609375 |xentropy_loss:0.841211 mutual_info_loss:0.828642
# epoch:942 loss:0.698400 accu:0.640625 |xentropy_loss:0.885485 mutual_info_loss:0.868445
# epoch:943 loss:0.721342 accu:0.562500 |xentropy_loss:0.965723 mutual_info_loss:0.909457
# epoch:944 loss:0.703303 accu:0.593750 |xentropy_loss:0.965702 mutual_info_loss:0.933349
# epoch:945 loss:0.701156 accu:0.609375 |xentropy_loss:1.089261 mutual_info_loss:0.986134
# epoch:946 loss:0.700064 accu:0.585938 |xentropy_loss:0.970364 mutual_info_loss:0.877660
# epoch:947 loss:0.686625 accu:0.609375 |xentropy_loss:0.979049 mutual_info_loss:0.940773
# epoch:948 loss:0.714077 accu:0.554688 |xentropy_loss:0.923266 mutual_info_loss:0.905026
# epoch:949 loss:0.694335 accu:0.570312 |xentropy_loss:0.999085 mutual_info_loss:0.932918
# epoch:950 loss:0.731926 accu:0.570312 |xentropy_loss:1.035846 mutual_info_loss:0.965930
# epoch:951 loss:0.688354 accu:0.593750 |xentropy_loss:0.957732 mutual_info_loss:0.905726
# epoch:952 loss:0.694808 accu:0.601562 |xentropy_loss:0.972502 mutual_info_loss:0.942115
# epoch:953 loss:0.706954 accu:0.578125 |xentropy_loss:0.858912 mutual_info_loss:0.849679
# epoch:954 loss:0.660592 accu:0.609375 |xentropy_loss:1.011859 mutual_info_loss:0.924526
# epoch:955 loss:0.697488 accu:0.601562 |xentropy_loss:0.943182 mutual_info_loss:0.892976
# epoch:956 loss:0.707475 accu:0.578125 |xentropy_loss:0.943672 mutual_info_loss:0.895339
# epoch:957 loss:0.665249 accu:0.625000 |xentropy_loss:0.979898 mutual_info_loss:0.958934
# epoch:958 loss:0.684167 accu:0.632812 |xentropy_loss:0.867974 mutual_info_loss:0.859776
# epoch:959 loss:0.703124 accu:0.625000 |xentropy_loss:1.001660 mutual_info_loss:0.914777
# epoch:960 loss:0.658676 accu:0.585938 |xentropy_loss:0.942031 mutual_info_loss:0.910996
# epoch:961 loss:0.695817 accu:0.585938 |xentropy_loss:1.060438 mutual_info_loss:1.007403
# epoch:962 loss:0.700851 accu:0.625000 |xentropy_loss:0.951042 mutual_info_loss:0.910304
# epoch:963 loss:0.674755 accu:0.640625 |xentropy_loss:0.949747 mutual_info_loss:0.914793
# epoch:964 loss:0.679958 accu:0.578125 |xentropy_loss:0.925790 mutual_info_loss:0.902305
# epoch:965 loss:0.683323 accu:0.593750 |xentropy_loss:1.053073 mutual_info_loss:0.977615
# epoch:966 loss:0.645892 accu:0.632812 |xentropy_loss:1.112227 mutual_info_loss:1.052062
# epoch:967 loss:0.676390 accu:0.625000 |xentropy_loss:0.991696 mutual_info_loss:0.960777
# epoch:968 loss:0.723669 accu:0.546875 |xentropy_loss:0.950119 mutual_info_loss:0.905558
# epoch:969 loss:0.636917 accu:0.679688 |xentropy_loss:0.950393 mutual_info_loss:0.898768
# epoch:970 loss:0.669842 accu:0.601562 |xentropy_loss:0.953883 mutual_info_loss:0.931798
# epoch:971 loss:0.674325 accu:0.632812 |xentropy_loss:0.909123 mutual_info_loss:0.880720
# epoch:972 loss:0.706417 accu:0.554688 |xentropy_loss:0.982113 mutual_info_loss:0.916464
# epoch:973 loss:0.748758 accu:0.570312 |xentropy_loss:0.839894 mutual_info_loss:0.805803
# epoch:974 loss:0.741868 accu:0.546875 |xentropy_loss:0.907065 mutual_info_loss:0.874924
# epoch:975 loss:0.702466 accu:0.593750 |xentropy_loss:1.000092 mutual_info_loss:0.968495
# epoch:976 loss:0.732188 accu:0.593750 |xentropy_loss:0.883475 mutual_info_loss:0.857285
# epoch:977 loss:0.658758 accu:0.671875 |xentropy_loss:0.957385 mutual_info_loss:0.895914
# epoch:978 loss:0.688109 accu:0.625000 |xentropy_loss:0.967704 mutual_info_loss:0.897180
# epoch:979 loss:0.690852 accu:0.617188 |xentropy_loss:0.936272 mutual_info_loss:0.909571
# epoch:980 loss:0.629717 accu:0.648438 |xentropy_loss:0.966541 mutual_info_loss:0.932086
# epoch:981 loss:0.645404 accu:0.625000 |xentropy_loss:0.907335 mutual_info_loss:0.878576
# epoch:982 loss:0.685259 accu:0.578125 |xentropy_loss:0.936411 mutual_info_loss:0.899418
# epoch:983 loss:0.638979 accu:0.648438 |xentropy_loss:1.028042 mutual_info_loss:0.943547
# epoch:984 loss:0.705100 accu:0.609375 |xentropy_loss:1.072753 mutual_info_loss:0.995580
# epoch:985 loss:0.708404 accu:0.578125 |xentropy_loss:1.016833 mutual_info_loss:0.936085
# epoch:986 loss:0.694461 accu:0.601562 |xentropy_loss:1.075900 mutual_info_loss:0.980425
# epoch:987 loss:0.695836 accu:0.609375 |xentropy_loss:0.958884 mutual_info_loss:0.920675
# epoch:988 loss:0.637230 accu:0.664062 |xentropy_loss:0.998140 mutual_info_loss:0.964361
# epoch:989 loss:0.686911 accu:0.585938 |xentropy_loss:0.923108 mutual_info_loss:0.891578
# epoch:990 loss:0.720463 accu:0.578125 |xentropy_loss:0.925284 mutual_info_loss:0.907029
# epoch:991 loss:0.689294 accu:0.609375 |xentropy_loss:0.912100 mutual_info_loss:0.903967
# epoch:992 loss:0.661086 accu:0.585938 |xentropy_loss:0.946071 mutual_info_loss:0.904227
# epoch:993 loss:0.685869 accu:0.546875 |xentropy_loss:0.871308 mutual_info_loss:0.861697
# epoch:994 loss:0.689133 accu:0.546875 |xentropy_loss:0.917519 mutual_info_loss:0.824518
# epoch:995 loss:0.725135 accu:0.562500 |xentropy_loss:0.852245 mutual_info_loss:0.829715
# epoch:996 loss:0.687175 accu:0.648438 |xentropy_loss:0.893689 mutual_info_loss:0.885350
# epoch:997 loss:0.685410 accu:0.585938 |xentropy_loss:0.848264 mutual_info_loss:0.838696
# epoch:998 loss:0.703714 accu:0.515625 |xentropy_loss:0.925433 mutual_info_loss:0.881388
# epoch:999 loss:0.682904 accu:0.578125 |xentropy_loss:0.896473 mutual_info_loss:0.850382
# epoch:1000 loss:0.723452 accu:0.578125 |xentropy_loss:0.910663 mutual_info_loss:0.892499

# %%
X_A.shape
# Out:
# (30000, 784)

# %%
real_labels.shape
# Out:
# (64, 1)

# %%
gc.collect()

# %%
gc.collect()
