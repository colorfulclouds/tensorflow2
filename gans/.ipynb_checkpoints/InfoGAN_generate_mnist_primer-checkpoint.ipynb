# %%
from keras.models import Sequential , Model
from keras.layers import Dense ,  BatchNormalization , Reshape , Input , Flatten
from keras.layers import Conv2D , MaxPool2D , Conv2DTranspose , UpSampling2D , ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU , PReLU
from keras.layers import Activation
from keras.layers import Dropout

from keras.layers import Concatenate

#addin cycleGAN 使用instance-norm
from keras_contrib.layers.normalization import InstanceNormalization

from keras.initializers import truncated_normal , constant , random_normal

from keras.optimizers import Adam , RMSprop

from keras.datasets import mnist

from keras.utils import to_categorical
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import os

import matplotlib as plt
import numpy as np

import gc

from glob import glob

import keras.backend as K

import scipy

# %matplotlib inline

# %%
WIDTH = 28
HEIGHT = 28
CHANNEL = 1

SHAPE = (WIDTH , HEIGHT , CHANNEL)

BATCH_SIZE = 64
EPOCHS = 10

#生成多少个图像 长*宽
ROW = 2
COL = 2

LATENT_DIM = 72 #infogan中变为72维
CLASSES_NUM = 10 #mnist一共10中类别

# %%
(X_train , y_train),(_ , _) = mnist.load_data()
X_train = X_train/127.5-1
X_train = np.expand_dims(X_train , 3)
y_train = y_train.reshape(-1 , 1)
y_train = to_categorical(y_train , num_classes=CLASSES_NUM)

# %%
def load_mnist(batch_size = BATCH_SIZE):
    idx = np.random.randint(0 , X_train.shape[0] ,batch_size)
    return X_train[idx] , y_train[idx]
    
def write_image_mnist(epoch):
    
    z = np.random.normal(0 , 1 , size=(ROW * COL , LATENT_DIM-CLASSES_NUM))
    c = np.random.randint(0 , high=CLASSES_NUM , size=(ROW*COL , 1))
    c_one_hot = to_categorical(c , num_classes=CLASSES_NUM)
    
    G_input = np.concatenate((z , c_one_hot) , axis = 1)
    
    imgs = generator_i.predict(G_input)
    
    imgs = imgs*0.5+0.5
    
    fig , axes = plt.pyplot.subplots(ROW , COL)
    
    axes[0][0].imshow(imgs[0,:,:,0] , cmap='gray')
    axes[0][0].set_title('%d' % (c[0]))
    axes[0][0].axis('off')

    axes[0][1].imshow(imgs[1,:,:,0] , cmap='gray')
    axes[0][1].set_title('%d' % (c[1]))
    axes[0][1].axis('off')
    
    axes[1][0].imshow(imgs[2,:,:,0] , cmap='gray')
    axes[1][0].set_title('%d' % (c[2]))
    axes[1][0].axis('off')

    axes[1][1].imshow(imgs[3,:,:,0] , cmap='gray')
    axes[1][1].set_title('%d' % (c[3]))
    axes[1][1].axis('off')

    fig.savefig('mnist_infogan/No.%d.png' % epoch)
    plt.pyplot.close()

# %%
def generator():
    z = Input(shape=(LATENT_DIM , )) #输入一个风格的图像 生成另一个风格的图像
    
    model = Sequential()

    model.add(Dense(128 * 7 * 7, activation="relu", input_shape=(LATENT_DIM , )))
    model.add(Reshape((7, 7, 128)))
    model.add(BatchNormalization(momentum=0.8))
    model.add(UpSampling2D())
    model.add(Conv2D(128, kernel_size=3, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(UpSampling2D())
    model.add(Conv2D(64, kernel_size=3, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(CHANNEL, kernel_size=3, padding="same"))
    model.add(Activation("tanh"))
    
    img = model(z)
    
    return Model(z , img)

# %%
def discriminator():
    img = Input(shape=SHAPE)
    
    model = Sequential()

    model.add(Conv2D(64, kernel_size=3, strides=2, input_shape=SHAPE , padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(256, kernel_size=3, strides=2, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(512, kernel_size=3, strides=2, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Flatten())
    
    feature = model(img)
   
    validity = Dense(1 , activation='sigmoid')(feature)
    
    q_net = Dense(units=128 , activation='relu')(feature)
    labels = Dense(CLASSES_NUM , activation='softmax')(q_net) #加1 因为多出来一个不存在的label 来代替fake的label
        
    return Model(img , validity) , Model(img , labels)

# %%
#给Q-NET使用的互信息损失
def mutual_info_loss(c , c_x):
    epsilon = 1e-8
    
    x_entropy = K.mean(-K.sum(c*K.log(c_x+epsilon)))
    entropy = K.mean(-K.sum(c*K.log(c+epsilon)))
    
    return x_entropy + entropy

# %%
adam = Adam(lr = 0.0002 , beta_1=0.5)
#构建计算图
D , Q = discriminator()

D.compile(optimizer = adam , loss='binary_crossentropy' , metrics=['accuracy'])
Q.compile(optimizer = adam , loss=mutual_info_loss , metrics=['accuracy'])

generator_i = generator()

z = Input(shape=(LATENT_DIM , ))
img = generator_i(z)

#freeze D
D.trainable = False

validity = D(img)
labels = Q(img)

combined = Model(z , [validity , labels])
combined.compile(optimizer=adam , loss=['binary_crossentropy' , mutual_info_loss])

# %%
def train():
    real_labels = np.ones(shape=(BATCH_SIZE , 1))
    fake_labels = np.zeros(shape=(BATCH_SIZE , 1))

    for i in range(1001):
        X_train , y_train = load_mnist()
        
        z = np.random.normal(0 , 1 , (BATCH_SIZE , LATENT_DIM-CLASSES_NUM)) #一定要减去 变为62 因为后面需要和隐藏编码c concatenate 一下
        c = np.random.randint(0 , CLASSES_NUM , size=(BATCH_SIZE , 1)) #隐藏编码c
        c = to_categorical(c , num_classes=CLASSES_NUM)
        
        G_input = np.concatenate((z , c) , axis = 1)

        img = generator_i.predict(G_input)
        #训练判别器
        real_loss = D.train_on_batch(X_train , real_labels  )
        fake_loss = D.train_on_batch(img , fake_labels )
        
        loss = np.add(real_loss , fake_loss)/2

        #训练生成器
        generator_loss = combined.train_on_batch(G_input , [real_labels , c])

        print('epoch:%d loss:%f accu:%f |xentropy_loss:%f mutual_info_loss:%f' % (i , loss[0] , loss[1] , generator_loss[0] , generator_loss[1]))

        if i % 50 == 0:
            write_image_mnist(i)

    write_image_mnist(999)

# %%
train()
# Out:
# C:\Anaconda3\lib\site-packages\keras\engine\training.py:479: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# epoch:0 loss:1.453244 accu:0.312500 |xentropy_loss:194.964401 mutual_info_loss:0.702166
# epoch:1 loss:0.697662 accu:0.648438 |xentropy_loss:185.331161 mutual_info_loss:1.461353
# epoch:2 loss:0.300386 accu:0.875000 |xentropy_loss:200.293365 mutual_info_loss:2.542433
# epoch:3 loss:0.193046 accu:0.953125 |xentropy_loss:178.210068 mutual_info_loss:3.078330
# epoch:4 loss:0.166678 accu:0.945312 |xentropy_loss:185.508011 mutual_info_loss:3.348593
# epoch:5 loss:0.147102 accu:0.937500 |xentropy_loss:171.259491 mutual_info_loss:3.639608
# epoch:6 loss:0.115704 accu:0.984375 |xentropy_loss:179.104614 mutual_info_loss:3.811452
# epoch:7 loss:0.072813 accu:0.984375 |xentropy_loss:169.574921 mutual_info_loss:4.354710
# epoch:8 loss:0.049793 accu:0.984375 |xentropy_loss:171.637314 mutual_info_loss:4.615820
# epoch:9 loss:0.033696 accu:0.992188 |xentropy_loss:182.234589 mutual_info_loss:4.557958
# epoch:10 loss:0.035176 accu:1.000000 |xentropy_loss:179.604004 mutual_info_loss:4.936716
# epoch:11 loss:0.029306 accu:0.992188 |xentropy_loss:182.353683 mutual_info_loss:5.015503
# epoch:12 loss:0.022506 accu:1.000000 |xentropy_loss:163.091248 mutual_info_loss:5.169487
# epoch:13 loss:0.021615 accu:1.000000 |xentropy_loss:172.432358 mutual_info_loss:4.797230
# epoch:14 loss:0.018248 accu:1.000000 |xentropy_loss:177.325134 mutual_info_loss:5.540735
# epoch:15 loss:0.029320 accu:0.992188 |xentropy_loss:169.350784 mutual_info_loss:5.736081
# epoch:16 loss:0.023930 accu:1.000000 |xentropy_loss:169.048462 mutual_info_loss:5.743690
# epoch:17 loss:0.019982 accu:1.000000 |xentropy_loss:157.242935 mutual_info_loss:5.305103
# epoch:18 loss:0.009644 accu:1.000000 |xentropy_loss:158.563950 mutual_info_loss:5.860089
# epoch:19 loss:0.021910 accu:1.000000 |xentropy_loss:151.724960 mutual_info_loss:6.068048
# epoch:20 loss:0.010167 accu:1.000000 |xentropy_loss:154.316803 mutual_info_loss:5.932444
# epoch:21 loss:0.010497 accu:1.000000 |xentropy_loss:159.126068 mutual_info_loss:5.919730
# epoch:22 loss:0.013665 accu:1.000000 |xentropy_loss:163.607468 mutual_info_loss:6.107742
# epoch:23 loss:0.007431 accu:1.000000 |xentropy_loss:165.703278 mutual_info_loss:6.059203
# epoch:24 loss:0.018812 accu:1.000000 |xentropy_loss:149.463791 mutual_info_loss:5.390470
# epoch:25 loss:0.008410 accu:1.000000 |xentropy_loss:155.245438 mutual_info_loss:6.478626
# epoch:26 loss:0.013124 accu:1.000000 |xentropy_loss:159.754959 mutual_info_loss:6.045046
# epoch:27 loss:0.005327 accu:1.000000 |xentropy_loss:153.267029 mutual_info_loss:5.817665
# epoch:28 loss:0.012866 accu:1.000000 |xentropy_loss:149.776535 mutual_info_loss:5.663953
# epoch:29 loss:0.013795 accu:1.000000 |xentropy_loss:155.041748 mutual_info_loss:5.291917
# epoch:30 loss:0.011288 accu:1.000000 |xentropy_loss:146.501755 mutual_info_loss:6.339557
# epoch:31 loss:0.007946 accu:1.000000 |xentropy_loss:150.420578 mutual_info_loss:6.061844
# epoch:32 loss:0.010522 accu:1.000000 |xentropy_loss:149.850861 mutual_info_loss:6.383818
# epoch:33 loss:0.010079 accu:1.000000 |xentropy_loss:147.293350 mutual_info_loss:5.896030
# epoch:34 loss:0.010327 accu:1.000000 |xentropy_loss:145.968735 mutual_info_loss:6.046004
# epoch:35 loss:0.010284 accu:1.000000 |xentropy_loss:145.858536 mutual_info_loss:5.793677
# epoch:36 loss:0.009060 accu:1.000000 |xentropy_loss:125.803970 mutual_info_loss:6.055047
# epoch:37 loss:0.004342 accu:1.000000 |xentropy_loss:137.514267 mutual_info_loss:6.377028
# epoch:38 loss:0.007954 accu:1.000000 |xentropy_loss:136.833160 mutual_info_loss:6.253686
# epoch:39 loss:0.004457 accu:1.000000 |xentropy_loss:141.019058 mutual_info_loss:6.140484
# epoch:40 loss:0.006348 accu:1.000000 |xentropy_loss:133.468018 mutual_info_loss:6.029437
# epoch:41 loss:0.008005 accu:1.000000 |xentropy_loss:129.382111 mutual_info_loss:6.012130
# epoch:42 loss:0.008379 accu:1.000000 |xentropy_loss:129.130524 mutual_info_loss:6.196595
# epoch:43 loss:0.004401 accu:1.000000 |xentropy_loss:126.285629 mutual_info_loss:6.144378
# epoch:44 loss:0.005398 accu:1.000000 |xentropy_loss:123.928886 mutual_info_loss:6.119034
# epoch:45 loss:0.005949 accu:1.000000 |xentropy_loss:127.829697 mutual_info_loss:6.153334
# epoch:46 loss:0.006653 accu:1.000000 |xentropy_loss:131.514801 mutual_info_loss:6.029436
# epoch:47 loss:0.005175 accu:1.000000 |xentropy_loss:106.845955 mutual_info_loss:6.060050
# epoch:48 loss:0.005243 accu:1.000000 |xentropy_loss:108.935081 mutual_info_loss:6.108713
# epoch:49 loss:0.004783 accu:1.000000 |xentropy_loss:100.357010 mutual_info_loss:5.921416
# epoch:50 loss:0.007316 accu:1.000000 |xentropy_loss:96.688263 mutual_info_loss:5.991333
# epoch:51 loss:0.004503 accu:1.000000 |xentropy_loss:110.306007 mutual_info_loss:5.687380
# epoch:52 loss:0.015860 accu:0.992188 |xentropy_loss:115.623726 mutual_info_loss:5.532417
# epoch:53 loss:0.004171 accu:1.000000 |xentropy_loss:91.312210 mutual_info_loss:5.982491
# epoch:54 loss:0.007911 accu:1.000000 |xentropy_loss:99.781700 mutual_info_loss:6.139503
# epoch:55 loss:0.010431 accu:1.000000 |xentropy_loss:92.588829 mutual_info_loss:6.267944
# epoch:56 loss:0.004674 accu:1.000000 |xentropy_loss:91.609665 mutual_info_loss:6.169373
# epoch:57 loss:0.003581 accu:1.000000 |xentropy_loss:91.189026 mutual_info_loss:6.547016
# epoch:58 loss:0.005278 accu:1.000000 |xentropy_loss:82.494781 mutual_info_loss:6.184810
# epoch:59 loss:0.006221 accu:1.000000 |xentropy_loss:58.559109 mutual_info_loss:5.854099
# epoch:60 loss:0.003385 accu:1.000000 |xentropy_loss:63.569225 mutual_info_loss:6.195189
# epoch:61 loss:0.004893 accu:1.000000 |xentropy_loss:72.182503 mutual_info_loss:6.049792
# epoch:62 loss:0.003739 accu:1.000000 |xentropy_loss:47.591930 mutual_info_loss:5.975551
# epoch:63 loss:0.007501 accu:1.000000 |xentropy_loss:66.039154 mutual_info_loss:6.169221
# epoch:64 loss:0.003798 accu:1.000000 |xentropy_loss:47.930130 mutual_info_loss:6.165328
# epoch:65 loss:0.005835 accu:1.000000 |xentropy_loss:60.858612 mutual_info_loss:5.984826
# epoch:66 loss:0.008822 accu:1.000000 |xentropy_loss:48.354607 mutual_info_loss:6.112806
# epoch:67 loss:0.002756 accu:1.000000 |xentropy_loss:45.996330 mutual_info_loss:6.174129
# epoch:68 loss:0.003515 accu:1.000000 |xentropy_loss:34.906658 mutual_info_loss:6.104309
# epoch:69 loss:0.003535 accu:1.000000 |xentropy_loss:43.241318 mutual_info_loss:6.274239
# epoch:70 loss:0.012865 accu:1.000000 |xentropy_loss:40.252197 mutual_info_loss:6.125512
# epoch:71 loss:0.003279 accu:1.000000 |xentropy_loss:37.232452 mutual_info_loss:6.213807
# epoch:72 loss:0.004622 accu:1.000000 |xentropy_loss:28.497349 mutual_info_loss:6.343460
# epoch:73 loss:0.005666 accu:1.000000 |xentropy_loss:40.507542 mutual_info_loss:5.971549
# epoch:74 loss:0.003298 accu:1.000000 |xentropy_loss:30.982918 mutual_info_loss:6.193066
# epoch:75 loss:0.007253 accu:1.000000 |xentropy_loss:23.378609 mutual_info_loss:5.737762
# epoch:76 loss:0.001929 accu:1.000000 |xentropy_loss:26.424175 mutual_info_loss:6.238049
# epoch:77 loss:0.002306 accu:1.000000 |xentropy_loss:21.420956 mutual_info_loss:6.236743
# epoch:78 loss:0.004820 accu:1.000000 |xentropy_loss:28.398750 mutual_info_loss:5.621380
# epoch:79 loss:0.007568 accu:1.000000 |xentropy_loss:22.618498 mutual_info_loss:5.664494
# epoch:80 loss:0.006079 accu:1.000000 |xentropy_loss:24.922607 mutual_info_loss:5.915874
# epoch:81 loss:0.004429 accu:1.000000 |xentropy_loss:31.937939 mutual_info_loss:6.034791
# epoch:82 loss:0.002497 accu:1.000000 |xentropy_loss:20.769293 mutual_info_loss:6.132148
# epoch:83 loss:0.001947 accu:1.000000 |xentropy_loss:17.733522 mutual_info_loss:6.469285
# epoch:84 loss:0.002569 accu:1.000000 |xentropy_loss:18.780766 mutual_info_loss:6.254419
# epoch:85 loss:0.006335 accu:1.000000 |xentropy_loss:17.898140 mutual_info_loss:5.698619
# epoch:86 loss:0.003149 accu:1.000000 |xentropy_loss:10.040232 mutual_info_loss:6.256027
# epoch:87 loss:0.004930 accu:1.000000 |xentropy_loss:11.523396 mutual_info_loss:5.666233
# epoch:88 loss:0.005054 accu:1.000000 |xentropy_loss:13.245117 mutual_info_loss:6.111594
# epoch:89 loss:0.002280 accu:1.000000 |xentropy_loss:12.590914 mutual_info_loss:5.913944
# epoch:90 loss:0.006667 accu:1.000000 |xentropy_loss:13.515345 mutual_info_loss:5.582384
# epoch:91 loss:0.004344 accu:1.000000 |xentropy_loss:16.108307 mutual_info_loss:5.857580
# epoch:92 loss:0.003614 accu:1.000000 |xentropy_loss:11.229563 mutual_info_loss:5.945180
# epoch:93 loss:0.001996 accu:1.000000 |xentropy_loss:9.389690 mutual_info_loss:6.039533
# epoch:94 loss:0.005685 accu:1.000000 |xentropy_loss:12.092136 mutual_info_loss:6.032244
# epoch:95 loss:0.004194 accu:1.000000 |xentropy_loss:14.108487 mutual_info_loss:6.042083
# epoch:96 loss:0.003649 accu:1.000000 |xentropy_loss:21.581364 mutual_info_loss:6.539426
# epoch:97 loss:0.003460 accu:1.000000 |xentropy_loss:13.902529 mutual_info_loss:6.148232
# epoch:98 loss:0.003184 accu:1.000000 |xentropy_loss:13.099068 mutual_info_loss:5.838982
# epoch:99 loss:0.003482 accu:1.000000 |xentropy_loss:11.685228 mutual_info_loss:6.256062
# epoch:100 loss:0.002684 accu:1.000000 |xentropy_loss:10.304833 mutual_info_loss:6.126686
# epoch:101 loss:0.005039 accu:1.000000 |xentropy_loss:7.844625 mutual_info_loss:5.861578
# epoch:102 loss:0.008356 accu:1.000000 |xentropy_loss:10.240515 mutual_info_loss:5.744391
# epoch:103 loss:0.002913 accu:1.000000 |xentropy_loss:9.498930 mutual_info_loss:6.386139
# epoch:104 loss:0.004789 accu:1.000000 |xentropy_loss:11.426422 mutual_info_loss:5.973050
# epoch:105 loss:0.003521 accu:1.000000 |xentropy_loss:14.433223 mutual_info_loss:5.701424
# epoch:106 loss:0.002316 accu:1.000000 |xentropy_loss:10.223568 mutual_info_loss:6.017028
# epoch:107 loss:0.003045 accu:1.000000 |xentropy_loss:7.714448 mutual_info_loss:5.993619
# epoch:108 loss:0.002313 accu:1.000000 |xentropy_loss:7.251972 mutual_info_loss:5.651701
# epoch:109 loss:0.004217 accu:1.000000 |xentropy_loss:9.636157 mutual_info_loss:5.785294
# epoch:110 loss:0.005966 accu:1.000000 |xentropy_loss:8.109545 mutual_info_loss:5.946654
# epoch:111 loss:0.007364 accu:1.000000 |xentropy_loss:8.644949 mutual_info_loss:6.133410
# epoch:112 loss:0.002154 accu:1.000000 |xentropy_loss:9.399940 mutual_info_loss:6.109172
# epoch:113 loss:0.003083 accu:1.000000 |xentropy_loss:8.318286 mutual_info_loss:6.424241
# epoch:114 loss:0.003287 accu:1.000000 |xentropy_loss:14.250345 mutual_info_loss:6.674667
# epoch:115 loss:0.006187 accu:1.000000 |xentropy_loss:8.457613 mutual_info_loss:6.338064
# epoch:116 loss:0.004209 accu:1.000000 |xentropy_loss:8.558574 mutual_info_loss:6.105381
# epoch:117 loss:0.003541 accu:1.000000 |xentropy_loss:7.981234 mutual_info_loss:6.026443
# epoch:118 loss:0.003869 accu:1.000000 |xentropy_loss:14.132650 mutual_info_loss:5.974000
# epoch:119 loss:0.003971 accu:1.000000 |xentropy_loss:8.791174 mutual_info_loss:6.295326
# epoch:120 loss:0.003294 accu:1.000000 |xentropy_loss:7.811638 mutual_info_loss:6.248724
# epoch:121 loss:0.002949 accu:1.000000 |xentropy_loss:8.298663 mutual_info_loss:6.156469
# epoch:122 loss:0.004436 accu:1.000000 |xentropy_loss:7.349604 mutual_info_loss:6.088688
# epoch:123 loss:0.003032 accu:1.000000 |xentropy_loss:7.718767 mutual_info_loss:6.604566
# epoch:124 loss:0.005151 accu:1.000000 |xentropy_loss:9.498750 mutual_info_loss:6.437141
# epoch:125 loss:0.002107 accu:1.000000 |xentropy_loss:12.059080 mutual_info_loss:6.381907
# epoch:126 loss:0.003055 accu:1.000000 |xentropy_loss:9.237322 mutual_info_loss:6.245728
# epoch:127 loss:0.002295 accu:1.000000 |xentropy_loss:9.921811 mutual_info_loss:6.138950
# epoch:128 loss:0.004257 accu:1.000000 |xentropy_loss:10.487026 mutual_info_loss:6.294469
# epoch:129 loss:0.002889 accu:1.000000 |xentropy_loss:7.867546 mutual_info_loss:6.115251
# epoch:130 loss:0.002835 accu:1.000000 |xentropy_loss:9.327896 mutual_info_loss:5.865627
# epoch:131 loss:0.004102 accu:1.000000 |xentropy_loss:8.345815 mutual_info_loss:6.477392
# epoch:132 loss:0.004529 accu:1.000000 |xentropy_loss:6.802771 mutual_info_loss:6.145351
# epoch:133 loss:0.000946 accu:1.000000 |xentropy_loss:8.837025 mutual_info_loss:6.163567
# epoch:134 loss:0.002560 accu:1.000000 |xentropy_loss:11.114294 mutual_info_loss:6.009006
# epoch:135 loss:0.004349 accu:1.000000 |xentropy_loss:7.148972 mutual_info_loss:6.306552
# epoch:136 loss:0.004119 accu:1.000000 |xentropy_loss:7.192585 mutual_info_loss:6.437716
# epoch:137 loss:0.004757 accu:1.000000 |xentropy_loss:7.059466 mutual_info_loss:6.505527
# epoch:138 loss:0.003103 accu:1.000000 |xentropy_loss:12.023684 mutual_info_loss:6.300484
# epoch:139 loss:0.002100 accu:1.000000 |xentropy_loss:7.648878 mutual_info_loss:6.524022
# epoch:140 loss:0.002575 accu:1.000000 |xentropy_loss:6.980823 mutual_info_loss:6.328270
# epoch:141 loss:0.004865 accu:1.000000 |xentropy_loss:8.004533 mutual_info_loss:6.021564
# epoch:142 loss:0.002711 accu:1.000000 |xentropy_loss:7.171738 mutual_info_loss:6.275163
# epoch:143 loss:0.002129 accu:1.000000 |xentropy_loss:8.064287 mutual_info_loss:6.369432
# epoch:144 loss:0.006041 accu:1.000000 |xentropy_loss:10.851850 mutual_info_loss:6.564172
# epoch:145 loss:0.002314 accu:1.000000 |xentropy_loss:9.308249 mutual_info_loss:6.453472
# epoch:146 loss:0.002137 accu:1.000000 |xentropy_loss:7.155106 mutual_info_loss:6.373914
# epoch:147 loss:0.001863 accu:1.000000 |xentropy_loss:6.409954 mutual_info_loss:5.729886
# epoch:148 loss:0.005349 accu:1.000000 |xentropy_loss:6.852485 mutual_info_loss:6.036436
# epoch:149 loss:0.003371 accu:1.000000 |xentropy_loss:6.797490 mutual_info_loss:6.249814
# epoch:150 loss:0.002050 accu:1.000000 |xentropy_loss:6.873696 mutual_info_loss:6.254231
# epoch:151 loss:0.002939 accu:1.000000 |xentropy_loss:7.824333 mutual_info_loss:5.933143
# epoch:152 loss:0.006360 accu:1.000000 |xentropy_loss:7.349116 mutual_info_loss:6.409064
# epoch:153 loss:0.001896 accu:1.000000 |xentropy_loss:6.728454 mutual_info_loss:6.462534
# epoch:154 loss:0.002729 accu:1.000000 |xentropy_loss:7.799891 mutual_info_loss:6.763536
# epoch:155 loss:0.004300 accu:1.000000 |xentropy_loss:7.224597 mutual_info_loss:6.434993
# epoch:156 loss:0.001478 accu:1.000000 |xentropy_loss:6.802523 mutual_info_loss:6.291472
# epoch:157 loss:0.002648 accu:1.000000 |xentropy_loss:6.182681 mutual_info_loss:5.883106
# epoch:158 loss:0.003821 accu:1.000000 |xentropy_loss:6.381660 mutual_info_loss:5.953459
# epoch:159 loss:0.002196 accu:1.000000 |xentropy_loss:7.166868 mutual_info_loss:6.188757
# epoch:160 loss:0.002862 accu:1.000000 |xentropy_loss:6.752179 mutual_info_loss:6.268506
# epoch:161 loss:0.003287 accu:1.000000 |xentropy_loss:6.628667 mutual_info_loss:6.081690
# epoch:162 loss:0.004751 accu:1.000000 |xentropy_loss:8.878389 mutual_info_loss:6.681479
# epoch:163 loss:0.001733 accu:1.000000 |xentropy_loss:7.322821 mutual_info_loss:6.208534
# epoch:164 loss:0.003683 accu:1.000000 |xentropy_loss:8.807476 mutual_info_loss:6.350062
# epoch:165 loss:0.003405 accu:1.000000 |xentropy_loss:6.629176 mutual_info_loss:6.300487
# epoch:166 loss:0.001826 accu:1.000000 |xentropy_loss:7.766494 mutual_info_loss:6.560408
# epoch:167 loss:0.002193 accu:1.000000 |xentropy_loss:7.783900 mutual_info_loss:6.520356
# epoch:168 loss:0.002003 accu:1.000000 |xentropy_loss:7.720626 mutual_info_loss:6.187846
# epoch:169 loss:0.003467 accu:1.000000 |xentropy_loss:7.911720 mutual_info_loss:6.173444
# epoch:170 loss:0.004351 accu:1.000000 |xentropy_loss:7.653833 mutual_info_loss:6.361420
# epoch:171 loss:0.005446 accu:1.000000 |xentropy_loss:7.046667 mutual_info_loss:6.245224
# epoch:172 loss:0.002954 accu:1.000000 |xentropy_loss:7.259323 mutual_info_loss:6.569471
# epoch:173 loss:0.004054 accu:1.000000 |xentropy_loss:7.041574 mutual_info_loss:6.629674
# epoch:174 loss:0.001755 accu:1.000000 |xentropy_loss:7.394967 mutual_info_loss:6.677312
# epoch:175 loss:0.001725 accu:1.000000 |xentropy_loss:8.575110 mutual_info_loss:6.469310
# epoch:176 loss:0.002013 accu:1.000000 |xentropy_loss:7.184303 mutual_info_loss:6.414226
# epoch:177 loss:0.002209 accu:1.000000 |xentropy_loss:8.044292 mutual_info_loss:6.244885
# epoch:178 loss:0.006026 accu:1.000000 |xentropy_loss:6.561145 mutual_info_loss:6.355537
# epoch:179 loss:0.005732 accu:1.000000 |xentropy_loss:6.706192 mutual_info_loss:6.303380
# epoch:180 loss:0.001509 accu:1.000000 |xentropy_loss:7.460272 mutual_info_loss:6.640505
# epoch:181 loss:0.005788 accu:1.000000 |xentropy_loss:6.838907 mutual_info_loss:6.631461
# epoch:182 loss:0.001607 accu:1.000000 |xentropy_loss:9.730685 mutual_info_loss:6.999373
# epoch:183 loss:0.001706 accu:1.000000 |xentropy_loss:7.004489 mutual_info_loss:6.639706
# epoch:184 loss:0.001943 accu:1.000000 |xentropy_loss:7.421442 mutual_info_loss:6.397486
# epoch:185 loss:0.002471 accu:1.000000 |xentropy_loss:7.055027 mutual_info_loss:6.402099
# epoch:186 loss:0.003222 accu:1.000000 |xentropy_loss:6.640432 mutual_info_loss:6.305123
# epoch:187 loss:0.003013 accu:1.000000 |xentropy_loss:6.514163 mutual_info_loss:6.236753
# epoch:188 loss:0.004696 accu:1.000000 |xentropy_loss:6.520231 mutual_info_loss:5.926260
# epoch:189 loss:0.003856 accu:1.000000 |xentropy_loss:7.250856 mutual_info_loss:6.320292
# epoch:190 loss:0.002694 accu:1.000000 |xentropy_loss:6.920531 mutual_info_loss:6.349882
# epoch:191 loss:0.003616 accu:1.000000 |xentropy_loss:6.716771 mutual_info_loss:6.418643
# epoch:192 loss:0.003440 accu:1.000000 |xentropy_loss:7.201082 mutual_info_loss:6.300027
# epoch:193 loss:0.002581 accu:1.000000 |xentropy_loss:9.876743 mutual_info_loss:6.718013
# epoch:194 loss:0.002148 accu:1.000000 |xentropy_loss:7.976922 mutual_info_loss:6.462908
# epoch:195 loss:0.002732 accu:1.000000 |xentropy_loss:6.582392 mutual_info_loss:6.319736
# epoch:196 loss:0.006378 accu:1.000000 |xentropy_loss:7.772297 mutual_info_loss:6.551520
# epoch:197 loss:0.001592 accu:1.000000 |xentropy_loss:8.252666 mutual_info_loss:6.434277
# epoch:198 loss:0.005018 accu:1.000000 |xentropy_loss:7.032641 mutual_info_loss:6.669829
# epoch:199 loss:0.002997 accu:1.000000 |xentropy_loss:6.965606 mutual_info_loss:6.669104
# epoch:200 loss:0.001741 accu:1.000000 |xentropy_loss:7.698767 mutual_info_loss:6.774482
# epoch:201 loss:0.004174 accu:1.000000 |xentropy_loss:6.720587 mutual_info_loss:6.516227
# epoch:202 loss:0.002332 accu:1.000000 |xentropy_loss:8.096835 mutual_info_loss:6.891940
# epoch:203 loss:0.003764 accu:1.000000 |xentropy_loss:7.830274 mutual_info_loss:6.364614
# epoch:204 loss:0.003174 accu:1.000000 |xentropy_loss:9.671087 mutual_info_loss:6.831576
# epoch:205 loss:0.002406 accu:1.000000 |xentropy_loss:7.094028 mutual_info_loss:6.606207
# epoch:206 loss:0.001748 accu:1.000000 |xentropy_loss:6.907483 mutual_info_loss:6.397037
# epoch:207 loss:0.002502 accu:1.000000 |xentropy_loss:6.778616 mutual_info_loss:6.271106
# epoch:208 loss:0.003821 accu:1.000000 |xentropy_loss:6.761288 mutual_info_loss:6.546532
# epoch:209 loss:0.007450 accu:1.000000 |xentropy_loss:8.560936 mutual_info_loss:7.048725
# epoch:210 loss:0.000866 accu:1.000000 |xentropy_loss:7.359832 mutual_info_loss:7.138585
# epoch:211 loss:0.002077 accu:1.000000 |xentropy_loss:8.109702 mutual_info_loss:7.296253
# epoch:212 loss:0.001422 accu:1.000000 |xentropy_loss:6.989261 mutual_info_loss:6.650268
# epoch:213 loss:0.002572 accu:1.000000 |xentropy_loss:7.738600 mutual_info_loss:6.440473
# epoch:214 loss:0.001998 accu:1.000000 |xentropy_loss:7.608217 mutual_info_loss:6.394330
# epoch:215 loss:0.002356 accu:1.000000 |xentropy_loss:7.788560 mutual_info_loss:6.306300
# epoch:216 loss:0.005465 accu:1.000000 |xentropy_loss:8.294665 mutual_info_loss:6.576367
# epoch:217 loss:0.001606 accu:1.000000 |xentropy_loss:8.631311 mutual_info_loss:6.892891
# epoch:218 loss:0.002960 accu:1.000000 |xentropy_loss:6.528097 mutual_info_loss:6.307025
# epoch:219 loss:0.006440 accu:1.000000 |xentropy_loss:6.923736 mutual_info_loss:6.401885
# epoch:220 loss:0.003728 accu:1.000000 |xentropy_loss:8.114216 mutual_info_loss:7.569483
# epoch:221 loss:0.000718 accu:1.000000 |xentropy_loss:7.771425 mutual_info_loss:7.064942
# epoch:222 loss:0.001695 accu:1.000000 |xentropy_loss:7.034024 mutual_info_loss:6.804604
# epoch:223 loss:0.004222 accu:1.000000 |xentropy_loss:6.617250 mutual_info_loss:6.251380
# epoch:224 loss:0.002586 accu:1.000000 |xentropy_loss:6.996593 mutual_info_loss:6.631088
# epoch:225 loss:0.001889 accu:1.000000 |xentropy_loss:8.567611 mutual_info_loss:6.392183
# epoch:226 loss:0.003637 accu:1.000000 |xentropy_loss:7.052601 mutual_info_loss:6.310667
# epoch:227 loss:0.002279 accu:1.000000 |xentropy_loss:8.828395 mutual_info_loss:6.848187
# epoch:228 loss:0.004672 accu:1.000000 |xentropy_loss:7.344214 mutual_info_loss:6.500947
# epoch:229 loss:0.001928 accu:1.000000 |xentropy_loss:6.988980 mutual_info_loss:6.615147
# epoch:230 loss:0.001671 accu:1.000000 |xentropy_loss:7.368447 mutual_info_loss:6.367291
# epoch:231 loss:0.001970 accu:1.000000 |xentropy_loss:8.282650 mutual_info_loss:6.544361
# epoch:232 loss:0.009817 accu:1.000000 |xentropy_loss:11.093570 mutual_info_loss:7.281754
# epoch:233 loss:0.001941 accu:1.000000 |xentropy_loss:7.823280 mutual_info_loss:7.373689
# epoch:234 loss:0.002155 accu:1.000000 |xentropy_loss:7.585895 mutual_info_loss:7.232251
# epoch:235 loss:0.002089 accu:1.000000 |xentropy_loss:7.099463 mutual_info_loss:6.730080
# epoch:236 loss:0.003954 accu:1.000000 |xentropy_loss:7.369967 mutual_info_loss:6.683950
# epoch:237 loss:0.001786 accu:1.000000 |xentropy_loss:6.957017 mutual_info_loss:6.562554
# epoch:238 loss:0.005843 accu:1.000000 |xentropy_loss:6.991789 mutual_info_loss:6.623514
# epoch:239 loss:0.001964 accu:1.000000 |xentropy_loss:7.206107 mutual_info_loss:7.042752
# epoch:240 loss:0.000697 accu:1.000000 |xentropy_loss:7.296423 mutual_info_loss:6.460766
# epoch:241 loss:0.002849 accu:1.000000 |xentropy_loss:6.810593 mutual_info_loss:6.411770
# epoch:242 loss:0.003201 accu:1.000000 |xentropy_loss:7.264217 mutual_info_loss:6.562230
# epoch:243 loss:0.001873 accu:1.000000 |xentropy_loss:7.824155 mutual_info_loss:6.476805
# epoch:244 loss:0.004608 accu:1.000000 |xentropy_loss:6.600103 mutual_info_loss:6.372334
# epoch:245 loss:0.003780 accu:1.000000 |xentropy_loss:8.169514 mutual_info_loss:6.797484
# epoch:246 loss:0.002946 accu:1.000000 |xentropy_loss:7.628410 mutual_info_loss:7.422763
# epoch:247 loss:0.002826 accu:1.000000 |xentropy_loss:6.580328 mutual_info_loss:6.340977
# epoch:248 loss:0.003819 accu:1.000000 |xentropy_loss:9.631340 mutual_info_loss:6.148421
# epoch:249 loss:0.004641 accu:1.000000 |xentropy_loss:8.574430 mutual_info_loss:6.017968
# epoch:250 loss:0.002532 accu:1.000000 |xentropy_loss:6.919339 mutual_info_loss:6.671224
# epoch:251 loss:0.001333 accu:1.000000 |xentropy_loss:7.996620 mutual_info_loss:6.589632
# epoch:252 loss:0.009091 accu:1.000000 |xentropy_loss:8.873518 mutual_info_loss:7.277513
# epoch:253 loss:0.001705 accu:1.000000 |xentropy_loss:7.942358 mutual_info_loss:7.609639
# epoch:254 loss:0.004001 accu:1.000000 |xentropy_loss:8.383862 mutual_info_loss:7.280712
# epoch:255 loss:0.001820 accu:1.000000 |xentropy_loss:7.564187 mutual_info_loss:7.335813
# epoch:256 loss:0.002946 accu:1.000000 |xentropy_loss:8.273464 mutual_info_loss:7.006237
# epoch:257 loss:0.001340 accu:1.000000 |xentropy_loss:7.179199 mutual_info_loss:6.819266
# epoch:258 loss:0.004160 accu:1.000000 |xentropy_loss:7.333127 mutual_info_loss:6.647448
# epoch:259 loss:0.004988 accu:1.000000 |xentropy_loss:7.487782 mutual_info_loss:7.139276
# epoch:260 loss:0.004641 accu:1.000000 |xentropy_loss:7.391677 mutual_info_loss:7.170784
# epoch:261 loss:0.001817 accu:1.000000 |xentropy_loss:9.047075 mutual_info_loss:6.869858
# epoch:262 loss:0.002113 accu:1.000000 |xentropy_loss:7.029227 mutual_info_loss:6.653703
# epoch:263 loss:0.005302 accu:1.000000 |xentropy_loss:6.367776 mutual_info_loss:6.266274
# epoch:264 loss:0.005480 accu:1.000000 |xentropy_loss:8.802593 mutual_info_loss:6.991801
# epoch:265 loss:0.001872 accu:1.000000 |xentropy_loss:7.465415 mutual_info_loss:7.237992
# epoch:266 loss:0.001399 accu:1.000000 |xentropy_loss:9.556234 mutual_info_loss:7.138027
# epoch:267 loss:0.002638 accu:1.000000 |xentropy_loss:9.224396 mutual_info_loss:6.535079
# epoch:268 loss:0.001703 accu:1.000000 |xentropy_loss:6.781081 mutual_info_loss:6.492827
# epoch:269 loss:0.003486 accu:1.000000 |xentropy_loss:7.491561 mutual_info_loss:6.371031
# epoch:270 loss:0.002723 accu:1.000000 |xentropy_loss:7.312570 mutual_info_loss:7.158997
# epoch:271 loss:0.002381 accu:1.000000 |xentropy_loss:6.893683 mutual_info_loss:6.589641
# epoch:272 loss:0.000865 accu:1.000000 |xentropy_loss:7.683720 mutual_info_loss:6.871168
# epoch:273 loss:0.004888 accu:1.000000 |xentropy_loss:8.084465 mutual_info_loss:6.813544
# epoch:274 loss:0.006948 accu:1.000000 |xentropy_loss:8.195395 mutual_info_loss:7.435082
# epoch:275 loss:0.003675 accu:1.000000 |xentropy_loss:8.588481 mutual_info_loss:7.654149
# epoch:276 loss:0.001262 accu:1.000000 |xentropy_loss:7.888933 mutual_info_loss:7.574455
# epoch:277 loss:0.001701 accu:1.000000 |xentropy_loss:7.279872 mutual_info_loss:6.877775
# epoch:278 loss:0.002609 accu:1.000000 |xentropy_loss:7.313287 mutual_info_loss:6.933096
# epoch:279 loss:0.002307 accu:1.000000 |xentropy_loss:7.865832 mutual_info_loss:6.856245
# epoch:280 loss:0.003495 accu:1.000000 |xentropy_loss:7.310582 mutual_info_loss:6.771944
# epoch:281 loss:0.003063 accu:1.000000 |xentropy_loss:7.244631 mutual_info_loss:6.727700
# epoch:282 loss:0.002263 accu:1.000000 |xentropy_loss:7.145779 mutual_info_loss:6.933306
# epoch:283 loss:0.001798 accu:1.000000 |xentropy_loss:7.634421 mutual_info_loss:6.608213
# epoch:284 loss:0.003264 accu:1.000000 |xentropy_loss:6.407469 mutual_info_loss:6.352909
# epoch:285 loss:0.003887 accu:1.000000 |xentropy_loss:7.330215 mutual_info_loss:7.033831
# epoch:286 loss:0.002155 accu:1.000000 |xentropy_loss:7.353854 mutual_info_loss:6.762799
# epoch:287 loss:0.002600 accu:1.000000 |xentropy_loss:6.559950 mutual_info_loss:6.050184
# epoch:288 loss:0.004561 accu:1.000000 |xentropy_loss:6.758438 mutual_info_loss:6.639702
# epoch:289 loss:0.003042 accu:1.000000 |xentropy_loss:8.170339 mutual_info_loss:7.359140
# epoch:290 loss:0.006024 accu:1.000000 |xentropy_loss:7.483604 mutual_info_loss:7.126861
# epoch:291 loss:0.004298 accu:1.000000 |xentropy_loss:7.953258 mutual_info_loss:7.175683
# epoch:292 loss:0.005374 accu:1.000000 |xentropy_loss:7.350877 mutual_info_loss:7.213202
# epoch:293 loss:0.003745 accu:1.000000 |xentropy_loss:7.167581 mutual_info_loss:6.702818
# epoch:294 loss:0.010636 accu:1.000000 |xentropy_loss:7.903548 mutual_info_loss:7.636692
# epoch:295 loss:0.001338 accu:1.000000 |xentropy_loss:8.566883 mutual_info_loss:8.180218
# epoch:296 loss:0.001950 accu:1.000000 |xentropy_loss:7.727513 mutual_info_loss:7.440612
# epoch:297 loss:0.000822 accu:1.000000 |xentropy_loss:8.962480 mutual_info_loss:7.178769
# epoch:298 loss:0.002356 accu:1.000000 |xentropy_loss:7.064151 mutual_info_loss:6.443551
# epoch:299 loss:0.004249 accu:1.000000 |xentropy_loss:7.355970 mutual_info_loss:6.911200
# epoch:300 loss:0.005725 accu:1.000000 |xentropy_loss:7.418763 mutual_info_loss:7.223780
# epoch:301 loss:0.000889 accu:1.000000 |xentropy_loss:9.397221 mutual_info_loss:7.808955
# epoch:302 loss:0.003895 accu:1.000000 |xentropy_loss:8.168661 mutual_info_loss:6.977496
# epoch:303 loss:0.002499 accu:1.000000 |xentropy_loss:7.581171 mutual_info_loss:6.636441
# epoch:304 loss:0.005763 accu:1.000000 |xentropy_loss:8.006775 mutual_info_loss:7.584143
# epoch:305 loss:0.001961 accu:1.000000 |xentropy_loss:7.510418 mutual_info_loss:7.079209
# epoch:306 loss:0.002601 accu:1.000000 |xentropy_loss:7.756143 mutual_info_loss:7.037373
# epoch:307 loss:0.010822 accu:1.000000 |xentropy_loss:8.209238 mutual_info_loss:7.911322
# epoch:308 loss:0.003642 accu:1.000000 |xentropy_loss:9.131102 mutual_info_loss:8.085316
# epoch:309 loss:0.004256 accu:1.000000 |xentropy_loss:7.247802 mutual_info_loss:7.047139
# epoch:310 loss:0.010551 accu:1.000000 |xentropy_loss:9.139467 mutual_info_loss:8.555823
# epoch:311 loss:0.001215 accu:1.000000 |xentropy_loss:9.806507 mutual_info_loss:8.822169
# epoch:312 loss:0.011112 accu:1.000000 |xentropy_loss:7.084492 mutual_info_loss:6.629053
# epoch:313 loss:0.008990 accu:1.000000 |xentropy_loss:8.056557 mutual_info_loss:7.397577
# epoch:314 loss:0.000814 accu:1.000000 |xentropy_loss:8.659515 mutual_info_loss:7.928348
# epoch:315 loss:0.001053 accu:1.000000 |xentropy_loss:7.773228 mutual_info_loss:7.648003
# epoch:316 loss:0.004359 accu:1.000000 |xentropy_loss:7.376809 mutual_info_loss:7.053335
# epoch:317 loss:0.003503 accu:1.000000 |xentropy_loss:8.218968 mutual_info_loss:7.730557
# epoch:318 loss:0.001489 accu:1.000000 |xentropy_loss:8.177422 mutual_info_loss:7.863862
# epoch:319 loss:0.001715 accu:1.000000 |xentropy_loss:7.715858 mutual_info_loss:7.413807
# epoch:320 loss:0.006195 accu:1.000000 |xentropy_loss:7.894941 mutual_info_loss:7.510634
# epoch:321 loss:0.003868 accu:1.000000 |xentropy_loss:7.736668 mutual_info_loss:7.463929
# epoch:322 loss:0.005387 accu:1.000000 |xentropy_loss:7.686003 mutual_info_loss:6.735875
# epoch:323 loss:0.022008 accu:1.000000 |xentropy_loss:10.408263 mutual_info_loss:9.581505
# epoch:324 loss:0.035441 accu:0.992188 |xentropy_loss:6.841639 mutual_info_loss:6.275213
# epoch:325 loss:0.016563 accu:0.992188 |xentropy_loss:9.671407 mutual_info_loss:9.011871
# epoch:326 loss:0.001552 accu:1.000000 |xentropy_loss:10.728191 mutual_info_loss:10.044440
# epoch:327 loss:0.001713 accu:1.000000 |xentropy_loss:9.396671 mutual_info_loss:8.937877
# epoch:328 loss:0.000870 accu:1.000000 |xentropy_loss:10.105579 mutual_info_loss:8.702131
# epoch:329 loss:0.012310 accu:0.992188 |xentropy_loss:9.234797 mutual_info_loss:8.926762
# epoch:330 loss:0.002001 accu:1.000000 |xentropy_loss:10.419212 mutual_info_loss:8.704163
# epoch:331 loss:0.008010 accu:1.000000 |xentropy_loss:10.547527 mutual_info_loss:6.392074
# epoch:332 loss:0.014683 accu:0.992188 |xentropy_loss:10.107362 mutual_info_loss:8.189597
# epoch:333 loss:0.006391 accu:1.000000 |xentropy_loss:10.143293 mutual_info_loss:9.504069
# epoch:334 loss:0.002332 accu:1.000000 |xentropy_loss:9.660020 mutual_info_loss:9.117873
# epoch:335 loss:0.036792 accu:1.000000 |xentropy_loss:9.943285 mutual_info_loss:6.728077
# epoch:336 loss:0.003105 accu:1.000000 |xentropy_loss:13.158373 mutual_info_loss:8.852507
# epoch:337 loss:0.003662 accu:1.000000 |xentropy_loss:9.588226 mutual_info_loss:9.195055
# epoch:338 loss:0.004525 accu:1.000000 |xentropy_loss:10.060360 mutual_info_loss:8.262161
# epoch:339 loss:0.000674 accu:1.000000 |xentropy_loss:8.568002 mutual_info_loss:7.642514
# epoch:340 loss:0.008447 accu:1.000000 |xentropy_loss:16.144016 mutual_info_loss:8.111917
# epoch:341 loss:0.003379 accu:1.000000 |xentropy_loss:10.079926 mutual_info_loss:8.191484
# epoch:342 loss:0.114527 accu:0.976562 |xentropy_loss:25.885841 mutual_info_loss:15.775730
# epoch:343 loss:10.007933 accu:0.101562 |xentropy_loss:10.093327 mutual_info_loss:4.611382
# epoch:344 loss:1.389067 accu:0.820312 |xentropy_loss:13.299131 mutual_info_loss:8.220333
# epoch:345 loss:1.565773 accu:0.757812 |xentropy_loss:9.991876 mutual_info_loss:5.353829
# epoch:346 loss:0.020746 accu:0.992188 |xentropy_loss:11.540438 mutual_info_loss:8.517740
# epoch:347 loss:0.046451 accu:0.976562 |xentropy_loss:12.434624 mutual_info_loss:7.219705
# epoch:348 loss:0.041008 accu:0.984375 |xentropy_loss:9.407755 mutual_info_loss:6.842774
# epoch:349 loss:0.012046 accu:1.000000 |xentropy_loss:13.051065 mutual_info_loss:6.853312
# epoch:350 loss:0.012572 accu:1.000000 |xentropy_loss:8.373310 mutual_info_loss:6.185127
# epoch:351 loss:0.006166 accu:1.000000 |xentropy_loss:8.725261 mutual_info_loss:7.005552
# epoch:352 loss:0.016099 accu:1.000000 |xentropy_loss:11.488424 mutual_info_loss:5.873320
# epoch:353 loss:0.010472 accu:1.000000 |xentropy_loss:8.933823 mutual_info_loss:6.577108
# epoch:354 loss:0.003705 accu:1.000000 |xentropy_loss:8.995514 mutual_info_loss:7.160944
# epoch:355 loss:0.004151 accu:1.000000 |xentropy_loss:7.649002 mutual_info_loss:6.529426
# epoch:356 loss:0.010118 accu:1.000000 |xentropy_loss:6.443307 mutual_info_loss:5.592446
# epoch:357 loss:0.010507 accu:1.000000 |xentropy_loss:8.358543 mutual_info_loss:6.607867
# epoch:358 loss:0.015964 accu:0.992188 |xentropy_loss:7.772188 mutual_info_loss:6.370565
# epoch:359 loss:0.010012 accu:1.000000 |xentropy_loss:6.666624 mutual_info_loss:6.047336
# epoch:360 loss:0.007826 accu:1.000000 |xentropy_loss:8.170286 mutual_info_loss:6.205167
# epoch:361 loss:0.017227 accu:0.992188 |xentropy_loss:6.836446 mutual_info_loss:5.775269
# epoch:362 loss:0.005079 accu:1.000000 |xentropy_loss:6.983951 mutual_info_loss:6.655560
# epoch:363 loss:0.027013 accu:0.992188 |xentropy_loss:7.036624 mutual_info_loss:5.547112
# epoch:364 loss:0.014284 accu:1.000000 |xentropy_loss:6.908671 mutual_info_loss:6.317909
# epoch:365 loss:0.015245 accu:1.000000 |xentropy_loss:6.838229 mutual_info_loss:5.154906
# epoch:366 loss:0.008619 accu:1.000000 |xentropy_loss:6.636868 mutual_info_loss:5.816411
# epoch:367 loss:0.012174 accu:1.000000 |xentropy_loss:9.977177 mutual_info_loss:6.721389
# epoch:368 loss:0.009729 accu:1.000000 |xentropy_loss:6.924263 mutual_info_loss:5.640656
# epoch:369 loss:0.015875 accu:1.000000 |xentropy_loss:6.050336 mutual_info_loss:5.640118
# epoch:370 loss:0.009544 accu:1.000000 |xentropy_loss:8.170734 mutual_info_loss:5.880754
# epoch:371 loss:0.006736 accu:1.000000 |xentropy_loss:6.333275 mutual_info_loss:5.640970
# epoch:372 loss:0.018063 accu:0.992188 |xentropy_loss:8.296873 mutual_info_loss:5.912304
# epoch:373 loss:0.005399 accu:1.000000 |xentropy_loss:7.385674 mutual_info_loss:5.949779
# epoch:374 loss:0.012507 accu:1.000000 |xentropy_loss:7.140188 mutual_info_loss:4.852188
# epoch:375 loss:0.014079 accu:1.000000 |xentropy_loss:6.997089 mutual_info_loss:5.358901
# epoch:376 loss:0.007560 accu:1.000000 |xentropy_loss:6.961537 mutual_info_loss:6.012252
# epoch:377 loss:0.040190 accu:0.992188 |xentropy_loss:7.550861 mutual_info_loss:5.542336
# epoch:378 loss:0.022273 accu:0.992188 |xentropy_loss:7.037471 mutual_info_loss:5.414548
# epoch:379 loss:0.012870 accu:1.000000 |xentropy_loss:6.231892 mutual_info_loss:5.731722
# epoch:380 loss:0.021339 accu:1.000000 |xentropy_loss:6.068645 mutual_info_loss:5.247360
# epoch:381 loss:0.011535 accu:1.000000 |xentropy_loss:7.859032 mutual_info_loss:5.799368
# epoch:382 loss:0.018211 accu:1.000000 |xentropy_loss:6.164380 mutual_info_loss:5.067134
# epoch:383 loss:0.003776 accu:1.000000 |xentropy_loss:7.155517 mutual_info_loss:5.829760
# epoch:384 loss:0.009058 accu:1.000000 |xentropy_loss:6.890091 mutual_info_loss:5.850469
# epoch:385 loss:0.011784 accu:1.000000 |xentropy_loss:6.863315 mutual_info_loss:6.091824
# epoch:386 loss:0.008341 accu:1.000000 |xentropy_loss:6.265419 mutual_info_loss:5.393392
# epoch:387 loss:0.007404 accu:1.000000 |xentropy_loss:6.507227 mutual_info_loss:5.814703
# epoch:388 loss:0.006416 accu:1.000000 |xentropy_loss:12.155219 mutual_info_loss:5.818784
# epoch:389 loss:0.013870 accu:0.992188 |xentropy_loss:7.440734 mutual_info_loss:5.743717
# epoch:390 loss:0.008085 accu:1.000000 |xentropy_loss:6.596288 mutual_info_loss:5.919394
# epoch:391 loss:0.005315 accu:1.000000 |xentropy_loss:6.660111 mutual_info_loss:5.758626
# epoch:392 loss:0.010967 accu:1.000000 |xentropy_loss:6.249157 mutual_info_loss:5.292562
# epoch:393 loss:0.006702 accu:1.000000 |xentropy_loss:6.877643 mutual_info_loss:5.533998
# epoch:394 loss:0.011702 accu:1.000000 |xentropy_loss:6.257587 mutual_info_loss:5.528886
# epoch:395 loss:0.014523 accu:1.000000 |xentropy_loss:6.805962 mutual_info_loss:5.797653
# epoch:396 loss:0.006805 accu:1.000000 |xentropy_loss:6.739373 mutual_info_loss:5.932642
# epoch:397 loss:0.005588 accu:1.000000 |xentropy_loss:8.116544 mutual_info_loss:6.398849
# epoch:398 loss:0.006553 accu:1.000000 |xentropy_loss:6.124463 mutual_info_loss:5.794141
# epoch:399 loss:0.014684 accu:1.000000 |xentropy_loss:6.790194 mutual_info_loss:5.449083
# epoch:400 loss:0.016115 accu:1.000000 |xentropy_loss:8.939451 mutual_info_loss:5.904450
# epoch:401 loss:0.004150 accu:1.000000 |xentropy_loss:7.440674 mutual_info_loss:6.620155
# epoch:402 loss:0.007035 accu:1.000000 |xentropy_loss:6.682070 mutual_info_loss:5.837009
# epoch:403 loss:0.017201 accu:1.000000 |xentropy_loss:7.196091 mutual_info_loss:4.811361
# epoch:404 loss:0.006741 accu:1.000000 |xentropy_loss:7.329237 mutual_info_loss:5.187932
# epoch:405 loss:0.014117 accu:0.992188 |xentropy_loss:7.325000 mutual_info_loss:5.574453
# epoch:406 loss:0.006809 accu:1.000000 |xentropy_loss:7.687195 mutual_info_loss:5.950399
# epoch:407 loss:0.010752 accu:1.000000 |xentropy_loss:5.808779 mutual_info_loss:5.096572
# epoch:408 loss:0.008884 accu:1.000000 |xentropy_loss:7.729465 mutual_info_loss:6.085244
# epoch:409 loss:0.030827 accu:1.000000 |xentropy_loss:6.157299 mutual_info_loss:5.572374
# epoch:410 loss:0.010591 accu:1.000000 |xentropy_loss:10.021824 mutual_info_loss:5.909797
# epoch:411 loss:0.005343 accu:1.000000 |xentropy_loss:6.915884 mutual_info_loss:6.489513
# epoch:412 loss:0.012257 accu:1.000000 |xentropy_loss:8.171974 mutual_info_loss:5.232552
# epoch:413 loss:0.012959 accu:1.000000 |xentropy_loss:7.109991 mutual_info_loss:5.206166
# epoch:414 loss:0.027835 accu:1.000000 |xentropy_loss:10.453487 mutual_info_loss:5.821948
# epoch:415 loss:0.009673 accu:1.000000 |xentropy_loss:8.942157 mutual_info_loss:6.188858
# epoch:416 loss:0.013263 accu:1.000000 |xentropy_loss:7.241031 mutual_info_loss:5.175624
# epoch:417 loss:0.015277 accu:1.000000 |xentropy_loss:6.693687 mutual_info_loss:4.935637
# epoch:418 loss:0.024098 accu:1.000000 |xentropy_loss:7.237235 mutual_info_loss:6.069487
# epoch:419 loss:0.017944 accu:1.000000 |xentropy_loss:7.894160 mutual_info_loss:6.708735
# epoch:420 loss:0.015926 accu:1.000000 |xentropy_loss:12.691718 mutual_info_loss:6.201613
# epoch:421 loss:0.017216 accu:1.000000 |xentropy_loss:6.256556 mutual_info_loss:5.033367
# epoch:422 loss:0.024181 accu:1.000000 |xentropy_loss:9.151789 mutual_info_loss:5.419627
# epoch:423 loss:0.026211 accu:1.000000 |xentropy_loss:8.695433 mutual_info_loss:6.197030
# epoch:424 loss:0.012848 accu:1.000000 |xentropy_loss:7.085827 mutual_info_loss:6.265211
# epoch:425 loss:0.020707 accu:1.000000 |xentropy_loss:8.197013 mutual_info_loss:5.165197
# epoch:426 loss:0.156556 accu:0.953125 |xentropy_loss:18.271019 mutual_info_loss:11.431980
# epoch:427 loss:7.189611 accu:0.000000 |xentropy_loss:7.971886 mutual_info_loss:0.915967
# epoch:428 loss:0.405046 accu:0.859375 |xentropy_loss:6.358384 mutual_info_loss:5.691806
# epoch:429 loss:0.119197 accu:0.968750 |xentropy_loss:9.385401 mutual_info_loss:5.629879
# epoch:430 loss:0.056906 accu:0.984375 |xentropy_loss:8.203532 mutual_info_loss:5.554256
# epoch:431 loss:0.091821 accu:0.992188 |xentropy_loss:7.660789 mutual_info_loss:4.217721
# epoch:432 loss:0.043249 accu:1.000000 |xentropy_loss:7.091402 mutual_info_loss:4.551437
# epoch:433 loss:0.056944 accu:0.984375 |xentropy_loss:6.967601 mutual_info_loss:4.532189
# epoch:434 loss:0.028967 accu:1.000000 |xentropy_loss:6.368567 mutual_info_loss:5.245974
# epoch:435 loss:0.019188 accu:1.000000 |xentropy_loss:5.832647 mutual_info_loss:4.711377
# epoch:436 loss:0.025160 accu:1.000000 |xentropy_loss:5.266748 mutual_info_loss:4.863889
# epoch:437 loss:0.028582 accu:1.000000 |xentropy_loss:5.287001 mutual_info_loss:4.279437
# epoch:438 loss:0.009781 accu:1.000000 |xentropy_loss:6.568861 mutual_info_loss:5.161642
# epoch:439 loss:0.037269 accu:1.000000 |xentropy_loss:4.962812 mutual_info_loss:4.235889
# epoch:440 loss:0.022143 accu:1.000000 |xentropy_loss:5.252274 mutual_info_loss:4.663896
# epoch:441 loss:0.058432 accu:1.000000 |xentropy_loss:5.793337 mutual_info_loss:4.476912
# epoch:442 loss:0.016570 accu:1.000000 |xentropy_loss:5.359390 mutual_info_loss:4.857576
# epoch:443 loss:0.032390 accu:1.000000 |xentropy_loss:5.543337 mutual_info_loss:4.858117
# epoch:444 loss:0.032247 accu:1.000000 |xentropy_loss:5.391399 mutual_info_loss:4.660688
# epoch:445 loss:0.028208 accu:1.000000 |xentropy_loss:4.950905 mutual_info_loss:4.088632
# epoch:446 loss:0.022417 accu:1.000000 |xentropy_loss:4.821241 mutual_info_loss:4.462486
# epoch:447 loss:0.028663 accu:1.000000 |xentropy_loss:5.379655 mutual_info_loss:4.425602
# epoch:448 loss:0.016164 accu:1.000000 |xentropy_loss:5.157435 mutual_info_loss:4.859840
# epoch:449 loss:0.042964 accu:1.000000 |xentropy_loss:5.265897 mutual_info_loss:4.350254
# epoch:450 loss:0.039250 accu:1.000000 |xentropy_loss:5.505260 mutual_info_loss:4.062285
# epoch:451 loss:0.043241 accu:1.000000 |xentropy_loss:5.762123 mutual_info_loss:4.175423
# epoch:452 loss:0.055568 accu:1.000000 |xentropy_loss:9.345145 mutual_info_loss:4.045539
# epoch:453 loss:0.028327 accu:1.000000 |xentropy_loss:6.094864 mutual_info_loss:4.119407
# epoch:454 loss:0.033037 accu:1.000000 |xentropy_loss:6.219952 mutual_info_loss:4.619876
# epoch:455 loss:0.016732 accu:1.000000 |xentropy_loss:4.924572 mutual_info_loss:4.379953
# epoch:456 loss:0.020271 accu:1.000000 |xentropy_loss:6.110986 mutual_info_loss:4.208352
# epoch:457 loss:0.031755 accu:1.000000 |xentropy_loss:6.404736 mutual_info_loss:4.660898
# epoch:458 loss:0.025433 accu:1.000000 |xentropy_loss:6.134461 mutual_info_loss:4.714230
# epoch:459 loss:0.044845 accu:1.000000 |xentropy_loss:5.639160 mutual_info_loss:5.098635
# epoch:460 loss:0.043293 accu:0.992188 |xentropy_loss:5.412067 mutual_info_loss:4.335396
# epoch:461 loss:0.021618 accu:1.000000 |xentropy_loss:4.587336 mutual_info_loss:4.044242
# epoch:462 loss:0.020944 accu:1.000000 |xentropy_loss:6.218743 mutual_info_loss:4.447662
# epoch:463 loss:0.062045 accu:0.992188 |xentropy_loss:6.362751 mutual_info_loss:4.556279
# epoch:464 loss:0.018605 accu:1.000000 |xentropy_loss:10.062288 mutual_info_loss:5.556151
# epoch:465 loss:0.028803 accu:1.000000 |xentropy_loss:6.442983 mutual_info_loss:4.487660
# epoch:466 loss:0.051442 accu:1.000000 |xentropy_loss:4.738429 mutual_info_loss:4.015481
# epoch:467 loss:0.039762 accu:1.000000 |xentropy_loss:5.728276 mutual_info_loss:4.321354
# epoch:468 loss:0.012653 accu:1.000000 |xentropy_loss:6.317815 mutual_info_loss:5.567042
# epoch:469 loss:0.025783 accu:1.000000 |xentropy_loss:5.494129 mutual_info_loss:4.493676
# epoch:470 loss:0.037673 accu:1.000000 |xentropy_loss:7.834383 mutual_info_loss:4.149475
# epoch:471 loss:0.019660 accu:1.000000 |xentropy_loss:6.061206 mutual_info_loss:4.288327
# epoch:472 loss:0.037362 accu:1.000000 |xentropy_loss:5.602153 mutual_info_loss:4.972959
# epoch:473 loss:0.027143 accu:0.992188 |xentropy_loss:6.839282 mutual_info_loss:5.134422
# epoch:474 loss:0.018718 accu:1.000000 |xentropy_loss:8.817874 mutual_info_loss:4.627512
# epoch:475 loss:0.032421 accu:1.000000 |xentropy_loss:5.545232 mutual_info_loss:4.458145
# epoch:476 loss:0.015918 accu:1.000000 |xentropy_loss:7.989838 mutual_info_loss:5.341719
# epoch:477 loss:0.014538 accu:1.000000 |xentropy_loss:5.673120 mutual_info_loss:5.198914
# epoch:478 loss:0.019503 accu:1.000000 |xentropy_loss:7.531320 mutual_info_loss:4.704385
# epoch:479 loss:0.016256 accu:1.000000 |xentropy_loss:4.878246 mutual_info_loss:4.642928
# epoch:480 loss:0.037783 accu:1.000000 |xentropy_loss:5.704123 mutual_info_loss:4.608171
# epoch:481 loss:0.012736 accu:1.000000 |xentropy_loss:5.959828 mutual_info_loss:5.062615
# epoch:482 loss:0.043377 accu:1.000000 |xentropy_loss:9.215289 mutual_info_loss:4.986278
# epoch:483 loss:0.021734 accu:1.000000 |xentropy_loss:5.601986 mutual_info_loss:5.087710
# epoch:484 loss:0.031526 accu:1.000000 |xentropy_loss:6.093205 mutual_info_loss:3.892166
# epoch:485 loss:0.031554 accu:1.000000 |xentropy_loss:7.541628 mutual_info_loss:4.806221
# epoch:486 loss:0.042653 accu:0.992188 |xentropy_loss:7.636893 mutual_info_loss:4.469030
# epoch:487 loss:0.042233 accu:1.000000 |xentropy_loss:5.022106 mutual_info_loss:4.498327
# epoch:488 loss:0.030493 accu:1.000000 |xentropy_loss:5.428600 mutual_info_loss:4.851953
# epoch:489 loss:0.051260 accu:1.000000 |xentropy_loss:7.919057 mutual_info_loss:4.743174
# epoch:490 loss:0.050298 accu:0.992188 |xentropy_loss:9.198666 mutual_info_loss:4.646677
# epoch:491 loss:0.079574 accu:0.992188 |xentropy_loss:7.866912 mutual_info_loss:4.656816
# epoch:492 loss:0.036271 accu:1.000000 |xentropy_loss:6.509910 mutual_info_loss:4.899310
# epoch:493 loss:0.026599 accu:1.000000 |xentropy_loss:7.848894 mutual_info_loss:4.616401
# epoch:494 loss:0.066578 accu:0.992188 |xentropy_loss:9.306131 mutual_info_loss:4.004633
# epoch:495 loss:0.074603 accu:0.992188 |xentropy_loss:7.292846 mutual_info_loss:5.095502
# epoch:496 loss:0.017909 accu:1.000000 |xentropy_loss:6.825460 mutual_info_loss:6.208654
# epoch:497 loss:0.032858 accu:1.000000 |xentropy_loss:6.662739 mutual_info_loss:5.128870
# epoch:498 loss:0.028387 accu:1.000000 |xentropy_loss:5.795688 mutual_info_loss:4.677714
# epoch:499 loss:0.075180 accu:0.976562 |xentropy_loss:6.050469 mutual_info_loss:5.642205
# epoch:500 loss:0.062816 accu:0.992188 |xentropy_loss:6.972693 mutual_info_loss:4.311926
# epoch:501 loss:0.075210 accu:0.992188 |xentropy_loss:6.738365 mutual_info_loss:4.511562
# epoch:502 loss:0.112425 accu:1.000000 |xentropy_loss:8.666348 mutual_info_loss:4.338759
# epoch:503 loss:0.020862 accu:1.000000 |xentropy_loss:5.948967 mutual_info_loss:5.211549
# epoch:504 loss:0.047709 accu:1.000000 |xentropy_loss:6.384038 mutual_info_loss:4.800963
# epoch:505 loss:0.026532 accu:1.000000 |xentropy_loss:10.735073 mutual_info_loss:4.916028
# epoch:506 loss:0.021692 accu:1.000000 |xentropy_loss:6.655437 mutual_info_loss:6.109318
# epoch:507 loss:0.082764 accu:1.000000 |xentropy_loss:6.211887 mutual_info_loss:4.107142
# epoch:508 loss:0.033238 accu:1.000000 |xentropy_loss:6.848668 mutual_info_loss:5.039236
# epoch:509 loss:0.026209 accu:0.992188 |xentropy_loss:5.634121 mutual_info_loss:5.382181
# epoch:510 loss:0.015085 accu:1.000000 |xentropy_loss:6.504605 mutual_info_loss:4.293196
# epoch:511 loss:0.039431 accu:1.000000 |xentropy_loss:4.715973 mutual_info_loss:4.394654
# epoch:512 loss:0.061383 accu:0.992188 |xentropy_loss:5.565058 mutual_info_loss:5.055826
# epoch:513 loss:0.136777 accu:0.968750 |xentropy_loss:6.434533 mutual_info_loss:5.349508
# epoch:514 loss:0.086898 accu:0.992188 |xentropy_loss:9.815243 mutual_info_loss:4.214054
# epoch:515 loss:0.090630 accu:0.984375 |xentropy_loss:5.080892 mutual_info_loss:4.694495
# epoch:516 loss:0.040678 accu:1.000000 |xentropy_loss:8.147141 mutual_info_loss:4.650492
# epoch:517 loss:0.030451 accu:1.000000 |xentropy_loss:6.673050 mutual_info_loss:4.993578
# epoch:518 loss:0.031319 accu:1.000000 |xentropy_loss:4.674948 mutual_info_loss:4.288479
# epoch:519 loss:0.033962 accu:1.000000 |xentropy_loss:7.496172 mutual_info_loss:5.033063
# epoch:520 loss:0.031103 accu:0.992188 |xentropy_loss:9.194750 mutual_info_loss:5.111238
# epoch:521 loss:0.018695 accu:1.000000 |xentropy_loss:7.940947 mutual_info_loss:5.507789
# epoch:522 loss:0.016528 accu:1.000000 |xentropy_loss:5.758772 mutual_info_loss:5.278579
# epoch:523 loss:0.006827 accu:1.000000 |xentropy_loss:12.468863 mutual_info_loss:5.554718
# epoch:524 loss:0.014360 accu:1.000000 |xentropy_loss:5.522071 mutual_info_loss:5.100634
# epoch:525 loss:0.006361 accu:1.000000 |xentropy_loss:8.863118 mutual_info_loss:5.224410
# epoch:526 loss:0.023880 accu:1.000000 |xentropy_loss:5.892904 mutual_info_loss:5.020867
# epoch:527 loss:0.015057 accu:1.000000 |xentropy_loss:5.566162 mutual_info_loss:4.713877
# epoch:528 loss:0.011528 accu:1.000000 |xentropy_loss:7.521832 mutual_info_loss:5.110996
# epoch:529 loss:0.037747 accu:1.000000 |xentropy_loss:6.043362 mutual_info_loss:5.071555
# epoch:530 loss:0.030807 accu:1.000000 |xentropy_loss:5.851581 mutual_info_loss:4.994364
# epoch:531 loss:0.045720 accu:0.992188 |xentropy_loss:7.840132 mutual_info_loss:4.406522
# epoch:532 loss:0.015821 accu:1.000000 |xentropy_loss:5.605675 mutual_info_loss:5.486711
# epoch:533 loss:0.027637 accu:1.000000 |xentropy_loss:6.046919 mutual_info_loss:4.268515
# epoch:534 loss:0.026176 accu:1.000000 |xentropy_loss:7.372241 mutual_info_loss:4.939648
# epoch:535 loss:0.032739 accu:1.000000 |xentropy_loss:6.177502 mutual_info_loss:4.989841
# epoch:536 loss:0.022714 accu:1.000000 |xentropy_loss:6.658325 mutual_info_loss:5.392173
# epoch:537 loss:0.043131 accu:1.000000 |xentropy_loss:8.439565 mutual_info_loss:5.071794
# epoch:538 loss:0.021282 accu:1.000000 |xentropy_loss:6.089384 mutual_info_loss:5.546309
# epoch:539 loss:0.030326 accu:1.000000 |xentropy_loss:6.508205 mutual_info_loss:4.698380

# %%
X_A.shape
# Out:
# (30000, 784)

# %%
real_labels.shape
# Out:
# (64, 1)

# %%
gc.collect()

# %%
gc.collect()
