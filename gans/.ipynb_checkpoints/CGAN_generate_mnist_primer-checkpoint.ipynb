# %%
from keras.models import Sequential , Model
from keras.layers import Dense ,  BatchNormalization , Reshape , Input , Flatten
from keras.layers import Conv2D , MaxPool2D , Conv2DTranspose , UpSampling2D , ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import Activation
from keras.layers import Dropout

from keras.layers import Embedding

from keras.layers import Multiply

from keras.optimizers import Adam

from keras.datasets import mnist
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import os

import matplotlib as plt
import numpy as np

import gc

# %matplotlib inline

# %%
WIDTH = 28
HEIGHT = 28
CHANNEL = 1

LATENT_DIM = 100 #latent variable z sample from normal distribution

BATCH_SIZE = 64
EPOCHS = 10

PATH = 'faces/'

#生成多少个图像 长*宽
ROW = 5
COL = 5

#=========
#=========
#add new FLAG(s)
CLASS_NUM = 10 #mnist=10 CIFAR10=10 CIFAR100=100 CIFAR1000=1000

# %%
(X_train , y_train),(X_test , y_test) = mnist.load_data()
X_train = X_train/127.5-1
X_train = np.expand_dims(X_train , 3)
y_train = np.expand_dims(y_train , 1)

# %%
def load_mnist():
    random_index = np.random.randint(0, X_train.shape[0], BATCH_SIZE)
    return X_train[random_index] , y_train[random_index]
    
def write_image_mnist(epoch):
    
    noise = np.random.normal(size = (ROW*COL , LATENT_DIM))
    label = np.random.randint(low=0 , high=CLASS_NUM , size=(ROW*COL , 1)) #CLASS_NUM 是否需要加1
    
    generated_image = generator_i.predict([noise , label])
    generated_image = generated_image*0.5+0.5
    
    fig , axes = plt.pyplot.subplots(ROW , COL)
    fig.subplots_adjust(hspace=0.9 , wspace=0.9) #将每一个图像在高度 宽度 上进行缩放或者放大
    #fig.tight_layout()
    
    count=0
    
    for i in range(ROW):
        for j in range(COL):
            axes[i][j].imshow(generated_image[count,:,:,0] , cmap = 'gray')
            axes[i][j].axis('off')
            axes[i][j].set_title('%d' % (label[i*ROW+j]))
            count += 1
    
    
    fig.savefig('mnist_cgan/No.%d.png' % (epoch))
    plt.pyplot.close()

# %%
def generator():
    #sample from noise z
    model = Sequential(name='generator')
    
    #mnist 图像使用 28*28*1
    model.add(Dense(128 * 7 * 7, activation="relu", input_shape=(LATENT_DIM,)))
    model.add(Reshape((7, 7, 128)))
    model.add(UpSampling2D())
    
    model.add(Conv2D(128, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    model.add(UpSampling2D())
    
    model.add(Conv2D(64, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    
    model.add(Conv2D(CHANNEL, kernel_size=3, padding="same"))
    model.add(Activation("tanh"))
    #
    model.summary()
    
    noise = Input(shape=(LATENT_DIM , ) , name='input1')
    label = Input(shape=(1,) , dtype='int32')
    
    _ = Embedding(input_dim=CLASS_NUM , output_dim=LATENT_DIM)(label)
    embedding_label = Flatten()(_)
    
    noise_embedding_label = Multiply()([noise , embedding_label]) #(None , LATENT_DIM)
    
    image = model(noise_embedding_label)
    
    return Model([noise , label] , image , name='generator_Model')

# %%
def discriminator():
    #input a image to discriminate real or fake
    model = Sequential(name='discriminator')
    
    #model.add(Conv2D(filters=32 , kernel_size=(3,3) , strides=(2,2) , padding='same' , input_shape=(WIDTH , HEIGHT , CHANNEL) , name='conv1'))
    #model.add(LeakyReLU(0.2))
    #model.add(Dropout(0.25))
    #
    ##model.add(BatchNormalization(momentum=0.8))
    #model.add(Conv2D(filters=64 , kernel_size=(3,3) , strides=(2,2) , padding='same' , name='conv2'))
    #model.add(ZeroPadding2D(padding=((0,1) , (0,1))))
    #model.add(BatchNormalization(momentum=0.8))
    #model.add(LeakyReLU(0.2))
    #model.add(Dropout(0.25))
    #
    #model.add(Conv2D(filters=128 , kernel_size=(3,3) , strides=(2,2) , padding='same' , name='conv3'))
    #model.add(BatchNormalization(momentum=0.8))  
    #model.add(LeakyReLU(0.2))
    #model.add(Dropout(0.25))


    #model.add(Conv2D(filters=256 , kernel_size=(3,3) , strides=(1,1) , name='conv4'))
    #model.add(BatchNormalization(momentum=0.8))  
    #model.add(LeakyReLU(0.2))
    #model.add(Dropout(0.25))

    #model.add(Flatten())
    
    #model.add(Dense(1 , activation='sigmoid'))
    
    model.add(Dense(512 , input_shape=(HEIGHT*WIDTH*CHANNEL , )))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.4))
    
    model.add(Dense(1 , activation='sigmoid'))
    
    model.summary()
    
    image = Input(shape=(WIDTH , HEIGHT , CHANNEL) , name='input1')
    flatten_image = Flatten()(image)
    
    label = Input(shape=(1,))
    embedding_label = Embedding(input_dim=CLASS_NUM , output_dim=HEIGHT*WIDTH*CHANNEL)(label)
    flatten_embedding_label = Flatten()(embedding_label)
    
    input_ = Multiply()([flatten_image , flatten_embedding_label])
    
    
    validity = model(input_)
    
    return Model([image , label] , validity , name='discriminator_Model')

# %%
def combined_model(generator_i , discriminator_i):
    #生成器和判别器组合成整体
    z = Input(shape=(LATENT_DIM , ) , name='z')
    label = Input(shape=(1,) , dtype='int32')
    
    image = generator_i([z , label])
    
    #print(image.shape)
    
    discriminator_i.trainable = False
    validity  = discriminator_i([image , label])
    
    return Model([z , label] , validity , name='combined_model')

# %%
adam = Adam(lr = 0.0002 , beta_1=0.5)

# %%
discriminator_i = discriminator()
discriminator_i.compile(optimizer=adam , loss='binary_crossentropy' , metrics=['accuracy'])

generator_i = generator()

combined_model_i = combined_model(generator_i , discriminator_i)


combined_model_i.compile(optimizer=adam , loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               401920
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 927,745
# Trainable params: 927,745
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 6272)              633472
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# activation_4 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 64)        73792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# activation_5 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 1)         577
# _________________________________________________________________
# activation_6 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 856,193
# Trainable params: 855,809
# Non-trainable params: 384
# _________________________________________________________________

# %%
real_labels = np.ones(shape=(BATCH_SIZE , 1)) #真实样本label为1
fake_labels = np.zeros(shape=(BATCH_SIZE , 1)) #假样本label为0

for i in range(11001):
    noise = np.random.normal(size=(BATCH_SIZE , LATENT_DIM))
    corresponding_fake_label = np.random.randint(low=0 , high=CLASS_NUM , size=(BATCH_SIZE , 1)) #label的取值范围 可能会发生变化

    #real_image = load_image()
    real_image , corresponding_real_label = load_mnist()
    #训练判别器
    fake_image = generator_i.predict([noise , corresponding_fake_label]) #这里是使用 corresponding_fake_label还是corresponding_real_label

    real_loss = discriminator_i.train_on_batch([real_image , corresponding_real_label] , real_labels)
    fake_loss = discriminator_i.train_on_batch([fake_image , corresponding_fake_label] , fake_labels)

    loss = np.add(real_loss , fake_loss)/2

    #训练生成器
    noise2 = np.random.normal(size=(BATCH_SIZE , LATENT_DIM))
    corresponding_fake_label2 = np.random.randint(low=0 , high=CLASS_NUM , size=(BATCH_SIZE , 1))
    
        #下面的损失是一个list 有两个损失 一个是validity一个是与label的softmax
    generator_loss = combined_model_i.train_on_batch([noise2 , corresponding_fake_label2] , real_labels)
    
    print('epoch:%d loss:%f accu:%f gene_loss:[validity:%f]' % (i , loss[0] , loss[1] , generator_loss))
    
    if i % 100 == 0:
        #write_image(i)
        write_image_mnist(i)
    
#write_image(999)
write_image_mnist(999)
# Out:
# C:\Anaconda3\lib\site-packages\keras\engine\training.py:478: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# epoch:0 loss:1.201445 accu:0.484375 gene_loss:[validity:0.222226]
# epoch:1 loss:0.885261 accu:0.500000 gene_loss:[validity:0.315892]
# epoch:2 loss:0.831376 accu:0.468750 gene_loss:[validity:0.380578]
# epoch:3 loss:0.791297 accu:0.476562 gene_loss:[validity:0.420727]
# epoch:4 loss:0.744633 accu:0.476562 gene_loss:[validity:0.463567]
# epoch:5 loss:0.746369 accu:0.476562 gene_loss:[validity:0.511917]
# epoch:6 loss:0.729542 accu:0.492188 gene_loss:[validity:0.533460]
# epoch:7 loss:0.742360 accu:0.476562 gene_loss:[validity:0.547832]
# epoch:8 loss:0.699251 accu:0.500000 gene_loss:[validity:0.687003]
# epoch:9 loss:0.714246 accu:0.476562 gene_loss:[validity:0.545673]
# epoch:10 loss:0.723465 accu:0.500000 gene_loss:[validity:0.555218]
# epoch:11 loss:0.677165 accu:0.507812 gene_loss:[validity:0.575857]
# epoch:12 loss:0.697827 accu:0.492188 gene_loss:[validity:0.589275]
# epoch:13 loss:0.715064 accu:0.460938 gene_loss:[validity:0.582011]
# epoch:14 loss:0.693700 accu:0.484375 gene_loss:[validity:0.612145]
# epoch:15 loss:0.689583 accu:0.460938 gene_loss:[validity:0.596332]
# epoch:16 loss:0.711799 accu:0.421875 gene_loss:[validity:0.611032]
# epoch:17 loss:0.696630 accu:0.460938 gene_loss:[validity:0.601944]
# epoch:18 loss:0.653597 accu:0.531250 gene_loss:[validity:0.620536]
# epoch:19 loss:0.673538 accu:0.500000 gene_loss:[validity:0.643311]
# epoch:20 loss:0.687064 accu:0.437500 gene_loss:[validity:0.645727]
# epoch:21 loss:0.679676 accu:0.507812 gene_loss:[validity:0.673660]
# epoch:22 loss:0.655580 accu:0.507812 gene_loss:[validity:0.680364]
# epoch:23 loss:0.654404 accu:0.585938 gene_loss:[validity:0.682941]
# epoch:24 loss:0.649852 accu:0.515625 gene_loss:[validity:0.719782]
# epoch:25 loss:0.655670 accu:0.585938 gene_loss:[validity:0.670419]
# epoch:26 loss:0.667728 accu:0.476562 gene_loss:[validity:0.673001]
# epoch:27 loss:0.687555 accu:0.500000 gene_loss:[validity:0.685541]
# epoch:28 loss:0.704414 accu:0.484375 gene_loss:[validity:0.665561]
# epoch:29 loss:0.699950 accu:0.492188 gene_loss:[validity:0.654844]
# epoch:30 loss:0.723168 accu:0.390625 gene_loss:[validity:0.631551]
# epoch:31 loss:0.782199 accu:0.429688 gene_loss:[validity:0.716665]
# epoch:32 loss:0.683361 accu:0.523438 gene_loss:[validity:0.959212]
# epoch:33 loss:0.689319 accu:0.500000 gene_loss:[validity:1.019856]
# epoch:34 loss:0.713047 accu:0.484375 gene_loss:[validity:0.849101]
# epoch:35 loss:0.700313 accu:0.429688 gene_loss:[validity:0.695597]
# epoch:36 loss:0.768962 accu:0.382812 gene_loss:[validity:0.704295]
# epoch:37 loss:0.711008 accu:0.468750 gene_loss:[validity:0.734798]
# epoch:38 loss:0.680744 accu:0.515625 gene_loss:[validity:0.755967]
# epoch:39 loss:0.672948 accu:0.632812 gene_loss:[validity:0.711692]
# epoch:40 loss:0.679296 accu:0.609375 gene_loss:[validity:0.708016]
# epoch:41 loss:0.700907 accu:0.484375 gene_loss:[validity:0.710137]
# epoch:42 loss:0.704057 accu:0.421875 gene_loss:[validity:0.766120]
# epoch:43 loss:0.668783 accu:0.531250 gene_loss:[validity:0.902074]
# epoch:44 loss:0.674729 accu:0.476562 gene_loss:[validity:0.864112]
# epoch:45 loss:0.664150 accu:0.476562 gene_loss:[validity:0.880869]
# epoch:46 loss:0.682037 accu:0.507812 gene_loss:[validity:0.952881]
# epoch:47 loss:0.651256 accu:0.601562 gene_loss:[validity:0.936795]
# epoch:48 loss:0.672227 accu:0.570312 gene_loss:[validity:0.760582]
# epoch:49 loss:0.659948 accu:0.593750 gene_loss:[validity:0.725453]
# epoch:50 loss:0.670828 accu:0.593750 gene_loss:[validity:0.684752]
# epoch:51 loss:0.656982 accu:0.570312 gene_loss:[validity:0.716814]
# epoch:52 loss:0.699540 accu:0.500000 gene_loss:[validity:0.713421]
# epoch:53 loss:0.662246 accu:0.578125 gene_loss:[validity:0.695819]
# epoch:54 loss:0.696224 accu:0.554688 gene_loss:[validity:0.700536]
# epoch:55 loss:0.681929 accu:0.546875 gene_loss:[validity:0.703194]
# epoch:56 loss:0.652187 accu:0.632812 gene_loss:[validity:0.708679]
# epoch:57 loss:0.680670 accu:0.546875 gene_loss:[validity:0.706378]
# epoch:58 loss:0.675547 accu:0.460938 gene_loss:[validity:0.713342]
# epoch:59 loss:0.675004 accu:0.445312 gene_loss:[validity:0.691367]
# epoch:60 loss:0.681253 accu:0.593750 gene_loss:[validity:0.689827]
# epoch:61 loss:0.650756 accu:0.539062 gene_loss:[validity:0.753620]
# epoch:62 loss:0.651220 accu:0.539062 gene_loss:[validity:0.705711]
# epoch:63 loss:0.677622 accu:0.492188 gene_loss:[validity:0.725877]
# epoch:64 loss:0.672616 accu:0.476562 gene_loss:[validity:0.695995]
# epoch:65 loss:0.689720 accu:0.421875 gene_loss:[validity:0.746781]
# epoch:66 loss:0.668695 accu:0.492188 gene_loss:[validity:0.738601]
# epoch:67 loss:0.667172 accu:0.546875 gene_loss:[validity:0.741933]
# epoch:68 loss:0.653880 accu:0.593750 gene_loss:[validity:0.713595]
# epoch:69 loss:0.647996 accu:0.546875 gene_loss:[validity:0.695399]
# epoch:70 loss:0.650118 accu:0.507812 gene_loss:[validity:0.719730]
# epoch:71 loss:0.655699 accu:0.484375 gene_loss:[validity:0.753445]
# epoch:72 loss:0.652623 accu:0.484375 gene_loss:[validity:0.734863]
# epoch:73 loss:0.661526 accu:0.554688 gene_loss:[validity:0.782876]
# epoch:74 loss:0.676903 accu:0.468750 gene_loss:[validity:0.730979]
# epoch:75 loss:0.645959 accu:0.507812 gene_loss:[validity:0.745023]
# epoch:76 loss:0.656855 accu:0.492188 gene_loss:[validity:0.794741]
# epoch:77 loss:0.651448 accu:0.546875 gene_loss:[validity:0.821489]
# epoch:78 loss:0.671930 accu:0.500000 gene_loss:[validity:0.804499]
# epoch:79 loss:0.655210 accu:0.492188 gene_loss:[validity:0.852421]
# epoch:80 loss:0.667521 accu:0.531250 gene_loss:[validity:0.795000]
# epoch:81 loss:0.657653 accu:0.570312 gene_loss:[validity:0.816546]
# epoch:82 loss:0.686118 accu:0.500000 gene_loss:[validity:0.886367]
# epoch:83 loss:0.662973 accu:0.468750 gene_loss:[validity:0.830179]
# epoch:84 loss:0.685407 accu:0.484375 gene_loss:[validity:1.187937]
# epoch:85 loss:0.709708 accu:0.523438 gene_loss:[validity:0.840655]
# epoch:86 loss:0.709633 accu:0.445312 gene_loss:[validity:0.847917]
# epoch:87 loss:0.664871 accu:0.484375 gene_loss:[validity:1.110081]
# epoch:88 loss:0.660615 accu:0.539062 gene_loss:[validity:0.956213]
# epoch:89 loss:0.674601 accu:0.539062 gene_loss:[validity:0.938567]
# epoch:90 loss:0.651974 accu:0.531250 gene_loss:[validity:0.924201]
# epoch:91 loss:0.625880 accu:0.554688 gene_loss:[validity:1.089568]
# epoch:92 loss:0.634873 accu:0.546875 gene_loss:[validity:1.038071]
# epoch:93 loss:0.652710 accu:0.601562 gene_loss:[validity:1.061791]
# epoch:94 loss:0.647475 accu:0.507812 gene_loss:[validity:0.986983]
# epoch:95 loss:0.631877 accu:0.625000 gene_loss:[validity:1.115067]
# epoch:96 loss:0.629022 accu:0.601562 gene_loss:[validity:0.932369]
# epoch:97 loss:0.637164 accu:0.585938 gene_loss:[validity:0.927892]
# epoch:98 loss:0.672249 accu:0.445312 gene_loss:[validity:0.903440]
# epoch:99 loss:0.582395 accu:0.656250 gene_loss:[validity:1.115100]
# epoch:100 loss:0.615791 accu:0.640625 gene_loss:[validity:0.930649]
# epoch:101 loss:0.623309 accu:0.562500 gene_loss:[validity:0.854870]
# epoch:102 loss:0.636052 accu:0.554688 gene_loss:[validity:0.850144]
# epoch:103 loss:0.641383 accu:0.593750 gene_loss:[validity:1.236178]
# epoch:104 loss:0.662364 accu:0.578125 gene_loss:[validity:0.794739]
# epoch:105 loss:0.635461 accu:0.617188 gene_loss:[validity:1.079049]
# epoch:106 loss:0.625746 accu:0.601562 gene_loss:[validity:1.366745]
# epoch:107 loss:0.883797 accu:0.476562 gene_loss:[validity:0.880257]
# epoch:108 loss:0.658798 accu:0.570312 gene_loss:[validity:1.256617]
# epoch:109 loss:0.635613 accu:0.578125 gene_loss:[validity:0.857361]
# epoch:110 loss:0.664894 accu:0.570312 gene_loss:[validity:1.076393]
# epoch:111 loss:0.657535 accu:0.554688 gene_loss:[validity:0.897861]
# epoch:112 loss:0.683913 accu:0.468750 gene_loss:[validity:0.784382]
# epoch:113 loss:0.661333 accu:0.562500 gene_loss:[validity:0.870112]
# epoch:114 loss:0.633337 accu:0.570312 gene_loss:[validity:0.919675]
# epoch:115 loss:0.671643 accu:0.531250 gene_loss:[validity:0.776100]
# epoch:116 loss:0.651928 accu:0.562500 gene_loss:[validity:0.797738]
# epoch:117 loss:0.655135 accu:0.507812 gene_loss:[validity:0.716012]
# epoch:118 loss:0.723622 accu:0.500000 gene_loss:[validity:0.742068]
# epoch:119 loss:0.680028 accu:0.562500 gene_loss:[validity:0.709304]
# epoch:120 loss:0.659220 accu:0.609375 gene_loss:[validity:0.716996]
# epoch:121 loss:0.691958 accu:0.476562 gene_loss:[validity:0.725042]
# epoch:122 loss:0.650199 accu:0.609375 gene_loss:[validity:0.715471]
# epoch:123 loss:0.686983 accu:0.507812 gene_loss:[validity:0.735139]
# epoch:124 loss:0.677772 accu:0.507812 gene_loss:[validity:0.721582]
# epoch:125 loss:0.668637 accu:0.500000 gene_loss:[validity:0.690528]
# epoch:126 loss:0.684684 accu:0.523438 gene_loss:[validity:0.747764]
# epoch:127 loss:0.666873 accu:0.578125 gene_loss:[validity:0.711028]
# epoch:128 loss:0.647054 accu:0.632812 gene_loss:[validity:0.714730]
# epoch:129 loss:0.668272 accu:0.593750 gene_loss:[validity:0.709609]
# epoch:130 loss:0.672614 accu:0.500000 gene_loss:[validity:0.703500]
# epoch:131 loss:0.690524 accu:0.468750 gene_loss:[validity:0.685691]
# epoch:132 loss:0.677598 accu:0.492188 gene_loss:[validity:0.710102]
# epoch:133 loss:0.660267 accu:0.507812 gene_loss:[validity:0.686077]
# epoch:134 loss:0.714253 accu:0.429688 gene_loss:[validity:0.690571]
# epoch:135 loss:0.700142 accu:0.398438 gene_loss:[validity:0.697519]
# epoch:136 loss:0.691666 accu:0.445312 gene_loss:[validity:0.692338]
# epoch:137 loss:0.667089 accu:0.531250 gene_loss:[validity:0.717362]
# epoch:138 loss:0.655831 accu:0.585938 gene_loss:[validity:0.729462]
# epoch:139 loss:0.666593 accu:0.523438 gene_loss:[validity:0.724777]
# epoch:140 loss:0.672179 accu:0.484375 gene_loss:[validity:0.712283]
# epoch:141 loss:0.663789 accu:0.531250 gene_loss:[validity:0.712837]
# epoch:142 loss:0.677417 accu:0.507812 gene_loss:[validity:0.728825]
# epoch:143 loss:0.666192 accu:0.546875 gene_loss:[validity:0.723865]
# epoch:144 loss:0.677126 accu:0.515625 gene_loss:[validity:0.723154]
# epoch:145 loss:0.666784 accu:0.546875 gene_loss:[validity:0.713912]
# epoch:146 loss:0.665762 accu:0.562500 gene_loss:[validity:0.698702]
# epoch:147 loss:0.687213 accu:0.484375 gene_loss:[validity:0.681802]
# epoch:148 loss:0.684542 accu:0.531250 gene_loss:[validity:0.678546]
# epoch:149 loss:0.682475 accu:0.539062 gene_loss:[validity:0.708409]
# epoch:150 loss:0.709492 accu:0.484375 gene_loss:[validity:0.685744]
# epoch:151 loss:0.685887 accu:0.500000 gene_loss:[validity:0.693557]
# epoch:152 loss:0.693873 accu:0.484375 gene_loss:[validity:0.666359]
# epoch:153 loss:0.682303 accu:0.515625 gene_loss:[validity:0.673540]
# epoch:154 loss:0.707403 accu:0.515625 gene_loss:[validity:0.664638]
# epoch:155 loss:0.707954 accu:0.468750 gene_loss:[validity:0.669748]
# epoch:156 loss:0.699962 accu:0.468750 gene_loss:[validity:0.677526]
# epoch:157 loss:0.688232 accu:0.453125 gene_loss:[validity:0.667206]
# epoch:158 loss:0.692414 accu:0.500000 gene_loss:[validity:0.679936]
# epoch:159 loss:0.689970 accu:0.445312 gene_loss:[validity:0.707705]
# epoch:160 loss:0.690474 accu:0.539062 gene_loss:[validity:0.717798]
# epoch:161 loss:0.698831 accu:0.492188 gene_loss:[validity:0.679821]
# epoch:162 loss:0.696728 accu:0.445312 gene_loss:[validity:0.698237]
# epoch:163 loss:0.702070 accu:0.445312 gene_loss:[validity:0.694937]
# epoch:164 loss:0.726218 accu:0.460938 gene_loss:[validity:0.714952]
# epoch:165 loss:0.705676 accu:0.484375 gene_loss:[validity:0.704812]
# epoch:166 loss:0.701106 accu:0.492188 gene_loss:[validity:0.687781]
# epoch:167 loss:0.687278 accu:0.562500 gene_loss:[validity:0.722495]
# epoch:168 loss:0.695901 accu:0.476562 gene_loss:[validity:0.720267]
# epoch:169 loss:0.689309 accu:0.562500 gene_loss:[validity:0.733057]
# epoch:170 loss:0.685143 accu:0.593750 gene_loss:[validity:0.709649]
# epoch:171 loss:0.694221 accu:0.484375 gene_loss:[validity:0.722546]
# epoch:172 loss:0.704960 accu:0.429688 gene_loss:[validity:0.711808]
# epoch:173 loss:0.672547 accu:0.539062 gene_loss:[validity:0.714483]
# epoch:174 loss:0.684258 accu:0.562500 gene_loss:[validity:0.711308]
# epoch:175 loss:0.684259 accu:0.578125 gene_loss:[validity:0.694096]
# epoch:176 loss:0.657329 accu:0.554688 gene_loss:[validity:0.712826]
# epoch:177 loss:0.679258 accu:0.523438 gene_loss:[validity:0.717586]
# epoch:178 loss:0.682567 accu:0.492188 gene_loss:[validity:0.700761]
# epoch:179 loss:0.715385 accu:0.429688 gene_loss:[validity:0.680193]
# epoch:180 loss:0.701177 accu:0.539062 gene_loss:[validity:0.708783]
# epoch:181 loss:0.713632 accu:0.500000 gene_loss:[validity:0.711849]
# epoch:182 loss:0.663595 accu:0.578125 gene_loss:[validity:0.729023]
# epoch:183 loss:0.684867 accu:0.515625 gene_loss:[validity:0.690580]
# epoch:184 loss:0.687622 accu:0.515625 gene_loss:[validity:0.696959]
# epoch:185 loss:0.722094 accu:0.515625 gene_loss:[validity:0.679594]
# epoch:186 loss:0.709076 accu:0.476562 gene_loss:[validity:1.059774]
# epoch:187 loss:0.664888 accu:0.554688 gene_loss:[validity:0.820395]
# epoch:188 loss:0.688452 accu:0.578125 gene_loss:[validity:0.788342]
# epoch:189 loss:0.703026 accu:0.562500 gene_loss:[validity:0.766646]
# epoch:190 loss:0.718759 accu:0.507812 gene_loss:[validity:0.714337]
# epoch:191 loss:0.695538 accu:0.515625 gene_loss:[validity:0.702478]
# epoch:192 loss:0.669180 accu:0.648438 gene_loss:[validity:0.702473]
# epoch:193 loss:0.671045 accu:0.601562 gene_loss:[validity:0.669835]
# epoch:194 loss:0.671780 accu:0.578125 gene_loss:[validity:0.722969]
# epoch:195 loss:0.691286 accu:0.492188 gene_loss:[validity:0.689276]
# epoch:196 loss:0.695804 accu:0.500000 gene_loss:[validity:0.676911]
# epoch:197 loss:0.692082 accu:0.539062 gene_loss:[validity:0.675335]
# epoch:198 loss:0.689332 accu:0.484375 gene_loss:[validity:0.692366]
# epoch:199 loss:0.674023 accu:0.523438 gene_loss:[validity:0.712930]
# epoch:200 loss:0.700747 accu:0.468750 gene_loss:[validity:0.701353]
# epoch:201 loss:0.689648 accu:0.546875 gene_loss:[validity:0.688825]
# epoch:202 loss:0.696593 accu:0.515625 gene_loss:[validity:0.684848]
# epoch:203 loss:0.671150 accu:0.609375 gene_loss:[validity:0.729577]
# epoch:204 loss:0.682706 accu:0.546875 gene_loss:[validity:0.703354]
# epoch:205 loss:0.687914 accu:0.515625 gene_loss:[validity:0.738969]
# epoch:206 loss:0.697607 accu:0.453125 gene_loss:[validity:0.706408]
# epoch:207 loss:0.689792 accu:0.539062 gene_loss:[validity:0.742191]
# epoch:208 loss:0.699252 accu:0.492188 gene_loss:[validity:0.735803]
# epoch:209 loss:0.681162 accu:0.531250 gene_loss:[validity:0.719298]
# epoch:210 loss:0.677243 accu:0.546875 gene_loss:[validity:0.734177]
# epoch:211 loss:0.664312 accu:0.539062 gene_loss:[validity:0.780562]
# epoch:212 loss:0.712204 accu:0.492188 gene_loss:[validity:0.721234]
# epoch:213 loss:0.689779 accu:0.492188 gene_loss:[validity:0.728722]
# epoch:214 loss:0.684962 accu:0.515625 gene_loss:[validity:0.737728]
# epoch:215 loss:0.702170 accu:0.546875 gene_loss:[validity:0.733052]
# epoch:216 loss:0.710390 accu:0.484375 gene_loss:[validity:0.732507]
# epoch:217 loss:0.693582 accu:0.632812 gene_loss:[validity:0.705662]
# epoch:218 loss:0.696044 accu:0.531250 gene_loss:[validity:0.693052]
# epoch:219 loss:0.679251 accu:0.570312 gene_loss:[validity:0.736378]
# epoch:220 loss:0.703183 accu:0.507812 gene_loss:[validity:0.698774]
# epoch:221 loss:0.673278 accu:0.546875 gene_loss:[validity:0.694314]
# epoch:222 loss:0.689933 accu:0.515625 gene_loss:[validity:0.703444]
# epoch:223 loss:0.685627 accu:0.515625 gene_loss:[validity:0.694847]
# epoch:224 loss:0.678854 accu:0.570312 gene_loss:[validity:0.703904]
# epoch:225 loss:0.692471 accu:0.484375 gene_loss:[validity:0.697443]
# epoch:226 loss:0.658242 accu:0.570312 gene_loss:[validity:0.707714]
# epoch:227 loss:0.681150 accu:0.562500 gene_loss:[validity:0.707758]
# epoch:228 loss:0.672525 accu:0.578125 gene_loss:[validity:0.731265]
# epoch:229 loss:0.667888 accu:0.562500 gene_loss:[validity:0.733330]
# epoch:230 loss:0.636929 accu:0.609375 gene_loss:[validity:0.756120]
# epoch:231 loss:0.648672 accu:0.546875 gene_loss:[validity:0.741557]
# epoch:232 loss:0.646301 accu:0.632812 gene_loss:[validity:0.777934]
# epoch:233 loss:0.656806 accu:0.578125 gene_loss:[validity:0.780276]
# epoch:234 loss:0.657086 accu:0.578125 gene_loss:[validity:0.913447]
# epoch:235 loss:0.678142 accu:0.578125 gene_loss:[validity:0.740804]
# epoch:236 loss:0.679300 accu:0.593750 gene_loss:[validity:0.798138]
# epoch:237 loss:0.800649 accu:0.570312 gene_loss:[validity:0.912556]
# epoch:238 loss:0.721178 accu:0.570312 gene_loss:[validity:0.845529]
# epoch:239 loss:0.804146 accu:0.429688 gene_loss:[validity:0.688852]
# epoch:240 loss:0.700684 accu:0.453125 gene_loss:[validity:0.703772]
# epoch:241 loss:0.719330 accu:0.429688 gene_loss:[validity:0.708832]
# epoch:242 loss:0.684293 accu:0.539062 gene_loss:[validity:0.695589]
# epoch:243 loss:0.682550 accu:0.484375 gene_loss:[validity:0.721122]
# epoch:244 loss:0.684030 accu:0.562500 gene_loss:[validity:0.698571]
# epoch:245 loss:0.689012 accu:0.546875 gene_loss:[validity:0.696159]
# epoch:246 loss:0.717511 accu:0.367188 gene_loss:[validity:0.720324]
# epoch:247 loss:0.699540 accu:0.515625 gene_loss:[validity:0.701308]
# epoch:248 loss:0.687133 accu:0.554688 gene_loss:[validity:0.723380]
# epoch:249 loss:0.692796 accu:0.531250 gene_loss:[validity:0.735116]
# epoch:250 loss:0.680565 accu:0.562500 gene_loss:[validity:0.734795]
# epoch:251 loss:0.674103 accu:0.601562 gene_loss:[validity:0.746972]
# epoch:252 loss:0.675053 accu:0.562500 gene_loss:[validity:0.718600]
# epoch:253 loss:0.670628 accu:0.546875 gene_loss:[validity:0.739025]
# epoch:254 loss:0.668610 accu:0.562500 gene_loss:[validity:0.775805]
# epoch:255 loss:0.670524 accu:0.648438 gene_loss:[validity:0.767379]
# epoch:256 loss:0.661874 accu:0.570312 gene_loss:[validity:0.752415]
# epoch:257 loss:0.677176 accu:0.531250 gene_loss:[validity:0.787593]
# epoch:258 loss:0.660503 accu:0.703125 gene_loss:[validity:0.785307]
# epoch:259 loss:0.667338 accu:0.523438 gene_loss:[validity:0.739908]
# epoch:260 loss:0.650286 accu:0.656250 gene_loss:[validity:0.721688]
# epoch:261 loss:0.637118 accu:0.648438 gene_loss:[validity:0.770342]
# epoch:262 loss:0.645340 accu:0.617188 gene_loss:[validity:0.710381]
# epoch:263 loss:0.635522 accu:0.578125 gene_loss:[validity:0.712610]
# epoch:264 loss:0.663228 accu:0.625000 gene_loss:[validity:0.704382]
# epoch:265 loss:0.655504 accu:0.625000 gene_loss:[validity:0.715290]
# epoch:266 loss:0.650355 accu:0.593750 gene_loss:[validity:0.680306]
# epoch:267 loss:0.668712 accu:0.554688 gene_loss:[validity:0.630577]
# epoch:268 loss:0.743624 accu:0.421875 gene_loss:[validity:0.824325]
# epoch:269 loss:0.631568 accu:0.632812 gene_loss:[validity:0.736155]
# epoch:270 loss:0.654983 accu:0.531250 gene_loss:[validity:0.835533]
# epoch:271 loss:0.650855 accu:0.617188 gene_loss:[validity:0.796038]
# epoch:272 loss:0.664498 accu:0.546875 gene_loss:[validity:0.788008]
# epoch:273 loss:0.678958 accu:0.507812 gene_loss:[validity:0.743104]
# epoch:274 loss:0.702707 accu:0.406250 gene_loss:[validity:0.846192]
# epoch:275 loss:0.657801 accu:0.593750 gene_loss:[validity:0.757047]
# epoch:276 loss:0.661137 accu:0.531250 gene_loss:[validity:0.832001]
# epoch:277 loss:0.656381 accu:0.531250 gene_loss:[validity:0.825044]
# epoch:278 loss:0.671312 accu:0.585938 gene_loss:[validity:0.841323]
# epoch:279 loss:0.691053 accu:0.609375 gene_loss:[validity:0.918918]
# epoch:280 loss:0.622128 accu:0.640625 gene_loss:[validity:0.857639]
# epoch:281 loss:0.688884 accu:0.460938 gene_loss:[validity:0.835903]
# epoch:282 loss:0.679775 accu:0.492188 gene_loss:[validity:0.844360]
# epoch:283 loss:0.649440 accu:0.531250 gene_loss:[validity:0.833267]
# epoch:284 loss:0.634363 accu:0.562500 gene_loss:[validity:0.786083]
# epoch:285 loss:0.627541 accu:0.617188 gene_loss:[validity:0.912849]
# epoch:286 loss:0.649537 accu:0.523438 gene_loss:[validity:0.938765]
# epoch:287 loss:0.642573 accu:0.640625 gene_loss:[validity:0.904816]
# epoch:288 loss:0.703245 accu:0.507812 gene_loss:[validity:0.722402]
# epoch:289 loss:0.696286 accu:0.492188 gene_loss:[validity:0.820798]
# epoch:290 loss:0.677774 accu:0.515625 gene_loss:[validity:0.800849]
# epoch:291 loss:0.658323 accu:0.562500 gene_loss:[validity:0.787149]
# epoch:292 loss:0.681777 accu:0.554688 gene_loss:[validity:0.724617]
# epoch:293 loss:0.641603 accu:0.640625 gene_loss:[validity:0.744076]
# epoch:294 loss:0.664348 accu:0.523438 gene_loss:[validity:0.735304]
# epoch:295 loss:0.634004 accu:0.640625 gene_loss:[validity:0.754487]
# epoch:296 loss:0.660273 accu:0.515625 gene_loss:[validity:0.890014]
# epoch:297 loss:0.633932 accu:0.546875 gene_loss:[validity:0.799143]
# epoch:298 loss:0.657907 accu:0.585938 gene_loss:[validity:0.785836]
# epoch:299 loss:0.675520 accu:0.578125 gene_loss:[validity:0.812777]
# epoch:300 loss:0.667577 accu:0.570312 gene_loss:[validity:0.851864]
# epoch:301 loss:0.681372 accu:0.585938 gene_loss:[validity:0.800341]
# epoch:302 loss:0.653507 accu:0.609375 gene_loss:[validity:0.800959]
# epoch:303 loss:0.674759 accu:0.468750 gene_loss:[validity:0.755389]
# epoch:304 loss:0.644913 accu:0.601562 gene_loss:[validity:0.847670]
# epoch:305 loss:0.673293 accu:0.445312 gene_loss:[validity:0.783022]
# epoch:306 loss:0.631875 accu:0.617188 gene_loss:[validity:0.745182]
# epoch:307 loss:0.683126 accu:0.492188 gene_loss:[validity:0.887633]
# epoch:308 loss:0.657403 accu:0.554688 gene_loss:[validity:0.776395]
# epoch:309 loss:0.685765 accu:0.562500 gene_loss:[validity:0.854081]
# epoch:310 loss:0.716479 accu:0.515625 gene_loss:[validity:0.807919]
# epoch:311 loss:0.698487 accu:0.500000 gene_loss:[validity:0.887029]
# epoch:312 loss:0.685917 accu:0.484375 gene_loss:[validity:1.026059]
# epoch:313 loss:0.691593 accu:0.453125 gene_loss:[validity:0.910382]
# epoch:314 loss:0.764462 accu:0.445312 gene_loss:[validity:0.798987]
# epoch:315 loss:0.695546 accu:0.492188 gene_loss:[validity:1.291874]
# epoch:316 loss:0.690496 accu:0.500000 gene_loss:[validity:1.188114]
# epoch:317 loss:0.841574 accu:0.406250 gene_loss:[validity:0.686224]
# epoch:318 loss:0.703574 accu:0.460938 gene_loss:[validity:0.750069]
# epoch:319 loss:0.652049 accu:0.562500 gene_loss:[validity:0.875805]
# epoch:320 loss:0.644816 accu:0.546875 gene_loss:[validity:1.040818]
# epoch:321 loss:0.625659 accu:0.617188 gene_loss:[validity:0.852314]
# epoch:322 loss:0.665935 accu:0.554688 gene_loss:[validity:0.804990]
# epoch:323 loss:0.718543 accu:0.632812 gene_loss:[validity:0.745807]
# epoch:324 loss:0.676229 accu:0.585938 gene_loss:[validity:0.711573]
# epoch:325 loss:0.662561 accu:0.648438 gene_loss:[validity:0.820812]
# epoch:326 loss:0.653150 accu:0.562500 gene_loss:[validity:0.832063]
# epoch:327 loss:0.640541 accu:0.609375 gene_loss:[validity:0.891589]
# epoch:328 loss:0.634886 accu:0.609375 gene_loss:[validity:0.804358]
# epoch:329 loss:0.659247 accu:0.593750 gene_loss:[validity:0.820821]
# epoch:330 loss:0.648586 accu:0.570312 gene_loss:[validity:0.837751]
# epoch:331 loss:0.646628 accu:0.546875 gene_loss:[validity:0.806068]
# epoch:332 loss:0.633425 accu:0.578125 gene_loss:[validity:0.908294]
# epoch:333 loss:0.640524 accu:0.648438 gene_loss:[validity:0.794422]
# epoch:334 loss:0.649650 accu:0.617188 gene_loss:[validity:0.801477]
# epoch:335 loss:0.656845 accu:0.562500 gene_loss:[validity:0.735127]
# epoch:336 loss:0.666317 accu:0.562500 gene_loss:[validity:0.752426]
# epoch:337 loss:0.647204 accu:0.593750 gene_loss:[validity:0.804206]
# epoch:338 loss:0.639054 accu:0.484375 gene_loss:[validity:0.798363]
# epoch:339 loss:0.603341 accu:0.664062 gene_loss:[validity:0.856796]
# epoch:340 loss:0.630402 accu:0.562500 gene_loss:[validity:0.854159]
# epoch:341 loss:0.648401 accu:0.585938 gene_loss:[validity:0.763745]
# epoch:342 loss:0.660423 accu:0.492188 gene_loss:[validity:0.833386]
# epoch:343 loss:0.646403 accu:0.625000 gene_loss:[validity:0.781192]
# epoch:344 loss:0.663452 accu:0.617188 gene_loss:[validity:0.785616]
# epoch:345 loss:0.628149 accu:0.664062 gene_loss:[validity:0.755501]
# epoch:346 loss:0.676923 accu:0.570312 gene_loss:[validity:0.700295]
# epoch:347 loss:0.643847 accu:0.523438 gene_loss:[validity:0.756091]
# epoch:348 loss:0.704576 accu:0.554688 gene_loss:[validity:0.712754]
# epoch:349 loss:0.702971 accu:0.562500 gene_loss:[validity:0.775409]
# epoch:350 loss:0.665469 accu:0.593750 gene_loss:[validity:0.837343]
# epoch:351 loss:0.676510 accu:0.578125 gene_loss:[validity:0.779609]
# epoch:352 loss:0.653844 accu:0.632812 gene_loss:[validity:0.872084]
# epoch:353 loss:0.706991 accu:0.554688 gene_loss:[validity:0.882819]
# epoch:354 loss:0.660886 accu:0.640625 gene_loss:[validity:0.864798]
# epoch:355 loss:0.651408 accu:0.585938 gene_loss:[validity:0.979275]
# epoch:356 loss:0.650163 accu:0.585938 gene_loss:[validity:0.918272]
# epoch:357 loss:0.649442 accu:0.617188 gene_loss:[validity:0.847118]
# epoch:358 loss:0.617525 accu:0.632812 gene_loss:[validity:1.001834]
# epoch:359 loss:0.647512 accu:0.632812 gene_loss:[validity:0.873706]
# epoch:360 loss:0.646889 accu:0.601562 gene_loss:[validity:0.805200]
# epoch:361 loss:0.708706 accu:0.515625 gene_loss:[validity:0.744471]
# epoch:362 loss:0.677259 accu:0.578125 gene_loss:[validity:0.829321]
# epoch:363 loss:0.679178 accu:0.562500 gene_loss:[validity:0.756830]
# epoch:364 loss:0.658312 accu:0.593750 gene_loss:[validity:0.829905]
# epoch:365 loss:0.695897 accu:0.546875 gene_loss:[validity:0.782643]
# epoch:366 loss:0.665317 accu:0.570312 gene_loss:[validity:0.689146]
# epoch:367 loss:0.707066 accu:0.453125 gene_loss:[validity:0.796297]
# epoch:368 loss:0.674031 accu:0.578125 gene_loss:[validity:0.842952]
# epoch:369 loss:0.706097 accu:0.492188 gene_loss:[validity:0.949274]
# epoch:370 loss:0.640232 accu:0.601562 gene_loss:[validity:0.965902]
# epoch:371 loss:0.670978 accu:0.507812 gene_loss:[validity:1.049666]
# epoch:372 loss:0.654803 accu:0.554688 gene_loss:[validity:0.949293]
# epoch:373 loss:0.710521 accu:0.484375 gene_loss:[validity:0.878015]
# epoch:374 loss:0.717536 accu:0.570312 gene_loss:[validity:0.912335]
# epoch:375 loss:0.656805 accu:0.585938 gene_loss:[validity:0.925263]
# epoch:376 loss:0.664623 accu:0.562500 gene_loss:[validity:1.037737]
# epoch:377 loss:0.690906 accu:0.554688 gene_loss:[validity:0.726838]
# epoch:378 loss:0.698524 accu:0.531250 gene_loss:[validity:0.775594]
# epoch:379 loss:0.656769 accu:0.585938 gene_loss:[validity:0.749097]
# epoch:380 loss:0.703755 accu:0.554688 gene_loss:[validity:0.741726]
# epoch:381 loss:0.669470 accu:0.562500 gene_loss:[validity:0.733917]
# epoch:382 loss:0.643289 accu:0.593750 gene_loss:[validity:0.731701]
# epoch:383 loss:0.643229 accu:0.562500 gene_loss:[validity:0.759640]
# epoch:384 loss:0.652785 accu:0.562500 gene_loss:[validity:0.749827]
# epoch:385 loss:0.651671 accu:0.632812 gene_loss:[validity:0.743986]
# epoch:386 loss:0.642932 accu:0.554688 gene_loss:[validity:0.752102]
# epoch:387 loss:0.695368 accu:0.507812 gene_loss:[validity:0.709776]
# epoch:388 loss:0.634416 accu:0.617188 gene_loss:[validity:0.892866]
# epoch:389 loss:0.630664 accu:0.609375 gene_loss:[validity:0.822546]
# epoch:390 loss:0.657970 accu:0.632812 gene_loss:[validity:0.881030]
# epoch:391 loss:0.579193 accu:0.687500 gene_loss:[validity:1.035249]
# epoch:392 loss:0.655415 accu:0.523438 gene_loss:[validity:1.029921]
# epoch:393 loss:0.656102 accu:0.570312 gene_loss:[validity:1.010522]
# epoch:394 loss:0.736639 accu:0.593750 gene_loss:[validity:0.751221]
# epoch:395 loss:0.690788 accu:0.539062 gene_loss:[validity:0.965027]
# epoch:396 loss:0.669983 accu:0.531250 gene_loss:[validity:1.184613]
# epoch:397 loss:0.696084 accu:0.515625 gene_loss:[validity:1.080912]
# epoch:398 loss:0.698891 accu:0.570312 gene_loss:[validity:1.079811]
# epoch:399 loss:0.663060 accu:0.460938 gene_loss:[validity:0.841101]
# epoch:400 loss:0.638916 accu:0.593750 gene_loss:[validity:0.883974]
# epoch:401 loss:0.656609 accu:0.500000 gene_loss:[validity:0.796887]
# epoch:402 loss:0.647022 accu:0.554688 gene_loss:[validity:0.774292]
# epoch:403 loss:0.633138 accu:0.593750 gene_loss:[validity:0.955800]
# epoch:404 loss:0.658476 accu:0.507812 gene_loss:[validity:0.914538]
# epoch:405 loss:0.682594 accu:0.476562 gene_loss:[validity:0.745208]
# epoch:406 loss:0.654974 accu:0.570312 gene_loss:[validity:0.821983]
# epoch:407 loss:0.688235 accu:0.531250 gene_loss:[validity:0.894077]
# epoch:408 loss:0.708088 accu:0.437500 gene_loss:[validity:0.927279]
# epoch:409 loss:0.725312 accu:0.460938 gene_loss:[validity:0.777553]
# epoch:410 loss:0.692014 accu:0.484375 gene_loss:[validity:0.848265]
# epoch:411 loss:0.690643 accu:0.453125 gene_loss:[validity:0.734823]
# epoch:412 loss:0.692614 accu:0.492188 gene_loss:[validity:0.760072]
# epoch:413 loss:0.671958 accu:0.539062 gene_loss:[validity:0.735496]
# epoch:414 loss:0.668713 accu:0.523438 gene_loss:[validity:0.738079]
# epoch:415 loss:0.661027 accu:0.492188 gene_loss:[validity:0.758828]
# epoch:416 loss:0.703976 accu:0.484375 gene_loss:[validity:0.756489]
# epoch:417 loss:0.660900 accu:0.554688 gene_loss:[validity:0.803858]
# epoch:418 loss:0.676126 accu:0.617188 gene_loss:[validity:0.750150]
# epoch:419 loss:0.672681 accu:0.578125 gene_loss:[validity:0.779419]
# epoch:420 loss:0.627041 accu:0.593750 gene_loss:[validity:0.738440]
# epoch:421 loss:0.684412 accu:0.578125 gene_loss:[validity:0.721456]
# epoch:422 loss:0.649573 accu:0.601562 gene_loss:[validity:0.747268]
# epoch:423 loss:0.631534 accu:0.570312 gene_loss:[validity:0.700664]
# epoch:424 loss:0.674982 accu:0.523438 gene_loss:[validity:0.707323]
# epoch:425 loss:0.644409 accu:0.609375 gene_loss:[validity:0.728125]
# epoch:426 loss:0.698103 accu:0.554688 gene_loss:[validity:0.754717]
# epoch:427 loss:0.638645 accu:0.656250 gene_loss:[validity:0.803961]
# epoch:428 loss:0.648677 accu:0.515625 gene_loss:[validity:0.789852]
# epoch:429 loss:0.646359 accu:0.578125 gene_loss:[validity:0.855747]
# epoch:430 loss:0.645239 accu:0.601562 gene_loss:[validity:0.917647]
# epoch:431 loss:0.707684 accu:0.500000 gene_loss:[validity:0.848028]
# epoch:432 loss:0.670314 accu:0.625000 gene_loss:[validity:0.745884]
# epoch:433 loss:0.641934 accu:0.562500 gene_loss:[validity:0.805947]
# epoch:434 loss:0.643137 accu:0.632812 gene_loss:[validity:0.726714]
# epoch:435 loss:0.650945 accu:0.562500 gene_loss:[validity:0.782277]
# epoch:436 loss:0.757522 accu:0.484375 gene_loss:[validity:0.668499]
# epoch:437 loss:0.723004 accu:0.539062 gene_loss:[validity:0.706942]
# epoch:438 loss:0.749926 accu:0.445312 gene_loss:[validity:0.765474]
# epoch:439 loss:0.687766 accu:0.546875 gene_loss:[validity:0.739042]
# epoch:440 loss:0.719607 accu:0.460938 gene_loss:[validity:0.786727]
# epoch:441 loss:0.674913 accu:0.578125 gene_loss:[validity:0.764627]
# epoch:442 loss:0.697269 accu:0.531250 gene_loss:[validity:0.789655]
# epoch:443 loss:0.690100 accu:0.507812 gene_loss:[validity:0.730441]
# epoch:444 loss:0.719569 accu:0.500000 gene_loss:[validity:0.719831]
# epoch:445 loss:0.710371 accu:0.484375 gene_loss:[validity:0.744428]
# epoch:446 loss:0.696337 accu:0.585938 gene_loss:[validity:0.705370]
# epoch:447 loss:0.706574 accu:0.468750 gene_loss:[validity:0.659976]
# epoch:448 loss:0.694144 accu:0.531250 gene_loss:[validity:0.798119]
# epoch:449 loss:0.686916 accu:0.570312 gene_loss:[validity:0.700956]
# epoch:450 loss:0.699060 accu:0.578125 gene_loss:[validity:0.740523]
# epoch:451 loss:0.687328 accu:0.578125 gene_loss:[validity:0.715292]
# epoch:452 loss:0.699637 accu:0.476562 gene_loss:[validity:0.699179]
# epoch:453 loss:0.686409 accu:0.570312 gene_loss:[validity:0.731067]
# epoch:454 loss:0.706694 accu:0.500000 gene_loss:[validity:0.689842]
# epoch:455 loss:0.703744 accu:0.484375 gene_loss:[validity:0.710374]
# epoch:456 loss:0.712986 accu:0.546875 gene_loss:[validity:0.695753]
# epoch:457 loss:0.701435 accu:0.523438 gene_loss:[validity:0.734076]
# epoch:458 loss:0.701153 accu:0.500000 gene_loss:[validity:0.721102]
# epoch:459 loss:0.707129 accu:0.554688 gene_loss:[validity:0.732259]
# epoch:460 loss:0.672254 accu:0.578125 gene_loss:[validity:1.013932]
# epoch:461 loss:0.726639 accu:0.476562 gene_loss:[validity:0.719597]
# epoch:462 loss:0.711762 accu:0.507812 gene_loss:[validity:0.711660]
# epoch:463 loss:0.689332 accu:0.539062 gene_loss:[validity:0.724751]
# epoch:464 loss:0.687704 accu:0.539062 gene_loss:[validity:0.720521]
# epoch:465 loss:0.679976 accu:0.593750 gene_loss:[validity:0.726072]
# epoch:466 loss:0.692628 accu:0.515625 gene_loss:[validity:0.721879]
# epoch:467 loss:0.675824 accu:0.570312 gene_loss:[validity:0.730927]
# epoch:468 loss:0.668830 accu:0.609375 gene_loss:[validity:0.766578]
# epoch:469 loss:0.693799 accu:0.546875 gene_loss:[validity:0.741994]
# epoch:470 loss:0.672702 accu:0.632812 gene_loss:[validity:0.745019]
# epoch:471 loss:0.663311 accu:0.656250 gene_loss:[validity:0.733654]
# epoch:472 loss:0.696381 accu:0.500000 gene_loss:[validity:0.717004]
# epoch:473 loss:0.688562 accu:0.531250 gene_loss:[validity:0.721027]
# epoch:474 loss:0.665983 accu:0.578125 gene_loss:[validity:0.733788]
# epoch:475 loss:0.680988 accu:0.585938 gene_loss:[validity:0.717171]
# epoch:476 loss:0.694024 accu:0.531250 gene_loss:[validity:0.742873]
# epoch:477 loss:0.673062 accu:0.578125 gene_loss:[validity:0.718809]
# epoch:478 loss:0.678768 accu:0.570312 gene_loss:[validity:0.718970]
# epoch:479 loss:0.692691 accu:0.492188 gene_loss:[validity:0.704660]
# epoch:480 loss:0.691982 accu:0.515625 gene_loss:[validity:0.725073]
# epoch:481 loss:0.699615 accu:0.476562 gene_loss:[validity:0.726746]
# epoch:482 loss:0.673555 accu:0.609375 gene_loss:[validity:0.738270]
# epoch:483 loss:0.695030 accu:0.570312 gene_loss:[validity:0.717258]
# epoch:484 loss:0.664843 accu:0.609375 gene_loss:[validity:0.727908]
# epoch:485 loss:0.668548 accu:0.601562 gene_loss:[validity:0.713054]
# epoch:486 loss:0.676672 accu:0.593750 gene_loss:[validity:0.705375]
# epoch:487 loss:0.678154 accu:0.531250 gene_loss:[validity:0.706803]
# epoch:488 loss:0.678592 accu:0.507812 gene_loss:[validity:0.695246]
# epoch:489 loss:0.690913 accu:0.500000 gene_loss:[validity:0.678198]
# epoch:490 loss:0.694983 accu:0.460938 gene_loss:[validity:0.661286]
# epoch:491 loss:0.698233 accu:0.531250 gene_loss:[validity:0.693862]
# epoch:492 loss:0.699897 accu:0.453125 gene_loss:[validity:0.681350]
# epoch:493 loss:0.696084 accu:0.523438 gene_loss:[validity:0.657080]
# epoch:494 loss:0.695382 accu:0.421875 gene_loss:[validity:0.688021]
# epoch:495 loss:0.683233 accu:0.515625 gene_loss:[validity:0.693545]
# epoch:496 loss:0.691859 accu:0.484375 gene_loss:[validity:0.698886]
# epoch:497 loss:0.701108 accu:0.492188 gene_loss:[validity:0.706007]
# epoch:498 loss:0.693697 accu:0.554688 gene_loss:[validity:0.673481]
# epoch:499 loss:0.688401 accu:0.500000 gene_loss:[validity:0.684774]
# epoch:500 loss:0.705916 accu:0.476562 gene_loss:[validity:0.670560]
# epoch:501 loss:0.675157 accu:0.562500 gene_loss:[validity:0.685630]
# epoch:502 loss:0.687836 accu:0.562500 gene_loss:[validity:0.678803]
# epoch:503 loss:0.687380 accu:0.554688 gene_loss:[validity:0.679747]
# epoch:504 loss:0.681451 accu:0.515625 gene_loss:[validity:0.670718]
# epoch:505 loss:0.703828 accu:0.414062 gene_loss:[validity:0.689949]
# epoch:506 loss:0.688165 accu:0.507812 gene_loss:[validity:0.698396]
# epoch:507 loss:0.694179 accu:0.507812 gene_loss:[validity:0.695142]
# epoch:508 loss:0.687253 accu:0.484375 gene_loss:[validity:0.691032]
# epoch:509 loss:0.701117 accu:0.500000 gene_loss:[validity:0.690097]
# epoch:510 loss:0.688926 accu:0.531250 gene_loss:[validity:0.677211]
# epoch:511 loss:0.689407 accu:0.546875 gene_loss:[validity:0.726424]
# epoch:512 loss:0.704881 accu:0.460938 gene_loss:[validity:0.702461]
# epoch:513 loss:0.693152 accu:0.562500 gene_loss:[validity:0.711801]
# epoch:514 loss:0.686364 accu:0.515625 gene_loss:[validity:0.718722]
# epoch:515 loss:0.691525 accu:0.476562 gene_loss:[validity:0.736954]
# epoch:516 loss:0.696910 accu:0.476562 gene_loss:[validity:0.696352]
# epoch:517 loss:0.691448 accu:0.570312 gene_loss:[validity:0.712465]
# epoch:518 loss:0.690016 accu:0.507812 gene_loss:[validity:0.683416]
# epoch:519 loss:0.675071 accu:0.570312 gene_loss:[validity:0.697944]
# epoch:520 loss:0.675374 accu:0.539062 gene_loss:[validity:0.708445]
# epoch:521 loss:0.688680 accu:0.507812 gene_loss:[validity:0.689698]
# epoch:522 loss:0.690851 accu:0.507812 gene_loss:[validity:0.701178]
# epoch:523 loss:0.700415 accu:0.476562 gene_loss:[validity:0.722062]
# epoch:524 loss:0.698362 accu:0.484375 gene_loss:[validity:0.730197]
# epoch:525 loss:0.681875 accu:0.492188 gene_loss:[validity:0.721455]
# epoch:526 loss:0.691778 accu:0.546875 gene_loss:[validity:0.737890]
# epoch:527 loss:0.692561 accu:0.453125 gene_loss:[validity:0.755278]
# epoch:528 loss:0.695849 accu:0.515625 gene_loss:[validity:0.716456]
# epoch:529 loss:0.691254 accu:0.539062 gene_loss:[validity:0.719121]
# epoch:530 loss:0.682769 accu:0.625000 gene_loss:[validity:0.725632]
# epoch:531 loss:0.677582 accu:0.539062 gene_loss:[validity:0.725671]
# epoch:532 loss:0.701855 accu:0.554688 gene_loss:[validity:0.713726]
# epoch:533 loss:0.671486 accu:0.585938 gene_loss:[validity:0.718088]
# epoch:534 loss:0.672447 accu:0.609375 gene_loss:[validity:0.718262]
# epoch:535 loss:0.673599 accu:0.531250 gene_loss:[validity:0.720926]
# epoch:536 loss:0.661913 accu:0.625000 gene_loss:[validity:0.714165]
# epoch:537 loss:0.658434 accu:0.625000 gene_loss:[validity:0.731429]
# epoch:538 loss:0.663555 accu:0.625000 gene_loss:[validity:0.724288]
# epoch:539 loss:0.662269 accu:0.515625 gene_loss:[validity:0.725147]
# epoch:540 loss:0.694721 accu:0.500000 gene_loss:[validity:0.718313]
# epoch:541 loss:0.658405 accu:0.593750 gene_loss:[validity:0.727220]
# epoch:542 loss:0.663709 accu:0.492188 gene_loss:[validity:0.727012]
# epoch:543 loss:0.663361 accu:0.570312 gene_loss:[validity:0.711705]
# epoch:544 loss:0.670051 accu:0.562500 gene_loss:[validity:0.713914]
# epoch:545 loss:0.667520 accu:0.531250 gene_loss:[validity:0.710513]
# epoch:546 loss:0.689445 accu:0.500000 gene_loss:[validity:0.704474]
# epoch:547 loss:0.680253 accu:0.531250 gene_loss:[validity:0.691900]
# epoch:548 loss:0.674988 accu:0.562500 gene_loss:[validity:0.741956]
# epoch:549 loss:0.708065 accu:0.515625 gene_loss:[validity:0.754841]
# epoch:550 loss:0.655212 accu:0.570312 gene_loss:[validity:0.762762]
# epoch:551 loss:0.685035 accu:0.539062 gene_loss:[validity:0.750546]
# epoch:552 loss:0.666894 accu:0.625000 gene_loss:[validity:0.789859]
# epoch:553 loss:0.707066 accu:0.515625 gene_loss:[validity:0.769501]
# epoch:554 loss:0.677026 accu:0.570312 gene_loss:[validity:0.779234]
# epoch:555 loss:0.675071 accu:0.546875 gene_loss:[validity:0.782090]
# epoch:556 loss:0.660881 accu:0.562500 gene_loss:[validity:0.825054]
# epoch:557 loss:0.665268 accu:0.539062 gene_loss:[validity:0.808497]
# epoch:558 loss:0.694862 accu:0.492188 gene_loss:[validity:0.763092]
# epoch:559 loss:0.721144 accu:0.515625 gene_loss:[validity:0.748189]
# epoch:560 loss:0.692612 accu:0.531250 gene_loss:[validity:0.787214]
# epoch:561 loss:0.694166 accu:0.585938 gene_loss:[validity:0.711390]
# epoch:562 loss:0.707133 accu:0.500000 gene_loss:[validity:0.761232]
# epoch:563 loss:0.716140 accu:0.421875 gene_loss:[validity:0.738347]
# epoch:564 loss:0.720016 accu:0.468750 gene_loss:[validity:0.709383]
# epoch:565 loss:0.715860 accu:0.468750 gene_loss:[validity:0.727204]
# epoch:566 loss:0.694328 accu:0.539062 gene_loss:[validity:0.701919]
# epoch:567 loss:0.706883 accu:0.515625 gene_loss:[validity:0.727110]
# epoch:568 loss:0.697416 accu:0.523438 gene_loss:[validity:0.733757]
# epoch:569 loss:0.697045 accu:0.500000 gene_loss:[validity:0.736709]
# epoch:570 loss:0.694801 accu:0.546875 gene_loss:[validity:0.742366]
# epoch:571 loss:0.695734 accu:0.507812 gene_loss:[validity:0.747735]
# epoch:572 loss:0.723108 accu:0.445312 gene_loss:[validity:0.730556]
# epoch:573 loss:0.724669 accu:0.445312 gene_loss:[validity:0.721089]
# epoch:574 loss:0.713286 accu:0.484375 gene_loss:[validity:0.751708]
# epoch:575 loss:0.689279 accu:0.539062 gene_loss:[validity:0.728356]
# epoch:576 loss:0.693400 accu:0.507812 gene_loss:[validity:0.730225]
# epoch:577 loss:0.690942 accu:0.539062 gene_loss:[validity:0.758852]
# epoch:578 loss:0.685204 accu:0.515625 gene_loss:[validity:0.757321]
# epoch:579 loss:0.670986 accu:0.609375 gene_loss:[validity:0.800252]
# epoch:580 loss:0.690303 accu:0.507812 gene_loss:[validity:0.764589]
# epoch:581 loss:0.694230 accu:0.476562 gene_loss:[validity:0.790471]
# epoch:582 loss:0.695837 accu:0.445312 gene_loss:[validity:0.805405]
# epoch:583 loss:0.706021 accu:0.476562 gene_loss:[validity:0.738056]
# epoch:584 loss:0.692776 accu:0.539062 gene_loss:[validity:0.723696]
# epoch:585 loss:0.705139 accu:0.468750 gene_loss:[validity:0.723114]
# epoch:586 loss:0.675093 accu:0.609375 gene_loss:[validity:0.716752]
# epoch:587 loss:0.708681 accu:0.468750 gene_loss:[validity:0.733914]
# epoch:588 loss:0.693103 accu:0.523438 gene_loss:[validity:0.721958]
# epoch:589 loss:0.690244 accu:0.523438 gene_loss:[validity:0.722032]
# epoch:590 loss:0.697944 accu:0.500000 gene_loss:[validity:0.740971]
# epoch:591 loss:0.686359 accu:0.562500 gene_loss:[validity:0.709721]
# epoch:592 loss:0.688935 accu:0.539062 gene_loss:[validity:0.750278]
# epoch:593 loss:0.684021 accu:0.562500 gene_loss:[validity:0.724252]
# epoch:594 loss:0.693771 accu:0.500000 gene_loss:[validity:0.731794]
# epoch:595 loss:0.681905 accu:0.539062 gene_loss:[validity:0.741170]
# epoch:596 loss:0.687681 accu:0.539062 gene_loss:[validity:0.716995]
# epoch:597 loss:0.691552 accu:0.546875 gene_loss:[validity:0.731936]
# epoch:598 loss:0.695605 accu:0.492188 gene_loss:[validity:0.729400]
# epoch:599 loss:0.673840 accu:0.609375 gene_loss:[validity:0.767540]
# epoch:600 loss:0.689860 accu:0.492188 gene_loss:[validity:0.733464]
# epoch:601 loss:0.695064 accu:0.429688 gene_loss:[validity:0.740990]
# epoch:602 loss:0.704958 accu:0.500000 gene_loss:[validity:0.721362]
# epoch:603 loss:0.681720 accu:0.578125 gene_loss:[validity:0.707013]
# epoch:604 loss:0.669513 accu:0.570312 gene_loss:[validity:0.760393]
# epoch:605 loss:0.684839 accu:0.507812 gene_loss:[validity:0.748189]
# epoch:606 loss:0.696135 accu:0.500000 gene_loss:[validity:0.715720]
# epoch:607 loss:0.668145 accu:0.554688 gene_loss:[validity:0.716814]
# epoch:608 loss:0.671480 accu:0.562500 gene_loss:[validity:0.743085]
# epoch:609 loss:0.646167 accu:0.585938 gene_loss:[validity:0.742798]
# epoch:610 loss:0.667255 accu:0.554688 gene_loss:[validity:0.747787]
# epoch:611 loss:0.677331 accu:0.523438 gene_loss:[validity:0.775919]
# epoch:612 loss:0.662376 accu:0.617188 gene_loss:[validity:0.755120]
# epoch:613 loss:0.667999 accu:0.578125 gene_loss:[validity:0.797289]
# epoch:614 loss:0.669950 accu:0.562500 gene_loss:[validity:0.722598]
# epoch:615 loss:0.677416 accu:0.539062 gene_loss:[validity:0.702890]
# epoch:616 loss:0.683377 accu:0.507812 gene_loss:[validity:0.730079]
# epoch:617 loss:0.654560 accu:0.609375 gene_loss:[validity:0.688190]
# epoch:618 loss:0.682747 accu:0.500000 gene_loss:[validity:0.712757]
# epoch:619 loss:0.655082 accu:0.570312 gene_loss:[validity:0.724155]
# epoch:620 loss:0.652350 accu:0.578125 gene_loss:[validity:0.721938]
# epoch:621 loss:0.659109 accu:0.585938 gene_loss:[validity:0.691914]
# epoch:622 loss:0.671477 accu:0.515625 gene_loss:[validity:0.695942]
# epoch:623 loss:0.689709 accu:0.546875 gene_loss:[validity:0.739385]
# epoch:624 loss:0.664844 accu:0.515625 gene_loss:[validity:0.762262]
# epoch:625 loss:0.672394 accu:0.570312 gene_loss:[validity:0.845349]
# epoch:626 loss:0.675564 accu:0.601562 gene_loss:[validity:0.794232]
# epoch:627 loss:0.662244 accu:0.648438 gene_loss:[validity:0.744147]
# epoch:628 loss:0.631506 accu:0.625000 gene_loss:[validity:0.756425]
# epoch:629 loss:0.711713 accu:0.507812 gene_loss:[validity:0.727433]
# epoch:630 loss:0.661068 accu:0.617188 gene_loss:[validity:0.720376]
# epoch:631 loss:0.675800 accu:0.546875 gene_loss:[validity:0.711878]
# epoch:632 loss:0.643895 accu:0.585938 gene_loss:[validity:0.748574]
# epoch:633 loss:0.636391 accu:0.617188 gene_loss:[validity:0.745537]
# epoch:634 loss:0.633097 accu:0.601562 gene_loss:[validity:0.788948]
# epoch:635 loss:0.626781 accu:0.585938 gene_loss:[validity:0.871235]
# epoch:636 loss:0.661236 accu:0.562500 gene_loss:[validity:0.804131]
# epoch:637 loss:0.702149 accu:0.492188 gene_loss:[validity:0.740107]
# epoch:638 loss:0.742635 accu:0.546875 gene_loss:[validity:0.781823]
# epoch:639 loss:0.703575 accu:0.539062 gene_loss:[validity:0.971670]
# epoch:640 loss:0.697218 accu:0.593750 gene_loss:[validity:0.724198]
# epoch:641 loss:0.732599 accu:0.562500 gene_loss:[validity:0.805110]
# epoch:642 loss:0.692603 accu:0.492188 gene_loss:[validity:1.043932]
# epoch:643 loss:0.752703 accu:0.523438 gene_loss:[validity:0.924653]
# epoch:644 loss:0.817131 accu:0.492188 gene_loss:[validity:0.785654]
# epoch:645 loss:0.697263 accu:0.625000 gene_loss:[validity:0.771681]
# epoch:646 loss:0.760502 accu:0.632812 gene_loss:[validity:0.765111]
# epoch:647 loss:0.732881 accu:0.562500 gene_loss:[validity:0.804615]
# epoch:648 loss:0.702377 accu:0.546875 gene_loss:[validity:0.864922]
# epoch:649 loss:0.689766 accu:0.593750 gene_loss:[validity:0.836447]
# epoch:650 loss:0.682299 accu:0.554688 gene_loss:[validity:0.789694]
# epoch:651 loss:0.670084 accu:0.625000 gene_loss:[validity:0.752675]
# epoch:652 loss:0.679863 accu:0.601562 gene_loss:[validity:0.759293]
# epoch:653 loss:0.695003 accu:0.515625 gene_loss:[validity:0.714446]
# epoch:654 loss:0.709856 accu:0.484375 gene_loss:[validity:0.719223]
# epoch:655 loss:0.676355 accu:0.562500 gene_loss:[validity:0.704272]
# epoch:656 loss:0.710741 accu:0.484375 gene_loss:[validity:0.721614]
# epoch:657 loss:0.676664 accu:0.531250 gene_loss:[validity:0.715555]
# epoch:658 loss:0.693677 accu:0.523438 gene_loss:[validity:0.692670]
# epoch:659 loss:0.688143 accu:0.500000 gene_loss:[validity:0.740053]
# epoch:660 loss:0.677384 accu:0.531250 gene_loss:[validity:0.710707]
# epoch:661 loss:0.695725 accu:0.515625 gene_loss:[validity:0.745251]
# epoch:662 loss:0.644252 accu:0.632812 gene_loss:[validity:0.733824]
# epoch:663 loss:0.671220 accu:0.531250 gene_loss:[validity:0.712673]
# epoch:664 loss:0.678261 accu:0.507812 gene_loss:[validity:0.729802]
# epoch:665 loss:0.655750 accu:0.570312 gene_loss:[validity:0.752252]
# epoch:666 loss:0.658231 accu:0.578125 gene_loss:[validity:0.712467]
# epoch:667 loss:0.674166 accu:0.515625 gene_loss:[validity:0.730092]
# epoch:668 loss:0.678998 accu:0.515625 gene_loss:[validity:0.737913]
# epoch:669 loss:0.653963 accu:0.601562 gene_loss:[validity:0.739578]
# epoch:670 loss:0.677910 accu:0.515625 gene_loss:[validity:0.747486]
# epoch:671 loss:0.682024 accu:0.539062 gene_loss:[validity:0.801285]
# epoch:672 loss:0.662619 accu:0.507812 gene_loss:[validity:0.714155]
# epoch:673 loss:0.654584 accu:0.593750 gene_loss:[validity:0.728830]
# epoch:674 loss:0.662417 accu:0.585938 gene_loss:[validity:0.728088]
# epoch:675 loss:0.654733 accu:0.601562 gene_loss:[validity:0.714973]
# epoch:676 loss:0.653475 accu:0.640625 gene_loss:[validity:0.748798]
# epoch:677 loss:0.656146 accu:0.617188 gene_loss:[validity:0.739171]
# epoch:678 loss:0.678932 accu:0.515625 gene_loss:[validity:0.726175]
# epoch:679 loss:0.700085 accu:0.460938 gene_loss:[validity:0.714280]
# epoch:680 loss:0.685568 accu:0.539062 gene_loss:[validity:0.693943]
# epoch:681 loss:0.748461 accu:0.468750 gene_loss:[validity:0.764732]
# epoch:682 loss:0.670692 accu:0.476562 gene_loss:[validity:0.766216]
# epoch:683 loss:0.692300 accu:0.523438 gene_loss:[validity:0.821992]
# epoch:684 loss:0.699322 accu:0.539062 gene_loss:[validity:0.809650]
# epoch:685 loss:0.707465 accu:0.484375 gene_loss:[validity:0.802501]
# epoch:686 loss:0.732930 accu:0.453125 gene_loss:[validity:0.773112]
# epoch:687 loss:0.725160 accu:0.414062 gene_loss:[validity:0.773670]
# epoch:688 loss:0.693939 accu:0.460938 gene_loss:[validity:0.782022]
# epoch:689 loss:0.711498 accu:0.468750 gene_loss:[validity:0.794497]
# epoch:690 loss:0.714310 accu:0.492188 gene_loss:[validity:0.780571]
# epoch:691 loss:0.689264 accu:0.539062 gene_loss:[validity:0.838491]
# epoch:692 loss:0.675783 accu:0.531250 gene_loss:[validity:0.799772]
# epoch:693 loss:0.681007 accu:0.539062 gene_loss:[validity:0.874346]
# epoch:694 loss:0.686663 accu:0.515625 gene_loss:[validity:0.764106]
# epoch:695 loss:0.687433 accu:0.539062 gene_loss:[validity:0.844570]
# epoch:696 loss:0.687997 accu:0.531250 gene_loss:[validity:0.770867]
# epoch:697 loss:0.685075 accu:0.554688 gene_loss:[validity:0.755378]
# epoch:698 loss:0.685297 accu:0.523438 gene_loss:[validity:0.746866]
# epoch:699 loss:0.668819 accu:0.617188 gene_loss:[validity:0.757773]
# epoch:700 loss:0.677139 accu:0.570312 gene_loss:[validity:0.740230]
# epoch:701 loss:0.675693 accu:0.531250 gene_loss:[validity:0.759651]
# epoch:702 loss:0.678430 accu:0.515625 gene_loss:[validity:0.760716]
# ...
# epoch:2770 loss:0.686056 accu:0.523438 gene_loss:[validity:0.718272]
# epoch:2771 loss:0.685166 accu:0.570312 gene_loss:[validity:0.736706]
# epoch:2772 loss:0.689732 accu:0.523438 gene_loss:[validity:0.726906]
# epoch:2773 loss:0.684172 accu:0.562500 gene_loss:[validity:0.715022]
# epoch:2774 loss:0.687045 accu:0.546875 gene_loss:[validity:0.721921]
# epoch:2775 loss:0.681264 accu:0.546875 gene_loss:[validity:0.718999]
# epoch:2776 loss:0.693479 accu:0.445312 gene_loss:[validity:0.718101]
# epoch:2777 loss:0.677317 accu:0.617188 gene_loss:[validity:0.732657]
# epoch:2778 loss:0.684307 accu:0.570312 gene_loss:[validity:0.729556]
# epoch:2779 loss:0.690635 accu:0.500000 gene_loss:[validity:0.718088]
# epoch:2780 loss:0.687751 accu:0.585938 gene_loss:[validity:0.720481]
# epoch:2781 loss:0.684251 accu:0.609375 gene_loss:[validity:0.717406]
# epoch:2782 loss:0.677094 accu:0.593750 gene_loss:[validity:0.708037]
# epoch:2783 loss:0.685835 accu:0.554688 gene_loss:[validity:0.730263]
# epoch:2784 loss:0.692265 accu:0.570312 gene_loss:[validity:0.715927]
# epoch:2785 loss:0.698895 accu:0.453125 gene_loss:[validity:0.711180]
# epoch:2786 loss:0.680922 accu:0.617188 gene_loss:[validity:0.704585]
# epoch:2787 loss:0.682702 accu:0.570312 gene_loss:[validity:0.717510]
# epoch:2788 loss:0.705071 accu:0.453125 gene_loss:[validity:0.703622]
# epoch:2789 loss:0.687691 accu:0.523438 gene_loss:[validity:0.701485]
# epoch:2790 loss:0.701263 accu:0.437500 gene_loss:[validity:0.703173]
# epoch:2791 loss:0.696594 accu:0.484375 gene_loss:[validity:0.689220]
# epoch:2792 loss:0.685020 accu:0.484375 gene_loss:[validity:0.698631]
# epoch:2793 loss:0.701073 accu:0.429688 gene_loss:[validity:0.698624]
# epoch:2794 loss:0.698107 accu:0.445312 gene_loss:[validity:0.700637]
# epoch:2795 loss:0.687208 accu:0.546875 gene_loss:[validity:0.698883]
# epoch:2796 loss:0.692972 accu:0.429688 gene_loss:[validity:0.700923]
# epoch:2797 loss:0.712104 accu:0.390625 gene_loss:[validity:0.693311]
# epoch:2798 loss:0.691943 accu:0.492188 gene_loss:[validity:0.710166]
# epoch:2799 loss:0.697361 accu:0.507812 gene_loss:[validity:0.695447]
# epoch:2800 loss:0.692737 accu:0.507812 gene_loss:[validity:0.697131]
# epoch:2801 loss:0.693995 accu:0.492188 gene_loss:[validity:0.694213]
# epoch:2802 loss:0.693439 accu:0.531250 gene_loss:[validity:0.678602]
# epoch:2803 loss:0.690382 accu:0.554688 gene_loss:[validity:0.696396]
# epoch:2804 loss:0.701576 accu:0.468750 gene_loss:[validity:0.700054]
# epoch:2805 loss:0.700089 accu:0.468750 gene_loss:[validity:0.696453]
# epoch:2806 loss:0.684821 accu:0.539062 gene_loss:[validity:0.693934]
# epoch:2807 loss:0.692006 accu:0.570312 gene_loss:[validity:0.699416]
# epoch:2808 loss:0.699277 accu:0.492188 gene_loss:[validity:0.684077]
# epoch:2809 loss:0.693095 accu:0.492188 gene_loss:[validity:0.686140]
# epoch:2810 loss:0.695899 accu:0.476562 gene_loss:[validity:0.686196]
# epoch:2811 loss:0.698999 accu:0.476562 gene_loss:[validity:0.692174]
# epoch:2812 loss:0.698862 accu:0.531250 gene_loss:[validity:0.685924]
# epoch:2813 loss:0.698466 accu:0.507812 gene_loss:[validity:0.691350]
# epoch:2814 loss:0.694353 accu:0.515625 gene_loss:[validity:0.695138]
# epoch:2815 loss:0.691411 accu:0.585938 gene_loss:[validity:0.694129]
# epoch:2816 loss:0.695778 accu:0.523438 gene_loss:[validity:0.680339]
# epoch:2817 loss:0.700233 accu:0.460938 gene_loss:[validity:0.701360]
# epoch:2818 loss:0.680496 accu:0.531250 gene_loss:[validity:0.683193]
# epoch:2819 loss:0.708897 accu:0.421875 gene_loss:[validity:0.707667]
# epoch:2820 loss:0.701383 accu:0.351562 gene_loss:[validity:0.699220]
# epoch:2821 loss:0.702406 accu:0.445312 gene_loss:[validity:0.700917]
# epoch:2822 loss:0.699351 accu:0.492188 gene_loss:[validity:0.729224]
# epoch:2823 loss:0.687126 accu:0.531250 gene_loss:[validity:0.711532]
# epoch:2824 loss:0.694336 accu:0.531250 gene_loss:[validity:0.714827]
# epoch:2825 loss:0.690634 accu:0.500000 gene_loss:[validity:0.705448]
# epoch:2826 loss:0.683242 accu:0.531250 gene_loss:[validity:0.695508]
# epoch:2827 loss:0.697609 accu:0.492188 gene_loss:[validity:0.712874]
# epoch:2828 loss:0.690408 accu:0.531250 gene_loss:[validity:0.713316]
# epoch:2829 loss:0.692409 accu:0.562500 gene_loss:[validity:0.707748]
# epoch:2830 loss:0.690675 accu:0.523438 gene_loss:[validity:0.724060]
# epoch:2831 loss:0.678032 accu:0.609375 gene_loss:[validity:0.698075]
# epoch:2832 loss:0.691317 accu:0.476562 gene_loss:[validity:0.706335]
# epoch:2833 loss:0.688754 accu:0.578125 gene_loss:[validity:0.743952]
# epoch:2834 loss:0.692962 accu:0.562500 gene_loss:[validity:0.696583]
# epoch:2835 loss:0.681144 accu:0.507812 gene_loss:[validity:0.709358]
# epoch:2836 loss:0.688538 accu:0.531250 gene_loss:[validity:0.696683]
# epoch:2837 loss:0.676243 accu:0.640625 gene_loss:[validity:0.694609]
# epoch:2838 loss:0.679658 accu:0.617188 gene_loss:[validity:0.704739]
# epoch:2839 loss:0.693728 accu:0.546875 gene_loss:[validity:0.714239]
# epoch:2840 loss:0.682411 accu:0.601562 gene_loss:[validity:0.701353]
# epoch:2841 loss:0.690251 accu:0.414062 gene_loss:[validity:0.695106]
# epoch:2842 loss:0.690639 accu:0.500000 gene_loss:[validity:0.694152]
# epoch:2843 loss:0.695050 accu:0.585938 gene_loss:[validity:0.692324]
# epoch:2844 loss:0.679316 accu:0.546875 gene_loss:[validity:0.697364]
# epoch:2845 loss:0.690369 accu:0.500000 gene_loss:[validity:0.687537]
# epoch:2846 loss:0.687412 accu:0.460938 gene_loss:[validity:0.716260]
# epoch:2847 loss:0.691083 accu:0.500000 gene_loss:[validity:0.717613]
# epoch:2848 loss:0.692861 accu:0.515625 gene_loss:[validity:0.698485]
# epoch:2849 loss:0.695591 accu:0.539062 gene_loss:[validity:0.687674]
# epoch:2850 loss:0.683698 accu:0.546875 gene_loss:[validity:0.710938]
# epoch:2851 loss:0.695021 accu:0.515625 gene_loss:[validity:0.698573]
# epoch:2852 loss:0.687268 accu:0.539062 gene_loss:[validity:0.690796]
# epoch:2853 loss:0.673621 accu:0.601562 gene_loss:[validity:0.712704]
# epoch:2854 loss:0.685568 accu:0.554688 gene_loss:[validity:0.764709]
# epoch:2855 loss:0.694569 accu:0.507812 gene_loss:[validity:0.738558]
# epoch:2856 loss:0.690572 accu:0.460938 gene_loss:[validity:0.705494]
# epoch:2857 loss:0.692968 accu:0.500000 gene_loss:[validity:0.719295]
# epoch:2858 loss:0.680086 accu:0.531250 gene_loss:[validity:0.725962]
# epoch:2859 loss:0.697415 accu:0.507812 gene_loss:[validity:0.717731]
# epoch:2860 loss:0.698041 accu:0.460938 gene_loss:[validity:0.705187]
# epoch:2861 loss:0.696348 accu:0.507812 gene_loss:[validity:0.708735]
# epoch:2862 loss:0.706550 accu:0.523438 gene_loss:[validity:0.691889]
# epoch:2863 loss:0.695818 accu:0.570312 gene_loss:[validity:0.721126]
# epoch:2864 loss:0.701860 accu:0.445312 gene_loss:[validity:0.720138]
# epoch:2865 loss:0.694558 accu:0.453125 gene_loss:[validity:0.696223]
# epoch:2866 loss:0.682402 accu:0.585938 gene_loss:[validity:0.744859]
# epoch:2867 loss:0.695093 accu:0.531250 gene_loss:[validity:0.726908]
# epoch:2868 loss:0.693757 accu:0.507812 gene_loss:[validity:0.705796]
# epoch:2869 loss:0.692249 accu:0.492188 gene_loss:[validity:0.706348]
# epoch:2870 loss:0.703618 accu:0.546875 gene_loss:[validity:0.705948]
# epoch:2871 loss:0.692454 accu:0.562500 gene_loss:[validity:0.689241]
# epoch:2872 loss:0.698461 accu:0.570312 gene_loss:[validity:0.697522]
# epoch:2873 loss:0.678304 accu:0.578125 gene_loss:[validity:0.692772]
# epoch:2874 loss:0.692560 accu:0.523438 gene_loss:[validity:0.686534]
# epoch:2875 loss:0.681519 accu:0.531250 gene_loss:[validity:0.681062]
# epoch:2876 loss:0.691819 accu:0.507812 gene_loss:[validity:0.682689]
# epoch:2877 loss:0.683815 accu:0.476562 gene_loss:[validity:0.697923]
# epoch:2878 loss:0.685254 accu:0.476562 gene_loss:[validity:0.697110]
# epoch:2879 loss:0.684770 accu:0.531250 gene_loss:[validity:0.699583]
# epoch:2880 loss:0.677311 accu:0.507812 gene_loss:[validity:0.695522]
# epoch:2881 loss:0.673545 accu:0.585938 gene_loss:[validity:0.692845]
# epoch:2882 loss:0.670415 accu:0.507812 gene_loss:[validity:0.692806]
# epoch:2883 loss:0.693051 accu:0.507812 gene_loss:[validity:0.684710]
# epoch:2884 loss:0.665074 accu:0.562500 gene_loss:[validity:0.683300]
# epoch:2885 loss:0.690439 accu:0.468750 gene_loss:[validity:0.682972]
# epoch:2886 loss:0.695909 accu:0.476562 gene_loss:[validity:0.679704]
# epoch:2887 loss:0.698100 accu:0.507812 gene_loss:[validity:0.681582]
# epoch:2888 loss:0.685454 accu:0.546875 gene_loss:[validity:0.701609]
# epoch:2889 loss:0.687431 accu:0.539062 gene_loss:[validity:0.706218]
# epoch:2890 loss:0.688857 accu:0.570312 gene_loss:[validity:0.715463]
# epoch:2891 loss:0.677548 accu:0.531250 gene_loss:[validity:0.707774]
# epoch:2892 loss:0.684610 accu:0.507812 gene_loss:[validity:0.706978]
# epoch:2893 loss:0.690640 accu:0.515625 gene_loss:[validity:0.700768]
# epoch:2894 loss:0.701103 accu:0.429688 gene_loss:[validity:0.751538]
# epoch:2895 loss:0.684172 accu:0.507812 gene_loss:[validity:0.740510]
# epoch:2896 loss:0.691061 accu:0.562500 gene_loss:[validity:0.699588]
# epoch:2897 loss:0.688765 accu:0.500000 gene_loss:[validity:0.741420]
# epoch:2898 loss:0.697254 accu:0.460938 gene_loss:[validity:0.735532]
# epoch:2899 loss:0.700166 accu:0.523438 gene_loss:[validity:0.721773]
# epoch:2900 loss:0.707958 accu:0.429688 gene_loss:[validity:0.709897]
# epoch:2901 loss:0.699210 accu:0.468750 gene_loss:[validity:0.706868]
# epoch:2902 loss:0.698577 accu:0.445312 gene_loss:[validity:0.707271]
# epoch:2903 loss:0.690378 accu:0.531250 gene_loss:[validity:0.730982]
# epoch:2904 loss:0.696598 accu:0.531250 gene_loss:[validity:0.719643]
# epoch:2905 loss:0.687222 accu:0.562500 gene_loss:[validity:0.721904]
# epoch:2906 loss:0.700512 accu:0.445312 gene_loss:[validity:0.708194]
# epoch:2907 loss:0.683043 accu:0.570312 gene_loss:[validity:0.731859]
# epoch:2908 loss:0.687806 accu:0.484375 gene_loss:[validity:0.730333]
# epoch:2909 loss:0.697824 accu:0.515625 gene_loss:[validity:0.733031]
# epoch:2910 loss:0.698477 accu:0.585938 gene_loss:[validity:0.709239]
# epoch:2911 loss:0.688760 accu:0.546875 gene_loss:[validity:0.712708]
# epoch:2912 loss:0.692110 accu:0.609375 gene_loss:[validity:0.707381]
# epoch:2913 loss:0.705361 accu:0.460938 gene_loss:[validity:0.694421]
# epoch:2914 loss:0.693720 accu:0.539062 gene_loss:[validity:0.706599]
# epoch:2915 loss:0.691359 accu:0.562500 gene_loss:[validity:0.698869]
# epoch:2916 loss:0.696993 accu:0.500000 gene_loss:[validity:0.708205]
# epoch:2917 loss:0.687845 accu:0.539062 gene_loss:[validity:0.718175]
# epoch:2918 loss:0.702783 accu:0.570312 gene_loss:[validity:0.735353]
# epoch:2919 loss:0.701535 accu:0.460938 gene_loss:[validity:0.700369]
# epoch:2920 loss:0.702670 accu:0.500000 gene_loss:[validity:0.708682]
# epoch:2921 loss:0.692777 accu:0.507812 gene_loss:[validity:0.705255]
# epoch:2922 loss:0.692776 accu:0.484375 gene_loss:[validity:0.699577]
# epoch:2923 loss:0.690689 accu:0.585938 gene_loss:[validity:0.709137]
# epoch:2924 loss:0.684299 accu:0.593750 gene_loss:[validity:0.711716]
# epoch:2925 loss:0.695580 accu:0.460938 gene_loss:[validity:0.719970]
# epoch:2926 loss:0.693878 accu:0.500000 gene_loss:[validity:0.721610]
# epoch:2927 loss:0.690283 accu:0.562500 gene_loss:[validity:0.711050]
# epoch:2928 loss:0.688882 accu:0.585938 gene_loss:[validity:0.713861]
# epoch:2929 loss:0.688966 accu:0.546875 gene_loss:[validity:0.712651]
# epoch:2930 loss:0.689378 accu:0.515625 gene_loss:[validity:0.697487]
# epoch:2931 loss:0.694682 accu:0.460938 gene_loss:[validity:0.703423]
# epoch:2932 loss:0.688716 accu:0.570312 gene_loss:[validity:0.709815]
# epoch:2933 loss:0.688699 accu:0.539062 gene_loss:[validity:0.697188]
# epoch:2934 loss:0.683186 accu:0.585938 gene_loss:[validity:0.696462]
# epoch:2935 loss:0.696362 accu:0.468750 gene_loss:[validity:0.712412]
# epoch:2936 loss:0.684319 accu:0.585938 gene_loss:[validity:0.709398]
# epoch:2937 loss:0.687748 accu:0.570312 gene_loss:[validity:0.713923]
# epoch:2938 loss:0.695814 accu:0.445312 gene_loss:[validity:0.700797]
# epoch:2939 loss:0.691137 accu:0.539062 gene_loss:[validity:0.703047]
# epoch:2940 loss:0.697578 accu:0.484375 gene_loss:[validity:0.696037]
# epoch:2941 loss:0.699944 accu:0.437500 gene_loss:[validity:0.691539]
# epoch:2942 loss:0.697852 accu:0.429688 gene_loss:[validity:0.702005]
# epoch:2943 loss:0.701605 accu:0.460938 gene_loss:[validity:0.688223]
# epoch:2944 loss:0.689532 accu:0.531250 gene_loss:[validity:0.698189]
# epoch:2945 loss:0.701138 accu:0.476562 gene_loss:[validity:0.696596]
# epoch:2946 loss:0.699546 accu:0.460938 gene_loss:[validity:0.704877]
# epoch:2947 loss:0.694118 accu:0.460938 gene_loss:[validity:0.702475]
# epoch:2948 loss:0.695005 accu:0.429688 gene_loss:[validity:0.700866]
# epoch:2949 loss:0.689829 accu:0.546875 gene_loss:[validity:0.709699]
# epoch:2950 loss:0.695717 accu:0.531250 gene_loss:[validity:0.721938]
# epoch:2951 loss:0.688171 accu:0.515625 gene_loss:[validity:0.725221]
# epoch:2952 loss:0.689236 accu:0.562500 gene_loss:[validity:0.737930]
# epoch:2953 loss:0.699626 accu:0.421875 gene_loss:[validity:0.715946]
# epoch:2954 loss:0.693079 accu:0.546875 gene_loss:[validity:0.716997]
# epoch:2955 loss:0.691516 accu:0.546875 gene_loss:[validity:0.716634]
# epoch:2956 loss:0.693869 accu:0.468750 gene_loss:[validity:0.706452]
# epoch:2957 loss:0.696358 accu:0.500000 gene_loss:[validity:0.710359]
# epoch:2958 loss:0.693670 accu:0.468750 gene_loss:[validity:0.696671]
# epoch:2959 loss:0.687557 accu:0.546875 gene_loss:[validity:0.715407]
# epoch:2960 loss:0.690770 accu:0.554688 gene_loss:[validity:0.695547]
# epoch:2961 loss:0.696763 accu:0.484375 gene_loss:[validity:0.705507]
# epoch:2962 loss:0.688759 accu:0.601562 gene_loss:[validity:0.705781]
# epoch:2963 loss:0.691928 accu:0.500000 gene_loss:[validity:0.703607]
# epoch:2964 loss:0.694670 accu:0.468750 gene_loss:[validity:0.704593]
# epoch:2965 loss:0.687820 accu:0.585938 gene_loss:[validity:0.697790]
# epoch:2966 loss:0.691930 accu:0.484375 gene_loss:[validity:0.702900]
# epoch:2967 loss:0.700898 accu:0.406250 gene_loss:[validity:0.702362]
# epoch:2968 loss:0.689108 accu:0.546875 gene_loss:[validity:0.693816]
# epoch:2969 loss:0.691832 accu:0.500000 gene_loss:[validity:0.691587]
# epoch:2970 loss:0.681120 accu:0.617188 gene_loss:[validity:0.694043]
# epoch:2971 loss:0.691356 accu:0.539062 gene_loss:[validity:0.694394]
# epoch:2972 loss:0.698401 accu:0.476562 gene_loss:[validity:0.696536]
# epoch:2973 loss:0.684833 accu:0.531250 gene_loss:[validity:0.693152]
# epoch:2974 loss:0.690561 accu:0.507812 gene_loss:[validity:0.698321]
# epoch:2975 loss:0.690086 accu:0.546875 gene_loss:[validity:0.702381]
# epoch:2976 loss:0.690102 accu:0.539062 gene_loss:[validity:0.684757]
# epoch:2977 loss:0.684716 accu:0.539062 gene_loss:[validity:0.704257]
# epoch:2978 loss:0.684362 accu:0.468750 gene_loss:[validity:0.695882]
# epoch:2979 loss:0.692534 accu:0.507812 gene_loss:[validity:0.701434]
# epoch:2980 loss:0.688240 accu:0.562500 gene_loss:[validity:0.706735]
# epoch:2981 loss:0.681800 accu:0.546875 gene_loss:[validity:0.720644]
# epoch:2982 loss:0.697899 accu:0.492188 gene_loss:[validity:0.695372]
# epoch:2983 loss:0.693266 accu:0.460938 gene_loss:[validity:0.694367]
# epoch:2984 loss:0.685464 accu:0.585938 gene_loss:[validity:0.697546]
# epoch:2985 loss:0.689633 accu:0.585938 gene_loss:[validity:0.711007]
# epoch:2986 loss:0.687704 accu:0.539062 gene_loss:[validity:0.692306]
# epoch:2987 loss:0.690106 accu:0.539062 gene_loss:[validity:0.702630]
# epoch:2988 loss:0.682746 accu:0.554688 gene_loss:[validity:0.702200]
# epoch:2989 loss:0.701243 accu:0.539062 gene_loss:[validity:0.696138]
# epoch:2990 loss:0.692219 accu:0.546875 gene_loss:[validity:0.699931]
# epoch:2991 loss:0.693410 accu:0.500000 gene_loss:[validity:0.701325]
# epoch:2992 loss:0.702339 accu:0.507812 gene_loss:[validity:0.699794]
# epoch:2993 loss:0.698518 accu:0.500000 gene_loss:[validity:0.705193]
# epoch:2994 loss:0.695381 accu:0.476562 gene_loss:[validity:0.713372]
# epoch:2995 loss:0.688526 accu:0.570312 gene_loss:[validity:0.702052]
# epoch:2996 loss:0.706910 accu:0.460938 gene_loss:[validity:0.699520]
# epoch:2997 loss:0.691728 accu:0.531250 gene_loss:[validity:0.709569]
# epoch:2998 loss:0.703049 accu:0.414062 gene_loss:[validity:0.698507]
# epoch:2999 loss:0.689338 accu:0.539062 gene_loss:[validity:0.713135]
# epoch:3000 loss:0.694492 accu:0.460938 gene_loss:[validity:0.719921]

# %%
real_labels.shape
# Out:
# (64, 1)

# %%
discriminator_i.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input1 (InputLayer)          (None, 28, 28, 1)         0
# _________________________________________________________________
# discriminator (Sequential)   (None, 1)                 533505
# =================================================================
# Total params: 533,505
# Trainable params: 0
# Non-trainable params: 533,505
# _________________________________________________________________

# %%
generator_i.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input1 (InputLayer)          (None, 100)               0
# _________________________________________________________________
# generator (Sequential)       (None, 28, 28, 1)         1097744
# =================================================================
# Total params: 1,097,744
# Trainable params: 1,095,184
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
combined_model_i.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z (InputLayer)               (None, 100)               0
# _________________________________________________________________
# generator_Model (Model)      (None, 96, 96, 3)         29029120
# _________________________________________________________________
# discriminator_Model (Model)  (None, 1)                 14320641
# =================================================================
# Total params: 43,349,761
# Trainable params: 29,025,536
# Non-trainable params: 14,324,225
# _________________________________________________________________

# %%
gc.collect()

# %%
modeli = Sequential()

modeli.add(Dense(128 * 7 * 7, activation="relu", input_shape=(LATENT_DIM,)))
modeli.add(Reshape((7, 7, 128)))
modeli.add(UpSampling2D())
modeli.add(Conv2D(128, kernel_size=3, padding="same"))
modeli.add(BatchNormalization(momentum=0.8))
modeli.add(Activation("relu"))
modeli.add(UpSampling2D())
modeli.add(Conv2D(64, kernel_size=3, padding="same"))
modeli.add(BatchNormalization(momentum=0.8))
modeli.add(Activation("relu"))
modeli.add(Conv2D(CHANNEL, kernel_size=3, padding="same"))
modeli.add(Activation("tanh"))

# %%
modeli.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 64)        73792
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         577
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 856,193
# Trainable params: 855,809
# Non-trainable params: 384
# _________________________________________________________________

# %%
32*400
# Out:
# 12800

# %%
gc.collect()
# Out:
# 1059600
