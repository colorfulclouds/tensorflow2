# %%
from keras.models import Sequential , Model
from keras.layers import Dense ,  BatchNormalization , Reshape , Input , Flatten
from keras.layers import Conv2D , MaxPool2D , Conv2DTranspose , UpSampling2D , ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers import Activation
from keras.layers import Dropout

from keras.optimizers import Adam

from keras.datasets import mnist
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import os

import matplotlib as plt
import numpy as np

import gc

# %matplotlib inline

# %%
WIDTH = 28
HEIGHT = 28
CHANNEL = 1

LATENT_DIM = 100 #latent variable z sample from normal distribution

BATCH_SIZE = 64
EPOCHS = 10

PATH = 'faces/'

#生成多少个图像 长*宽
ROW = 5
COL = 5

# %%
'''
load_index = 0

images_name = os.listdir(PATH)

IMAGES_COUNT = len(images_name)
'''
# Out:
# '\nload_index = 0\n\nimages_name = os.listdir(PATH)\n\nIMAGES_COUNT = len(images_name)\n'

# %%
(X_train , y_train),(X_test , y_test) = mnist.load_data()
X_train = X_train/127.5-1
X_train = np.expand_dims(X_train , 3)

# %%
def load_mnist():
    return X_train[np.random.randint(0, X_train.shape[0], BATCH_SIZE)]
    
def write_image_mnist(epoch):
    
    noise = np.random.normal(size = (ROW*COL , LATENT_DIM))
    generated_image = generator_i.predict(noise)
    generated_image = generated_image*0.5+0.5
    
    fig , axes = plt.pyplot.subplots(ROW , COL)
    
    count=0
    
    for i in range(ROW):
        for j in range(COL):
            axes[i][j].imshow(generated_image[count,:,:,0] , cmap = 'gray')
            axes[i][j].axis('off')
            count += 1
            
    fig.savefig('mnist_dcgan/No.%d.png' % epoch)
    plt.pyplot.close()

# %%
'''
def load_image(batch_size = BATCH_SIZE):
    global load_index
    
    images = []
    
    for i in range(batch_size):
        images.append(plt.image.imread(PATH + images_name[(load_index + i) % IMAGES_COUNT]))
    
    load_index += batch_size
    
    return np.array(images)/127.5-1

def write_image(epoch):
    
    noise = np.random.normal(size = (ROW*COL , LATENT_DIM))
    generated_image = generator_i.predict(noise)
    generated_image = (generated_image+1)*127.5
    
    fig , axes = plt.pyplot.subplots(ROW , COL)
    
    count=0
    
    for i in range(ROW):
        for j in range(COL):
            axes[i][j].imshow(generated_image[count])
            axes[i][j].axis('off')
            count += 1
            
    fig.savefig('generated_faces_dcgan/No.%d.png' % epoch)
    plt.pyplot.close()
    
    #plt.image.imsave('images/'+str(epoch)+'.jpg')
'''
# Out:
# "\ndef load_image(batch_size = BATCH_SIZE):\n    global load_index\n    \n    images = []\n    \n    for i in range(batch_size):\n        images.append(plt.image.imread(PATH + images_name[(load_index + i) % IMAGES_COUNT]))\n    \n    load_index += batch_size\n    \n    return np.array(images)/127.5-1\n\ndef write_image(epoch):\n    \n    noise = np.random.normal(size = (ROW*COL , LATENT_DIM))\n    generated_image = generator_i.predict(noise)\n    generated_image = (generated_image+1)*127.5\n    \n    fig , axes = plt.pyplot.subplots(ROW , COL)\n    \n    count=0\n    \n    for i in range(ROW):\n        for j in range(COL):\n            axes[i][j].imshow(generated_image[count])\n            axes[i][j].axis('off')\n            count += 1\n            \n    fig.savefig('generated_faces_dcgan/No.%d.png' % epoch)\n    plt.pyplot.close()\n    \n    #plt.image.imsave('images/'+str(epoch)+'.jpg')\n"

# %%
def generator():
    #sample from noise z
    model = Sequential(name='generator')
    
    #cartoon 图像使用 96*96*3
    #model.add(Reshape(target_shape=(10,10,1) , input_shape=(LATENT_DIM , ))) #隐变量的维度为100维 所以将其reshape一下 成为图片的形状
    #
    #model.add(Conv2DTranspose(filters=2 , kernel_size=(4,4) , activation='relu' , name='transconv1'))
    #model.add(BatchNormalization(momentum=0.8 , name='batchnorm1'))
    #model.add(Conv2DTranspose(filters=2 , kernel_size=(5,5) , activation='relu' , name='transconv2'))
    #model.add(BatchNormalization(momentum=0.8 , name='batchnorm2'))
    #model.add(Conv2DTranspose(filters=2 , kernel_size=(5,5) , activation='relu' , name='transconv3'))
    #model.add(BatchNormalization(momentum=0.8 , name='batchnorm3'))
    #model.add(Conv2DTranspose(filters=2 , kernel_size=(10,10) , activation='relu' , name='transconv4'))
    #model.add(BatchNormalization(momentum=0.8 , name='batchnorm4'))
    #model.add(Conv2DTranspose(filters=2 , kernel_size=(10,10) , activation='relu' , name='transconv5'))
    #model.add(BatchNormalization(momentum=0.8 , name='batchnorm5'))
    #model.add(Conv2DTranspose(filters=2 , kernel_size=(20,20) , activation='relu' , name='transconv6'))
    #model.add(BatchNormalization(momentum=0.8 , name='batchnorm6'))
    #model.add(Conv2DTranspose(filters=2 , kernel_size=(20,20) , activation='relu' , name='transconv7'))
    #model.add(BatchNormalization(momentum=0.8 , name='batchnorm7'))
    #
    #model.add(Conv2DTranspose(filters=FINAL_LAYER_FILTER , kernel_size=(20,20) , activation='tanh' , name='transconv8')) #最后一层必须与判别器的输入channel一致
    #model.add(BatchNormalization(momentum=0.8 , name='batchnorm8'))

    #mnist 图像使用 28*28*1
    model.add(Dense(128 * 7 * 7, activation="relu", input_shape=(LATENT_DIM,)))
    model.add(Reshape((7, 7, 128)))
    model.add(UpSampling2D())
    
    model.add(Conv2D(128, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    model.add(UpSampling2D())
    
    model.add(Conv2D(64, kernel_size=3, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
    
    model.add(Conv2D(CHANNEL, kernel_size=3, padding="same"))
    model.add(Activation("tanh"))
    #
    model.summary()
    
    noise = Input(shape=(LATENT_DIM , ) , name='input1')
    image = model(noise)
    
    return Model(noise , image , name='generator_Model')

# %%
def discriminator():
    #input a image to discriminate real or fake
    model = Sequential(name='discriminator')
    
    model.add(Conv2D(filters=32 , kernel_size=(3,3) , strides=(2,2) , padding='same' , input_shape=(WIDTH , HEIGHT , CHANNEL) , name='conv1'))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.25))
    
    #model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(filters=64 , kernel_size=(3,3) , strides=(2,2) , padding='same' , name='conv2'))
    model.add(ZeroPadding2D(padding=((0,1) , (0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.25))
    
    model.add(Conv2D(filters=128 , kernel_size=(3,3) , strides=(2,2) , padding='same' , name='conv3'))
    model.add(BatchNormalization(momentum=0.8))  
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.25))

    
    model.add(Conv2D(filters=256 , kernel_size=(3,3) , strides=(1,1) , name='conv4'))
    model.add(BatchNormalization(momentum=0.8))  
    model.add(LeakyReLU(0.2))
    model.add(Dropout(0.25))

    model.add(Flatten())
    
    model.add(Dense(units=1 , activation='sigmoid' , name='dense16'))
    
    model.summary()
    
    image = Input(shape=(WIDTH , HEIGHT , CHANNEL) , name='input1')
    validity = model(image)
    
    return Model(image , validity , name='discriminator_Model')

# %%
def combined_model(generator_i , discriminator_i):
    #生成器和判别器组合成整体
    z = Input(shape=(LATENT_DIM , ) , name='z')
    
    image = generator_i(z)
    
    #print(image.shape)
    
    discriminator_i.trainable = False
    validity = discriminator_i(image)
    
    return Model(z , validity , name='combined_model')

# %%
adam = Adam(lr = 0.0002 , beta_1=0.5)

# %%
discriminator_i = discriminator()
discriminator_i.compile(optimizer=adam , loss='binary_crossentropy' , metrics=['accuracy'])

generator_i = generator()

combined_model_i = combined_model(generator_i , discriminator_i)


combined_model_i.compile(optimizer=adam , loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 14, 14, 32)        320
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 7, 7, 64)          18496
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 8, 8, 64)          0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 2, 2, 256)         295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 2, 256)         1024
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense16 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 390,657
# Trainable params: 389,761
# Non-trainable params: 896
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        73792
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 1)         577
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 856,193
# Trainable params: 855,809
# Non-trainable params: 384
# _________________________________________________________________

# %%
real_labels = np.ones(shape=(BATCH_SIZE , 1)) #真实样本label为1
fake_labels = np.zeros(shape=(BATCH_SIZE , 1)) #假样本label为0

for i in range(10000):
    noise = np.random.normal(size=(BATCH_SIZE , LATENT_DIM))

    #real_image = load_image()
    real_image = load_mnist()
    #训练判别器
    fake_image = generator_i.predict(noise)

    real_loss = discriminator_i.train_on_batch(real_image , real_labels)
    fake_loss = discriminator_i.train_on_batch(fake_image , fake_labels)

    loss = np.add(real_loss , fake_loss)/2

    #训练生成器
    noise2 = np.random.normal(size=(BATCH_SIZE , LATENT_DIM))
    generator_loss = combined_model_i.train_on_batch(noise2 , real_labels)
    
    print('epoch:%d loss:%f accu:%f gene_loss:%f' % (i , loss[0] , loss[1] , generator_loss))
    
    if i % 100 == 0:
        #write_image(i)
        write_image_mnist(i)
    
#write_image(999)
write_image_mnist(999)
# Out:
# C:\Anaconda3\lib\site-packages\keras\engine\training.py:478: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# epoch:0 loss:0.944372 accu:0.429688 gene_loss:0.664394
# epoch:1 loss:0.628822 accu:0.648438 gene_loss:0.885968
# epoch:2 loss:0.467271 accu:0.734375 gene_loss:1.136587
# epoch:3 loss:0.250192 accu:0.929688 gene_loss:1.387456
# epoch:4 loss:0.215087 accu:0.953125 gene_loss:1.255647
# epoch:5 loss:0.208758 accu:0.953125 gene_loss:1.029696
# epoch:6 loss:0.207502 accu:0.929688 gene_loss:0.932798
# epoch:7 loss:0.389681 accu:0.820312 gene_loss:0.897569
# epoch:8 loss:0.572808 accu:0.671875 gene_loss:1.175625
# epoch:9 loss:0.848456 accu:0.554688 gene_loss:1.860921
# epoch:10 loss:0.941301 accu:0.468750 gene_loss:2.176312
# epoch:11 loss:0.832453 accu:0.500000 gene_loss:1.902400
# epoch:12 loss:0.713410 accu:0.601562 gene_loss:1.638576
# epoch:13 loss:0.617894 accu:0.687500 gene_loss:1.260773
# epoch:14 loss:0.498941 accu:0.718750 gene_loss:1.392766
# epoch:15 loss:0.427026 accu:0.804688 gene_loss:1.355153
# epoch:16 loss:0.293547 accu:0.937500 gene_loss:0.930678
# epoch:17 loss:0.261232 accu:0.921875 gene_loss:0.485050
# epoch:18 loss:0.247782 accu:0.898438 gene_loss:0.357179
# epoch:19 loss:0.205514 accu:0.929688 gene_loss:0.420966
# epoch:20 loss:0.274406 accu:0.906250 gene_loss:0.435383
# epoch:21 loss:0.395736 accu:0.781250 gene_loss:0.713805
# epoch:22 loss:0.765519 accu:0.585938 gene_loss:1.380768
# epoch:23 loss:0.848467 accu:0.507812 gene_loss:2.024155
# epoch:24 loss:0.860413 accu:0.453125 gene_loss:1.705235
# epoch:25 loss:0.789400 accu:0.554688 gene_loss:1.484286
# epoch:26 loss:0.643093 accu:0.648438 gene_loss:1.166089
# epoch:27 loss:0.664265 accu:0.640625 gene_loss:1.499898
# epoch:28 loss:0.870184 accu:0.523438 gene_loss:1.840408
# epoch:211 loss:0.727305 accu:0.523438 gene_loss:0.950893
# epoch:212 loss:0.774397 accu:0.468750 gene_loss:0.974993
# epoch:213 loss:0.738252 accu:0.546875 gene_loss:0.936829
# epoch:214 loss:0.758463 accu:0.492188 gene_loss:0.835893
# epoch:215 loss:0.787858 accu:0.460938 gene_loss:0.856688
# epoch:216 loss:0.686797 accu:0.617188 gene_loss:0.951746
# epoch:217 loss:0.750575 accu:0.492188 gene_loss:0.870549
# epoch:218 loss:0.732697 accu:0.578125 gene_loss:0.933160
# epoch:219 loss:0.764964 accu:0.539062 gene_loss:0.957311
# epoch:220 loss:0.723812 accu:0.554688 gene_loss:0.874377
# epoch:221 loss:0.741869 accu:0.500000 gene_loss:0.854973
# epoch:222 loss:0.678512 accu:0.617188 gene_loss:0.785716
# epoch:223 loss:0.772722 accu:0.523438 gene_loss:0.863220
# epoch:224 loss:0.789805 accu:0.492188 gene_loss:0.937940
# epoch:225 loss:0.742758 accu:0.515625 gene_loss:0.894243
# epoch:226 loss:0.816051 accu:0.453125 gene_loss:0.839691
# epoch:227 loss:0.714631 accu:0.539062 gene_loss:0.915563
# epoch:228 loss:0.828765 accu:0.453125 gene_loss:0.841588
# epoch:229 loss:0.740011 accu:0.500000 gene_loss:0.806134
# epoch:230 loss:0.734050 accu:0.500000 gene_loss:1.050852
# epoch:231 loss:0.669245 accu:0.617188 gene_loss:0.850871
# epoch:232 loss:0.788869 accu:0.546875 gene_loss:0.931014
# epoch:233 loss:0.775894 accu:0.492188 gene_loss:0.894360
# epoch:234 loss:0.681547 accu:0.554688 gene_loss:0.937821
# epoch:235 loss:0.752001 accu:0.515625 gene_loss:0.975378
# epoch:236 loss:0.775581 accu:0.539062 gene_loss:0.961004
# epoch:237 loss:0.708435 accu:0.539062 gene_loss:0.945765
# epoch:238 loss:0.800426 accu:0.437500 gene_loss:1.006558
# epoch:239 loss:0.720028 accu:0.585938 gene_loss:1.112950
# epoch:240 loss:0.752391 accu:0.484375 gene_loss:0.975481
# epoch:241 loss:0.690758 accu:0.539062 gene_loss:0.847148
# epoch:242 loss:0.666974 accu:0.617188 gene_loss:0.876032
# epoch:243 loss:0.710328 accu:0.562500 gene_loss:0.797270
# epoch:244 loss:0.673981 accu:0.546875 gene_loss:0.877948
# epoch:245 loss:0.679082 accu:0.554688 gene_loss:0.976042
# epoch:246 loss:0.702814 accu:0.578125 gene_loss:1.069955
# epoch:247 loss:0.717334 accu:0.531250 gene_loss:1.027320
# epoch:248 loss:0.613389 accu:0.703125 gene_loss:0.970444
# epoch:249 loss:0.709602 accu:0.562500 gene_loss:0.942168
# epoch:250 loss:0.603618 accu:0.710938 gene_loss:1.077442
# epoch:251 loss:0.720760 accu:0.562500 gene_loss:0.967818
# epoch:252 loss:0.731860 accu:0.570312 gene_loss:1.058467
# epoch:253 loss:0.750084 accu:0.531250 gene_loss:1.023438
# epoch:254 loss:0.727307 accu:0.546875 gene_loss:0.998748
# epoch:255 loss:0.682710 accu:0.570312 gene_loss:0.906723
# epoch:302 loss:0.678500 accu:0.593750 gene_loss:0.898954
# epoch:303 loss:0.656064 accu:0.609375 gene_loss:0.881762
# epoch:304 loss:0.689659 accu:0.585938 gene_loss:0.943390
# epoch:305 loss:0.718093 accu:0.515625 gene_loss:0.852253
# epoch:306 loss:0.756406 accu:0.515625 gene_loss:0.918919
# epoch:307 loss:0.660568 accu:0.585938 gene_loss:0.937360
# epoch:308 loss:0.699331 accu:0.585938 gene_loss:1.092797
# epoch:309 loss:0.683679 accu:0.562500 gene_loss:0.946375
# epoch:310 loss:0.708511 accu:0.546875 gene_loss:0.917351
# epoch:311 loss:0.650828 accu:0.625000 gene_loss:0.858367
# epoch:312 loss:0.709466 accu:0.570312 gene_loss:0.844184
# epoch:313 loss:0.683446 accu:0.585938 gene_loss:1.010252
# epoch:314 loss:0.726277 accu:0.539062 gene_loss:0.909453
# epoch:315 loss:0.743844 accu:0.539062 gene_loss:0.987750
# epoch:316 loss:0.738136 accu:0.554688 gene_loss:1.004569
# epoch:317 loss:0.677287 accu:0.632812 gene_loss:0.962929
# epoch:318 loss:0.773445 accu:0.500000 gene_loss:0.939753
# epoch:319 loss:0.740432 accu:0.492188 gene_loss:0.950878
# epoch:320 loss:0.770508 accu:0.523438 gene_loss:0.968139
# epoch:321 loss:0.751574 accu:0.507812 gene_loss:0.895445
# epoch:322 loss:0.701238 accu:0.578125 gene_loss:0.958320
# epoch:323 loss:0.652273 accu:0.609375 gene_loss:0.870021
# epoch:324 loss:0.695442 accu:0.585938 gene_loss:0.938648
# epoch:325 loss:0.738157 accu:0.507812 gene_loss:0.983615
# epoch:326 loss:0.690038 accu:0.562500 gene_loss:0.961802
# epoch:327 loss:0.684527 accu:0.585938 gene_loss:0.908570
# epoch:328 loss:0.777575 accu:0.507812 gene_loss:0.888595
# epoch:329 loss:0.773578 accu:0.476562 gene_loss:0.852780
# epoch:330 loss:0.686489 accu:0.593750 gene_loss:0.873654
# epoch:331 loss:0.697187 accu:0.554688 gene_loss:0.932837
# epoch:332 loss:0.683046 accu:0.570312 gene_loss:0.904636
# epoch:333 loss:0.784856 accu:0.453125 gene_loss:0.884460
# epoch:334 loss:0.753413 accu:0.460938 gene_loss:0.946896
# epoch:335 loss:0.714526 accu:0.500000 gene_loss:0.982144
# epoch:336 loss:0.721841 accu:0.546875 gene_loss:0.920730
# epoch:337 loss:0.738173 accu:0.539062 gene_loss:0.967593
# epoch:338 loss:0.680738 accu:0.585938 gene_loss:0.979847
# epoch:339 loss:0.747473 accu:0.570312 gene_loss:1.042321
# epoch:340 loss:0.732857 accu:0.523438 gene_loss:0.948103
# epoch:341 loss:0.724495 accu:0.570312 gene_loss:0.959608
# epoch:342 loss:0.721749 accu:0.531250 gene_loss:0.901187
# epoch:343 loss:0.673618 accu:0.601562 gene_loss:0.937917
# epoch:344 loss:0.742853 accu:0.492188 gene_loss:0.869197
# epoch:345 loss:0.698726 accu:0.601562 gene_loss:1.003955
# epoch:346 loss:0.739888 accu:0.531250 gene_loss:0.781186
# epoch:483 loss:0.631755 accu:0.625000 gene_loss:1.017033
# epoch:484 loss:0.647403 accu:0.625000 gene_loss:1.063031
# epoch:485 loss:0.746419 accu:0.468750 gene_loss:0.943010
# epoch:486 loss:0.688924 accu:0.523438 gene_loss:0.973747
# epoch:487 loss:0.698366 accu:0.554688 gene_loss:0.928398
# epoch:488 loss:0.662893 accu:0.578125 gene_loss:0.942498
# epoch:489 loss:0.606342 accu:0.664062 gene_loss:1.032849
# epoch:490 loss:0.678201 accu:0.585938 gene_loss:0.992116
# epoch:491 loss:0.679245 accu:0.601562 gene_loss:1.056946
# epoch:492 loss:0.691113 accu:0.570312 gene_loss:0.908828
# epoch:493 loss:0.622997 accu:0.656250 gene_loss:0.948435
# epoch:494 loss:0.713149 accu:0.554688 gene_loss:0.940297
# epoch:495 loss:0.607074 accu:0.710938 gene_loss:1.054578
# epoch:496 loss:0.602855 accu:0.671875 gene_loss:0.872206
# epoch:497 loss:0.704830 accu:0.601562 gene_loss:0.927049
# epoch:498 loss:0.692705 accu:0.625000 gene_loss:0.904349
# epoch:499 loss:0.682188 accu:0.648438 gene_loss:0.979361
# epoch:500 loss:0.691418 accu:0.570312 gene_loss:0.874307
# epoch:501 loss:0.661984 accu:0.593750 gene_loss:0.889437
# epoch:502 loss:0.669825 accu:0.570312 gene_loss:0.960505
# epoch:503 loss:0.647455 accu:0.609375 gene_loss:0.942723
# epoch:504 loss:0.645597 accu:0.617188 gene_loss:1.018890
# epoch:505 loss:0.683641 accu:0.570312 gene_loss:0.981958
# epoch:506 loss:0.666114 accu:0.554688 gene_loss:0.992238
# epoch:507 loss:0.676793 accu:0.570312 gene_loss:1.014130
# epoch:508 loss:0.677395 accu:0.609375 gene_loss:0.979098
# epoch:509 loss:0.676158 accu:0.562500 gene_loss:0.962867
# epoch:510 loss:0.684913 accu:0.601562 gene_loss:0.962569
# epoch:511 loss:0.648493 accu:0.617188 gene_loss:0.956796
# epoch:512 loss:0.619784 accu:0.648438 gene_loss:0.958969
# epoch:513 loss:0.652564 accu:0.625000 gene_loss:0.991746
# epoch:514 loss:0.654199 accu:0.648438 gene_loss:0.871681
# epoch:515 loss:0.643549 accu:0.632812 gene_loss:0.957000
# epoch:516 loss:0.591256 accu:0.656250 gene_loss:0.965212
# epoch:517 loss:0.677480 accu:0.593750 gene_loss:0.993279
# epoch:518 loss:0.675939 accu:0.554688 gene_loss:0.979698
# epoch:519 loss:0.698247 accu:0.500000 gene_loss:0.943367
# epoch:520 loss:0.676608 accu:0.609375 gene_loss:0.911392
# epoch:521 loss:0.678675 accu:0.539062 gene_loss:1.059476
# epoch:522 loss:0.741769 accu:0.531250 gene_loss:0.946217
# epoch:523 loss:0.591227 accu:0.679688 gene_loss:1.158209
# epoch:524 loss:0.644224 accu:0.578125 gene_loss:1.012054
# epoch:525 loss:0.646534 accu:0.585938 gene_loss:0.905653
# epoch:526 loss:0.599301 accu:0.679688 gene_loss:0.924886
# epoch:527 loss:0.649110 accu:0.656250 gene_loss:0.981612
# epoch:528 loss:0.631293 accu:0.640625 gene_loss:0.904331
# epoch:529 loss:0.633897 accu:0.656250 gene_loss:0.928827
# epoch:530 loss:0.627119 accu:0.640625 gene_loss:0.917462
# epoch:531 loss:0.626655 accu:0.640625 gene_loss:1.009964
# epoch:532 loss:0.676153 accu:0.601562 gene_loss:0.982538
# epoch:533 loss:0.644186 accu:0.640625 gene_loss:0.937399
# epoch:534 loss:0.703197 accu:0.593750 gene_loss:0.860532
# epoch:535 loss:0.627816 accu:0.617188 gene_loss:0.976740
# epoch:536 loss:0.662104 accu:0.609375 gene_loss:1.005041
# epoch:537 loss:0.663986 accu:0.601562 gene_loss:0.977528
# epoch:538 loss:0.707254 accu:0.585938 gene_loss:1.060743
# epoch:539 loss:0.677012 accu:0.515625 gene_loss:0.953813
# epoch:540 loss:0.635146 accu:0.656250 gene_loss:0.903256
# epoch:541 loss:0.616521 accu:0.687500 gene_loss:1.029403
# epoch:542 loss:0.724318 accu:0.546875 gene_loss:0.928021
# epoch:543 loss:0.698913 accu:0.500000 gene_loss:0.967497
# epoch:544 loss:0.635616 accu:0.609375 gene_loss:1.073709
# epoch:545 loss:0.657669 accu:0.632812 gene_loss:0.911538
# epoch:546 loss:0.676933 accu:0.546875 gene_loss:0.974383
# epoch:547 loss:0.691239 accu:0.593750 gene_loss:1.114505
# epoch:548 loss:0.641744 accu:0.632812 gene_loss:1.046515
# epoch:549 loss:0.704411 accu:0.554688 gene_loss:1.021811
# epoch:550 loss:0.652953 accu:0.593750 gene_loss:0.866240
# epoch:551 loss:0.675036 accu:0.609375 gene_loss:0.944510
# epoch:552 loss:0.573889 accu:0.664062 gene_loss:1.038722
# epoch:553 loss:0.671609 accu:0.625000 gene_loss:0.804850
# epoch:554 loss:0.628783 accu:0.593750 gene_loss:0.921364
# epoch:555 loss:0.604007 accu:0.687500 gene_loss:1.059313
# epoch:556 loss:0.671013 accu:0.632812 gene_loss:0.900526
# epoch:557 loss:0.602033 accu:0.664062 gene_loss:1.022473
# epoch:558 loss:0.641209 accu:0.648438 gene_loss:1.077866
# epoch:559 loss:0.633662 accu:0.617188 gene_loss:1.074728
# epoch:560 loss:0.697748 accu:0.609375 gene_loss:1.066051
# epoch:561 loss:0.692671 accu:0.578125 gene_loss:1.109748
# epoch:562 loss:0.672560 accu:0.625000 gene_loss:0.912661
# epoch:563 loss:0.730499 accu:0.515625 gene_loss:0.962363
# epoch:564 loss:0.564238 accu:0.757812 gene_loss:1.053586
# epoch:565 loss:0.616296 accu:0.648438 gene_loss:0.963283
# epoch:566 loss:0.603214 accu:0.640625 gene_loss:0.940192
# epoch:567 loss:0.678566 accu:0.562500 gene_loss:0.967591
# epoch:568 loss:0.621757 accu:0.656250 gene_loss:0.942943
# epoch:569 loss:0.692311 accu:0.562500 gene_loss:0.987237
# epoch:570 loss:0.638439 accu:0.695312 gene_loss:0.882601
# epoch:571 loss:0.617004 accu:0.671875 gene_loss:1.022669
# epoch:572 loss:0.655151 accu:0.617188 gene_loss:0.910438
# epoch:573 loss:0.669504 accu:0.593750 gene_loss:0.833227
# epoch:574 loss:0.680611 accu:0.609375 gene_loss:1.014868
# epoch:575 loss:0.652511 accu:0.648438 gene_loss:0.984006
# epoch:576 loss:0.723548 accu:0.546875 gene_loss:1.026463
# epoch:577 loss:0.685298 accu:0.554688 gene_loss:0.934757
# epoch:578 loss:0.630580 accu:0.648438 gene_loss:1.167288
# epoch:579 loss:0.688534 accu:0.601562 gene_loss:1.079254
# epoch:580 loss:0.655083 accu:0.656250 gene_loss:0.970415
# epoch:581 loss:0.622187 accu:0.632812 gene_loss:1.181343
# epoch:582 loss:0.714581 accu:0.554688 gene_loss:1.026402
# epoch:583 loss:0.611305 accu:0.609375 gene_loss:0.991669
# epoch:584 loss:0.654659 accu:0.625000 gene_loss:1.114046
# epoch:585 loss:0.650594 accu:0.593750 gene_loss:0.931330
# epoch:586 loss:0.648846 accu:0.632812 gene_loss:1.036228
# epoch:587 loss:0.635019 accu:0.687500 gene_loss:0.918004
# epoch:588 loss:0.645159 accu:0.609375 gene_loss:0.910456
# epoch:589 loss:0.635923 accu:0.625000 gene_loss:0.914505
# epoch:590 loss:0.643657 accu:0.609375 gene_loss:0.967026
# epoch:591 loss:0.652264 accu:0.617188 gene_loss:0.930863
# epoch:592 loss:0.642783 accu:0.679688 gene_loss:1.043738
# epoch:593 loss:0.685248 accu:0.554688 gene_loss:0.902779
# epoch:594 loss:0.602314 accu:0.671875 gene_loss:1.060047
# epoch:595 loss:0.567733 accu:0.750000 gene_loss:0.947366
# epoch:596 loss:0.640073 accu:0.609375 gene_loss:0.985948
# epoch:597 loss:0.638585 accu:0.640625 gene_loss:0.968998
# epoch:598 loss:0.668401 accu:0.632812 gene_loss:0.906446
# epoch:599 loss:0.667021 accu:0.632812 gene_loss:0.950105
# epoch:600 loss:0.673839 accu:0.593750 gene_loss:0.915337
# epoch:601 loss:0.664696 accu:0.593750 gene_loss:0.981661
# epoch:602 loss:0.670653 accu:0.625000 gene_loss:1.019961
# epoch:603 loss:0.676464 accu:0.585938 gene_loss:0.896322
# epoch:604 loss:0.645549 accu:0.617188 gene_loss:1.019946
# epoch:605 loss:0.727774 accu:0.515625 gene_loss:0.907089
# epoch:606 loss:0.604886 accu:0.687500 gene_loss:1.054106
# epoch:607 loss:0.721040 accu:0.515625 gene_loss:1.031016
# epoch:608 loss:0.601956 accu:0.695312 gene_loss:0.953906
# epoch:609 loss:0.722560 accu:0.507812 gene_loss:1.046416
# epoch:610 loss:0.659840 accu:0.578125 gene_loss:0.931963
# epoch:611 loss:0.636306 accu:0.609375 gene_loss:0.899488
# epoch:612 loss:0.695993 accu:0.578125 gene_loss:1.020120
# epoch:613 loss:0.627529 accu:0.617188 gene_loss:0.911943
# epoch:614 loss:0.650785 accu:0.617188 gene_loss:0.857627
# epoch:615 loss:0.680003 accu:0.578125 gene_loss:0.985439
# epoch:616 loss:0.591408 accu:0.664062 gene_loss:0.930364
# epoch:617 loss:0.642710 accu:0.625000 gene_loss:0.959557
# epoch:618 loss:0.702700 accu:0.593750 gene_loss:0.993714
# epoch:619 loss:0.622102 accu:0.609375 gene_loss:0.951611
# epoch:620 loss:0.636294 accu:0.671875 gene_loss:1.037797
# epoch:621 loss:0.634779 accu:0.671875 gene_loss:1.011854
# epoch:622 loss:0.636049 accu:0.617188 gene_loss:0.907408
# epoch:623 loss:0.581872 accu:0.671875 gene_loss:1.035952
# epoch:624 loss:0.669178 accu:0.601562 gene_loss:0.904599
# epoch:625 loss:0.621160 accu:0.640625 gene_loss:0.897244
# epoch:626 loss:0.712932 accu:0.562500 gene_loss:1.050799
# epoch:627 loss:0.692342 accu:0.554688 gene_loss:1.100523
# epoch:628 loss:0.666471 accu:0.609375 gene_loss:0.952559
# epoch:629 loss:0.682944 accu:0.601562 gene_loss:0.957522
# epoch:630 loss:0.701580 accu:0.546875 gene_loss:0.933076
# epoch:631 loss:0.659181 accu:0.578125 gene_loss:0.957458
# epoch:632 loss:0.673208 accu:0.609375 gene_loss:0.906142
# epoch:633 loss:0.660459 accu:0.632812 gene_loss:1.027718
# epoch:634 loss:0.702855 accu:0.585938 gene_loss:1.043042
# epoch:635 loss:0.616685 accu:0.687500 gene_loss:1.043494
# epoch:636 loss:0.661492 accu:0.625000 gene_loss:0.897570
# epoch:637 loss:0.655439 accu:0.617188 gene_loss:0.982600
# epoch:638 loss:0.601274 accu:0.640625 gene_loss:1.084340
# epoch:639 loss:0.701101 accu:0.554688 gene_loss:1.008559
# epoch:640 loss:0.691463 accu:0.578125 gene_loss:0.890762
# epoch:641 loss:0.686707 accu:0.554688 gene_loss:1.045025
# epoch:642 loss:0.614147 accu:0.632812 gene_loss:0.956522
# epoch:643 loss:0.701475 accu:0.492188 gene_loss:0.946356
# epoch:644 loss:0.577495 accu:0.726562 gene_loss:0.959097
# epoch:645 loss:0.611022 accu:0.687500 gene_loss:0.982436
# epoch:646 loss:0.642781 accu:0.632812 gene_loss:0.973320
# epoch:647 loss:0.640868 accu:0.664062 gene_loss:0.968263
# epoch:648 loss:0.617897 accu:0.625000 gene_loss:0.880533
# epoch:649 loss:0.581326 accu:0.703125 gene_loss:1.025731
# epoch:650 loss:0.588182 accu:0.703125 gene_loss:0.870076
# epoch:651 loss:0.662706 accu:0.562500 gene_loss:1.123499
# epoch:652 loss:0.641921 accu:0.632812 gene_loss:0.960131
# epoch:653 loss:0.597912 accu:0.695312 gene_loss:1.033575
# epoch:654 loss:0.635677 accu:0.601562 gene_loss:0.981331
# epoch:655 loss:0.634067 accu:0.656250 gene_loss:1.008264
# epoch:656 loss:0.653747 accu:0.656250 gene_loss:0.966993
# epoch:657 loss:0.647351 accu:0.585938 gene_loss:0.938282
# epoch:658 loss:0.670954 accu:0.601562 gene_loss:0.902503
# epoch:659 loss:0.674305 accu:0.578125 gene_loss:1.019727
# epoch:660 loss:0.632853 accu:0.640625 gene_loss:0.969372
# epoch:661 loss:0.667768 accu:0.609375 gene_loss:0.943989
# epoch:662 loss:0.643657 accu:0.625000 gene_loss:0.948302
# epoch:663 loss:0.678782 accu:0.570312 gene_loss:0.887973
# epoch:664 loss:0.658833 accu:0.609375 gene_loss:0.955603
# epoch:665 loss:0.601857 accu:0.710938 gene_loss:0.887979
# epoch:666 loss:0.627457 accu:0.671875 gene_loss:1.039795
# epoch:667 loss:0.621207 accu:0.656250 gene_loss:0.954121
# epoch:668 loss:0.706038 accu:0.578125 gene_loss:0.984713
# epoch:669 loss:0.672319 accu:0.656250 gene_loss:1.057916
# epoch:670 loss:0.669849 accu:0.578125 gene_loss:0.950887
# epoch:671 loss:0.658835 accu:0.593750 gene_loss:0.940138
# epoch:672 loss:0.711184 accu:0.570312 gene_loss:0.888440
# epoch:673 loss:0.624242 accu:0.664062 gene_loss:0.852898
# epoch:674 loss:0.646352 accu:0.625000 gene_loss:0.896906
# epoch:675 loss:0.683372 accu:0.609375 gene_loss:0.907277
# epoch:676 loss:0.647048 accu:0.585938 gene_loss:0.983883
# epoch:677 loss:0.667592 accu:0.601562 gene_loss:0.933214
# epoch:678 loss:0.651054 accu:0.632812 gene_loss:1.063820
# epoch:679 loss:0.692162 accu:0.585938 gene_loss:0.925456
# epoch:680 loss:0.636377 accu:0.601562 gene_loss:0.957077
# epoch:681 loss:0.684004 accu:0.570312 gene_loss:0.935505
# epoch:682 loss:0.703565 accu:0.515625 gene_loss:1.055631
# epoch:683 loss:0.571498 accu:0.750000 gene_loss:1.022280
# epoch:684 loss:0.694770 accu:0.546875 gene_loss:1.004485
# epoch:685 loss:0.645417 accu:0.593750 gene_loss:1.048113
# epoch:686 loss:0.623644 accu:0.617188 gene_loss:1.194232
# epoch:687 loss:0.672777 accu:0.625000 gene_loss:1.112457
# epoch:688 loss:0.639614 accu:0.593750 gene_loss:1.080862
# epoch:689 loss:0.669139 accu:0.625000 gene_loss:0.956891
# epoch:690 loss:0.701581 accu:0.585938 gene_loss:0.960642
# epoch:691 loss:0.671790 accu:0.617188 gene_loss:0.984950
# epoch:692 loss:0.635101 accu:0.609375 gene_loss:1.063508
# epoch:693 loss:0.607095 accu:0.710938 gene_loss:0.972117
# epoch:694 loss:0.652783 accu:0.625000 gene_loss:0.929852
# epoch:695 loss:0.705586 accu:0.601562 gene_loss:1.022752
# epoch:696 loss:0.649453 accu:0.609375 gene_loss:1.049454
# epoch:697 loss:0.662736 accu:0.585938 gene_loss:1.035781
# epoch:698 loss:0.714745 accu:0.507812 gene_loss:0.984160
# epoch:699 loss:0.642907 accu:0.578125 gene_loss:0.928071
# epoch:700 loss:0.689252 accu:0.562500 gene_loss:0.882739
# epoch:701 loss:0.587147 accu:0.726562 gene_loss:1.053464
# epoch:702 loss:0.635346 accu:0.710938 gene_loss:1.019601
# epoch:703 loss:0.605995 accu:0.695312 gene_loss:0.997395
# epoch:704 loss:0.680350 accu:0.601562 gene_loss:1.005444
# epoch:705 loss:0.727584 accu:0.500000 gene_loss:0.897118
# epoch:706 loss:0.720401 accu:0.515625 gene_loss:1.015660
# epoch:707 loss:0.655828 accu:0.585938 gene_loss:1.120128
# epoch:708 loss:0.597820 accu:0.679688 gene_loss:0.987506
# epoch:709 loss:0.653164 accu:0.601562 gene_loss:0.950957
# epoch:710 loss:0.687397 accu:0.617188 gene_loss:0.967783
# epoch:711 loss:0.671762 accu:0.585938 gene_loss:0.890092
# epoch:712 loss:0.599596 accu:0.726562 gene_loss:1.012281
# epoch:713 loss:0.617727 accu:0.656250 gene_loss:0.946530
# epoch:714 loss:0.625042 accu:0.632812 gene_loss:0.987987
# epoch:715 loss:0.738976 accu:0.523438 gene_loss:0.947537
# epoch:716 loss:0.632958 accu:0.609375 gene_loss:1.132178
# epoch:717 loss:0.647786 accu:0.617188 gene_loss:0.990330
# epoch:718 loss:0.647005 accu:0.601562 gene_loss:1.101819
# epoch:719 loss:0.650761 accu:0.625000 gene_loss:0.977742
# epoch:720 loss:0.674480 accu:0.625000 gene_loss:0.960559
# epoch:721 loss:0.646008 accu:0.609375 gene_loss:0.995021
# epoch:722 loss:0.687139 accu:0.632812 gene_loss:1.115989
# epoch:723 loss:0.688624 accu:0.554688 gene_loss:1.149432
# epoch:724 loss:0.654904 accu:0.609375 gene_loss:1.011750
# epoch:725 loss:0.658475 accu:0.601562 gene_loss:0.985284
# epoch:726 loss:0.657098 accu:0.593750 gene_loss:0.969807
# epoch:727 loss:0.700230 accu:0.593750 gene_loss:0.958329
# epoch:728 loss:0.667158 accu:0.593750 gene_loss:0.980151
# epoch:729 loss:0.677590 accu:0.625000 gene_loss:0.897415
# epoch:730 loss:0.692166 accu:0.554688 gene_loss:0.780898
# epoch:731 loss:0.619772 accu:0.640625 gene_loss:1.013067
# epoch:732 loss:0.709775 accu:0.507812 gene_loss:0.941918
# epoch:733 loss:0.618368 accu:0.695312 gene_loss:0.980024
# epoch:734 loss:0.710442 accu:0.500000 gene_loss:0.955635
# epoch:735 loss:0.663986 accu:0.609375 gene_loss:1.025862
# epoch:736 loss:0.638266 accu:0.640625 gene_loss:1.036092
# epoch:737 loss:0.586324 accu:0.742188 gene_loss:0.984233
# epoch:738 loss:0.677284 accu:0.617188 gene_loss:1.161593
# epoch:739 loss:0.682374 accu:0.578125 gene_loss:1.097270
# epoch:740 loss:0.654769 accu:0.656250 gene_loss:0.903807
# epoch:741 loss:0.690811 accu:0.531250 gene_loss:0.850039
# epoch:742 loss:0.685282 accu:0.585938 gene_loss:0.829930
# epoch:743 loss:0.650527 accu:0.625000 gene_loss:0.905985
# epoch:744 loss:0.645006 accu:0.585938 gene_loss:0.971599
# epoch:745 loss:0.648293 accu:0.632812 gene_loss:0.908019
# epoch:746 loss:0.655885 accu:0.593750 gene_loss:1.037348
# epoch:747 loss:0.617113 accu:0.679688 gene_loss:1.090094
# epoch:748 loss:0.654052 accu:0.609375 gene_loss:1.072244
# epoch:749 loss:0.722555 accu:0.515625 gene_loss:1.028594
# epoch:750 loss:0.750898 accu:0.476562 gene_loss:0.963913
# epoch:751 loss:0.687751 accu:0.609375 gene_loss:0.868962
# epoch:752 loss:0.631768 accu:0.664062 gene_loss:1.009963
# epoch:753 loss:0.751207 accu:0.476562 gene_loss:0.934999
# epoch:754 loss:0.664995 accu:0.593750 gene_loss:0.911402
# epoch:755 loss:0.686682 accu:0.570312 gene_loss:0.886068
# epoch:756 loss:0.728537 accu:0.523438 gene_loss:0.944023
# epoch:757 loss:0.665878 accu:0.617188 gene_loss:1.000991
# epoch:758 loss:0.599037 accu:0.664062 gene_loss:0.902410
# epoch:759 loss:0.683791 accu:0.554688 gene_loss:1.016030
# epoch:760 loss:0.652908 accu:0.640625 gene_loss:0.997912
# epoch:761 loss:0.663116 accu:0.585938 gene_loss:1.033573
# epoch:762 loss:0.698960 accu:0.507812 gene_loss:1.048820
# epoch:763 loss:0.725851 accu:0.539062 gene_loss:0.963904
# epoch:764 loss:0.599018 accu:0.687500 gene_loss:1.006774
# epoch:765 loss:0.703212 accu:0.570312 gene_loss:0.959554
# epoch:766 loss:0.625315 accu:0.617188 gene_loss:0.943233
# epoch:767 loss:0.648810 accu:0.632812 gene_loss:0.930718
# epoch:768 loss:0.625899 accu:0.640625 gene_loss:0.923141
# epoch:769 loss:0.677165 accu:0.593750 gene_loss:0.990045
# epoch:770 loss:0.644228 accu:0.640625 gene_loss:0.917491
# epoch:771 loss:0.597194 accu:0.671875 gene_loss:0.961705
# epoch:772 loss:0.650948 accu:0.585938 gene_loss:0.955168
# epoch:773 loss:0.632616 accu:0.625000 gene_loss:0.859999
# epoch:774 loss:0.692935 accu:0.554688 gene_loss:0.882945
# epoch:775 loss:0.633473 accu:0.640625 gene_loss:0.948431
# epoch:776 loss:0.653295 accu:0.593750 gene_loss:0.924363
# epoch:777 loss:0.714228 accu:0.515625 gene_loss:1.017380
# epoch:778 loss:0.665095 accu:0.585938 gene_loss:0.907175
# epoch:779 loss:0.626370 accu:0.664062 gene_loss:0.915830
# epoch:780 loss:0.719193 accu:0.539062 gene_loss:1.053233
# epoch:781 loss:0.648425 accu:0.640625 gene_loss:1.027629
# epoch:782 loss:0.691307 accu:0.578125 gene_loss:0.862204
# epoch:783 loss:0.688068 accu:0.632812 gene_loss:1.021700
# epoch:784 loss:0.676974 accu:0.570312 gene_loss:1.022840
# epoch:785 loss:0.652795 accu:0.593750 gene_loss:0.979887
# epoch:786 loss:0.718276 accu:0.546875 gene_loss:0.936828
# epoch:787 loss:0.710618 accu:0.539062 gene_loss:1.052744
# epoch:788 loss:0.634923 accu:0.640625 gene_loss:0.979862
# epoch:789 loss:0.713973 accu:0.523438 gene_loss:1.011424
# epoch:790 loss:0.696451 accu:0.554688 gene_loss:0.883648
# epoch:791 loss:0.639729 accu:0.593750 gene_loss:0.900032
# epoch:792 loss:0.672558 accu:0.562500 gene_loss:0.949511
# epoch:793 loss:0.678768 accu:0.578125 gene_loss:0.923506
# epoch:794 loss:0.666891 accu:0.593750 gene_loss:1.025963
# epoch:795 loss:0.625537 accu:0.609375 gene_loss:0.946438
# epoch:796 loss:0.671535 accu:0.585938 gene_loss:0.851145
# epoch:797 loss:0.694024 accu:0.554688 gene_loss:1.070845
# epoch:798 loss:0.688051 accu:0.546875 gene_loss:1.021080
# epoch:799 loss:0.669231 accu:0.601562 gene_loss:0.915990
# epoch:800 loss:0.621946 accu:0.671875 gene_loss:1.013751
# epoch:801 loss:0.582488 accu:0.687500 gene_loss:0.975099
# epoch:802 loss:0.661422 accu:0.578125 gene_loss:0.979639
# epoch:803 loss:0.643751 accu:0.679688 gene_loss:1.015220
# epoch:804 loss:0.669311 accu:0.578125 gene_loss:1.133483
# epoch:805 loss:0.605414 accu:0.703125 gene_loss:1.050223
# epoch:806 loss:0.691370 accu:0.593750 gene_loss:0.915258
# epoch:807 loss:0.635898 accu:0.570312 gene_loss:0.900639
# epoch:808 loss:0.768896 accu:0.507812 gene_loss:0.806639
# epoch:809 loss:0.698374 accu:0.570312 gene_loss:0.877695
# epoch:810 loss:0.660616 accu:0.585938 gene_loss:0.921931
# epoch:811 loss:0.710199 accu:0.570312 gene_loss:0.882970
# epoch:812 loss:0.634919 accu:0.671875 gene_loss:0.890349
# epoch:813 loss:0.721731 accu:0.609375 gene_loss:0.929836
# epoch:814 loss:0.659347 accu:0.601562 gene_loss:0.934238
# epoch:815 loss:0.731371 accu:0.554688 gene_loss:0.854874
# epoch:816 loss:0.699226 accu:0.515625 gene_loss:0.971252
# epoch:817 loss:0.672568 accu:0.554688 gene_loss:0.946379
# epoch:818 loss:0.764370 accu:0.492188 gene_loss:0.919748
# epoch:819 loss:0.697984 accu:0.554688 gene_loss:0.931949
# epoch:820 loss:0.633407 accu:0.703125 gene_loss:0.931872
# epoch:821 loss:0.695475 accu:0.554688 gene_loss:0.929509
# epoch:822 loss:0.725752 accu:0.539062 gene_loss:0.974371
# epoch:823 loss:0.743853 accu:0.546875 gene_loss:0.889027
# epoch:824 loss:0.645442 accu:0.585938 gene_loss:0.893545
# epoch:825 loss:0.609894 accu:0.718750 gene_loss:0.943529
# epoch:826 loss:0.726973 accu:0.500000 gene_loss:0.853026
# epoch:827 loss:0.676154 accu:0.585938 gene_loss:0.866053
# epoch:828 loss:0.671643 accu:0.625000 gene_loss:1.077325
# epoch:829 loss:0.670020 accu:0.601562 gene_loss:0.987550
# epoch:830 loss:0.672702 accu:0.523438 gene_loss:0.993474
# epoch:831 loss:0.740616 accu:0.500000 gene_loss:0.931999
# epoch:832 loss:0.635294 accu:0.632812 gene_loss:1.005349
# epoch:833 loss:0.659600 accu:0.593750 gene_loss:0.821119
# epoch:834 loss:0.772664 accu:0.539062 gene_loss:0.914407
# epoch:835 loss:0.683502 accu:0.523438 gene_loss:0.910594
# epoch:836 loss:0.675625 accu:0.593750 gene_loss:0.952736
# epoch:837 loss:0.636099 accu:0.617188 gene_loss:0.963461
# epoch:838 loss:0.670859 accu:0.609375 gene_loss:0.869270
# ...
# epoch:7719 loss:0.695680 accu:0.554688 gene_loss:1.007973
# epoch:7720 loss:0.680323 accu:0.601562 gene_loss:0.837627
# epoch:7721 loss:0.587864 accu:0.679688 gene_loss:0.937226
# epoch:7722 loss:0.650777 accu:0.593750 gene_loss:0.739290
# epoch:7723 loss:0.647742 accu:0.585938 gene_loss:0.843168
# epoch:7724 loss:0.552471 accu:0.781250 gene_loss:0.890651
# epoch:7725 loss:0.625400 accu:0.648438 gene_loss:0.966554
# epoch:7771 loss:0.667059 accu:0.593750 gene_loss:0.893122
# epoch:7772 loss:0.589771 accu:0.703125 gene_loss:0.953825
# epoch:7773 loss:0.692729 accu:0.609375 gene_loss:0.852104
# epoch:7774 loss:0.695345 accu:0.531250 gene_loss:0.816777
# epoch:7775 loss:0.628961 accu:0.640625 gene_loss:1.083725
# epoch:7776 loss:0.630474 accu:0.625000 gene_loss:0.910816
# epoch:7777 loss:0.575994 accu:0.726562 gene_loss:0.955241
# epoch:7778 loss:0.678246 accu:0.562500 gene_loss:0.848358
# epoch:7779 loss:0.719218 accu:0.468750 gene_loss:0.805715
# epoch:7780 loss:0.618588 accu:0.625000 gene_loss:0.821862
# epoch:7781 loss:0.650735 accu:0.601562 gene_loss:0.978714
# epoch:7782 loss:0.591806 accu:0.625000 gene_loss:0.865889
# epoch:7783 loss:0.633297 accu:0.632812 gene_loss:0.773361
# epoch:7784 loss:0.643215 accu:0.664062 gene_loss:0.893154
# epoch:7785 loss:0.730574 accu:0.468750 gene_loss:0.833401
# epoch:7786 loss:0.579324 accu:0.671875 gene_loss:0.783250
# epoch:7787 loss:0.728043 accu:0.515625 gene_loss:0.890327
# epoch:7788 loss:0.633239 accu:0.648438 gene_loss:0.838501
# epoch:7789 loss:0.623697 accu:0.640625 gene_loss:0.792368
# epoch:7790 loss:0.654008 accu:0.617188 gene_loss:0.882106
# epoch:7791 loss:0.654518 accu:0.601562 gene_loss:0.742540
# epoch:7792 loss:0.597615 accu:0.687500 gene_loss:0.864597
# epoch:7793 loss:0.654259 accu:0.585938 gene_loss:0.766512
# epoch:7794 loss:0.683188 accu:0.593750 gene_loss:0.879260
# epoch:7795 loss:0.668829 accu:0.578125 gene_loss:0.831499
# epoch:7796 loss:0.689451 accu:0.546875 gene_loss:0.834468
# epoch:7797 loss:0.611397 accu:0.679688 gene_loss:0.966274
# epoch:7798 loss:0.666932 accu:0.625000 gene_loss:0.984026
# epoch:7799 loss:0.574470 accu:0.695312 gene_loss:0.819254
# epoch:7800 loss:0.613306 accu:0.656250 gene_loss:0.902861
# epoch:7801 loss:0.598801 accu:0.648438 gene_loss:0.981161
# epoch:7802 loss:0.722675 accu:0.523438 gene_loss:0.907197
# epoch:7803 loss:0.641830 accu:0.648438 gene_loss:0.966903
# epoch:7804 loss:0.658681 accu:0.640625 gene_loss:0.861850
# epoch:7805 loss:0.689925 accu:0.539062 gene_loss:0.890380
# epoch:7806 loss:0.627602 accu:0.703125 gene_loss:0.871527
# epoch:7807 loss:0.656853 accu:0.625000 gene_loss:0.901961
# epoch:7808 loss:0.668819 accu:0.648438 gene_loss:0.852498
# epoch:7809 loss:0.692510 accu:0.546875 gene_loss:0.905168
# epoch:7810 loss:0.667216 accu:0.609375 gene_loss:0.940738
# epoch:7811 loss:0.580184 accu:0.687500 gene_loss:0.918703
# epoch:7812 loss:0.608780 accu:0.664062 gene_loss:0.921084
# epoch:7813 loss:0.637537 accu:0.593750 gene_loss:0.872707
# epoch:7814 loss:0.669703 accu:0.570312 gene_loss:1.030394
# epoch:7859 loss:0.606463 accu:0.687500 gene_loss:0.961089
# epoch:7860 loss:0.707581 accu:0.570312 gene_loss:0.890913
# epoch:7861 loss:0.678188 accu:0.585938 gene_loss:0.777648
# epoch:7862 loss:0.705748 accu:0.570312 gene_loss:0.923128
# epoch:7863 loss:0.677249 accu:0.585938 gene_loss:0.836826
# epoch:7864 loss:0.663586 accu:0.625000 gene_loss:1.066373
# epoch:7865 loss:0.620103 accu:0.625000 gene_loss:0.919352
# epoch:7866 loss:0.635093 accu:0.640625 gene_loss:0.910500
# epoch:7867 loss:0.582714 accu:0.703125 gene_loss:0.995827
# epoch:7868 loss:0.682074 accu:0.539062 gene_loss:0.899138
# epoch:7869 loss:0.685196 accu:0.585938 gene_loss:0.973150
# epoch:7870 loss:0.664505 accu:0.617188 gene_loss:0.821720
# epoch:7871 loss:0.619132 accu:0.664062 gene_loss:0.874136
# epoch:7872 loss:0.673166 accu:0.609375 gene_loss:0.909013
# epoch:7873 loss:0.666488 accu:0.609375 gene_loss:0.868466
# epoch:7874 loss:0.643018 accu:0.632812 gene_loss:0.849745
# epoch:7875 loss:0.674215 accu:0.609375 gene_loss:0.902123
# epoch:7876 loss:0.638601 accu:0.617188 gene_loss:0.944831
# epoch:7877 loss:0.667308 accu:0.601562 gene_loss:0.812350
# epoch:7878 loss:0.656083 accu:0.625000 gene_loss:0.887327
# epoch:7879 loss:0.659401 accu:0.609375 gene_loss:0.972724
# epoch:7880 loss:0.634841 accu:0.640625 gene_loss:1.009371
# epoch:7881 loss:0.660015 accu:0.632812 gene_loss:0.937230
# epoch:7882 loss:0.585155 accu:0.671875 gene_loss:0.853822
# epoch:7883 loss:0.623441 accu:0.609375 gene_loss:0.919121
# epoch:7884 loss:0.614291 accu:0.687500 gene_loss:0.928233
# epoch:7885 loss:0.697689 accu:0.554688 gene_loss:0.798595
# epoch:7886 loss:0.682663 accu:0.562500 gene_loss:0.898335
# epoch:7887 loss:0.690843 accu:0.562500 gene_loss:0.886088
# epoch:7888 loss:0.642059 accu:0.617188 gene_loss:0.862950
# epoch:7889 loss:0.617845 accu:0.656250 gene_loss:0.880172
# epoch:7890 loss:0.706165 accu:0.492188 gene_loss:0.896105
# epoch:7891 loss:0.628703 accu:0.656250 gene_loss:0.906360
# epoch:7892 loss:0.704760 accu:0.554688 gene_loss:1.080040
# epoch:7893 loss:0.623519 accu:0.671875 gene_loss:0.852402
# epoch:7894 loss:0.671038 accu:0.570312 gene_loss:0.994048
# epoch:7895 loss:0.634181 accu:0.656250 gene_loss:0.919955
# epoch:7896 loss:0.684510 accu:0.578125 gene_loss:0.855330
# epoch:7897 loss:0.594694 accu:0.671875 gene_loss:0.796565
# epoch:7898 loss:0.623985 accu:0.671875 gene_loss:0.859472
# epoch:7899 loss:0.627739 accu:0.640625 gene_loss:0.872543
# epoch:7900 loss:0.627589 accu:0.664062 gene_loss:0.883053
# epoch:7901 loss:0.601145 accu:0.671875 gene_loss:1.001549
# epoch:7902 loss:0.609725 accu:0.640625 gene_loss:0.790737
# epoch:7903 loss:0.731772 accu:0.492188 gene_loss:0.836283
# epoch:7904 loss:0.694564 accu:0.507812 gene_loss:0.811211
# epoch:7905 loss:0.658991 accu:0.632812 gene_loss:0.940936
# epoch:7906 loss:0.575598 accu:0.718750 gene_loss:0.866896
# epoch:7907 loss:0.564720 accu:0.750000 gene_loss:0.938868
# epoch:7908 loss:0.730259 accu:0.531250 gene_loss:0.841145
# epoch:7909 loss:0.618517 accu:0.687500 gene_loss:0.940930
# epoch:7910 loss:0.622884 accu:0.671875 gene_loss:0.792010
# epoch:7911 loss:0.653837 accu:0.617188 gene_loss:0.827820
# epoch:7912 loss:0.701465 accu:0.531250 gene_loss:0.859650
# epoch:7913 loss:0.640574 accu:0.632812 gene_loss:0.909553
# epoch:7914 loss:0.600243 accu:0.679688 gene_loss:0.900670
# epoch:7915 loss:0.724218 accu:0.523438 gene_loss:1.009071
# epoch:7916 loss:0.643002 accu:0.617188 gene_loss:0.925491
# epoch:7917 loss:0.613073 accu:0.640625 gene_loss:0.849014
# epoch:7918 loss:0.759385 accu:0.460938 gene_loss:0.937353
# epoch:7919 loss:0.642105 accu:0.671875 gene_loss:0.904881
# epoch:7920 loss:0.619024 accu:0.640625 gene_loss:0.992740
# epoch:7921 loss:0.647709 accu:0.648438 gene_loss:0.931553
# epoch:7922 loss:0.616641 accu:0.664062 gene_loss:0.897821
# epoch:7923 loss:0.628356 accu:0.609375 gene_loss:0.820465
# epoch:7924 loss:0.643306 accu:0.625000 gene_loss:0.855120
# epoch:7925 loss:0.614731 accu:0.671875 gene_loss:0.847260
# epoch:7926 loss:0.588540 accu:0.710938 gene_loss:0.959859
# epoch:7927 loss:0.624324 accu:0.671875 gene_loss:1.072687
# epoch:7928 loss:0.625479 accu:0.632812 gene_loss:0.793352
# epoch:7929 loss:0.620279 accu:0.695312 gene_loss:0.859038
# epoch:7930 loss:0.772287 accu:0.507812 gene_loss:0.865484
# epoch:7931 loss:0.604911 accu:0.656250 gene_loss:0.875349
# epoch:7932 loss:0.620068 accu:0.640625 gene_loss:0.904309
# epoch:7933 loss:0.647512 accu:0.632812 gene_loss:0.822994
# epoch:7934 loss:0.611488 accu:0.671875 gene_loss:0.770874
# epoch:7935 loss:0.711383 accu:0.539062 gene_loss:0.811057
# epoch:7936 loss:0.609697 accu:0.656250 gene_loss:0.977818
# epoch:7937 loss:0.707648 accu:0.578125 gene_loss:1.006895
# epoch:7938 loss:0.641870 accu:0.617188 gene_loss:0.830582
# epoch:7939 loss:0.590993 accu:0.679688 gene_loss:0.864628
# epoch:7940 loss:0.655288 accu:0.601562 gene_loss:0.950354
# epoch:7941 loss:0.626623 accu:0.648438 gene_loss:0.931685
# epoch:7942 loss:0.572810 accu:0.773438 gene_loss:1.040165
# epoch:7943 loss:0.578754 accu:0.757812 gene_loss:0.984981
# epoch:7944 loss:0.629524 accu:0.640625 gene_loss:0.888406
# epoch:7945 loss:0.610613 accu:0.695312 gene_loss:0.956821
# epoch:7946 loss:0.650435 accu:0.656250 gene_loss:1.051692
# epoch:7947 loss:0.633088 accu:0.656250 gene_loss:0.892002
# epoch:7948 loss:0.642881 accu:0.617188 gene_loss:0.860416
# epoch:7949 loss:0.657980 accu:0.570312 gene_loss:0.825636
# epoch:7950 loss:0.585147 accu:0.718750 gene_loss:0.971578
# epoch:7951 loss:0.686706 accu:0.578125 gene_loss:0.954555
# epoch:7952 loss:0.685763 accu:0.546875 gene_loss:0.871662
# epoch:7953 loss:0.659801 accu:0.601562 gene_loss:0.819265
# epoch:7954 loss:0.648727 accu:0.609375 gene_loss:0.827838
# epoch:7955 loss:0.657706 accu:0.593750 gene_loss:0.937519
# epoch:7956 loss:0.582975 accu:0.726562 gene_loss:0.854740
# epoch:7957 loss:0.754177 accu:0.492188 gene_loss:1.018474
# epoch:7958 loss:0.640013 accu:0.664062 gene_loss:0.948821
# epoch:7959 loss:0.678408 accu:0.578125 gene_loss:0.938533
# epoch:7960 loss:0.623582 accu:0.648438 gene_loss:0.732693
# epoch:7961 loss:0.645858 accu:0.601562 gene_loss:0.911717
# epoch:7962 loss:0.650928 accu:0.593750 gene_loss:1.113036
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-be470c9c4f3c> in <module>()
#      17     #训练生成器
#      18     noise2 = np.random.normal(size=(BATCH_SIZE , LATENT_DIM))
# ---> 19     generator_loss = combined_model_i.train_on_batch(noise2 , real_labels)
#      20
#      21     print('epoch:%d loss:%f accu:%f gene_loss:%f' % (i , loss[0] , loss[1] , generator_loss))
#
# C:\Anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1218             ins = x + y + sample_weights
#    1219         self._make_train_function()
# -> 1220         outputs = self.train_function(ins)
#    1221         if len(outputs) == 1:
#    1222             return outputs[0]
#
# C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
real_labels.shape
# Out:
# (64, 1)

# %%
discriminator_i.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input1 (InputLayer)          (None, 28, 28, 1)         0
# _________________________________________________________________
# discriminator (Sequential)   (None, 1)                 533505
# =================================================================
# Total params: 533,505
# Trainable params: 0
# Non-trainable params: 533,505
# _________________________________________________________________

# %%
generator_i.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input1 (InputLayer)          (None, 100)               0
# _________________________________________________________________
# generator (Sequential)       (None, 28, 28, 1)         1097744
# =================================================================
# Total params: 1,097,744
# Trainable params: 1,095,184
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
combined_model_i.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# z (InputLayer)               (None, 100)               0
# _________________________________________________________________
# generator_Model (Model)      (None, 96, 96, 3)         29029120
# _________________________________________________________________
# discriminator_Model (Model)  (None, 1)                 14320641
# =================================================================
# Total params: 43,349,761
# Trainable params: 29,025,536
# Non-trainable params: 14,324,225
# _________________________________________________________________

# %%
gc.collect()

# %%
modeli = Sequential()

modeli.add(Dense(128 * 7 * 7, activation="relu", input_shape=(LATENT_DIM,)))
modeli.add(Reshape((7, 7, 128)))
modeli.add(UpSampling2D())
modeli.add(Conv2D(128, kernel_size=3, padding="same"))
modeli.add(BatchNormalization(momentum=0.8))
modeli.add(Activation("relu"))
modeli.add(UpSampling2D())
modeli.add(Conv2D(64, kernel_size=3, padding="same"))
modeli.add(BatchNormalization(momentum=0.8))
modeli.add(Activation("relu"))
modeli.add(Conv2D(CHANNEL, kernel_size=3, padding="same"))
modeli.add(Activation("tanh"))

# %%
modeli.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 64)        73792
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 1)         577
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 856,193
# Trainable params: 855,809
# Non-trainable params: 384
# _________________________________________________________________

# %%
32*400
# Out:
# 12800

# %%
gc.collect()
