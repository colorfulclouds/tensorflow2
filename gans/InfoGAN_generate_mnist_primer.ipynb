# %%
#对偶学习的原理

# %%
from keras.models import Sequential , Model
from keras.layers import Dense ,  BatchNormalization , Reshape , Input , Flatten
from keras.layers import Conv2D , MaxPool2D , Conv2DTranspose , UpSampling2D , ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU , PReLU
from keras.layers import Activation
from keras.layers import Dropout

from keras.layers import Concatenate

#addin cycleGAN 使用instance-norm
from keras_contrib.layers.normalization import InstanceNormalization

from keras.initializers import truncated_normal , constant , random_normal

from keras.optimizers import Adam , RMSprop

from keras.datasets import mnist

from keras.utils import to_categorical

# %%
import os

import matplotlib as plt
import numpy as np

import gc

from glob import glob

import keras.backend as K

import scipy

# %matplotlib inline

# %%
WIDTH = 28
HEIGHT = 28
CHANNEL = 1

SHAPE = (WIDTH , HEIGHT , CHANNEL)

BATCH_SIZE = 64
EPOCHS = 10

#生成多少个图像 长*宽
ROW = 2
COL = 2

LATENT_DIM = 100 #噪音维度 100维  noise z
CLASSES_NUM = 10 #mnist一共10中类别

# %%
(X_train , y_train),(_ , _) = mnist.load_data()
X_train = X_train/127.5-1
X_train = np.expand_dims(X_train , 3)
y_train = y_train.reshape(-1 , 1)
y_train = to_categorical(y_train , num_classes=CLASSES_NUM + 1) #加1 是因为多出来一个表示不存在的label 代替fake的label

# %%
def load_mnist(batch_size = BATCH_SIZE):
    idx = np.random.randint(0 , X_train.shape[0] ,batch_size)
    return X_train[idx] , y_train[idx]
    
def write_image_mnist(epoch):
    
    z = np.random.normal(0 , 1 , size=(ROW * COL , LATENT_DIM))
    
    imgs = generator_i.predict(z)
    
    imgs = imgs*0.5+0.5
    
    fig , axes = plt.pyplot.subplots(ROW , COL)
    
    axes[0][0].imshow(imgs[0,:,:,0] , cmap='gray')
    axes[0][0].axis('off')

    axes[0][1].imshow(imgs[1,:,:,0] , cmap='gray')
    axes[0][1].axis('off')
    
    axes[1][0].imshow(imgs[2,:,:,0] , cmap='gray')
    axes[1][0].axis('off')

    axes[1][1].imshow(imgs[3,:,:,0] , cmap='gray')
    axes[1][1].axis('off')

    fig.savefig('mnist_infogan/No.%d.png' % epoch)
    plt.pyplot.close()

# %%
def generator():
    z = Input(shape=(LATENT_DIM , )) #输入一个风格的图像 生成另一个风格的图像
    
    model = Sequential()

    model.add(Dense(128 * 7 * 7, activation="relu", input_shape=(LATENT_DIM , )))
    model.add(Reshape((7, 7, 128)))
    model.add(BatchNormalization(momentum=0.8))
    model.add(UpSampling2D())
    model.add(Conv2D(128, kernel_size=3, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(UpSampling2D())
    model.add(Conv2D(64, kernel_size=3, padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(1, kernel_size=3, padding="same"))
    model.add(Activation("tanh"))
    
    img = model(z)
    
    return Model(z , img)

# %%
def discriminator():
    img = Input(shape=SHAPE)
    
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=SHAPE , padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Flatten())
    
    feature = model(img)
   
    validity = Dense(1 , activation='sigmoid')(feature)
    labels = Dense(CLASSES_NUM+1 , activation='softmax')(feature) #加1 因为多出来一个不存在的label 来代替fake的label
        
    return Model(img , [validity , labels])

# %%
adam = Adam(lr = 0.0002 , beta_1=0.5)
#构建计算图
discriminator_i = discriminator()
discriminator_i.compile(optimizer = adam , loss=['binary_crossentropy' , 'categorical_crossentropy'] , metrics=['accuracy'] , loss_weights=[0.5,0.5])

generator_i = generator()

z = Input(shape=(LATENT_DIM , ))

img = generator_i(z)

#freeze D
discriminator_i.trainable = False

validity , labels = discriminator_i(img)

combined = Model(z , validity)
combined.compile(optimizer=adam , loss='binary_crossentropy')

# %%
#SGAN add
#防止数据不平衡 引入类别权重
class_weight1 = {0:1 , 1:1}
class_weight2 = {i: CLASSES_NUM/(int(BATCH_SIZE/2)) for i in range(CLASSES_NUM)}
class_weight2[CLASSES_NUM] = 1/int(BATCH_SIZE/2)

# %%
def train():
    real_labels = np.ones(shape=(BATCH_SIZE , 1))
    fake_labels = np.zeros(shape=(BATCH_SIZE , 1))

    for i in range(1001):
        X_train , y_train = load_mnist()
        
        z = np.random.normal(0 , 1 , (BATCH_SIZE , LATENT_DIM))
        fake_y_train = to_categorical(np.full(shape=(BATCH_SIZE , 1) , fill_value=CLASSES_NUM) , num_classes=CLASSES_NUM+1) #加1 表示多一个不存在的label fake的label

        img = generator_i.predict(z)
        #训练判别器
        real_loss = discriminator_i.train_on_batch(X_train , [real_labels , y_train] , class_weight=[class_weight1 , class_weight2])
        fake_loss = discriminator_i.train_on_batch(img , [fake_labels , fake_y_train] , class_weight=[class_weight1 , class_weight2])
        loss = np.add(real_loss , fake_loss)/2

        #训练生成器
        generator_loss = combined.train_on_batch(z , real_labels , class_weight=[class_weight1 , class_weight2])

        print('epoch:%d loss:%f loss:%f accu:%f |xentropy_loss:%f' % (i , loss[0] , loss[1] , loss[2] , generator_loss))

        if i % 50 == 0:
            write_image_mnist(i)

    write_image_mnist(999)

# %%
train()
# Out:
# C:\Anaconda3\lib\site-packages\keras\engine\training.py:479: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# epoch:0 loss:0.514145 loss:0.562888 accu:0.465401 |xentropy_loss:0.951901
# epoch:1 loss:0.436431 loss:0.420730 accu:0.452131 |xentropy_loss:1.196074
# epoch:2 loss:0.397500 loss:0.365278 accu:0.429723 |xentropy_loss:1.366534
# epoch:3 loss:0.373885 loss:0.337564 accu:0.410206 |xentropy_loss:1.456960
# epoch:4 loss:0.364652 loss:0.340888 accu:0.388417 |xentropy_loss:1.623733
# epoch:5 loss:0.320986 loss:0.272020 accu:0.369953 |xentropy_loss:1.828723
# epoch:6 loss:0.329750 loss:0.284810 accu:0.374690 |xentropy_loss:1.709741
# epoch:7 loss:0.335962 loss:0.300877 accu:0.371047 |xentropy_loss:1.953167
# epoch:8 loss:0.305127 loss:0.241958 accu:0.368296 |xentropy_loss:2.176242
# epoch:9 loss:0.282134 loss:0.222279 accu:0.341989 |xentropy_loss:2.319942
# epoch:10 loss:0.267649 loss:0.190256 accu:0.345043 |xentropy_loss:2.315417
# epoch:11 loss:0.255751 loss:0.162791 accu:0.348711 |xentropy_loss:2.401908
# epoch:12 loss:0.240089 loss:0.158151 accu:0.322027 |xentropy_loss:2.453415
# epoch:13 loss:0.214539 loss:0.116895 accu:0.312184 |xentropy_loss:2.780993
# epoch:14 loss:0.199147 loss:0.094395 accu:0.303900 |xentropy_loss:2.658213
# epoch:15 loss:0.216154 loss:0.111731 accu:0.320576 |xentropy_loss:3.024441
# epoch:16 loss:0.209807 loss:0.118203 accu:0.301411 |xentropy_loss:2.996994
# epoch:17 loss:0.167774 loss:0.075167 accu:0.260381 |xentropy_loss:3.134625
# epoch:18 loss:0.190010 loss:0.082122 accu:0.297898 |xentropy_loss:3.454527
# epoch:19 loss:0.182988 loss:0.077797 accu:0.288180 |xentropy_loss:3.180344
# epoch:20 loss:0.164377 loss:0.062422 accu:0.266333 |xentropy_loss:3.417890
# epoch:21 loss:0.172276 loss:0.105310 accu:0.239242 |xentropy_loss:3.107819
# epoch:22 loss:0.157732 loss:0.080107 accu:0.235357 |xentropy_loss:3.150073
# epoch:23 loss:0.155088 loss:0.072588 accu:0.237587 |xentropy_loss:3.447086
# epoch:24 loss:0.152802 loss:0.062991 accu:0.242614 |xentropy_loss:3.524604
# epoch:25 loss:0.159882 loss:0.078030 accu:0.241734 |xentropy_loss:3.431682
# epoch:26 loss:0.150065 loss:0.063576 accu:0.236555 |xentropy_loss:3.420295
# epoch:27 loss:0.147128 loss:0.059717 accu:0.234540 |xentropy_loss:3.264670
# epoch:28 loss:0.139129 loss:0.065653 accu:0.212605 |xentropy_loss:3.171069
# epoch:29 loss:0.127202 loss:0.069269 accu:0.185135 |xentropy_loss:3.244371
# epoch:30 loss:0.143885 loss:0.086155 accu:0.201616 |xentropy_loss:3.718343
# epoch:31 loss:0.122697 loss:0.065268 accu:0.180126 |xentropy_loss:3.511093
# epoch:32 loss:0.124152 loss:0.070958 accu:0.177346 |xentropy_loss:3.318304
# epoch:33 loss:0.123998 loss:0.068786 accu:0.179209 |xentropy_loss:3.558089
# epoch:34 loss:0.127169 loss:0.058948 accu:0.195389 |xentropy_loss:3.556539
# epoch:35 loss:0.138730 loss:0.072203 accu:0.205256 |xentropy_loss:3.049725
# epoch:36 loss:0.146015 loss:0.091558 accu:0.200472 |xentropy_loss:2.865865
# epoch:37 loss:0.143237 loss:0.081467 accu:0.205007 |xentropy_loss:3.133612
# epoch:38 loss:0.126040 loss:0.052826 accu:0.199253 |xentropy_loss:3.149249
# epoch:39 loss:0.139236 loss:0.078173 accu:0.200298 |xentropy_loss:2.925463
# epoch:40 loss:0.101643 loss:0.049834 accu:0.153451 |xentropy_loss:3.279566
# epoch:41 loss:0.102136 loss:0.057698 accu:0.146575 |xentropy_loss:3.195323
# epoch:42 loss:0.115287 loss:0.042207 accu:0.188368 |xentropy_loss:3.481612
# epoch:43 loss:0.185295 loss:0.179668 accu:0.190921 |xentropy_loss:3.034295
# epoch:44 loss:0.094384 loss:0.057808 accu:0.130960 |xentropy_loss:3.550972
# epoch:45 loss:0.106698 loss:0.039537 accu:0.173858 |xentropy_loss:3.260142
# epoch:46 loss:0.167064 loss:0.151783 accu:0.182344 |xentropy_loss:3.301873
# epoch:47 loss:0.138871 loss:0.088811 accu:0.188932 |xentropy_loss:3.894659
# epoch:48 loss:0.195895 loss:0.192685 accu:0.199106 |xentropy_loss:2.966208
# epoch:49 loss:0.102614 loss:0.062545 accu:0.142683 |xentropy_loss:3.764650
# epoch:50 loss:0.227081 loss:0.248791 accu:0.205371 |xentropy_loss:2.687660
# epoch:51 loss:0.106004 loss:0.045695 accu:0.166314 |xentropy_loss:3.915268
# epoch:52 loss:0.109233 loss:0.087012 accu:0.131453 |xentropy_loss:3.819329
# epoch:53 loss:0.155929 loss:0.140295 accu:0.171562 |xentropy_loss:2.469853
# epoch:54 loss:0.127446 loss:0.096416 accu:0.158476 |xentropy_loss:4.621869
# epoch:55 loss:0.136737 loss:0.086848 accu:0.186625 |xentropy_loss:3.274457
# epoch:56 loss:0.126066 loss:0.061427 accu:0.190706 |xentropy_loss:3.359936
# epoch:57 loss:0.106771 loss:0.080317 accu:0.133224 |xentropy_loss:2.897997
# epoch:58 loss:0.164099 loss:0.151596 accu:0.176602 |xentropy_loss:4.444690
# epoch:59 loss:0.132362 loss:0.104982 accu:0.159741 |xentropy_loss:2.947456
# epoch:60 loss:0.218987 loss:0.274971 accu:0.163003 |xentropy_loss:4.706758
# epoch:61 loss:0.237905 loss:0.298786 accu:0.177024 |xentropy_loss:1.693972
# epoch:62 loss:0.181124 loss:0.212055 accu:0.150193 |xentropy_loss:4.516706
# epoch:63 loss:0.164688 loss:0.173330 accu:0.156045 |xentropy_loss:3.159179
# epoch:64 loss:0.104398 loss:0.078539 accu:0.130257 |xentropy_loss:2.934684
# epoch:65 loss:0.137196 loss:0.135229 accu:0.139163 |xentropy_loss:2.881696
# epoch:66 loss:0.168898 loss:0.176509 accu:0.161287 |xentropy_loss:4.713682
# epoch:67 loss:0.304914 loss:0.463206 accu:0.146621 |xentropy_loss:5.295949
# epoch:68 loss:0.226556 loss:0.304414 accu:0.148697 |xentropy_loss:3.174476
# epoch:69 loss:0.182394 loss:0.233049 accu:0.131738 |xentropy_loss:4.476378
# epoch:70 loss:0.118130 loss:0.110560 accu:0.125699 |xentropy_loss:3.999029
# epoch:71 loss:0.254304 loss:0.351894 accu:0.156714 |xentropy_loss:4.489017
# epoch:72 loss:0.127114 loss:0.105793 accu:0.148435 |xentropy_loss:4.227862
# epoch:73 loss:0.672611 loss:1.167189 accu:0.178034 |xentropy_loss:4.178482
# epoch:74 loss:0.186403 loss:0.233842 accu:0.138964 |xentropy_loss:4.666756
# epoch:75 loss:0.360517 loss:0.564068 accu:0.156965 |xentropy_loss:3.448656
# epoch:76 loss:0.148265 loss:0.149076 accu:0.147454 |xentropy_loss:5.177461
# epoch:77 loss:0.388882 loss:0.587911 accu:0.189853 |xentropy_loss:2.865576
# epoch:78 loss:0.184913 loss:0.224490 accu:0.145335 |xentropy_loss:4.574421
# epoch:79 loss:0.416821 loss:0.673949 accu:0.159692 |xentropy_loss:4.278451
# epoch:80 loss:0.332405 loss:0.502195 accu:0.162616 |xentropy_loss:3.997889
# epoch:81 loss:0.382036 loss:0.607888 accu:0.156185 |xentropy_loss:4.530478
# epoch:82 loss:0.430678 loss:0.681916 accu:0.179441 |xentropy_loss:3.125753
# epoch:83 loss:0.339475 loss:0.524934 accu:0.154016 |xentropy_loss:5.097920
# epoch:84 loss:0.356102 loss:0.552923 accu:0.159281 |xentropy_loss:4.103755
# epoch:85 loss:0.412976 loss:0.664623 accu:0.161330 |xentropy_loss:4.238465
# epoch:86 loss:0.484089 loss:0.781816 accu:0.186362 |xentropy_loss:3.881395
# epoch:87 loss:0.306906 loss:0.447122 accu:0.166691 |xentropy_loss:3.827395
# epoch:88 loss:0.731374 loss:1.253801 accu:0.208948 |xentropy_loss:3.165194
# epoch:89 loss:0.391880 loss:0.663500 accu:0.120260 |xentropy_loss:3.615578
# epoch:90 loss:0.518533 loss:0.880388 accu:0.156678 |xentropy_loss:2.307020
# epoch:91 loss:0.570941 loss:0.941698 accu:0.200184 |xentropy_loss:2.686651
# epoch:92 loss:0.499766 loss:0.828809 accu:0.170722 |xentropy_loss:2.679437
# epoch:93 loss:0.506080 loss:0.826064 accu:0.186095 |xentropy_loss:2.992471
# epoch:94 loss:0.644092 loss:1.133256 accu:0.154927 |xentropy_loss:1.995993
# epoch:95 loss:0.357646 loss:0.606296 accu:0.108996 |xentropy_loss:3.200904
# epoch:96 loss:0.558678 loss:0.944561 accu:0.172795 |xentropy_loss:2.514217
# epoch:97 loss:0.450563 loss:0.716670 accu:0.184456 |xentropy_loss:2.358725
# epoch:98 loss:0.777995 loss:1.412755 accu:0.143236 |xentropy_loss:2.421257
# epoch:99 loss:0.679428 loss:1.181248 accu:0.177609 |xentropy_loss:2.357664
# epoch:100 loss:0.707371 loss:1.250304 accu:0.164438 |xentropy_loss:1.515826
# epoch:101 loss:0.514682 loss:0.863354 accu:0.166009 |xentropy_loss:1.472762
# epoch:102 loss:0.606673 loss:1.042956 accu:0.170390 |xentropy_loss:1.964692
# epoch:103 loss:0.620305 loss:1.086713 accu:0.153896 |xentropy_loss:1.775159
# epoch:104 loss:0.535017 loss:0.920508 accu:0.149525 |xentropy_loss:1.823635
# epoch:105 loss:0.630767 loss:1.076980 accu:0.184554 |xentropy_loss:1.383258
# epoch:106 loss:0.610641 loss:1.085368 accu:0.135914 |xentropy_loss:1.511606
# epoch:107 loss:0.602412 loss:1.064783 accu:0.140041 |xentropy_loss:1.712436
# epoch:108 loss:0.619991 loss:1.044764 accu:0.195217 |xentropy_loss:1.604164
# epoch:109 loss:0.691122 loss:1.222319 accu:0.159925 |xentropy_loss:1.428437
# epoch:110 loss:0.574018 loss:0.985301 accu:0.162734 |xentropy_loss:1.386343
# epoch:111 loss:0.485352 loss:0.824234 accu:0.146471 |xentropy_loss:1.472415
# epoch:112 loss:0.564502 loss:1.002212 accu:0.126792 |xentropy_loss:1.634392
# epoch:113 loss:0.536006 loss:0.944445 accu:0.127567 |xentropy_loss:1.622544
# epoch:114 loss:0.578331 loss:0.968153 accu:0.188508 |xentropy_loss:1.720972
# epoch:115 loss:0.484507 loss:0.838538 accu:0.130476 |xentropy_loss:1.754562
# epoch:116 loss:0.557829 loss:0.945978 accu:0.169681 |xentropy_loss:1.506038
# epoch:117 loss:0.551632 loss:0.954948 accu:0.148316 |xentropy_loss:1.684857
# epoch:118 loss:0.609607 loss:1.079880 accu:0.139334 |xentropy_loss:1.542286
# epoch:119 loss:0.452072 loss:0.750799 accu:0.153346 |xentropy_loss:1.613542
# epoch:120 loss:0.480333 loss:0.789990 accu:0.170677 |xentropy_loss:1.507253
# epoch:121 loss:0.516080 loss:0.859737 accu:0.172422 |xentropy_loss:1.320386
# epoch:122 loss:0.505460 loss:0.872749 accu:0.138172 |xentropy_loss:1.629429
# epoch:123 loss:0.531001 loss:0.902387 accu:0.159616 |xentropy_loss:1.389093
# epoch:124 loss:0.492758 loss:0.845755 accu:0.139762 |xentropy_loss:1.259111
# epoch:125 loss:0.512911 loss:0.875440 accu:0.150382 |xentropy_loss:1.476598
# epoch:126 loss:0.495493 loss:0.833347 accu:0.157640 |xentropy_loss:1.201068
# epoch:127 loss:0.509724 loss:0.883296 accu:0.136152 |xentropy_loss:1.317701
# epoch:128 loss:0.568967 loss:0.973775 accu:0.164159 |xentropy_loss:1.277568
# epoch:129 loss:0.470022 loss:0.793631 accu:0.146413 |xentropy_loss:1.566531
# epoch:130 loss:0.470596 loss:0.798843 accu:0.142350 |xentropy_loss:1.257105
# epoch:131 loss:0.575101 loss:1.028018 accu:0.122183 |xentropy_loss:1.156553
# epoch:132 loss:0.452298 loss:0.752540 accu:0.152056 |xentropy_loss:1.318174
# epoch:133 loss:0.433196 loss:0.748200 accu:0.118191 |xentropy_loss:1.425266
# epoch:134 loss:0.481444 loss:0.815790 accu:0.147098 |xentropy_loss:1.377640
# epoch:135 loss:0.507648 loss:0.878412 accu:0.136885 |xentropy_loss:1.188236
# epoch:136 loss:0.447897 loss:0.740333 accu:0.155461 |xentropy_loss:1.381454
# epoch:137 loss:0.429353 loss:0.735156 accu:0.123549 |xentropy_loss:1.512149
# epoch:138 loss:0.577378 loss:1.010497 accu:0.144260 |xentropy_loss:1.405085
# epoch:139 loss:0.507985 loss:0.867916 accu:0.148054 |xentropy_loss:1.271429
# epoch:140 loss:0.529868 loss:0.912814 accu:0.146923 |xentropy_loss:1.191004
# epoch:141 loss:0.455548 loss:0.768382 accu:0.142713 |xentropy_loss:1.351358
# epoch:142 loss:0.430500 loss:0.720815 accu:0.140186 |xentropy_loss:1.362356
# epoch:143 loss:0.568550 loss:0.993701 accu:0.143398 |xentropy_loss:1.269920
# epoch:144 loss:0.484323 loss:0.826301 accu:0.142344 |xentropy_loss:1.299926
# epoch:145 loss:0.499003 loss:0.822149 accu:0.175857 |xentropy_loss:1.310513
# epoch:146 loss:0.484570 loss:0.792945 accu:0.176194 |xentropy_loss:1.278217
# epoch:147 loss:0.472427 loss:0.825935 accu:0.118918 |xentropy_loss:1.267490
# epoch:148 loss:0.437187 loss:0.732795 accu:0.141579 |xentropy_loss:1.527599
# epoch:149 loss:0.482556 loss:0.833619 accu:0.131494 |xentropy_loss:1.435536
# epoch:150 loss:0.483082 loss:0.845619 accu:0.120545 |xentropy_loss:1.430792
# epoch:151 loss:0.485039 loss:0.837322 accu:0.132757 |xentropy_loss:1.296537
# epoch:152 loss:0.510750 loss:0.854967 accu:0.166532 |xentropy_loss:1.183206
# epoch:153 loss:0.456967 loss:0.804344 accu:0.109591 |xentropy_loss:1.220069
# epoch:154 loss:0.438694 loss:0.758506 accu:0.118882 |xentropy_loss:1.298927
# epoch:155 loss:0.486839 loss:0.817558 accu:0.156120 |xentropy_loss:1.180665
# epoch:156 loss:0.474334 loss:0.794780 accu:0.153888 |xentropy_loss:1.315341
# epoch:157 loss:0.490069 loss:0.830136 accu:0.150002 |xentropy_loss:1.073678
# epoch:158 loss:0.483973 loss:0.830108 accu:0.137838 |xentropy_loss:1.151155
# epoch:159 loss:0.497676 loss:0.847321 accu:0.148032 |xentropy_loss:1.134870
# epoch:160 loss:0.451097 loss:0.765290 accu:0.136904 |xentropy_loss:1.283944
# epoch:161 loss:0.442730 loss:0.786980 accu:0.098480 |xentropy_loss:1.213857
# epoch:162 loss:0.426087 loss:0.713119 accu:0.139056 |xentropy_loss:1.197594
# epoch:163 loss:0.446422 loss:0.769130 accu:0.123714 |xentropy_loss:1.100007
# epoch:164 loss:0.471083 loss:0.810519 accu:0.131647 |xentropy_loss:1.108691
# epoch:165 loss:0.419143 loss:0.707871 accu:0.130414 |xentropy_loss:1.254986
# epoch:166 loss:0.476975 loss:0.821165 accu:0.132785 |xentropy_loss:1.110376
# epoch:167 loss:0.427085 loss:0.721028 accu:0.133141 |xentropy_loss:1.395491
# epoch:168 loss:0.495961 loss:0.825417 accu:0.166505 |xentropy_loss:1.275604
# epoch:169 loss:0.392544 loss:0.663662 accu:0.121426 |xentropy_loss:1.209843
# epoch:170 loss:0.461808 loss:0.803739 accu:0.119877 |xentropy_loss:1.134243
# epoch:171 loss:0.435263 loss:0.733562 accu:0.136964 |xentropy_loss:1.176692
# epoch:172 loss:0.438705 loss:0.759667 accu:0.117744 |xentropy_loss:1.087950
# epoch:173 loss:0.477594 loss:0.807422 accu:0.147765 |xentropy_loss:1.206912
# epoch:174 loss:0.424289 loss:0.725930 accu:0.122648 |xentropy_loss:1.283831
# epoch:175 loss:0.473984 loss:0.808646 accu:0.139323 |xentropy_loss:1.095535
# epoch:176 loss:0.421399 loss:0.727042 accu:0.115755 |xentropy_loss:1.412130
# epoch:177 loss:0.461829 loss:0.749588 accu:0.174070 |xentropy_loss:1.268552
# epoch:178 loss:0.458355 loss:0.792300 accu:0.124409 |xentropy_loss:1.138980
# epoch:179 loss:0.371665 loss:0.611848 accu:0.131481 |xentropy_loss:1.144533
# epoch:180 loss:0.428054 loss:0.723588 accu:0.132521 |xentropy_loss:1.255815
# epoch:181 loss:0.458900 loss:0.790315 accu:0.127486 |xentropy_loss:1.243926
# epoch:182 loss:0.436977 loss:0.766377 accu:0.107578 |xentropy_loss:1.290330
# epoch:183 loss:0.445860 loss:0.751262 accu:0.140458 |xentropy_loss:1.269718
# epoch:184 loss:0.364628 loss:0.621821 accu:0.107435 |xentropy_loss:1.260374
# epoch:185 loss:0.450769 loss:0.773854 accu:0.127685 |xentropy_loss:1.052445
# epoch:186 loss:0.396525 loss:0.678433 accu:0.114617 |xentropy_loss:1.179669
# epoch:187 loss:0.430296 loss:0.732607 accu:0.127986 |xentropy_loss:1.266109
# epoch:188 loss:0.418510 loss:0.693911 accu:0.143110 |xentropy_loss:1.221660
# epoch:189 loss:0.448312 loss:0.750831 accu:0.145792 |xentropy_loss:1.272347
# epoch:190 loss:0.434720 loss:0.763827 accu:0.105614 |xentropy_loss:1.072767
# epoch:191 loss:0.397755 loss:0.685118 accu:0.110391 |xentropy_loss:1.229845
# epoch:192 loss:0.417661 loss:0.717964 accu:0.117358 |xentropy_loss:0.978479
# epoch:193 loss:0.401372 loss:0.690297 accu:0.112447 |xentropy_loss:1.045086
# epoch:194 loss:0.464756 loss:0.761660 accu:0.167851 |xentropy_loss:1.105033
# epoch:195 loss:0.338521 loss:0.589841 accu:0.087202 |xentropy_loss:1.312589
# epoch:196 loss:0.452637 loss:0.760517 accu:0.144757 |xentropy_loss:1.214951
# epoch:197 loss:0.405268 loss:0.686835 accu:0.123702 |xentropy_loss:1.045645
# epoch:198 loss:0.456607 loss:0.766637 accu:0.146577 |xentropy_loss:1.078782
# epoch:199 loss:0.456156 loss:0.769194 accu:0.143118 |xentropy_loss:1.201207
# epoch:200 loss:0.446268 loss:0.759109 accu:0.133427 |xentropy_loss:1.212468
# epoch:201 loss:0.433908 loss:0.729989 accu:0.137826 |xentropy_loss:1.173082
# epoch:202 loss:0.406520 loss:0.704931 accu:0.108110 |xentropy_loss:1.264559
# epoch:203 loss:0.462957 loss:0.765839 accu:0.160076 |xentropy_loss:1.116662
# epoch:204 loss:0.448426 loss:0.775919 accu:0.120932 |xentropy_loss:1.177718
# epoch:205 loss:0.439473 loss:0.753485 accu:0.125461 |xentropy_loss:1.272968
# epoch:206 loss:0.484702 loss:0.803493 accu:0.165911 |xentropy_loss:1.225579
# epoch:207 loss:0.423754 loss:0.730806 accu:0.116701 |xentropy_loss:1.272873
# epoch:208 loss:0.430010 loss:0.704080 accu:0.155941 |xentropy_loss:1.266744
# epoch:209 loss:0.481599 loss:0.800963 accu:0.162234 |xentropy_loss:1.116229
# epoch:210 loss:0.403145 loss:0.663923 accu:0.142367 |xentropy_loss:1.321104
# epoch:211 loss:0.447908 loss:0.769947 accu:0.125868 |xentropy_loss:1.118467
# epoch:212 loss:0.400918 loss:0.705941 accu:0.095895 |xentropy_loss:1.225681
# epoch:213 loss:0.409341 loss:0.690256 accu:0.128426 |xentropy_loss:1.112072
# epoch:214 loss:0.447221 loss:0.785030 accu:0.109413 |xentropy_loss:1.051000
# epoch:215 loss:0.379381 loss:0.636312 accu:0.122450 |xentropy_loss:1.120727
# epoch:216 loss:0.471073 loss:0.756090 accu:0.186056 |xentropy_loss:1.159910
# epoch:217 loss:0.407857 loss:0.693539 accu:0.122176 |xentropy_loss:1.182995
# epoch:218 loss:0.437808 loss:0.762372 accu:0.113243 |xentropy_loss:1.241936
# epoch:219 loss:0.483254 loss:0.793266 accu:0.173242 |xentropy_loss:1.147890
# epoch:220 loss:0.444598 loss:0.753774 accu:0.135421 |xentropy_loss:1.107288
# epoch:221 loss:0.391919 loss:0.671821 accu:0.112018 |xentropy_loss:1.204853
# epoch:222 loss:0.421907 loss:0.704040 accu:0.139773 |xentropy_loss:1.201444
# epoch:223 loss:0.391989 loss:0.667501 accu:0.116477 |xentropy_loss:1.226295
# epoch:224 loss:0.370535 loss:0.663542 accu:0.077528 |xentropy_loss:1.218315
# epoch:225 loss:0.449385 loss:0.775780 accu:0.122989 |xentropy_loss:1.182901
# epoch:226 loss:0.390724 loss:0.669849 accu:0.111600 |xentropy_loss:1.152740
# epoch:227 loss:0.433638 loss:0.720702 accu:0.146575 |xentropy_loss:1.112723
# epoch:228 loss:0.477405 loss:0.795726 accu:0.159084 |xentropy_loss:1.066716
# epoch:229 loss:0.398354 loss:0.669098 accu:0.127610 |xentropy_loss:1.306246
# epoch:230 loss:0.472533 loss:0.775429 accu:0.169637 |xentropy_loss:1.077637
# epoch:231 loss:0.392681 loss:0.659838 accu:0.125525 |xentropy_loss:1.303366
# epoch:232 loss:0.406190 loss:0.706470 accu:0.105909 |xentropy_loss:1.097627
# epoch:233 loss:0.414056 loss:0.737101 accu:0.091011 |xentropy_loss:1.053106
# epoch:234 loss:0.444064 loss:0.749903 accu:0.138225 |xentropy_loss:1.091857
# epoch:235 loss:0.429574 loss:0.682303 accu:0.176845 |xentropy_loss:1.235502
# epoch:236 loss:0.449639 loss:0.790276 accu:0.109002 |xentropy_loss:1.160468
# epoch:237 loss:0.420888 loss:0.732512 accu:0.109264 |xentropy_loss:1.186687
# epoch:238 loss:0.409649 loss:0.700827 accu:0.118471 |xentropy_loss:1.152936
# epoch:239 loss:0.444891 loss:0.762317 accu:0.127464 |xentropy_loss:1.087667
# epoch:240 loss:0.420077 loss:0.728819 accu:0.111334 |xentropy_loss:1.125813
# epoch:241 loss:0.424592 loss:0.707858 accu:0.141327 |xentropy_loss:1.227549
# epoch:242 loss:0.408375 loss:0.713396 accu:0.103355 |xentropy_loss:1.153436
# epoch:243 loss:0.438263 loss:0.753101 accu:0.123425 |xentropy_loss:1.039689
# epoch:244 loss:0.392595 loss:0.685891 accu:0.099300 |xentropy_loss:1.215623
# epoch:245 loss:0.406761 loss:0.682226 accu:0.131296 |xentropy_loss:1.155713
# epoch:246 loss:0.365881 loss:0.631671 accu:0.100090 |xentropy_loss:1.237095
# epoch:247 loss:0.429522 loss:0.734746 accu:0.124299 |xentropy_loss:1.227871
# epoch:248 loss:0.427949 loss:0.695304 accu:0.160593 |xentropy_loss:1.285121
# epoch:249 loss:0.383856 loss:0.666761 accu:0.100952 |xentropy_loss:1.269389
# epoch:250 loss:0.405384 loss:0.707981 accu:0.102786 |xentropy_loss:1.318969
# epoch:251 loss:0.439748 loss:0.733459 accu:0.146036 |xentropy_loss:1.162920
# epoch:252 loss:0.429656 loss:0.707171 accu:0.152142 |xentropy_loss:1.219081
# epoch:253 loss:0.469406 loss:0.777773 accu:0.161040 |xentropy_loss:1.026243
# epoch:254 loss:0.430504 loss:0.727960 accu:0.133048 |xentropy_loss:1.117930
# epoch:255 loss:0.429186 loss:0.751327 accu:0.107044 |xentropy_loss:1.066806
# epoch:256 loss:0.403863 loss:0.711507 accu:0.096219 |xentropy_loss:1.261629
# epoch:257 loss:0.435569 loss:0.733109 accu:0.138029 |xentropy_loss:1.175992
# epoch:258 loss:0.499984 loss:0.826580 accu:0.173388 |xentropy_loss:1.128204
# epoch:259 loss:0.420100 loss:0.663519 accu:0.176682 |xentropy_loss:1.124344
# epoch:260 loss:0.408503 loss:0.729775 accu:0.087231 |xentropy_loss:1.171327
# epoch:261 loss:0.375181 loss:0.659293 accu:0.091069 |xentropy_loss:1.211466
# epoch:262 loss:0.411666 loss:0.723049 accu:0.100284 |xentropy_loss:1.214848
# epoch:263 loss:0.384935 loss:0.644468 accu:0.125402 |xentropy_loss:1.215170
# epoch:264 loss:0.434452 loss:0.743026 accu:0.125877 |xentropy_loss:1.112218
# epoch:265 loss:0.433494 loss:0.739447 accu:0.127541 |xentropy_loss:1.201922
# epoch:266 loss:0.388893 loss:0.670849 accu:0.106938 |xentropy_loss:1.167668
# epoch:267 loss:0.448536 loss:0.757634 accu:0.139438 |xentropy_loss:1.152984
# epoch:268 loss:0.386164 loss:0.670018 accu:0.102310 |xentropy_loss:1.169837
# epoch:269 loss:0.459727 loss:0.765192 accu:0.154261 |xentropy_loss:0.978022
# epoch:270 loss:0.390942 loss:0.670759 accu:0.111126 |xentropy_loss:1.106869
# epoch:271 loss:0.400378 loss:0.686371 accu:0.114384 |xentropy_loss:1.325370
# epoch:272 loss:0.426885 loss:0.688450 accu:0.165321 |xentropy_loss:1.212337
# epoch:273 loss:0.436859 loss:0.768193 accu:0.105525 |xentropy_loss:1.188892
# epoch:274 loss:0.406581 loss:0.678318 accu:0.134845 |xentropy_loss:1.305938
# epoch:275 loss:0.414520 loss:0.693277 accu:0.135763 |xentropy_loss:1.141953
# epoch:276 loss:0.446824 loss:0.797965 accu:0.095684 |xentropy_loss:1.132040
# epoch:277 loss:0.371181 loss:0.642844 accu:0.099517 |xentropy_loss:1.361301
# epoch:278 loss:0.447494 loss:0.784437 accu:0.110550 |xentropy_loss:1.177377
# epoch:279 loss:0.414614 loss:0.686359 accu:0.142868 |xentropy_loss:1.166597
# epoch:280 loss:0.446707 loss:0.764466 accu:0.128949 |xentropy_loss:1.103652
# epoch:281 loss:0.396454 loss:0.686970 accu:0.105937 |xentropy_loss:1.117850
# epoch:282 loss:0.428118 loss:0.714806 accu:0.141431 |xentropy_loss:1.248967
# epoch:283 loss:0.425292 loss:0.734277 accu:0.116308 |xentropy_loss:1.178482
# epoch:284 loss:0.428451 loss:0.746943 accu:0.109959 |xentropy_loss:1.137311
# epoch:285 loss:0.399690 loss:0.713383 accu:0.085997 |xentropy_loss:1.073892
# epoch:286 loss:0.418871 loss:0.715469 accu:0.122272 |xentropy_loss:1.165029
# epoch:287 loss:0.376273 loss:0.634957 accu:0.117588 |xentropy_loss:1.008342
# epoch:288 loss:0.402062 loss:0.701565 accu:0.102560 |xentropy_loss:1.142084
# epoch:289 loss:0.357819 loss:0.635431 accu:0.080206 |xentropy_loss:1.150796
# epoch:290 loss:0.396042 loss:0.669595 accu:0.122488 |xentropy_loss:1.166532
# epoch:291 loss:0.375479 loss:0.624184 accu:0.126775 |xentropy_loss:1.183184
# epoch:292 loss:0.425236 loss:0.710753 accu:0.139720 |xentropy_loss:1.225731
# epoch:293 loss:0.419628 loss:0.707784 accu:0.131473 |xentropy_loss:1.183033
# epoch:294 loss:0.380737 loss:0.652270 accu:0.109203 |xentropy_loss:1.181504
# epoch:295 loss:0.365768 loss:0.627172 accu:0.104363 |xentropy_loss:1.229175
# epoch:296 loss:0.432225 loss:0.723254 accu:0.141196 |xentropy_loss:1.024990
# epoch:297 loss:0.429312 loss:0.729476 accu:0.129148 |xentropy_loss:1.101512
# epoch:298 loss:0.429825 loss:0.716174 accu:0.143476 |xentropy_loss:1.164454
# epoch:299 loss:0.427668 loss:0.760530 accu:0.094806 |xentropy_loss:1.144852
# epoch:300 loss:0.374617 loss:0.656116 accu:0.093118 |xentropy_loss:1.171913
# epoch:301 loss:0.378980 loss:0.654543 accu:0.103417 |xentropy_loss:1.189414
# epoch:302 loss:0.403513 loss:0.682775 accu:0.124252 |xentropy_loss:1.150193
# epoch:303 loss:0.382425 loss:0.647268 accu:0.117582 |xentropy_loss:1.158280
# epoch:304 loss:0.395069 loss:0.681890 accu:0.108248 |xentropy_loss:1.189498
# epoch:305 loss:0.427363 loss:0.747599 accu:0.107127 |xentropy_loss:1.265022
# epoch:306 loss:0.392034 loss:0.681854 accu:0.102214 |xentropy_loss:1.144162
# epoch:307 loss:0.405763 loss:0.686746 accu:0.124780 |xentropy_loss:1.164597
# epoch:308 loss:0.431413 loss:0.752800 accu:0.110026 |xentropy_loss:1.216412
# epoch:309 loss:0.415989 loss:0.732396 accu:0.099581 |xentropy_loss:1.173761
# epoch:310 loss:0.389943 loss:0.674481 accu:0.105404 |xentropy_loss:1.213183
# epoch:311 loss:0.411257 loss:0.720461 accu:0.102053 |xentropy_loss:1.218488
# epoch:312 loss:0.384175 loss:0.673206 accu:0.095143 |xentropy_loss:1.283146
# epoch:313 loss:0.395089 loss:0.671672 accu:0.118506 |xentropy_loss:1.183758
# epoch:314 loss:0.408452 loss:0.684831 accu:0.132073 |xentropy_loss:1.127314
# epoch:315 loss:0.391831 loss:0.666104 accu:0.117559 |xentropy_loss:1.065333
# epoch:316 loss:0.374057 loss:0.649559 accu:0.098554 |xentropy_loss:1.225648
# epoch:317 loss:0.379362 loss:0.622980 accu:0.135745 |xentropy_loss:1.062518
# epoch:318 loss:0.404577 loss:0.678327 accu:0.130827 |xentropy_loss:1.024475
# epoch:319 loss:0.405844 loss:0.704516 accu:0.107173 |xentropy_loss:1.062701
# epoch:320 loss:0.409258 loss:0.699961 accu:0.118556 |xentropy_loss:1.056805
# epoch:321 loss:0.412483 loss:0.723804 accu:0.101162 |xentropy_loss:1.250270
# epoch:322 loss:0.397670 loss:0.677704 accu:0.117636 |xentropy_loss:1.376831
# epoch:323 loss:0.399894 loss:0.691951 accu:0.107837 |xentropy_loss:1.171218
# epoch:324 loss:0.430803 loss:0.709947 accu:0.151658 |xentropy_loss:1.173474
# epoch:325 loss:0.456057 loss:0.762588 accu:0.149526 |xentropy_loss:1.290127
# epoch:326 loss:0.416833 loss:0.690968 accu:0.142698 |xentropy_loss:1.343361
# epoch:327 loss:0.415102 loss:0.697731 accu:0.132473 |xentropy_loss:1.434701
# epoch:328 loss:0.394028 loss:0.677225 accu:0.110831 |xentropy_loss:1.137573
# epoch:329 loss:0.381971 loss:0.633476 accu:0.130466 |xentropy_loss:1.215041
# epoch:330 loss:0.407488 loss:0.713310 accu:0.101665 |xentropy_loss:1.133888
# epoch:331 loss:0.384658 loss:0.660709 accu:0.108608 |xentropy_loss:1.159201
# epoch:332 loss:0.441507 loss:0.757254 accu:0.125760 |xentropy_loss:1.191174
# epoch:333 loss:0.425108 loss:0.699195 accu:0.151021 |xentropy_loss:1.177933
# epoch:334 loss:0.410067 loss:0.666556 accu:0.153578 |xentropy_loss:1.038932
# epoch:335 loss:0.386036 loss:0.684583 accu:0.087488 |xentropy_loss:1.127638
# epoch:336 loss:0.367143 loss:0.633978 accu:0.100307 |xentropy_loss:1.285226
# epoch:337 loss:0.398588 loss:0.668666 accu:0.128511 |xentropy_loss:1.176688
# epoch:338 loss:0.403927 loss:0.706360 accu:0.101494 |xentropy_loss:1.121494
# epoch:339 loss:0.407345 loss:0.660024 accu:0.154666 |xentropy_loss:1.092636
# epoch:340 loss:0.404232 loss:0.721442 accu:0.087023 |xentropy_loss:1.243212
# epoch:341 loss:0.414047 loss:0.697198 accu:0.130895 |xentropy_loss:1.259846
# epoch:342 loss:0.404966 loss:0.678812 accu:0.131120 |xentropy_loss:1.314674
# epoch:343 loss:0.438151 loss:0.759489 accu:0.116812 |xentropy_loss:1.098539
# epoch:344 loss:0.408533 loss:0.699706 accu:0.117359 |xentropy_loss:1.157435
# epoch:345 loss:0.425360 loss:0.718660 accu:0.132060 |xentropy_loss:1.073102
# epoch:346 loss:0.408987 loss:0.737985 accu:0.079988 |xentropy_loss:1.180564
# epoch:347 loss:0.336394 loss:0.605179 accu:0.067609 |xentropy_loss:1.206631
# epoch:348 loss:0.416508 loss:0.705426 accu:0.127591 |xentropy_loss:1.130728
# epoch:349 loss:0.364474 loss:0.640113 accu:0.088835 |xentropy_loss:1.318963
# epoch:350 loss:0.375831 loss:0.666931 accu:0.084730 |xentropy_loss:1.362116
# epoch:351 loss:0.352913 loss:0.611184 accu:0.094641 |xentropy_loss:1.213685
# epoch:352 loss:0.377817 loss:0.667965 accu:0.087670 |xentropy_loss:1.113476
# epoch:353 loss:0.404397 loss:0.655857 accu:0.152937 |xentropy_loss:1.177431
# epoch:354 loss:0.414848 loss:0.716869 accu:0.112827 |xentropy_loss:1.277844
# epoch:355 loss:0.372758 loss:0.661065 accu:0.084451 |xentropy_loss:1.115032
# epoch:356 loss:0.465525 loss:0.805632 accu:0.125418 |xentropy_loss:1.051554
# epoch:357 loss:0.382592 loss:0.634116 accu:0.131068 |xentropy_loss:1.089090
# epoch:358 loss:0.394632 loss:0.672123 accu:0.117141 |xentropy_loss:1.212022
# epoch:359 loss:0.363414 loss:0.615713 accu:0.111116 |xentropy_loss:1.226253
# epoch:360 loss:0.410383 loss:0.705845 accu:0.114921 |xentropy_loss:1.074635
# epoch:361 loss:0.434800 loss:0.708079 accu:0.161521 |xentropy_loss:1.250575
# epoch:362 loss:0.414754 loss:0.663881 accu:0.165627 |xentropy_loss:1.152341
# epoch:363 loss:0.396824 loss:0.693717 accu:0.099931 |xentropy_loss:1.222375
# epoch:364 loss:0.450848 loss:0.769809 accu:0.131887 |xentropy_loss:1.119202
# epoch:365 loss:0.427875 loss:0.729391 accu:0.126358 |xentropy_loss:1.130897
# epoch:366 loss:0.391760 loss:0.662463 accu:0.121057 |xentropy_loss:1.135992
# epoch:367 loss:0.428456 loss:0.757837 accu:0.099075 |xentropy_loss:1.124372
# epoch:368 loss:0.386231 loss:0.683814 accu:0.088649 |xentropy_loss:1.158351
# epoch:369 loss:0.400137 loss:0.695884 accu:0.104389 |xentropy_loss:1.126597
# epoch:370 loss:0.395199 loss:0.665010 accu:0.125387 |xentropy_loss:1.251416
# epoch:371 loss:0.361834 loss:0.639401 accu:0.084267 |xentropy_loss:1.136139
# epoch:372 loss:0.405786 loss:0.691183 accu:0.120388 |xentropy_loss:1.154885
# epoch:373 loss:0.415369 loss:0.717665 accu:0.113073 |xentropy_loss:1.132672
# epoch:374 loss:0.449219 loss:0.761880 accu:0.136558 |xentropy_loss:1.218918
# epoch:375 loss:0.445050 loss:0.748693 accu:0.141407 |xentropy_loss:1.087097
# epoch:376 loss:0.383958 loss:0.666509 accu:0.101407 |xentropy_loss:1.263546
# epoch:377 loss:0.356411 loss:0.622258 accu:0.090565 |xentropy_loss:1.127124
# epoch:378 loss:0.430055 loss:0.718252 accu:0.141859 |xentropy_loss:1.147494
# epoch:379 loss:0.407228 loss:0.678760 accu:0.135696 |xentropy_loss:1.177156
# epoch:380 loss:0.354005 loss:0.619459 accu:0.088550 |xentropy_loss:1.248403
# epoch:381 loss:0.372950 loss:0.653857 accu:0.092043 |xentropy_loss:1.297602
# epoch:382 loss:0.378205 loss:0.618744 accu:0.137665 |xentropy_loss:1.335362
# epoch:383 loss:0.410031 loss:0.688717 accu:0.131346 |xentropy_loss:1.182410
# epoch:384 loss:0.386723 loss:0.686703 accu:0.086743 |xentropy_loss:1.132946
# epoch:385 loss:0.392804 loss:0.662285 accu:0.123323 |xentropy_loss:1.251697
# epoch:386 loss:0.333959 loss:0.564741 accu:0.103177 |xentropy_loss:1.268166
# epoch:387 loss:0.382993 loss:0.635666 accu:0.130321 |xentropy_loss:1.217339
# epoch:388 loss:0.375881 loss:0.657090 accu:0.094671 |xentropy_loss:1.169973
# epoch:389 loss:0.374134 loss:0.633489 accu:0.114778 |xentropy_loss:1.199849
# epoch:390 loss:0.362066 loss:0.614743 accu:0.109389 |xentropy_loss:1.175713
# epoch:391 loss:0.404646 loss:0.675180 accu:0.134112 |xentropy_loss:1.280255
# epoch:392 loss:0.374139 loss:0.679490 accu:0.068788 |xentropy_loss:1.111358
# epoch:393 loss:0.394022 loss:0.672375 accu:0.115668 |xentropy_loss:1.110853
# epoch:394 loss:0.442365 loss:0.752215 accu:0.132515 |xentropy_loss:1.109674
# epoch:395 loss:0.401425 loss:0.700057 accu:0.102793 |xentropy_loss:1.133731
# epoch:396 loss:0.404581 loss:0.703643 accu:0.105519 |xentropy_loss:1.241688
# epoch:397 loss:0.381888 loss:0.637237 accu:0.126540 |xentropy_loss:1.265992
# epoch:398 loss:0.398476 loss:0.672615 accu:0.124337 |xentropy_loss:1.271815
# epoch:399 loss:0.451525 loss:0.774744 accu:0.128306 |xentropy_loss:1.110907
# epoch:400 loss:0.363295 loss:0.629570 accu:0.097020 |xentropy_loss:1.078964
# epoch:401 loss:0.364715 loss:0.629193 accu:0.100238 |xentropy_loss:1.087242
# epoch:402 loss:0.341508 loss:0.594207 accu:0.088810 |xentropy_loss:1.318756
# epoch:403 loss:0.317095 loss:0.546488 accu:0.087702 |xentropy_loss:1.239337
# epoch:404 loss:0.375462 loss:0.640115 accu:0.110810 |xentropy_loss:1.158944
# epoch:405 loss:0.383784 loss:0.656426 accu:0.111143 |xentropy_loss:1.271075
# epoch:406 loss:0.368710 loss:0.649977 accu:0.087442 |xentropy_loss:1.095649
# epoch:407 loss:0.403726 loss:0.690532 accu:0.116919 |xentropy_loss:1.258420
# epoch:408 loss:0.360322 loss:0.628616 accu:0.092027 |xentropy_loss:1.137819
# epoch:409 loss:0.377203 loss:0.660529 accu:0.093877 |xentropy_loss:1.107141
# epoch:410 loss:0.363598 loss:0.621591 accu:0.105605 |xentropy_loss:1.233030
# epoch:411 loss:0.429836 loss:0.740487 accu:0.119186 |xentropy_loss:1.120025
# epoch:412 loss:0.352891 loss:0.613546 accu:0.092237 |xentropy_loss:1.316465
# epoch:413 loss:0.382545 loss:0.656703 accu:0.108388 |xentropy_loss:1.176066
# epoch:414 loss:0.386702 loss:0.699021 accu:0.074383 |xentropy_loss:1.181750
# epoch:415 loss:0.377335 loss:0.641315 accu:0.113355 |xentropy_loss:1.169414
# epoch:416 loss:0.384810 loss:0.648419 accu:0.121200 |xentropy_loss:1.247847
# epoch:417 loss:0.363122 loss:0.599883 accu:0.126361 |xentropy_loss:1.355998
# epoch:418 loss:0.444107 loss:0.767525 accu:0.120690 |xentropy_loss:1.153481
# epoch:419 loss:0.396053 loss:0.681860 accu:0.110247 |xentropy_loss:1.147603
# epoch:420 loss:0.394205 loss:0.691764 accu:0.096647 |xentropy_loss:1.325730
# epoch:421 loss:0.374349 loss:0.647798 accu:0.100900 |xentropy_loss:1.168348
# epoch:422 loss:0.387849 loss:0.674161 accu:0.101536 |xentropy_loss:1.181511
# epoch:423 loss:0.366627 loss:0.631067 accu:0.102187 |xentropy_loss:1.137877
# epoch:424 loss:0.401206 loss:0.675106 accu:0.127306 |xentropy_loss:1.126694
# epoch:425 loss:0.386817 loss:0.672438 accu:0.101195 |xentropy_loss:1.227845
# epoch:426 loss:0.375700 loss:0.663399 accu:0.088002 |xentropy_loss:1.232430
# epoch:427 loss:0.387543 loss:0.663955 accu:0.111132 |xentropy_loss:1.165106
# epoch:428 loss:0.368495 loss:0.633645 accu:0.103345 |xentropy_loss:1.075231
# epoch:429 loss:0.383911 loss:0.666369 accu:0.101452 |xentropy_loss:1.180043
# epoch:430 loss:0.406317 loss:0.685164 accu:0.127470 |xentropy_loss:1.308227
# epoch:431 loss:0.430300 loss:0.743701 accu:0.116900 |xentropy_loss:1.298694
# epoch:432 loss:0.397145 loss:0.662603 accu:0.131687 |xentropy_loss:1.201730
# epoch:433 loss:0.386337 loss:0.679438 accu:0.093235 |xentropy_loss:1.131432
# epoch:434 loss:0.342421 loss:0.601099 accu:0.083742 |xentropy_loss:1.357343
# epoch:435 loss:0.384902 loss:0.683689 accu:0.086114 |xentropy_loss:1.170164
# epoch:436 loss:0.365162 loss:0.615376 accu:0.114947 |xentropy_loss:1.233065
# epoch:437 loss:0.390233 loss:0.676762 accu:0.103704 |xentropy_loss:1.257604
# epoch:438 loss:0.354355 loss:0.606676 accu:0.102034 |xentropy_loss:1.223401
# epoch:439 loss:0.355218 loss:0.603810 accu:0.106626 |xentropy_loss:1.236938
# epoch:440 loss:0.372795 loss:0.640810 accu:0.104781 |xentropy_loss:1.171732
# epoch:441 loss:0.359235 loss:0.641266 accu:0.077203 |xentropy_loss:1.264588
# epoch:442 loss:0.355074 loss:0.632465 accu:0.077682 |xentropy_loss:1.260541
# epoch:443 loss:0.339496 loss:0.577074 accu:0.101917 |xentropy_loss:1.284221
# epoch:444 loss:0.349476 loss:0.611302 accu:0.087649 |xentropy_loss:1.272134
# epoch:445 loss:0.408739 loss:0.676396 accu:0.141082 |xentropy_loss:1.252805
# epoch:446 loss:0.364282 loss:0.633975 accu:0.094589 |xentropy_loss:1.154780
# epoch:447 loss:0.391116 loss:0.644038 accu:0.138194 |xentropy_loss:1.176312
# epoch:448 loss:0.405041 loss:0.673674 accu:0.136408 |xentropy_loss:1.107711
# epoch:449 loss:0.374873 loss:0.652387 accu:0.097360 |xentropy_loss:1.269799
# epoch:450 loss:0.375009 loss:0.654939 accu:0.095079 |xentropy_loss:1.258401
# epoch:451 loss:0.348716 loss:0.617598 accu:0.079834 |xentropy_loss:1.319594
# epoch:452 loss:0.413388 loss:0.702587 accu:0.124189 |xentropy_loss:1.145609
# epoch:453 loss:0.339037 loss:0.594168 accu:0.083907 |xentropy_loss:1.232822
# epoch:454 loss:0.352151 loss:0.607316 accu:0.096986 |xentropy_loss:1.226400
# epoch:455 loss:0.397320 loss:0.687806 accu:0.106833 |xentropy_loss:1.199429
# epoch:456 loss:0.350204 loss:0.613720 accu:0.086687 |xentropy_loss:1.550511
# epoch:457 loss:0.362988 loss:0.622621 accu:0.103356 |xentropy_loss:1.240051
# epoch:458 loss:0.377212 loss:0.649765 accu:0.104660 |xentropy_loss:1.239626
# epoch:459 loss:0.358202 loss:0.612307 accu:0.104098 |xentropy_loss:1.402154
# epoch:460 loss:0.401552 loss:0.709202 accu:0.093902 |xentropy_loss:1.344202
# epoch:461 loss:0.443406 loss:0.782118 accu:0.104695 |xentropy_loss:0.980878
# epoch:462 loss:0.384300 loss:0.677653 accu:0.090947 |xentropy_loss:1.550579
# epoch:463 loss:0.381927 loss:0.655919 accu:0.107936 |xentropy_loss:1.289336
# epoch:464 loss:0.358324 loss:0.631593 accu:0.085055 |xentropy_loss:1.286366
# epoch:465 loss:0.373734 loss:0.630329 accu:0.117139 |xentropy_loss:1.309994
# epoch:466 loss:0.370170 loss:0.654528 accu:0.085812 |xentropy_loss:1.286911
# epoch:467 loss:0.362796 loss:0.635791 accu:0.089801 |xentropy_loss:1.263837
# epoch:468 loss:0.333212 loss:0.574924 accu:0.091499 |xentropy_loss:1.389798
# epoch:469 loss:0.375425 loss:0.682254 accu:0.068596 |xentropy_loss:1.233048
# epoch:470 loss:0.370153 loss:0.648364 accu:0.091942 |xentropy_loss:1.269892
# epoch:471 loss:0.342113 loss:0.598931 accu:0.085296 |xentropy_loss:1.416651
# epoch:472 loss:0.335763 loss:0.579797 accu:0.091729 |xentropy_loss:1.354727
# epoch:473 loss:0.365728 loss:0.641324 accu:0.090133 |xentropy_loss:1.301446
# epoch:474 loss:0.408256 loss:0.696730 accu:0.119782 |xentropy_loss:1.191526
# epoch:475 loss:0.389038 loss:0.675336 accu:0.102740 |xentropy_loss:1.330657
# epoch:476 loss:0.401006 loss:0.669650 accu:0.132361 |xentropy_loss:1.170172
# epoch:477 loss:0.344569 loss:0.573758 accu:0.115379 |xentropy_loss:1.230273
# epoch:478 loss:0.342206 loss:0.587895 accu:0.096516 |xentropy_loss:1.092190
# epoch:479 loss:0.354093 loss:0.580393 accu:0.127792 |xentropy_loss:1.076763
# epoch:480 loss:0.380202 loss:0.664902 accu:0.095502 |xentropy_loss:1.235234
# epoch:481 loss:0.383059 loss:0.672836 accu:0.093282 |xentropy_loss:1.280541
# epoch:482 loss:0.438475 loss:0.744668 accu:0.132282 |xentropy_loss:1.115046
# epoch:483 loss:0.351417 loss:0.607400 accu:0.095435 |xentropy_loss:1.160294
# epoch:484 loss:0.361839 loss:0.625344 accu:0.098335 |xentropy_loss:1.336124
# epoch:485 loss:0.395052 loss:0.638846 accu:0.151258 |xentropy_loss:1.324350
# epoch:486 loss:0.334606 loss:0.588262 accu:0.080950 |xentropy_loss:1.246378
# epoch:487 loss:0.358246 loss:0.629567 accu:0.086926 |xentropy_loss:1.302142
# epoch:488 loss:0.324775 loss:0.559248 accu:0.090303 |xentropy_loss:1.320092
# epoch:489 loss:0.344725 loss:0.607565 accu:0.081885 |xentropy_loss:1.311279
# epoch:490 loss:0.434555 loss:0.772475 accu:0.096636 |xentropy_loss:1.364632
# epoch:491 loss:0.374301 loss:0.684567 accu:0.064035 |xentropy_loss:1.249344
# epoch:492 loss:0.420018 loss:0.739317 accu:0.100719 |xentropy_loss:1.131412
# epoch:493 loss:0.356412 loss:0.595867 accu:0.116958 |xentropy_loss:1.109639
# epoch:494 loss:0.367768 loss:0.653571 accu:0.081964 |xentropy_loss:1.195165
# epoch:495 loss:0.341823 loss:0.594876 accu:0.088770 |xentropy_loss:1.237400
# epoch:496 loss:0.358978 loss:0.646138 accu:0.071818 |xentropy_loss:1.128495
# epoch:497 loss:0.384289 loss:0.664839 accu:0.103740 |xentropy_loss:1.254614
# epoch:498 loss:0.412319 loss:0.709635 accu:0.115003 |xentropy_loss:1.274609
# epoch:499 loss:0.393455 loss:0.719492 accu:0.067419 |xentropy_loss:1.245245
# epoch:500 loss:0.326861 loss:0.549357 accu:0.104365 |xentropy_loss:1.293546
# epoch:501 loss:0.367211 loss:0.642435 accu:0.091987 |xentropy_loss:1.252395
# epoch:502 loss:0.399949 loss:0.647588 accu:0.152310 |xentropy_loss:1.183854
# epoch:503 loss:0.413114 loss:0.742904 accu:0.083325 |xentropy_loss:1.228146
# epoch:504 loss:0.351235 loss:0.614822 accu:0.087648 |xentropy_loss:1.309905
# epoch:505 loss:0.419753 loss:0.720671 accu:0.118836 |xentropy_loss:1.270622
# epoch:506 loss:0.311814 loss:0.553780 accu:0.069848 |xentropy_loss:1.217792
# epoch:507 loss:0.383567 loss:0.661252 accu:0.105882 |xentropy_loss:1.192636
# epoch:508 loss:0.368353 loss:0.624770 accu:0.111936 |xentropy_loss:1.168353
# epoch:509 loss:0.337687 loss:0.576502 accu:0.098873 |xentropy_loss:1.165653
# epoch:510 loss:0.364531 loss:0.647328 accu:0.081734 |xentropy_loss:1.253517
# epoch:511 loss:0.357919 loss:0.628931 accu:0.086906 |xentropy_loss:1.174269
# epoch:512 loss:0.358716 loss:0.589135 accu:0.128297 |xentropy_loss:1.369008
# epoch:513 loss:0.341046 loss:0.550207 accu:0.131885 |xentropy_loss:1.093735
# epoch:514 loss:0.380552 loss:0.677700 accu:0.083404 |xentropy_loss:1.209915
# epoch:515 loss:0.342580 loss:0.622888 accu:0.062271 |xentropy_loss:1.172877
# epoch:516 loss:0.360771 loss:0.623606 accu:0.097936 |xentropy_loss:1.232358
# epoch:517 loss:0.338711 loss:0.572310 accu:0.105112 |xentropy_loss:1.196662
# epoch:518 loss:0.384990 loss:0.704208 accu:0.065773 |xentropy_loss:1.093595
# epoch:519 loss:0.346502 loss:0.588395 accu:0.104609 |xentropy_loss:1.287909
# epoch:520 loss:0.361859 loss:0.623161 accu:0.100556 |xentropy_loss:1.504698
# epoch:521 loss:0.360582 loss:0.616894 accu:0.104271 |xentropy_loss:1.353752
# epoch:522 loss:0.362083 loss:0.656252 accu:0.067914 |xentropy_loss:1.210169
# epoch:523 loss:0.413962 loss:0.748341 accu:0.079583 |xentropy_loss:1.240756
# epoch:524 loss:0.413737 loss:0.718439 accu:0.109035 |xentropy_loss:1.392973
# epoch:525 loss:0.372549 loss:0.651036 accu:0.094062 |xentropy_loss:1.200099
# epoch:526 loss:0.369670 loss:0.647559 accu:0.091781 |xentropy_loss:1.209388
# epoch:527 loss:0.380222 loss:0.657419 accu:0.103026 |xentropy_loss:1.200169
# epoch:528 loss:0.343112 loss:0.603487 accu:0.082738 |xentropy_loss:1.258902
# epoch:529 loss:0.415617 loss:0.719560 accu:0.111674 |xentropy_loss:1.260434
# epoch:530 loss:0.339569 loss:0.589018 accu:0.090119 |xentropy_loss:1.231687
# epoch:531 loss:0.369702 loss:0.666673 accu:0.072731 |xentropy_loss:1.195495
# epoch:532 loss:0.344663 loss:0.613650 accu:0.075677 |xentropy_loss:1.220021
# epoch:533 loss:0.387883 loss:0.660122 accu:0.115644 |xentropy_loss:1.288150
# epoch:534 loss:0.337350 loss:0.596001 accu:0.078699 |xentropy_loss:1.219350
# epoch:535 loss:0.433742 loss:0.750928 accu:0.116556 |xentropy_loss:1.114113
# epoch:536 loss:0.405415 loss:0.695385 accu:0.115444 |xentropy_loss:1.149595
# epoch:537 loss:0.347900 loss:0.594741 accu:0.101059 |xentropy_loss:1.117175
# epoch:538 loss:0.408299 loss:0.699673 accu:0.116924 |xentropy_loss:1.156528
# epoch:539 loss:0.357562 loss:0.619351 accu:0.095772 |xentropy_loss:1.290953
# epoch:540 loss:0.379613 loss:0.638457 accu:0.120770 |xentropy_loss:1.269302
# epoch:541 loss:0.390915 loss:0.685886 accu:0.095944 |xentropy_loss:1.441280
# epoch:542 loss:0.345965 loss:0.598665 accu:0.093264 |xentropy_loss:1.274014
# epoch:543 loss:0.403906 loss:0.705793 accu:0.102019 |xentropy_loss:1.237991
# epoch:544 loss:0.384928 loss:0.685314 accu:0.084541 |xentropy_loss:1.144328
# epoch:545 loss:0.396220 loss:0.689387 accu:0.103053 |xentropy_loss:1.219561
# epoch:546 loss:0.328009 loss:0.565783 accu:0.090235 |xentropy_loss:1.306915
# epoch:547 loss:0.351824 loss:0.614871 accu:0.088778 |xentropy_loss:1.287965
# epoch:548 loss:0.363167 loss:0.635729 accu:0.090605 |xentropy_loss:1.318518
# epoch:549 loss:0.341799 loss:0.603359 accu:0.080238 |xentropy_loss:1.241890
# epoch:550 loss:0.396724 loss:0.687571 accu:0.105878 |xentropy_loss:1.140708
# epoch:551 loss:0.350483 loss:0.635429 accu:0.065538 |xentropy_loss:1.189190
# epoch:552 loss:0.312779 loss:0.552997 accu:0.072561 |xentropy_loss:1.279585
# epoch:553 loss:0.372688 loss:0.620525 accu:0.124852 |xentropy_loss:1.300593
# epoch:554 loss:0.330024 loss:0.588843 accu:0.071206 |xentropy_loss:1.326877
# epoch:555 loss:0.410619 loss:0.730374 accu:0.090865 |xentropy_loss:1.246990
# epoch:556 loss:0.442405 loss:0.742364 accu:0.142446 |xentropy_loss:1.304966
# epoch:557 loss:0.341417 loss:0.591409 accu:0.091426 |xentropy_loss:1.205105
# epoch:558 loss:0.375248 loss:0.652234 accu:0.098262 |xentropy_loss:1.250738
# epoch:559 loss:0.361936 loss:0.634253 accu:0.089620 |xentropy_loss:1.354230
# epoch:560 loss:0.343594 loss:0.598300 accu:0.088888 |xentropy_loss:1.182667
# epoch:561 loss:0.356157 loss:0.600722 accu:0.111592 |xentropy_loss:1.281870
# epoch:562 loss:0.402702 loss:0.688267 accu:0.117137 |xentropy_loss:1.325979
# epoch:563 loss:0.381601 loss:0.693789 accu:0.069414 |xentropy_loss:1.220823
# epoch:564 loss:0.364787 loss:0.642765 accu:0.086809 |xentropy_loss:1.260276
# epoch:565 loss:0.360732 loss:0.595847 accu:0.125617 |xentropy_loss:1.218115
# epoch:566 loss:0.368484 loss:0.653749 accu:0.083220 |xentropy_loss:1.110330
# epoch:567 loss:0.370254 loss:0.634209 accu:0.106299 |xentropy_loss:1.164973
# epoch:568 loss:0.361926 loss:0.638099 accu:0.085752 |xentropy_loss:1.131955
# epoch:569 loss:0.396378 loss:0.679721 accu:0.113035 |xentropy_loss:1.258429
# epoch:570 loss:0.334875 loss:0.578817 accu:0.090932 |xentropy_loss:1.287217
# epoch:571 loss:0.368560 loss:0.644092 accu:0.093027 |xentropy_loss:1.170606
# epoch:572 loss:0.373286 loss:0.618407 accu:0.128166 |xentropy_loss:1.117336
# epoch:573 loss:0.378324 loss:0.637863 accu:0.118785 |xentropy_loss:0.989637
# epoch:574 loss:0.374534 loss:0.654505 accu:0.094563 |xentropy_loss:1.129347
# epoch:575 loss:0.370045 loss:0.634375 accu:0.105714 |xentropy_loss:1.318739
# epoch:576 loss:0.359708 loss:0.628190 accu:0.091226 |xentropy_loss:1.400665
# epoch:577 loss:0.333412 loss:0.596063 accu:0.070761 |xentropy_loss:1.380173
# epoch:578 loss:0.335349 loss:0.602979 accu:0.067720 |xentropy_loss:1.229134
# epoch:579 loss:0.387247 loss:0.706030 accu:0.068464 |xentropy_loss:1.136992
# epoch:580 loss:0.340306 loss:0.612326 accu:0.068285 |xentropy_loss:1.192082
# epoch:581 loss:0.356980 loss:0.612393 accu:0.101567 |xentropy_loss:1.145077
# epoch:582 loss:0.354532 loss:0.619987 accu:0.089078 |xentropy_loss:1.323408
# epoch:583 loss:0.393801 loss:0.665206 accu:0.122397 |xentropy_loss:1.213228
# epoch:584 loss:0.397653 loss:0.707063 accu:0.088242 |xentropy_loss:1.538804
# epoch:585 loss:0.347331 loss:0.607639 accu:0.087023 |xentropy_loss:1.379431
# epoch:586 loss:0.359470 loss:0.641452 accu:0.077487 |xentropy_loss:1.308760
# epoch:587 loss:0.380897 loss:0.643134 accu:0.118660 |xentropy_loss:1.212011
# epoch:588 loss:0.383937 loss:0.671861 accu:0.096012 |xentropy_loss:1.203921
# epoch:589 loss:0.362883 loss:0.632118 accu:0.093648 |xentropy_loss:1.346347
# epoch:590 loss:0.353115 loss:0.620031 accu:0.086199 |xentropy_loss:1.308843
# epoch:591 loss:0.375789 loss:0.631215 accu:0.120363 |xentropy_loss:1.236380
# epoch:592 loss:0.411249 loss:0.699002 accu:0.123497 |xentropy_loss:1.212018
# epoch:593 loss:0.384885 loss:0.675849 accu:0.093920 |xentropy_loss:1.259892
# epoch:594 loss:0.327045 loss:0.584995 accu:0.069095 |xentropy_loss:1.303589
# epoch:595 loss:0.321583 loss:0.552058 accu:0.091107 |xentropy_loss:1.400637
# epoch:596 loss:0.365807 loss:0.632992 accu:0.098623 |xentropy_loss:1.322297
# epoch:597 loss:0.390367 loss:0.700676 accu:0.080058 |xentropy_loss:1.328336
# epoch:598 loss:0.421376 loss:0.754775 accu:0.087978 |xentropy_loss:1.299195
# epoch:599 loss:0.399768 loss:0.689896 accu:0.109640 |xentropy_loss:1.149963
# epoch:600 loss:0.382938 loss:0.660368 accu:0.105509 |xentropy_loss:1.222613
# epoch:601 loss:0.395393 loss:0.682904 accu:0.107882 |xentropy_loss:1.313344
# epoch:602 loss:0.387072 loss:0.704741 accu:0.069402 |xentropy_loss:1.168312
# epoch:603 loss:0.367782 loss:0.612856 accu:0.122708 |xentropy_loss:1.375815
# epoch:604 loss:0.369862 loss:0.643928 accu:0.095796 |xentropy_loss:1.140069
# epoch:605 loss:0.357651 loss:0.611304 accu:0.103999 |xentropy_loss:1.038174
# epoch:606 loss:0.325078 loss:0.553560 accu:0.096596 |xentropy_loss:1.150405
# epoch:607 loss:0.357093 loss:0.638987 accu:0.075199 |xentropy_loss:1.217314
# epoch:608 loss:0.358452 loss:0.599733 accu:0.117172 |xentropy_loss:1.125429
# epoch:609 loss:0.334035 loss:0.595116 accu:0.072955 |xentropy_loss:1.310066
# epoch:610 loss:0.393616 loss:0.682519 accu:0.104712 |xentropy_loss:1.288573
# epoch:611 loss:0.352829 loss:0.622370 accu:0.083288 |xentropy_loss:1.197685
# epoch:612 loss:0.370791 loss:0.668952 accu:0.072629 |xentropy_loss:1.313305
# epoch:613 loss:0.406626 loss:0.728416 accu:0.084835 |xentropy_loss:1.254617
# epoch:614 loss:0.389405 loss:0.690118 accu:0.088692 |xentropy_loss:1.060291
# epoch:615 loss:0.349216 loss:0.618153 accu:0.080279 |xentropy_loss:1.084416
# epoch:616 loss:0.369258 loss:0.650734 accu:0.087782 |xentropy_loss:1.330892
# epoch:617 loss:0.333843 loss:0.576672 accu:0.091014 |xentropy_loss:1.307447
# epoch:618 loss:0.375249 loss:0.663063 accu:0.087436 |xentropy_loss:1.336867
# epoch:619 loss:0.407104 loss:0.716846 accu:0.097362 |xentropy_loss:1.242746
# epoch:620 loss:0.365772 loss:0.657359 accu:0.074185 |xentropy_loss:1.107179
# epoch:621 loss:0.345779 loss:0.616272 accu:0.075285 |xentropy_loss:1.257273
# epoch:622 loss:0.390359 loss:0.686351 accu:0.094367 |xentropy_loss:1.326507
# epoch:623 loss:0.348414 loss:0.625510 accu:0.071318 |xentropy_loss:1.343191
# epoch:624 loss:0.376971 loss:0.645832 accu:0.108109 |xentropy_loss:1.272639
# epoch:625 loss:0.358413 loss:0.650515 accu:0.066311 |xentropy_loss:1.182690
# epoch:626 loss:0.396582 loss:0.671772 accu:0.121391 |xentropy_loss:1.253564
# epoch:627 loss:0.381788 loss:0.678343 accu:0.085233 |xentropy_loss:1.260910
# epoch:628 loss:0.368077 loss:0.646605 accu:0.089549 |xentropy_loss:1.223033
# ...
# epoch:791 loss:0.364251 loss:0.639132 accu:0.089370 |xentropy_loss:1.110939
# epoch:792 loss:0.392332 loss:0.691087 accu:0.093577 |xentropy_loss:1.108569
# epoch:793 loss:0.388882 loss:0.692557 accu:0.085207 |xentropy_loss:1.089300
# epoch:794 loss:0.346529 loss:0.608990 accu:0.084067 |xentropy_loss:1.237582
# epoch:795 loss:0.360033 loss:0.644640 accu:0.075425 |xentropy_loss:1.370814
# epoch:796 loss:0.419652 loss:0.726107 accu:0.113196 |xentropy_loss:1.164649
# epoch:797 loss:0.408569 loss:0.738454 accu:0.078685 |xentropy_loss:1.208611
# epoch:798 loss:0.388086 loss:0.686043 accu:0.090130 |xentropy_loss:1.180678
# epoch:799 loss:0.391684 loss:0.677503 accu:0.105865 |xentropy_loss:1.034739
# epoch:800 loss:0.379609 loss:0.677486 accu:0.081732 |xentropy_loss:1.202911
# epoch:801 loss:0.380998 loss:0.675369 accu:0.086626 |xentropy_loss:1.247812
# epoch:802 loss:0.363457 loss:0.670763 accu:0.056151 |xentropy_loss:1.251450
# epoch:803 loss:0.413029 loss:0.737985 accu:0.088073 |xentropy_loss:1.131427
# epoch:804 loss:0.292753 loss:0.520145 accu:0.065361 |xentropy_loss:1.203435
# epoch:805 loss:0.404718 loss:0.746951 accu:0.062485 |xentropy_loss:1.133548
# epoch:806 loss:0.395065 loss:0.695025 accu:0.095104 |xentropy_loss:1.218688
# epoch:807 loss:0.397267 loss:0.700068 accu:0.094465 |xentropy_loss:1.088841
# epoch:808 loss:0.368719 loss:0.640568 accu:0.096870 |xentropy_loss:1.134117
# epoch:809 loss:0.371520 loss:0.672367 accu:0.070673 |xentropy_loss:1.093753
# epoch:810 loss:0.375572 loss:0.665489 accu:0.085656 |xentropy_loss:1.185589
# epoch:811 loss:0.458042 loss:0.820201 accu:0.095883 |xentropy_loss:1.110990
# epoch:812 loss:0.359592 loss:0.631876 accu:0.087308 |xentropy_loss:1.314599
# epoch:813 loss:0.395469 loss:0.713513 accu:0.077425 |xentropy_loss:1.160352
# epoch:814 loss:0.384621 loss:0.683688 accu:0.085554 |xentropy_loss:1.071782
# epoch:815 loss:0.401649 loss:0.718483 accu:0.084814 |xentropy_loss:1.043601
# epoch:816 loss:0.381239 loss:0.699483 accu:0.062994 |xentropy_loss:1.074431
# epoch:817 loss:0.353179 loss:0.613777 accu:0.092580 |xentropy_loss:1.163264
# epoch:818 loss:0.368824 loss:0.638129 accu:0.099520 |xentropy_loss:1.113415
# epoch:819 loss:0.409004 loss:0.710609 accu:0.107399 |xentropy_loss:1.161947
# epoch:820 loss:0.389336 loss:0.715324 accu:0.063349 |xentropy_loss:1.018068
# epoch:821 loss:0.361597 loss:0.656774 accu:0.066421 |xentropy_loss:1.180099
# epoch:822 loss:0.359855 loss:0.644830 accu:0.074880 |xentropy_loss:1.092864
# epoch:823 loss:0.331716 loss:0.595624 accu:0.067808 |xentropy_loss:1.168525
# epoch:824 loss:0.375550 loss:0.667846 accu:0.083254 |xentropy_loss:1.103846
# epoch:825 loss:0.391208 loss:0.678351 accu:0.104065 |xentropy_loss:1.065385
# epoch:826 loss:0.387524 loss:0.666863 accu:0.108185 |xentropy_loss:1.165712
# epoch:827 loss:0.340678 loss:0.615705 accu:0.065652 |xentropy_loss:1.114208
# epoch:828 loss:0.421313 loss:0.718620 accu:0.124005 |xentropy_loss:1.086685
# epoch:829 loss:0.382483 loss:0.688017 accu:0.076950 |xentropy_loss:1.058818
# epoch:830 loss:0.408480 loss:0.717944 accu:0.099017 |xentropy_loss:1.143891
# epoch:831 loss:0.381576 loss:0.676697 accu:0.086455 |xentropy_loss:1.194917
# epoch:832 loss:0.387538 loss:0.713784 accu:0.061292 |xentropy_loss:1.145806
# epoch:833 loss:0.432147 loss:0.746234 accu:0.118060 |xentropy_loss:1.097057
# epoch:834 loss:0.376489 loss:0.669571 accu:0.083408 |xentropy_loss:1.108567
# epoch:835 loss:0.408916 loss:0.740858 accu:0.076974 |xentropy_loss:1.142520
# epoch:836 loss:0.388313 loss:0.700024 accu:0.076602 |xentropy_loss:1.101240
# epoch:837 loss:0.364563 loss:0.640988 accu:0.088137 |xentropy_loss:1.149881
# epoch:838 loss:0.387715 loss:0.691205 accu:0.084224 |xentropy_loss:1.094146
# epoch:839 loss:0.365240 loss:0.658045 accu:0.072436 |xentropy_loss:1.108181
# epoch:840 loss:0.378217 loss:0.669600 accu:0.086833 |xentropy_loss:1.119375
# epoch:841 loss:0.387389 loss:0.663374 accu:0.111405 |xentropy_loss:1.017491
# epoch:842 loss:0.392609 loss:0.708790 accu:0.076428 |xentropy_loss:1.091472
# epoch:843 loss:0.367659 loss:0.646129 accu:0.089189 |xentropy_loss:1.217128
# epoch:844 loss:0.371185 loss:0.676580 accu:0.065791 |xentropy_loss:1.102051
# epoch:845 loss:0.390687 loss:0.693678 accu:0.087695 |xentropy_loss:1.163553
# epoch:846 loss:0.371535 loss:0.675716 accu:0.067353 |xentropy_loss:1.080251
# epoch:847 loss:0.398144 loss:0.729114 accu:0.067174 |xentropy_loss:1.118007
# epoch:848 loss:0.345780 loss:0.621949 accu:0.069612 |xentropy_loss:1.127483
# epoch:849 loss:0.399848 loss:0.667700 accu:0.131995 |xentropy_loss:1.161854
# epoch:850 loss:0.399524 loss:0.709023 accu:0.090025 |xentropy_loss:1.175473
# epoch:851 loss:0.428052 loss:0.746980 accu:0.109123 |xentropy_loss:0.980776
# epoch:852 loss:0.358858 loss:0.658181 accu:0.059535 |xentropy_loss:1.077372
# epoch:853 loss:0.408203 loss:0.727118 accu:0.089289 |xentropy_loss:1.131533
# epoch:854 loss:0.382333 loss:0.692339 accu:0.072327 |xentropy_loss:1.067518
# epoch:855 loss:0.404193 loss:0.731094 accu:0.077293 |xentropy_loss:1.051018
# epoch:856 loss:0.380031 loss:0.687999 accu:0.072062 |xentropy_loss:1.162489
# epoch:857 loss:0.423477 loss:0.749246 accu:0.097707 |xentropy_loss:1.193929
# epoch:858 loss:0.396807 loss:0.680819 accu:0.112795 |xentropy_loss:1.121177
# epoch:859 loss:0.380394 loss:0.682459 accu:0.078329 |xentropy_loss:1.136972
# epoch:860 loss:0.406184 loss:0.712944 accu:0.099425 |xentropy_loss:0.991721
# epoch:861 loss:0.391708 loss:0.708356 accu:0.075060 |xentropy_loss:1.115874
# epoch:862 loss:0.413161 loss:0.701737 accu:0.124585 |xentropy_loss:1.064795
# epoch:863 loss:0.381902 loss:0.690544 accu:0.073259 |xentropy_loss:1.116868
# epoch:864 loss:0.355627 loss:0.627607 accu:0.083648 |xentropy_loss:1.029791
# epoch:865 loss:0.358164 loss:0.648708 accu:0.067619 |xentropy_loss:1.111830
# epoch:866 loss:0.366914 loss:0.638350 accu:0.095477 |xentropy_loss:1.181320
# epoch:867 loss:0.347926 loss:0.586629 accu:0.109223 |xentropy_loss:1.036129
# epoch:868 loss:0.373967 loss:0.668769 accu:0.079165 |xentropy_loss:1.064835
# epoch:869 loss:0.384731 loss:0.694947 accu:0.074514 |xentropy_loss:0.971035
# epoch:870 loss:0.387696 loss:0.689143 accu:0.086249 |xentropy_loss:1.038840
# epoch:871 loss:0.342389 loss:0.603275 accu:0.081503 |xentropy_loss:1.134893
# epoch:872 loss:0.378671 loss:0.690581 accu:0.066761 |xentropy_loss:1.164977
# epoch:873 loss:0.339280 loss:0.580936 accu:0.097625 |xentropy_loss:1.158542
# epoch:874 loss:0.401832 loss:0.711434 accu:0.092231 |xentropy_loss:1.107542
# epoch:875 loss:0.390779 loss:0.683866 accu:0.097691 |xentropy_loss:1.132298
# epoch:876 loss:0.362137 loss:0.635641 accu:0.088633 |xentropy_loss:1.156587
# epoch:877 loss:0.378769 loss:0.638469 accu:0.119069 |xentropy_loss:1.072580
# epoch:878 loss:0.379896 loss:0.687358 accu:0.072434 |xentropy_loss:1.180006
# epoch:879 loss:0.368488 loss:0.669642 accu:0.067335 |xentropy_loss:1.243827
# epoch:880 loss:0.380847 loss:0.668494 accu:0.093200 |xentropy_loss:1.097429
# epoch:881 loss:0.370599 loss:0.643718 accu:0.097480 |xentropy_loss:1.124681
# epoch:882 loss:0.359236 loss:0.630076 accu:0.088397 |xentropy_loss:1.227212
# epoch:883 loss:0.390497 loss:0.687993 accu:0.093001 |xentropy_loss:1.080902
# epoch:884 loss:0.312599 loss:0.562530 accu:0.062667 |xentropy_loss:1.145080
# epoch:885 loss:0.423150 loss:0.713975 accu:0.132324 |xentropy_loss:1.146893
# epoch:886 loss:0.374140 loss:0.661954 accu:0.086325 |xentropy_loss:1.018915
# epoch:887 loss:0.420322 loss:0.730912 accu:0.109732 |xentropy_loss:0.999476
# epoch:888 loss:0.338994 loss:0.622165 accu:0.055823 |xentropy_loss:1.095599
# epoch:889 loss:0.370565 loss:0.664795 accu:0.076334 |xentropy_loss:1.022239
# epoch:890 loss:0.335180 loss:0.596694 accu:0.073667 |xentropy_loss:1.098478
# epoch:891 loss:0.392190 loss:0.670326 accu:0.114055 |xentropy_loss:1.136831
# epoch:892 loss:0.375144 loss:0.650471 accu:0.099818 |xentropy_loss:1.168925
# epoch:893 loss:0.333789 loss:0.607385 accu:0.060193 |xentropy_loss:1.091987
# epoch:894 loss:0.388185 loss:0.695100 accu:0.081269 |xentropy_loss:1.353047
# epoch:895 loss:0.369093 loss:0.661494 accu:0.076692 |xentropy_loss:1.212524
# epoch:896 loss:0.335196 loss:0.593929 accu:0.076463 |xentropy_loss:1.188940
# epoch:897 loss:0.388048 loss:0.692085 accu:0.084011 |xentropy_loss:1.143234
# epoch:898 loss:0.376866 loss:0.664999 accu:0.088734 |xentropy_loss:1.200952
# epoch:899 loss:0.378150 loss:0.689101 accu:0.067199 |xentropy_loss:1.040648
# epoch:900 loss:0.360051 loss:0.625901 accu:0.094202 |xentropy_loss:1.210410
# epoch:901 loss:0.348748 loss:0.593632 accu:0.103864 |xentropy_loss:1.032198
# epoch:902 loss:0.377623 loss:0.676417 accu:0.078829 |xentropy_loss:1.229059
# epoch:903 loss:0.376067 loss:0.662566 accu:0.089567 |xentropy_loss:1.151920
# epoch:904 loss:0.373865 loss:0.689609 accu:0.058121 |xentropy_loss:1.036955
# epoch:905 loss:0.407564 loss:0.731777 accu:0.083350 |xentropy_loss:1.272591
# epoch:906 loss:0.386968 loss:0.669088 accu:0.104847 |xentropy_loss:1.150732
# epoch:907 loss:0.399948 loss:0.698496 accu:0.101399 |xentropy_loss:1.226271
# epoch:908 loss:0.388964 loss:0.679432 accu:0.098497 |xentropy_loss:1.091345
# epoch:909 loss:0.392151 loss:0.694457 accu:0.089844 |xentropy_loss:1.091895
# epoch:910 loss:0.370811 loss:0.646085 accu:0.095537 |xentropy_loss:1.192111
# epoch:911 loss:0.392469 loss:0.698391 accu:0.086548 |xentropy_loss:1.156787
# epoch:912 loss:0.353272 loss:0.618052 accu:0.088491 |xentropy_loss:1.131498
# epoch:913 loss:0.361444 loss:0.652787 accu:0.070100 |xentropy_loss:1.244716
# epoch:914 loss:0.367050 loss:0.640719 accu:0.093380 |xentropy_loss:1.263037
# epoch:915 loss:0.379220 loss:0.673122 accu:0.085318 |xentropy_loss:1.142825
# epoch:916 loss:0.354477 loss:0.633402 accu:0.075553 |xentropy_loss:1.098548
# epoch:917 loss:0.404210 loss:0.720478 accu:0.087941 |xentropy_loss:1.151248
# epoch:918 loss:0.374774 loss:0.662625 accu:0.086923 |xentropy_loss:1.170569
# epoch:919 loss:0.364553 loss:0.646384 accu:0.082722 |xentropy_loss:1.237187
# epoch:920 loss:0.353267 loss:0.653359 accu:0.053174 |xentropy_loss:1.163021
# epoch:921 loss:0.318980 loss:0.570874 accu:0.067086 |xentropy_loss:1.103637
# epoch:922 loss:0.381443 loss:0.698827 accu:0.064060 |xentropy_loss:1.133653
# epoch:923 loss:0.386854 loss:0.676944 accu:0.096765 |xentropy_loss:1.096321
# epoch:924 loss:0.414920 loss:0.712618 accu:0.117222 |xentropy_loss:1.124331
# epoch:925 loss:0.402979 loss:0.708219 accu:0.097739 |xentropy_loss:1.061910
# epoch:926 loss:0.404011 loss:0.713128 accu:0.094893 |xentropy_loss:0.995947
# epoch:927 loss:0.384632 loss:0.673307 accu:0.095956 |xentropy_loss:1.031633
# epoch:928 loss:0.430106 loss:0.779316 accu:0.080896 |xentropy_loss:0.979768
# epoch:929 loss:0.379565 loss:0.656349 accu:0.102782 |xentropy_loss:1.174493
# epoch:930 loss:0.380847 loss:0.697646 accu:0.064048 |xentropy_loss:1.169532
# epoch:931 loss:0.378976 loss:0.649801 accu:0.108151 |xentropy_loss:1.202192
# epoch:932 loss:0.422087 loss:0.759859 accu:0.084315 |xentropy_loss:1.150924
# epoch:933 loss:0.379024 loss:0.624623 accu:0.133425 |xentropy_loss:1.104805
# epoch:934 loss:0.404742 loss:0.725529 accu:0.083955 |xentropy_loss:1.067903
# epoch:935 loss:0.384384 loss:0.690721 accu:0.078047 |xentropy_loss:1.042663
# epoch:936 loss:0.391051 loss:0.688051 accu:0.094051 |xentropy_loss:1.136523
# epoch:937 loss:0.334805 loss:0.588685 accu:0.080925 |xentropy_loss:1.231132
# epoch:938 loss:0.415417 loss:0.756320 accu:0.074514 |xentropy_loss:0.985318
# epoch:939 loss:0.315258 loss:0.564687 accu:0.065828 |xentropy_loss:1.100190
# epoch:940 loss:0.394236 loss:0.700097 accu:0.088375 |xentropy_loss:1.173491
# epoch:941 loss:0.371579 loss:0.663341 accu:0.079816 |xentropy_loss:1.104236
# epoch:942 loss:0.368913 loss:0.662917 accu:0.074908 |xentropy_loss:1.057611
# epoch:943 loss:0.426360 loss:0.738744 accu:0.113975 |xentropy_loss:1.113931
# epoch:944 loss:0.380657 loss:0.666949 accu:0.094366 |xentropy_loss:0.975191
# epoch:945 loss:0.357310 loss:0.597599 accu:0.117021 |xentropy_loss:1.044655
# epoch:946 loss:0.392941 loss:0.715036 accu:0.070845 |xentropy_loss:1.083329
# epoch:947 loss:0.362426 loss:0.634913 accu:0.089940 |xentropy_loss:1.155014
# epoch:948 loss:0.377062 loss:0.691456 accu:0.062669 |xentropy_loss:1.261174
# epoch:949 loss:0.362826 loss:0.626948 accu:0.098704 |xentropy_loss:1.165628
# epoch:950 loss:0.444485 loss:0.804167 accu:0.084804 |xentropy_loss:1.043266
# epoch:951 loss:0.359824 loss:0.647416 accu:0.072231 |xentropy_loss:1.039689
# epoch:952 loss:0.383193 loss:0.674469 accu:0.091917 |xentropy_loss:1.153868
# epoch:953 loss:0.404324 loss:0.707001 accu:0.101647 |xentropy_loss:1.182415
# epoch:954 loss:0.414199 loss:0.735434 accu:0.092964 |xentropy_loss:1.143561
# epoch:955 loss:0.350782 loss:0.633998 accu:0.067565 |xentropy_loss:1.091649
# epoch:956 loss:0.338592 loss:0.609825 accu:0.067360 |xentropy_loss:1.150313
# epoch:957 loss:0.383326 loss:0.678120 accu:0.088533 |xentropy_loss:1.088081
# epoch:958 loss:0.367033 loss:0.636696 accu:0.097370 |xentropy_loss:1.021564
# epoch:959 loss:0.349696 loss:0.636018 accu:0.063374 |xentropy_loss:1.129747
# epoch:960 loss:0.374199 loss:0.649024 accu:0.099373 |xentropy_loss:1.068157
# epoch:961 loss:0.348354 loss:0.618738 accu:0.077969 |xentropy_loss:1.160504
# epoch:962 loss:0.393102 loss:0.670533 accu:0.115671 |xentropy_loss:1.348349
# epoch:963 loss:0.315940 loss:0.548912 accu:0.082968 |xentropy_loss:1.128016
# epoch:964 loss:0.430867 loss:0.761483 accu:0.100251 |xentropy_loss:0.974752
# epoch:965 loss:0.403632 loss:0.707910 accu:0.099354 |xentropy_loss:1.011281
# epoch:966 loss:0.400236 loss:0.708116 accu:0.092357 |xentropy_loss:0.999054
# epoch:967 loss:0.329932 loss:0.589038 accu:0.070827 |xentropy_loss:1.234948
# epoch:968 loss:0.355408 loss:0.637962 accu:0.072854 |xentropy_loss:1.138979
# epoch:969 loss:0.404825 loss:0.715059 accu:0.094591 |xentropy_loss:1.175038
# epoch:970 loss:0.339865 loss:0.600460 accu:0.079269 |xentropy_loss:1.155406
# epoch:971 loss:0.346456 loss:0.636362 accu:0.056550 |xentropy_loss:1.113489
# epoch:972 loss:0.360674 loss:0.643636 accu:0.077712 |xentropy_loss:1.140504
# epoch:973 loss:0.410805 loss:0.714578 accu:0.107032 |xentropy_loss:1.030262
# epoch:974 loss:0.374449 loss:0.668346 accu:0.080552 |xentropy_loss:1.060457
# epoch:975 loss:0.337830 loss:0.600643 accu:0.075017 |xentropy_loss:1.258106
# epoch:976 loss:0.374427 loss:0.686288 accu:0.062565 |xentropy_loss:1.051109
# epoch:977 loss:0.339942 loss:0.583644 accu:0.096239 |xentropy_loss:1.301728
# epoch:978 loss:0.383906 loss:0.671024 accu:0.096787 |xentropy_loss:1.063159
# epoch:979 loss:0.377738 loss:0.668545 accu:0.086932 |xentropy_loss:1.145597
# epoch:980 loss:0.388944 loss:0.697307 accu:0.080582 |xentropy_loss:1.095925
# epoch:981 loss:0.374338 loss:0.648769 accu:0.099907 |xentropy_loss:1.082815
# epoch:982 loss:0.371348 loss:0.667135 accu:0.075562 |xentropy_loss:1.074561
# epoch:983 loss:0.344150 loss:0.613276 accu:0.075024 |xentropy_loss:1.229592
# epoch:984 loss:0.417973 loss:0.728762 accu:0.107185 |xentropy_loss:1.027797
# epoch:985 loss:0.374714 loss:0.668816 accu:0.080613 |xentropy_loss:1.073743
# epoch:986 loss:0.380020 loss:0.673586 accu:0.086455 |xentropy_loss:1.053923
# epoch:987 loss:0.368127 loss:0.662382 accu:0.073871 |xentropy_loss:0.963663
# epoch:988 loss:0.427491 loss:0.769926 accu:0.085056 |xentropy_loss:0.987312
# epoch:989 loss:0.395098 loss:0.708172 accu:0.082024 |xentropy_loss:1.168592
# epoch:990 loss:0.383110 loss:0.698438 accu:0.067782 |xentropy_loss:1.050951
# epoch:991 loss:0.385164 loss:0.708899 accu:0.061430 |xentropy_loss:1.138181
# epoch:992 loss:0.375005 loss:0.681108 accu:0.068902 |xentropy_loss:1.076334
# epoch:993 loss:0.346258 loss:0.620849 accu:0.071668 |xentropy_loss:1.194771
# epoch:994 loss:0.360784 loss:0.626177 accu:0.095391 |xentropy_loss:1.104650
# epoch:995 loss:0.341931 loss:0.614425 accu:0.069437 |xentropy_loss:1.302683
# epoch:996 loss:0.378438 loss:0.673793 accu:0.083084 |xentropy_loss:1.216136
# epoch:997 loss:0.408247 loss:0.732946 accu:0.083548 |xentropy_loss:0.966499
# epoch:998 loss:0.347584 loss:0.628296 accu:0.066872 |xentropy_loss:1.105321
# epoch:999 loss:0.368848 loss:0.647434 accu:0.090262 |xentropy_loss:1.182199
# epoch:1000 loss:0.370808 loss:0.674310 accu:0.067307 |xentropy_loss:1.163575

# %%
X_A.shape
# Out:
# (30000, 784)

# %%
real_labels.shape
# Out:
# (64, 1)

# %%
gc.collect()

# %%
gc.collect()

# %%
5//2
# Out:
# 2

# %%
6//5
# Out:
# 1

# %%
5//6
# Out:
# 0
