# %%
#对偶学习的原理

# %%
from keras.models import Sequential , Model
from keras.layers import Dense ,  BatchNormalization , Reshape , Input , Flatten
from keras.layers import Conv2D , MaxPool2D , Conv2DTranspose , UpSampling2D , ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU , PReLU
from keras.layers import Activation
from keras.layers import Dropout

from keras.layers import Concatenate

#addin cycleGAN 使用instance-norm
from keras_contrib.layers.normalization import InstanceNormalization

from keras.initializers import truncated_normal , constant , random_normal

from keras.optimizers import Adam , RMSprop

#残差块使用
from keras.layers import Add

from keras.datasets import mnist

# %%
import os

import matplotlib as plt
import numpy as np

import gc

from glob import glob

import keras.backend as K

import scipy

# %matplotlib inline

# %%
WIDTH = 28
HEIGHT = 28
CHANNEL = 1

SHAPE = (WIDTH , HEIGHT , CHANNEL)

BATCH_SIZE = 64
EPOCHS = 10

#生成多少个图像 长*宽
ROW = 2
COL = 2

LATENT_DIM = 100 #噪音维度 100维  noise z

# %%
(X_train , _),(_ , _) = mnist.load_data()
X_train = X_train/127.5-1
X_train = np.expand_dims(X_train , 3)

#为了使用CoGAN 对样本简单处理一下 旋转90度
X_A = X_train[: int(X_train.shape[0]/2)]
X_B = scipy.ndimage.interpolation.rotate(X_train[int(X_train.shape[0]/2) : ] , angle=90 , axes=(1,2)) #沿着 1 2维上进行旋转 0维是样本数量 3维上是channel

# %%
def load_mnist(X , batch_size = BATCH_SIZE):
    return X[np.random.randint(0, X.shape[0], batch_size)]
    
def write_image_mnist(epoch):
    
    z = np.random.normal(0 , 1 , size=(2 , LATENT_DIM))
    
    style1 = generator_style1.predict(z)
    style2 = generator_style2.predict(z)
    
    style1 = style1*0.5+0.5
    style2 = style2*0.5+0.5
    
    fig , axes = plt.pyplot.subplots(ROW , COL)
    
    axes[0][0].imshow(style1[0,:,:,0] , cmap='gray')
    axes[0][0].set_title('style1')
    axes[0][0].axis('off')

    axes[0][1].imshow(style2[0,:,:,0] , cmap='gray')
    axes[0][1].set_title('style2')
    axes[0][1].axis('off')
    
    axes[1][0].imshow(style1[1,:,:,0] , cmap='gray')
    axes[1][0].set_title('style1')
    axes[1][0].axis('off')

    axes[1][1].imshow(style2[1,:,:,0] , cmap='gray')
    axes[1][1].set_title('style2')
    axes[1][1].axis('off')

    fig.savefig('mnist_cogan/No.%d.png' % epoch)
    plt.pyplot.close()

# %%
def generator():
    z = Input(shape=(LATENT_DIM , )) #输入一个风格的图像 生成另一个风格的图像
    
    model = Sequential()
    model.add(Dense(256, input_shape=(LATENT_DIM , )))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    
    feature = model(z)
    
    #G1 G2需要共享前面几层的权重参数
    #G1
    h1 = Dense(1024)(feature)
    h1 = LeakyReLU(alpha=0.2)(h1)
    h1 = BatchNormalization(momentum=0.8)(h1)
    h1 = Dense(units=WIDTH*HEIGHT*CHANNEL , activation='tanh')(h1)
    style1 = Reshape(target_shape=SHAPE)(h1)
    
    #G2
    h2 = Dense(1024)(feature)
    h2 = LeakyReLU(alpha=0.2)(h2)
    h2 = BatchNormalization(momentum=0.8)(h2)
    h2 = Dense(units=WIDTH*HEIGHT*CHANNEL , activation='tanh')(h2)
    style2 = Reshape(target_shape=SHAPE)(h2)
    
    return Model(z , style1) , Model(z , style2)

# %%
def discriminator():
    style1 = Input(shape=SHAPE)
    style2 = Input(shape=SHAPE)
    
    model = Sequential()
    model.add(Flatten(input_shape=SHAPE))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(256))
    model.add(LeakyReLU(alpha=0.2))
    
    hidden_style1 = model(style1)
    hidden_style2 = model(style2)
    
    validity_style1 = Dense(1 , activation='sigmoid')(hidden_style1)
    validity_style2 = Dense(1 , activation='sigmoid')(hidden_style2)
        
    return Model(style1 , validity_style1) , Model(style2 , validity_style2)

# %%
adam = Adam(lr = 0.0002 , beta_1=0.5)
#构建计算图
discriminator_style1 , discriminator_style2 = discriminator()
discriminator_style1.compile(optimizer = adam , loss='binary_crossentropy' , metrics=['accuracy'])
discriminator_style2.compile(optimizer = adam , loss='binary_crossentropy' , metrics=['accuracy'])

generator_style1 , generator_style2 = generator()

z = Input(shape=(LATENT_DIM , ))

style1 = generator_style1(z)
style2 = generator_style2(z)

#freeze D
discriminator_style1.trainable = False
discriminator_style2.trainable = False

validity_style1 = discriminator_style1(style1)
validity_style2 = discriminator_style2(style2)

#一共6个输出 最后4个输出希望和原图像一致 这样图像同时具有两个风格
combined = Model(z , [validity_style1 , validity_style2])
combined.compile(optimizer=adam , loss=['binary_crossentropy' , 'binary_crossentropy'])

# %%
#tuple类型相加 相当于cat连接
real_labels = np.ones(shape=(BATCH_SIZE , 1)) #真实的
fake_labels = np.zeros(shape=(BATCH_SIZE , 1))

for i in range(1001):
    apples_ = load_mnist(X_A)
    oranges_ = load_mnist(X_B)
    
    z = np.random.normal(0 , 1 , (BATCH_SIZE , LATENT_DIM))

    style1 = generator_style1.predict(z)
    style2 = generator_style2.predict(z)
    #训练判别器
    style1_loss = discriminator_style1.train_on_batch(apples_ , real_labels)
    style1_hat_loss = discriminator_style1.train_on_batch(style1 , fake_labels)
    loss_style1 = np.add(style1_loss , style1_hat_loss)/2

    style2_loss = discriminator_style2.train_on_batch(oranges_ , real_labels)
    style2_hat_loss = discriminator_style2.train_on_batch(style2 , fake_labels)
    loss_style2 = np.add(style2_loss , style2_hat_loss)/2
    
    loss = np.add(loss_style1 , loss_style2)/2

    #训练生成器
    generator_loss = combined.train_on_batch(z , [real_labels , real_labels])
    
    print('epoch:%d loss:%f accu:%f |xentropy_loss:%f xentropy_loss:%f' % (i , loss[0] , loss[1] , generator_loss[0] , generator_loss[1]))

    if i % 50 == 0:
        write_image_mnist(i)

write_image_mnist(999)
# Out:
# C:\Anaconda3\lib\site-packages\keras\engine\training.py:479: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# epoch:0 loss:2.854656 accu:0.570312 |xentropy_loss:5.427509 xentropy_loss:0.854947
# epoch:1 loss:0.394153 accu:0.773438 |xentropy_loss:11.464317 xentropy_loss:1.460063
# epoch:2 loss:1.210803 accu:0.429688 |xentropy_loss:13.263485 xentropy_loss:0.657380
# epoch:3 loss:0.359027 accu:0.769531 |xentropy_loss:12.772544 xentropy_loss:0.864516
# epoch:4 loss:0.591151 accu:0.718750 |xentropy_loss:14.746601 xentropy_loss:0.837653
# epoch:5 loss:0.396062 accu:0.738281 |xentropy_loss:11.800735 xentropy_loss:1.119213
# epoch:6 loss:0.613550 accu:0.722656 |xentropy_loss:13.050305 xentropy_loss:1.021489
# epoch:7 loss:0.389278 accu:0.722656 |xentropy_loss:13.867621 xentropy_loss:0.839195
# epoch:8 loss:0.417359 accu:0.714844 |xentropy_loss:13.116418 xentropy_loss:0.865474
# epoch:9 loss:0.399165 accu:0.738281 |xentropy_loss:14.128585 xentropy_loss:1.331273
# epoch:10 loss:0.677013 accu:0.457031 |xentropy_loss:12.734560 xentropy_loss:0.731470
# epoch:11 loss:0.346600 accu:0.769531 |xentropy_loss:11.441513 xentropy_loss:0.829321
# epoch:12 loss:0.554495 accu:0.714844 |xentropy_loss:14.863546 xentropy_loss:1.296357
# epoch:13 loss:1.355571 accu:0.281250 |xentropy_loss:8.571545 xentropy_loss:1.277919
# epoch:14 loss:0.868504 accu:0.601562 |xentropy_loss:9.389915 xentropy_loss:0.834247
# epoch:15 loss:0.507328 accu:0.589844 |xentropy_loss:11.074491 xentropy_loss:0.811888
# epoch:16 loss:0.463950 accu:0.656250 |xentropy_loss:10.992874 xentropy_loss:0.881786
# epoch:17 loss:0.824422 accu:0.519531 |xentropy_loss:7.669055 xentropy_loss:0.816472
# epoch:18 loss:0.597832 accu:0.589844 |xentropy_loss:9.917082 xentropy_loss:1.039004
# epoch:19 loss:0.975318 accu:0.375000 |xentropy_loss:8.167388 xentropy_loss:0.903521
# epoch:20 loss:0.538168 accu:0.632812 |xentropy_loss:9.158169 xentropy_loss:0.833470
# epoch:21 loss:0.848063 accu:0.425781 |xentropy_loss:7.214453 xentropy_loss:0.838665
# epoch:22 loss:0.483577 accu:0.652344 |xentropy_loss:9.380160 xentropy_loss:0.785107
# epoch:23 loss:0.912852 accu:0.433594 |xentropy_loss:7.001679 xentropy_loss:0.874933
# epoch:24 loss:0.517964 accu:0.582031 |xentropy_loss:8.500242 xentropy_loss:0.784428
# epoch:25 loss:0.677236 accu:0.507812 |xentropy_loss:7.441885 xentropy_loss:0.837128
# epoch:26 loss:0.471722 accu:0.718750 |xentropy_loss:8.625610 xentropy_loss:0.872460
# epoch:27 loss:0.618134 accu:0.566406 |xentropy_loss:8.552116 xentropy_loss:0.834204
# epoch:28 loss:0.618112 accu:0.589844 |xentropy_loss:8.682822 xentropy_loss:0.862379
# epoch:29 loss:0.549917 accu:0.613281 |xentropy_loss:8.036656 xentropy_loss:0.948091
# epoch:30 loss:0.634883 accu:0.574219 |xentropy_loss:7.810389 xentropy_loss:0.880177
# epoch:31 loss:0.541627 accu:0.632812 |xentropy_loss:7.906786 xentropy_loss:0.905421
# epoch:32 loss:0.564250 accu:0.558594 |xentropy_loss:8.212852 xentropy_loss:0.877152
# epoch:33 loss:0.600852 accu:0.601562 |xentropy_loss:8.488270 xentropy_loss:0.877901
# epoch:34 loss:0.580320 accu:0.609375 |xentropy_loss:8.437842 xentropy_loss:0.887401
# epoch:35 loss:0.548074 accu:0.601562 |xentropy_loss:8.609574 xentropy_loss:0.832753
# epoch:36 loss:0.566752 accu:0.578125 |xentropy_loss:8.132607 xentropy_loss:0.880975
# epoch:37 loss:0.571323 accu:0.597656 |xentropy_loss:8.617371 xentropy_loss:0.888996
# epoch:38 loss:0.561260 accu:0.582031 |xentropy_loss:8.849802 xentropy_loss:0.809441
# epoch:39 loss:0.615095 accu:0.531250 |xentropy_loss:7.563342 xentropy_loss:0.840463
# epoch:40 loss:0.537055 accu:0.656250 |xentropy_loss:8.699599 xentropy_loss:0.872075
# epoch:41 loss:0.575677 accu:0.597656 |xentropy_loss:7.864820 xentropy_loss:0.907412
# epoch:42 loss:0.450776 accu:0.691406 |xentropy_loss:8.185664 xentropy_loss:0.945320
# epoch:43 loss:0.524025 accu:0.613281 |xentropy_loss:8.985093 xentropy_loss:0.967664
# epoch:44 loss:0.490154 accu:0.644531 |xentropy_loss:8.619530 xentropy_loss:0.855236
# epoch:45 loss:0.456793 accu:0.656250 |xentropy_loss:8.319082 xentropy_loss:0.864932
# epoch:46 loss:0.478493 accu:0.707031 |xentropy_loss:9.651933 xentropy_loss:0.987172
# epoch:47 loss:0.576342 accu:0.597656 |xentropy_loss:10.072392 xentropy_loss:0.960502
# epoch:48 loss:0.536115 accu:0.691406 |xentropy_loss:7.546446 xentropy_loss:0.960960
# epoch:49 loss:0.424798 accu:0.742188 |xentropy_loss:9.648344 xentropy_loss:1.006291
# epoch:50 loss:0.749177 accu:0.523438 |xentropy_loss:8.848198 xentropy_loss:0.972109
# epoch:51 loss:0.412374 accu:0.750000 |xentropy_loss:8.674918 xentropy_loss:0.977492
# epoch:52 loss:0.550075 accu:0.687500 |xentropy_loss:7.536777 xentropy_loss:0.964902
# epoch:53 loss:0.471990 accu:0.714844 |xentropy_loss:9.171492 xentropy_loss:1.030541
# epoch:54 loss:0.591980 accu:0.621094 |xentropy_loss:8.115894 xentropy_loss:0.957608
# epoch:55 loss:0.401995 accu:0.843750 |xentropy_loss:8.422920 xentropy_loss:1.051761
# epoch:56 loss:0.543708 accu:0.687500 |xentropy_loss:9.439837 xentropy_loss:0.931187
# epoch:57 loss:0.494657 accu:0.687500 |xentropy_loss:8.072351 xentropy_loss:0.825393
# epoch:58 loss:0.465928 accu:0.714844 |xentropy_loss:9.020534 xentropy_loss:0.906209
# epoch:59 loss:0.523770 accu:0.691406 |xentropy_loss:8.108088 xentropy_loss:0.956673
# epoch:60 loss:0.442269 accu:0.750000 |xentropy_loss:8.343060 xentropy_loss:0.976258
# epoch:61 loss:0.520471 accu:0.660156 |xentropy_loss:9.227494 xentropy_loss:0.978229
# epoch:62 loss:0.534456 accu:0.644531 |xentropy_loss:8.466673 xentropy_loss:0.859132
# epoch:63 loss:0.429447 accu:0.722656 |xentropy_loss:7.731502 xentropy_loss:0.856667
# epoch:64 loss:0.472657 accu:0.769531 |xentropy_loss:8.343731 xentropy_loss:0.917519
# epoch:65 loss:0.481578 accu:0.703125 |xentropy_loss:7.759154 xentropy_loss:0.891660
# epoch:66 loss:0.480691 accu:0.726562 |xentropy_loss:7.626708 xentropy_loss:0.959931
# epoch:67 loss:0.473749 accu:0.734375 |xentropy_loss:7.848943 xentropy_loss:0.912509
# epoch:68 loss:0.449292 accu:0.742188 |xentropy_loss:7.925492 xentropy_loss:0.944449
# epoch:69 loss:0.463624 accu:0.703125 |xentropy_loss:8.216774 xentropy_loss:0.901606
# epoch:70 loss:0.526600 accu:0.644531 |xentropy_loss:8.777431 xentropy_loss:0.887105
# epoch:71 loss:0.505953 accu:0.707031 |xentropy_loss:7.798089 xentropy_loss:0.897148
# epoch:72 loss:0.435776 accu:0.804688 |xentropy_loss:7.562667 xentropy_loss:0.932166
# epoch:73 loss:0.457730 accu:0.753906 |xentropy_loss:8.270967 xentropy_loss:0.945426
# epoch:74 loss:0.565976 accu:0.675781 |xentropy_loss:8.317666 xentropy_loss:0.955084
# epoch:75 loss:0.496504 accu:0.710938 |xentropy_loss:7.036585 xentropy_loss:0.935022
# epoch:76 loss:0.439018 accu:0.789062 |xentropy_loss:7.982669 xentropy_loss:0.926569
# epoch:77 loss:0.492261 accu:0.679688 |xentropy_loss:8.240690 xentropy_loss:0.906975
# epoch:78 loss:0.542028 accu:0.648438 |xentropy_loss:7.860827 xentropy_loss:0.917056
# epoch:79 loss:0.474517 accu:0.742188 |xentropy_loss:8.465193 xentropy_loss:0.950503
# epoch:80 loss:0.502721 accu:0.687500 |xentropy_loss:7.862175 xentropy_loss:0.962249
# epoch:81 loss:0.529153 accu:0.660156 |xentropy_loss:7.664037 xentropy_loss:0.933147
# epoch:82 loss:0.480030 accu:0.710938 |xentropy_loss:7.725401 xentropy_loss:0.902357
# epoch:83 loss:0.639233 accu:0.589844 |xentropy_loss:6.797374 xentropy_loss:0.881672
# epoch:84 loss:0.376744 accu:0.835938 |xentropy_loss:8.206842 xentropy_loss:0.977595
# epoch:85 loss:0.512676 accu:0.710938 |xentropy_loss:7.264294 xentropy_loss:0.902756
# epoch:86 loss:0.620163 accu:0.605469 |xentropy_loss:8.020482 xentropy_loss:0.919226
# epoch:87 loss:0.523217 accu:0.699219 |xentropy_loss:7.543020 xentropy_loss:0.881361
# epoch:88 loss:0.474101 accu:0.765625 |xentropy_loss:7.302712 xentropy_loss:0.917871
# epoch:89 loss:0.491011 accu:0.746094 |xentropy_loss:7.212744 xentropy_loss:0.880930
# epoch:90 loss:0.523414 accu:0.714844 |xentropy_loss:7.647067 xentropy_loss:0.862880
# epoch:91 loss:0.522359 accu:0.691406 |xentropy_loss:6.820592 xentropy_loss:0.906268
# epoch:92 loss:0.453550 accu:0.769531 |xentropy_loss:7.475917 xentropy_loss:0.907774
# epoch:93 loss:0.501908 accu:0.707031 |xentropy_loss:6.865176 xentropy_loss:0.884231
# epoch:94 loss:0.514230 accu:0.695312 |xentropy_loss:7.399551 xentropy_loss:0.919646
# epoch:95 loss:0.574531 accu:0.664062 |xentropy_loss:7.037279 xentropy_loss:0.913437
# epoch:96 loss:0.465949 accu:0.800781 |xentropy_loss:6.883921 xentropy_loss:0.948061
# epoch:97 loss:0.492946 accu:0.714844 |xentropy_loss:7.223953 xentropy_loss:0.875252
# epoch:98 loss:0.457974 accu:0.773438 |xentropy_loss:6.298917 xentropy_loss:0.906623
# epoch:99 loss:0.539661 accu:0.695312 |xentropy_loss:8.112101 xentropy_loss:0.942261
# epoch:100 loss:0.650499 accu:0.585938 |xentropy_loss:6.468346 xentropy_loss:0.871358
# epoch:101 loss:0.504807 accu:0.703125 |xentropy_loss:7.054933 xentropy_loss:0.839633
# epoch:102 loss:0.532960 accu:0.667969 |xentropy_loss:7.104817 xentropy_loss:0.876731
# epoch:103 loss:0.673426 accu:0.582031 |xentropy_loss:5.738816 xentropy_loss:0.872911
# epoch:104 loss:0.455581 accu:0.785156 |xentropy_loss:6.765134 xentropy_loss:0.918432
# epoch:105 loss:0.540138 accu:0.683594 |xentropy_loss:5.928705 xentropy_loss:0.866554
# epoch:106 loss:0.478396 accu:0.769531 |xentropy_loss:6.222577 xentropy_loss:0.896312
# epoch:107 loss:0.586900 accu:0.609375 |xentropy_loss:7.208040 xentropy_loss:0.955591
# epoch:108 loss:0.558025 accu:0.656250 |xentropy_loss:6.477937 xentropy_loss:0.902497
# epoch:109 loss:0.502606 accu:0.710938 |xentropy_loss:6.231215 xentropy_loss:0.937293
# epoch:110 loss:0.550488 accu:0.640625 |xentropy_loss:7.285352 xentropy_loss:0.907793
# epoch:111 loss:0.513400 accu:0.714844 |xentropy_loss:6.110674 xentropy_loss:0.920249
# epoch:112 loss:0.515164 accu:0.710938 |xentropy_loss:7.036271 xentropy_loss:0.902812
# epoch:113 loss:0.534171 accu:0.730469 |xentropy_loss:6.634625 xentropy_loss:0.952507
# epoch:114 loss:0.496772 accu:0.781250 |xentropy_loss:6.327773 xentropy_loss:0.947204
# epoch:115 loss:0.521336 accu:0.722656 |xentropy_loss:6.767697 xentropy_loss:0.969728
# epoch:116 loss:0.488738 accu:0.773438 |xentropy_loss:6.314654 xentropy_loss:0.965091
# epoch:117 loss:0.524718 accu:0.730469 |xentropy_loss:5.265316 xentropy_loss:0.907279
# epoch:118 loss:0.547984 accu:0.695312 |xentropy_loss:6.255023 xentropy_loss:0.913718
# epoch:119 loss:0.578915 accu:0.660156 |xentropy_loss:5.293763 xentropy_loss:0.878292
# epoch:120 loss:0.497197 accu:0.773438 |xentropy_loss:6.074297 xentropy_loss:0.927497
# epoch:121 loss:0.508163 accu:0.750000 |xentropy_loss:6.013513 xentropy_loss:0.936307
# epoch:122 loss:0.500971 accu:0.777344 |xentropy_loss:6.355552 xentropy_loss:0.925664
# epoch:123 loss:0.486492 accu:0.734375 |xentropy_loss:6.374778 xentropy_loss:0.979683
# epoch:124 loss:0.509983 accu:0.710938 |xentropy_loss:6.356055 xentropy_loss:0.965608
# epoch:125 loss:0.574628 accu:0.625000 |xentropy_loss:6.133960 xentropy_loss:0.959675
# epoch:126 loss:0.518865 accu:0.734375 |xentropy_loss:6.207492 xentropy_loss:0.956030
# epoch:127 loss:0.575119 accu:0.687500 |xentropy_loss:6.431926 xentropy_loss:0.907987
# epoch:128 loss:0.584749 accu:0.652344 |xentropy_loss:6.491951 xentropy_loss:0.871793
# epoch:129 loss:0.622735 accu:0.656250 |xentropy_loss:5.884778 xentropy_loss:0.885983
# epoch:130 loss:0.525984 accu:0.738281 |xentropy_loss:5.608283 xentropy_loss:0.944730
# epoch:131 loss:0.578422 accu:0.667969 |xentropy_loss:5.618779 xentropy_loss:0.964714
# epoch:132 loss:0.509472 accu:0.730469 |xentropy_loss:6.067738 xentropy_loss:1.007108
# epoch:133 loss:0.588361 accu:0.589844 |xentropy_loss:5.883307 xentropy_loss:0.901305
# epoch:134 loss:0.500544 accu:0.730469 |xentropy_loss:5.464952 xentropy_loss:0.937523
# epoch:135 loss:0.621761 accu:0.632812 |xentropy_loss:5.978240 xentropy_loss:0.885251
# epoch:136 loss:0.543854 accu:0.699219 |xentropy_loss:5.783908 xentropy_loss:0.918949
# epoch:137 loss:0.580815 accu:0.632812 |xentropy_loss:6.686755 xentropy_loss:0.906174
# epoch:138 loss:0.585546 accu:0.656250 |xentropy_loss:5.864742 xentropy_loss:0.907744
# epoch:139 loss:0.511021 accu:0.722656 |xentropy_loss:5.954330 xentropy_loss:0.916574
# epoch:140 loss:0.709552 accu:0.550781 |xentropy_loss:4.346188 xentropy_loss:0.820306
# epoch:141 loss:0.570753 accu:0.691406 |xentropy_loss:5.605684 xentropy_loss:0.874026
# epoch:142 loss:0.636973 accu:0.656250 |xentropy_loss:5.251951 xentropy_loss:0.842848
# epoch:143 loss:0.549120 accu:0.710938 |xentropy_loss:5.239557 xentropy_loss:0.812187
# epoch:144 loss:0.588026 accu:0.683594 |xentropy_loss:5.037965 xentropy_loss:0.867195
# epoch:145 loss:0.589661 accu:0.675781 |xentropy_loss:4.931755 xentropy_loss:0.894075
# epoch:146 loss:0.571932 accu:0.636719 |xentropy_loss:5.281551 xentropy_loss:0.864348
# epoch:147 loss:0.572281 accu:0.644531 |xentropy_loss:4.700380 xentropy_loss:0.859746
# epoch:148 loss:0.553948 accu:0.703125 |xentropy_loss:5.352843 xentropy_loss:0.895017
# epoch:149 loss:0.565981 accu:0.687500 |xentropy_loss:4.189752 xentropy_loss:0.911054
# epoch:150 loss:0.577647 accu:0.707031 |xentropy_loss:4.532440 xentropy_loss:0.949942
# epoch:151 loss:0.642394 accu:0.578125 |xentropy_loss:4.913893 xentropy_loss:0.883951
# epoch:152 loss:0.627485 accu:0.632812 |xentropy_loss:4.638667 xentropy_loss:0.868640
# epoch:153 loss:0.551995 accu:0.699219 |xentropy_loss:4.855616 xentropy_loss:0.870783
# epoch:154 loss:0.570595 accu:0.648438 |xentropy_loss:5.483890 xentropy_loss:0.876391
# epoch:155 loss:0.578039 accu:0.667969 |xentropy_loss:4.424359 xentropy_loss:0.856812
# epoch:156 loss:0.533234 accu:0.703125 |xentropy_loss:4.576518 xentropy_loss:0.891113
# epoch:157 loss:0.504762 accu:0.785156 |xentropy_loss:4.992476 xentropy_loss:0.936766
# epoch:158 loss:0.572002 accu:0.699219 |xentropy_loss:4.928240 xentropy_loss:0.900982
# epoch:159 loss:0.629165 accu:0.628906 |xentropy_loss:4.605121 xentropy_loss:0.877931
# epoch:160 loss:0.545990 accu:0.714844 |xentropy_loss:4.990016 xentropy_loss:0.851975
# epoch:161 loss:0.591039 accu:0.675781 |xentropy_loss:4.968639 xentropy_loss:0.863564
# epoch:162 loss:0.595686 accu:0.621094 |xentropy_loss:4.999083 xentropy_loss:0.954422
# epoch:163 loss:0.632836 accu:0.625000 |xentropy_loss:4.466898 xentropy_loss:0.857806
# epoch:164 loss:0.558318 accu:0.664062 |xentropy_loss:4.822002 xentropy_loss:0.904119
# epoch:165 loss:0.578562 accu:0.648438 |xentropy_loss:4.597427 xentropy_loss:0.922448
# epoch:166 loss:0.566719 accu:0.687500 |xentropy_loss:4.753916 xentropy_loss:0.853079
# epoch:167 loss:0.620439 accu:0.613281 |xentropy_loss:4.013082 xentropy_loss:0.790518
# epoch:168 loss:0.602029 accu:0.621094 |xentropy_loss:4.493248 xentropy_loss:0.799417
# epoch:169 loss:0.608670 accu:0.621094 |xentropy_loss:4.337113 xentropy_loss:0.825675
# epoch:170 loss:0.566737 accu:0.675781 |xentropy_loss:4.242160 xentropy_loss:0.882909
# epoch:171 loss:0.603097 accu:0.671875 |xentropy_loss:5.253053 xentropy_loss:0.886793
# epoch:172 loss:0.541852 accu:0.707031 |xentropy_loss:4.578143 xentropy_loss:0.907055
# epoch:173 loss:0.629858 accu:0.605469 |xentropy_loss:4.906778 xentropy_loss:0.913651
# epoch:174 loss:0.597151 accu:0.656250 |xentropy_loss:4.404054 xentropy_loss:0.864083
# epoch:175 loss:0.614370 accu:0.656250 |xentropy_loss:4.386969 xentropy_loss:0.860004
# epoch:176 loss:0.604330 accu:0.656250 |xentropy_loss:4.176569 xentropy_loss:0.893842
# epoch:177 loss:0.604477 accu:0.679688 |xentropy_loss:4.097062 xentropy_loss:0.865283
# epoch:178 loss:0.582732 accu:0.683594 |xentropy_loss:4.517930 xentropy_loss:0.844818
# epoch:179 loss:0.607278 accu:0.652344 |xentropy_loss:4.089342 xentropy_loss:0.841028
# epoch:180 loss:0.592429 accu:0.617188 |xentropy_loss:4.564932 xentropy_loss:0.843619
# epoch:181 loss:0.592349 accu:0.679688 |xentropy_loss:4.370966 xentropy_loss:0.877024
# epoch:182 loss:0.542031 accu:0.750000 |xentropy_loss:4.265394 xentropy_loss:0.864442
# epoch:183 loss:0.602890 accu:0.679688 |xentropy_loss:4.986327 xentropy_loss:0.867483
# epoch:184 loss:0.576609 accu:0.671875 |xentropy_loss:4.643023 xentropy_loss:0.862278
# epoch:185 loss:0.638741 accu:0.570312 |xentropy_loss:4.465704 xentropy_loss:0.850923
# epoch:186 loss:0.629256 accu:0.570312 |xentropy_loss:4.645271 xentropy_loss:0.867823
# epoch:187 loss:0.631645 accu:0.613281 |xentropy_loss:4.278517 xentropy_loss:0.843000
# epoch:188 loss:0.644935 accu:0.562500 |xentropy_loss:4.130424 xentropy_loss:0.842820
# epoch:189 loss:0.614233 accu:0.636719 |xentropy_loss:3.869916 xentropy_loss:0.823022
# epoch:190 loss:0.647371 accu:0.589844 |xentropy_loss:3.010221 xentropy_loss:0.855161
# epoch:191 loss:0.600732 accu:0.660156 |xentropy_loss:4.245271 xentropy_loss:0.853646
# epoch:192 loss:0.588568 accu:0.664062 |xentropy_loss:4.141705 xentropy_loss:0.857598
# epoch:193 loss:0.597306 accu:0.640625 |xentropy_loss:3.651606 xentropy_loss:0.845797
# epoch:194 loss:0.627735 accu:0.593750 |xentropy_loss:4.032255 xentropy_loss:0.885722
# epoch:195 loss:0.625112 accu:0.601562 |xentropy_loss:4.048429 xentropy_loss:0.856629
# epoch:196 loss:0.591389 accu:0.640625 |xentropy_loss:3.691546 xentropy_loss:0.853827
# epoch:197 loss:0.637530 accu:0.593750 |xentropy_loss:4.073858 xentropy_loss:0.844115
# epoch:198 loss:0.642574 accu:0.574219 |xentropy_loss:3.248251 xentropy_loss:0.854963
# epoch:199 loss:0.655706 accu:0.570312 |xentropy_loss:3.519449 xentropy_loss:0.859189
# epoch:200 loss:0.646513 accu:0.593750 |xentropy_loss:3.507724 xentropy_loss:0.863110
# epoch:201 loss:0.602177 accu:0.656250 |xentropy_loss:3.799437 xentropy_loss:0.848340
# epoch:202 loss:0.603841 accu:0.667969 |xentropy_loss:3.974969 xentropy_loss:0.886202
# epoch:203 loss:0.625974 accu:0.617188 |xentropy_loss:3.463038 xentropy_loss:0.884564
# epoch:204 loss:0.650230 accu:0.582031 |xentropy_loss:3.330942 xentropy_loss:0.866033
# epoch:205 loss:0.605380 accu:0.679688 |xentropy_loss:3.989462 xentropy_loss:0.859484
# epoch:206 loss:0.647096 accu:0.601562 |xentropy_loss:3.391325 xentropy_loss:0.842733
# epoch:207 loss:0.652536 accu:0.617188 |xentropy_loss:3.945213 xentropy_loss:0.881620
# epoch:208 loss:0.646757 accu:0.601562 |xentropy_loss:3.537750 xentropy_loss:0.832496
# epoch:209 loss:0.629017 accu:0.566406 |xentropy_loss:3.669160 xentropy_loss:0.844782
# epoch:210 loss:0.635497 accu:0.589844 |xentropy_loss:3.522827 xentropy_loss:0.846630
# epoch:211 loss:0.623074 accu:0.648438 |xentropy_loss:3.799749 xentropy_loss:0.848713
# epoch:212 loss:0.611311 accu:0.648438 |xentropy_loss:3.406446 xentropy_loss:0.866337
# epoch:213 loss:0.599742 accu:0.652344 |xentropy_loss:3.540463 xentropy_loss:0.893744
# epoch:214 loss:0.613393 accu:0.656250 |xentropy_loss:3.956257 xentropy_loss:0.863878
# epoch:215 loss:0.617056 accu:0.625000 |xentropy_loss:4.271384 xentropy_loss:0.902662
# epoch:216 loss:0.575885 accu:0.667969 |xentropy_loss:3.452010 xentropy_loss:0.894725
# epoch:217 loss:0.587232 accu:0.679688 |xentropy_loss:3.278028 xentropy_loss:0.893784
# epoch:218 loss:0.593840 accu:0.683594 |xentropy_loss:4.030916 xentropy_loss:0.882900
# epoch:219 loss:0.605447 accu:0.675781 |xentropy_loss:3.208038 xentropy_loss:0.860743
# epoch:220 loss:0.624039 accu:0.625000 |xentropy_loss:3.280537 xentropy_loss:0.888309
# epoch:221 loss:0.577587 accu:0.699219 |xentropy_loss:3.586001 xentropy_loss:0.953500
# epoch:222 loss:0.603249 accu:0.656250 |xentropy_loss:3.585262 xentropy_loss:0.873775
# epoch:223 loss:0.637504 accu:0.628906 |xentropy_loss:3.100971 xentropy_loss:0.845642
# epoch:224 loss:0.601558 accu:0.683594 |xentropy_loss:2.968897 xentropy_loss:0.857787
# epoch:225 loss:0.610598 accu:0.648438 |xentropy_loss:4.059227 xentropy_loss:0.885852
# epoch:226 loss:0.582921 accu:0.703125 |xentropy_loss:2.856802 xentropy_loss:0.881712
# epoch:227 loss:0.591492 accu:0.664062 |xentropy_loss:3.744922 xentropy_loss:0.883375
# epoch:228 loss:0.581503 accu:0.710938 |xentropy_loss:3.363008 xentropy_loss:0.926821
# epoch:229 loss:0.611314 accu:0.667969 |xentropy_loss:3.536028 xentropy_loss:0.860448
# epoch:230 loss:0.626101 accu:0.648438 |xentropy_loss:3.202436 xentropy_loss:0.841517
# epoch:231 loss:0.595112 accu:0.679688 |xentropy_loss:3.289003 xentropy_loss:0.857731
# epoch:232 loss:0.633252 accu:0.640625 |xentropy_loss:3.308605 xentropy_loss:0.867657
# epoch:233 loss:0.570927 accu:0.707031 |xentropy_loss:3.362232 xentropy_loss:0.894558
# epoch:234 loss:0.636459 accu:0.605469 |xentropy_loss:3.356253 xentropy_loss:0.906740
# epoch:235 loss:0.590756 accu:0.703125 |xentropy_loss:3.257630 xentropy_loss:0.929951
# epoch:236 loss:0.640627 accu:0.609375 |xentropy_loss:3.564111 xentropy_loss:0.884148
# epoch:237 loss:0.639866 accu:0.656250 |xentropy_loss:3.367967 xentropy_loss:0.848706
# epoch:238 loss:0.609409 accu:0.656250 |xentropy_loss:3.376452 xentropy_loss:0.855769
# epoch:239 loss:0.602387 accu:0.671875 |xentropy_loss:3.568356 xentropy_loss:0.864681
# epoch:240 loss:0.604002 accu:0.625000 |xentropy_loss:3.115100 xentropy_loss:0.909995
# epoch:241 loss:0.606140 accu:0.632812 |xentropy_loss:2.889803 xentropy_loss:0.876822
# epoch:242 loss:0.620100 accu:0.632812 |xentropy_loss:2.825072 xentropy_loss:0.907278
# epoch:243 loss:0.618422 accu:0.652344 |xentropy_loss:2.581743 xentropy_loss:0.805898
# epoch:244 loss:0.601555 accu:0.636719 |xentropy_loss:3.436270 xentropy_loss:0.819241
# epoch:245 loss:0.581132 accu:0.667969 |xentropy_loss:2.729006 xentropy_loss:0.852589
# epoch:246 loss:0.568233 accu:0.699219 |xentropy_loss:3.164714 xentropy_loss:0.869046
# epoch:247 loss:0.610421 accu:0.589844 |xentropy_loss:3.500040 xentropy_loss:0.876136
# epoch:248 loss:0.597864 accu:0.648438 |xentropy_loss:3.218243 xentropy_loss:0.885168
# epoch:249 loss:0.620497 accu:0.609375 |xentropy_loss:3.541877 xentropy_loss:0.886599
# epoch:250 loss:0.619418 accu:0.613281 |xentropy_loss:2.736504 xentropy_loss:0.900807
# epoch:251 loss:0.621731 accu:0.656250 |xentropy_loss:3.658376 xentropy_loss:0.877495
# epoch:252 loss:0.624659 accu:0.644531 |xentropy_loss:2.994530 xentropy_loss:0.822460
# epoch:253 loss:0.576178 accu:0.695312 |xentropy_loss:3.290892 xentropy_loss:0.877554
# epoch:254 loss:0.622423 accu:0.589844 |xentropy_loss:3.532269 xentropy_loss:0.850049
# epoch:255 loss:0.596052 accu:0.632812 |xentropy_loss:3.441359 xentropy_loss:0.866727
# epoch:256 loss:0.560277 accu:0.683594 |xentropy_loss:3.536392 xentropy_loss:0.863760
# epoch:257 loss:0.617667 accu:0.609375 |xentropy_loss:3.381215 xentropy_loss:0.864570
# epoch:258 loss:0.627800 accu:0.644531 |xentropy_loss:3.170380 xentropy_loss:0.849310
# epoch:259 loss:0.597324 accu:0.640625 |xentropy_loss:2.981964 xentropy_loss:0.874923
# epoch:260 loss:0.602395 accu:0.652344 |xentropy_loss:3.084490 xentropy_loss:0.856867
# epoch:261 loss:0.600884 accu:0.664062 |xentropy_loss:3.261155 xentropy_loss:0.876421
# epoch:262 loss:0.602612 accu:0.628906 |xentropy_loss:3.307221 xentropy_loss:0.868707
# epoch:263 loss:0.606864 accu:0.628906 |xentropy_loss:3.383104 xentropy_loss:0.838728
# epoch:264 loss:0.616475 accu:0.667969 |xentropy_loss:3.262243 xentropy_loss:0.859681
# epoch:265 loss:0.603938 accu:0.664062 |xentropy_loss:2.742735 xentropy_loss:0.834188
# epoch:266 loss:0.577878 accu:0.687500 |xentropy_loss:3.246886 xentropy_loss:0.837719
# epoch:267 loss:0.598435 accu:0.640625 |xentropy_loss:3.154862 xentropy_loss:0.832753
# epoch:268 loss:0.623524 accu:0.625000 |xentropy_loss:2.882191 xentropy_loss:0.874522
# epoch:269 loss:0.547976 accu:0.710938 |xentropy_loss:3.466193 xentropy_loss:0.922010
# epoch:270 loss:0.592124 accu:0.683594 |xentropy_loss:2.870687 xentropy_loss:0.852438
# epoch:271 loss:0.556424 accu:0.726562 |xentropy_loss:2.840254 xentropy_loss:0.827284
# epoch:272 loss:0.591006 accu:0.632812 |xentropy_loss:3.135102 xentropy_loss:0.824510
# epoch:273 loss:0.646527 accu:0.523438 |xentropy_loss:2.908771 xentropy_loss:0.811734
# epoch:274 loss:0.570508 accu:0.703125 |xentropy_loss:2.733381 xentropy_loss:0.841131
# epoch:275 loss:0.586506 accu:0.691406 |xentropy_loss:3.359033 xentropy_loss:0.835261
# epoch:276 loss:0.606903 accu:0.656250 |xentropy_loss:2.991178 xentropy_loss:0.845723
# epoch:277 loss:0.565803 accu:0.726562 |xentropy_loss:3.280510 xentropy_loss:0.862145
# epoch:278 loss:0.571536 accu:0.683594 |xentropy_loss:2.784790 xentropy_loss:0.864627
# epoch:279 loss:0.584173 accu:0.695312 |xentropy_loss:3.027046 xentropy_loss:0.858784
# epoch:280 loss:0.583393 accu:0.671875 |xentropy_loss:3.174437 xentropy_loss:0.878246
# epoch:281 loss:0.586935 accu:0.675781 |xentropy_loss:2.946082 xentropy_loss:0.885651
# epoch:282 loss:0.564277 accu:0.734375 |xentropy_loss:2.961721 xentropy_loss:0.886008
# epoch:283 loss:0.564940 accu:0.714844 |xentropy_loss:2.591519 xentropy_loss:0.870744
# epoch:284 loss:0.594050 accu:0.644531 |xentropy_loss:3.099139 xentropy_loss:0.879004
# epoch:285 loss:0.584195 accu:0.722656 |xentropy_loss:3.434489 xentropy_loss:0.867263
# epoch:286 loss:0.615897 accu:0.648438 |xentropy_loss:2.831497 xentropy_loss:0.840820
# epoch:287 loss:0.583248 accu:0.683594 |xentropy_loss:2.764848 xentropy_loss:0.926496
# epoch:288 loss:0.587482 accu:0.695312 |xentropy_loss:2.946218 xentropy_loss:0.904595
# epoch:289 loss:0.598385 accu:0.726562 |xentropy_loss:2.851933 xentropy_loss:0.876635
# epoch:290 loss:0.580285 accu:0.691406 |xentropy_loss:2.841219 xentropy_loss:0.860344
# epoch:291 loss:0.591325 accu:0.667969 |xentropy_loss:2.526009 xentropy_loss:0.902078
# epoch:292 loss:0.588911 accu:0.652344 |xentropy_loss:2.942561 xentropy_loss:0.912135
# epoch:293 loss:0.571282 accu:0.695312 |xentropy_loss:2.544156 xentropy_loss:0.922104
# epoch:294 loss:0.602001 accu:0.640625 |xentropy_loss:2.692943 xentropy_loss:0.883356
# epoch:295 loss:0.563364 accu:0.699219 |xentropy_loss:2.935905 xentropy_loss:0.914410
# epoch:296 loss:0.627550 accu:0.609375 |xentropy_loss:2.804171 xentropy_loss:0.900005
# epoch:297 loss:0.572782 accu:0.718750 |xentropy_loss:2.980231 xentropy_loss:0.949264
# epoch:298 loss:0.585421 accu:0.726562 |xentropy_loss:3.041346 xentropy_loss:0.924103
# epoch:299 loss:0.605828 accu:0.660156 |xentropy_loss:3.047512 xentropy_loss:0.909283
# epoch:300 loss:0.610359 accu:0.644531 |xentropy_loss:2.620496 xentropy_loss:0.908864
# epoch:301 loss:0.586874 accu:0.714844 |xentropy_loss:3.279675 xentropy_loss:0.905170
# epoch:302 loss:0.587527 accu:0.703125 |xentropy_loss:2.654926 xentropy_loss:0.874278
# epoch:303 loss:0.578339 accu:0.718750 |xentropy_loss:3.327827 xentropy_loss:0.915313
# epoch:304 loss:0.582202 accu:0.730469 |xentropy_loss:3.350886 xentropy_loss:0.909573
# epoch:305 loss:0.555436 accu:0.726562 |xentropy_loss:2.961510 xentropy_loss:0.882228
# epoch:306 loss:0.574924 accu:0.699219 |xentropy_loss:2.972694 xentropy_loss:0.904955
# epoch:307 loss:0.564161 accu:0.738281 |xentropy_loss:2.814891 xentropy_loss:0.939816
# epoch:308 loss:0.598059 accu:0.683594 |xentropy_loss:2.940311 xentropy_loss:0.922055
# epoch:309 loss:0.604842 accu:0.671875 |xentropy_loss:2.814119 xentropy_loss:0.874131
# epoch:310 loss:0.621228 accu:0.617188 |xentropy_loss:2.678770 xentropy_loss:0.900101
# epoch:311 loss:0.562958 accu:0.781250 |xentropy_loss:3.350358 xentropy_loss:0.928411
# epoch:312 loss:0.577173 accu:0.722656 |xentropy_loss:2.585773 xentropy_loss:0.919875
# epoch:313 loss:0.575234 accu:0.695312 |xentropy_loss:2.801577 xentropy_loss:0.892276
# epoch:314 loss:0.587236 accu:0.683594 |xentropy_loss:3.214583 xentropy_loss:0.877486
# epoch:315 loss:0.568934 accu:0.730469 |xentropy_loss:2.786316 xentropy_loss:0.903136
# epoch:316 loss:0.540113 accu:0.765625 |xentropy_loss:3.229091 xentropy_loss:0.911579
# epoch:317 loss:0.583722 accu:0.687500 |xentropy_loss:2.533128 xentropy_loss:0.866110
# epoch:318 loss:0.566606 accu:0.718750 |xentropy_loss:2.826050 xentropy_loss:0.887155
# epoch:319 loss:0.571379 accu:0.687500 |xentropy_loss:2.831275 xentropy_loss:0.914103
# epoch:320 loss:0.588814 accu:0.660156 |xentropy_loss:2.636285 xentropy_loss:0.922314
# epoch:321 loss:0.626019 accu:0.632812 |xentropy_loss:2.440861 xentropy_loss:0.875168
# epoch:322 loss:0.612275 accu:0.632812 |xentropy_loss:2.240604 xentropy_loss:0.863545
# epoch:323 loss:0.599755 accu:0.671875 |xentropy_loss:3.024724 xentropy_loss:0.864906
# epoch:324 loss:0.540586 accu:0.781250 |xentropy_loss:2.533624 xentropy_loss:0.905279
# epoch:325 loss:0.592028 accu:0.726562 |xentropy_loss:2.480558 xentropy_loss:0.897870
# epoch:326 loss:0.577217 accu:0.718750 |xentropy_loss:2.794333 xentropy_loss:0.909206
# epoch:327 loss:0.586434 accu:0.703125 |xentropy_loss:2.463852 xentropy_loss:0.896695
# epoch:328 loss:0.665726 accu:0.609375 |xentropy_loss:2.350178 xentropy_loss:0.846676
# epoch:329 loss:0.612194 accu:0.640625 |xentropy_loss:2.600418 xentropy_loss:0.878824
# epoch:330 loss:0.596846 accu:0.675781 |xentropy_loss:2.883677 xentropy_loss:0.872673
# epoch:331 loss:0.581187 accu:0.746094 |xentropy_loss:2.404685 xentropy_loss:0.862817
# epoch:332 loss:0.606157 accu:0.675781 |xentropy_loss:2.445452 xentropy_loss:0.903711
# epoch:333 loss:0.582382 accu:0.707031 |xentropy_loss:2.605437 xentropy_loss:0.892418
# epoch:334 loss:0.591503 accu:0.664062 |xentropy_loss:2.354777 xentropy_loss:0.865710
# epoch:335 loss:0.564636 accu:0.726562 |xentropy_loss:2.546475 xentropy_loss:0.929151
# epoch:336 loss:0.623310 accu:0.664062 |xentropy_loss:2.588841 xentropy_loss:0.898115
# epoch:337 loss:0.568493 accu:0.734375 |xentropy_loss:2.738797 xentropy_loss:0.900521
# epoch:338 loss:0.580768 accu:0.695312 |xentropy_loss:2.429638 xentropy_loss:0.866940
# epoch:339 loss:0.605655 accu:0.695312 |xentropy_loss:2.371398 xentropy_loss:0.883589
# epoch:340 loss:0.585355 accu:0.722656 |xentropy_loss:2.452892 xentropy_loss:0.864351
# epoch:341 loss:0.592292 accu:0.660156 |xentropy_loss:2.296868 xentropy_loss:0.851664
# epoch:342 loss:0.581990 accu:0.722656 |xentropy_loss:2.128794 xentropy_loss:0.858640
# epoch:343 loss:0.547498 accu:0.753906 |xentropy_loss:2.351471 xentropy_loss:0.913918
# epoch:344 loss:0.572268 accu:0.738281 |xentropy_loss:2.437596 xentropy_loss:0.910589
# epoch:345 loss:0.585901 accu:0.695312 |xentropy_loss:2.528573 xentropy_loss:0.915562
# epoch:346 loss:0.590815 accu:0.691406 |xentropy_loss:2.192613 xentropy_loss:0.925202
# epoch:347 loss:0.585195 accu:0.742188 |xentropy_loss:2.330958 xentropy_loss:0.905796
# epoch:348 loss:0.565847 accu:0.742188 |xentropy_loss:2.390149 xentropy_loss:0.911481
# epoch:349 loss:0.540610 accu:0.761719 |xentropy_loss:2.443970 xentropy_loss:0.904009
# epoch:350 loss:0.557696 accu:0.761719 |xentropy_loss:2.414604 xentropy_loss:0.905275
# epoch:351 loss:0.591446 accu:0.718750 |xentropy_loss:2.185460 xentropy_loss:0.905969
# epoch:352 loss:0.550296 accu:0.757812 |xentropy_loss:2.315553 xentropy_loss:0.939146
# epoch:353 loss:0.556835 accu:0.750000 |xentropy_loss:2.337498 xentropy_loss:0.932946
# epoch:354 loss:0.578080 accu:0.718750 |xentropy_loss:2.495439 xentropy_loss:0.884265
# epoch:355 loss:0.589796 accu:0.687500 |xentropy_loss:2.297781 xentropy_loss:0.886102
# epoch:356 loss:0.589519 accu:0.699219 |xentropy_loss:2.176199 xentropy_loss:0.859234
# epoch:357 loss:0.573571 accu:0.726562 |xentropy_loss:2.132890 xentropy_loss:0.877426
# epoch:358 loss:0.577302 accu:0.730469 |xentropy_loss:2.179410 xentropy_loss:0.884224
# epoch:359 loss:0.598235 accu:0.675781 |xentropy_loss:2.202160 xentropy_loss:0.885713
# epoch:360 loss:0.565453 accu:0.722656 |xentropy_loss:2.356827 xentropy_loss:0.950071
# epoch:361 loss:0.591461 accu:0.667969 |xentropy_loss:2.296711 xentropy_loss:0.869401
# epoch:362 loss:0.589610 accu:0.710938 |xentropy_loss:2.272065 xentropy_loss:0.832122
# epoch:363 loss:0.568664 accu:0.707031 |xentropy_loss:2.343871 xentropy_loss:0.910223
# epoch:364 loss:0.622896 accu:0.652344 |xentropy_loss:2.158242 xentropy_loss:0.889368
# epoch:365 loss:0.584255 accu:0.726562 |xentropy_loss:2.404416 xentropy_loss:0.921431
# epoch:366 loss:0.545018 accu:0.746094 |xentropy_loss:2.249590 xentropy_loss:0.915332
# epoch:367 loss:0.570760 accu:0.687500 |xentropy_loss:2.230844 xentropy_loss:0.899625
# epoch:368 loss:0.573069 accu:0.738281 |xentropy_loss:2.592827 xentropy_loss:0.941236
# epoch:369 loss:0.575490 accu:0.699219 |xentropy_loss:2.286459 xentropy_loss:0.929338
# epoch:370 loss:0.597620 accu:0.671875 |xentropy_loss:2.357991 xentropy_loss:0.895158
# epoch:371 loss:0.578809 accu:0.730469 |xentropy_loss:2.203791 xentropy_loss:0.938548
# epoch:372 loss:0.587045 accu:0.722656 |xentropy_loss:2.230673 xentropy_loss:0.892279
# epoch:373 loss:0.620645 accu:0.652344 |xentropy_loss:2.061108 xentropy_loss:0.876149
# epoch:374 loss:0.603563 accu:0.687500 |xentropy_loss:2.162123 xentropy_loss:0.901406
# epoch:375 loss:0.580554 accu:0.726562 |xentropy_loss:2.266936 xentropy_loss:0.914336
# epoch:376 loss:0.596909 accu:0.707031 |xentropy_loss:2.417644 xentropy_loss:0.927488
# epoch:377 loss:0.585041 accu:0.722656 |xentropy_loss:2.282231 xentropy_loss:0.901220
# epoch:378 loss:0.588784 accu:0.683594 |xentropy_loss:2.075395 xentropy_loss:0.880011
# epoch:379 loss:0.623759 accu:0.644531 |xentropy_loss:1.947078 xentropy_loss:0.876198
# epoch:380 loss:0.610183 accu:0.664062 |xentropy_loss:2.217356 xentropy_loss:0.883314
# epoch:381 loss:0.595755 accu:0.664062 |xentropy_loss:2.229847 xentropy_loss:0.915780
# epoch:382 loss:0.609321 accu:0.683594 |xentropy_loss:2.189778 xentropy_loss:0.860696
# epoch:383 loss:0.617229 accu:0.660156 |xentropy_loss:2.109462 xentropy_loss:0.872789
# epoch:384 loss:0.594917 accu:0.695312 |xentropy_loss:2.177621 xentropy_loss:0.848963
# epoch:385 loss:0.587633 accu:0.707031 |xentropy_loss:2.000156 xentropy_loss:0.879028
# epoch:386 loss:0.587458 accu:0.691406 |xentropy_loss:2.096678 xentropy_loss:0.873082
# epoch:387 loss:0.677157 accu:0.546875 |xentropy_loss:2.291936 xentropy_loss:0.855751
# epoch:388 loss:0.598876 accu:0.671875 |xentropy_loss:2.159904 xentropy_loss:0.886078
# epoch:389 loss:0.635838 accu:0.636719 |xentropy_loss:2.183362 xentropy_loss:0.846648
# epoch:390 loss:0.600129 accu:0.664062 |xentropy_loss:2.018134 xentropy_loss:0.858450
# epoch:391 loss:0.589844 accu:0.687500 |xentropy_loss:2.210699 xentropy_loss:0.889156
# epoch:392 loss:0.600721 accu:0.671875 |xentropy_loss:2.082629 xentropy_loss:0.873260
# epoch:393 loss:0.612753 accu:0.644531 |xentropy_loss:2.121315 xentropy_loss:0.886553
# epoch:394 loss:0.644911 accu:0.597656 |xentropy_loss:2.024283 xentropy_loss:0.861029
# epoch:395 loss:0.605467 accu:0.652344 |xentropy_loss:2.078493 xentropy_loss:0.872423
# epoch:396 loss:0.614727 accu:0.652344 |xentropy_loss:2.349994 xentropy_loss:0.849873
# epoch:397 loss:0.589544 accu:0.714844 |xentropy_loss:2.123719 xentropy_loss:0.892062
# epoch:398 loss:0.625211 accu:0.621094 |xentropy_loss:2.108369 xentropy_loss:0.863226
# epoch:399 loss:0.582968 accu:0.667969 |xentropy_loss:2.016433 xentropy_loss:0.882219
# epoch:400 loss:0.635659 accu:0.656250 |xentropy_loss:1.874436 xentropy_loss:0.851595
# epoch:401 loss:0.600085 accu:0.660156 |xentropy_loss:2.020578 xentropy_loss:0.842535
# epoch:402 loss:0.562514 accu:0.742188 |xentropy_loss:2.279024 xentropy_loss:0.920734
# epoch:403 loss:0.642209 accu:0.617188 |xentropy_loss:2.227933 xentropy_loss:0.877688
# epoch:404 loss:0.629942 accu:0.648438 |xentropy_loss:2.028617 xentropy_loss:0.836651
# epoch:405 loss:0.595766 accu:0.699219 |xentropy_loss:2.042780 xentropy_loss:0.863406
# epoch:406 loss:0.591885 accu:0.738281 |xentropy_loss:2.068000 xentropy_loss:0.846417
# epoch:407 loss:0.641763 accu:0.597656 |xentropy_loss:1.865825 xentropy_loss:0.874552
# epoch:408 loss:0.587526 accu:0.671875 |xentropy_loss:2.021907 xentropy_loss:0.881344
# epoch:409 loss:0.596133 accu:0.691406 |xentropy_loss:2.172452 xentropy_loss:0.881213
# epoch:410 loss:0.588977 accu:0.714844 |xentropy_loss:2.068536 xentropy_loss:0.900781
# epoch:411 loss:0.562360 accu:0.742188 |xentropy_loss:2.214271 xentropy_loss:0.904034
# epoch:412 loss:0.592995 accu:0.710938 |xentropy_loss:2.176241 xentropy_loss:0.929992
# epoch:413 loss:0.600783 accu:0.683594 |xentropy_loss:2.004260 xentropy_loss:0.887144
# epoch:414 loss:0.604770 accu:0.683594 |xentropy_loss:2.034074 xentropy_loss:0.862637
# epoch:415 loss:0.617681 accu:0.636719 |xentropy_loss:1.946074 xentropy_loss:0.866948
# epoch:416 loss:0.568386 accu:0.742188 |xentropy_loss:2.205170 xentropy_loss:0.907744
# epoch:417 loss:0.615018 accu:0.652344 |xentropy_loss:1.992602 xentropy_loss:0.890672
# epoch:418 loss:0.603516 accu:0.679688 |xentropy_loss:2.100612 xentropy_loss:0.903166
# epoch:419 loss:0.607906 accu:0.710938 |xentropy_loss:2.076460 xentropy_loss:0.884426
# epoch:420 loss:0.614141 accu:0.656250 |xentropy_loss:2.055305 xentropy_loss:0.872000
# epoch:421 loss:0.618328 accu:0.644531 |xentropy_loss:2.152309 xentropy_loss:0.893599
# epoch:422 loss:0.600232 accu:0.679688 |xentropy_loss:2.105221 xentropy_loss:0.881692
# epoch:423 loss:0.611750 accu:0.671875 |xentropy_loss:2.052412 xentropy_loss:0.877933
# epoch:424 loss:0.587063 accu:0.671875 |xentropy_loss:1.937495 xentropy_loss:0.886160
# epoch:425 loss:0.588277 accu:0.691406 |xentropy_loss:2.060186 xentropy_loss:0.901792
# epoch:426 loss:0.577852 accu:0.699219 |xentropy_loss:1.965691 xentropy_loss:0.884272
# epoch:427 loss:0.594001 accu:0.687500 |xentropy_loss:2.017104 xentropy_loss:0.893615
# epoch:428 loss:0.613381 accu:0.636719 |xentropy_loss:2.143566 xentropy_loss:0.876903
# epoch:429 loss:0.604650 accu:0.667969 |xentropy_loss:2.178040 xentropy_loss:0.883878
# epoch:430 loss:0.579793 accu:0.714844 |xentropy_loss:2.061349 xentropy_loss:0.902408
# epoch:431 loss:0.587162 accu:0.679688 |xentropy_loss:2.069260 xentropy_loss:0.886602
# epoch:432 loss:0.601729 accu:0.664062 |xentropy_loss:2.127816 xentropy_loss:0.889041
# epoch:433 loss:0.630332 accu:0.628906 |xentropy_loss:1.990815 xentropy_loss:0.858582
# epoch:434 loss:0.627389 accu:0.636719 |xentropy_loss:2.039099 xentropy_loss:0.838291
# epoch:435 loss:0.640921 accu:0.613281 |xentropy_loss:1.929772 xentropy_loss:0.821526
# epoch:436 loss:0.622195 accu:0.644531 |xentropy_loss:2.076687 xentropy_loss:0.875018
# epoch:437 loss:0.658952 accu:0.617188 |xentropy_loss:2.032952 xentropy_loss:0.864259
# epoch:438 loss:0.626544 accu:0.625000 |xentropy_loss:1.977273 xentropy_loss:0.835779
# epoch:439 loss:0.588641 accu:0.667969 |xentropy_loss:2.130053 xentropy_loss:0.908370
# epoch:440 loss:0.595485 accu:0.648438 |xentropy_loss:2.110584 xentropy_loss:0.888295
# epoch:441 loss:0.615540 accu:0.671875 |xentropy_loss:2.024480 xentropy_loss:0.888305
# epoch:442 loss:0.613163 accu:0.644531 |xentropy_loss:2.155049 xentropy_loss:0.931459
# epoch:443 loss:0.648863 accu:0.609375 |xentropy_loss:2.232096 xentropy_loss:0.878421
# epoch:444 loss:0.635310 accu:0.625000 |xentropy_loss:2.020354 xentropy_loss:0.849309
# epoch:445 loss:0.625226 accu:0.625000 |xentropy_loss:1.987602 xentropy_loss:0.863778
# epoch:446 loss:0.603053 accu:0.660156 |xentropy_loss:2.062142 xentropy_loss:0.901500
# epoch:447 loss:0.588758 accu:0.707031 |xentropy_loss:2.121159 xentropy_loss:0.889834
# epoch:448 loss:0.631398 accu:0.640625 |xentropy_loss:2.178584 xentropy_loss:0.891039
# epoch:449 loss:0.633122 accu:0.617188 |xentropy_loss:2.147951 xentropy_loss:0.892122
# epoch:450 loss:0.629201 accu:0.628906 |xentropy_loss:2.021294 xentropy_loss:0.883122
# epoch:451 loss:0.610484 accu:0.703125 |xentropy_loss:2.068302 xentropy_loss:0.872933
# epoch:452 loss:0.602767 accu:0.656250 |xentropy_loss:2.072847 xentropy_loss:0.925589
# epoch:453 loss:0.583905 accu:0.710938 |xentropy_loss:2.076732 xentropy_loss:0.972232
# epoch:454 loss:0.625355 accu:0.652344 |xentropy_loss:2.020854 xentropy_loss:0.906107
# epoch:455 loss:0.623128 accu:0.648438 |xentropy_loss:1.981758 xentropy_loss:0.888246
# epoch:456 loss:0.612160 accu:0.656250 |xentropy_loss:2.097396 xentropy_loss:0.908704
# epoch:457 loss:0.625624 accu:0.640625 |xentropy_loss:2.178518 xentropy_loss:0.901835
# epoch:458 loss:0.613061 accu:0.675781 |xentropy_loss:1.970701 xentropy_loss:0.893256
# epoch:459 loss:0.640171 accu:0.609375 |xentropy_loss:1.945367 xentropy_loss:0.868595
# epoch:460 loss:0.612691 accu:0.691406 |xentropy_loss:2.019439 xentropy_loss:0.885238
# epoch:461 loss:0.633471 accu:0.632812 |xentropy_loss:1.908842 xentropy_loss:0.865349
# epoch:462 loss:0.611601 accu:0.656250 |xentropy_loss:1.965951 xentropy_loss:0.869121
# epoch:463 loss:0.615214 accu:0.632812 |xentropy_loss:1.954913 xentropy_loss:0.885315
# epoch:464 loss:0.620023 accu:0.656250 |xentropy_loss:1.975640 xentropy_loss:0.891117
# epoch:465 loss:0.609884 accu:0.687500 |xentropy_loss:2.068693 xentropy_loss:0.930832
# epoch:466 loss:0.600080 accu:0.679688 |xentropy_loss:2.039321 xentropy_loss:0.894355
# epoch:467 loss:0.618312 accu:0.667969 |xentropy_loss:1.946489 xentropy_loss:0.886377
# epoch:468 loss:0.636635 accu:0.593750 |xentropy_loss:1.896476 xentropy_loss:0.853035
# epoch:469 loss:0.623857 accu:0.625000 |xentropy_loss:1.904042 xentropy_loss:0.878435
# epoch:470 loss:0.602200 accu:0.695312 |xentropy_loss:1.961904 xentropy_loss:0.902875
# epoch:471 loss:0.607089 accu:0.652344 |xentropy_loss:1.939255 xentropy_loss:0.936714
# epoch:472 loss:0.582977 accu:0.730469 |xentropy_loss:2.062007 xentropy_loss:0.933880
# epoch:473 loss:0.617064 accu:0.636719 |xentropy_loss:1.887207 xentropy_loss:0.885288
# epoch:474 loss:0.597014 accu:0.730469 |xentropy_loss:1.939959 xentropy_loss:0.896384
# epoch:475 loss:0.641533 accu:0.574219 |xentropy_loss:2.018100 xentropy_loss:0.891672
# epoch:476 loss:0.585529 accu:0.753906 |xentropy_loss:2.071707 xentropy_loss:0.945417
# epoch:477 loss:0.614468 accu:0.656250 |xentropy_loss:1.921227 xentropy_loss:0.900850
# epoch:478 loss:0.619226 accu:0.664062 |xentropy_loss:1.942168 xentropy_loss:0.918296
# epoch:479 loss:0.604462 accu:0.691406 |xentropy_loss:1.981662 xentropy_loss:0.937063
# epoch:480 loss:0.599491 accu:0.679688 |xentropy_loss:1.981033 xentropy_loss:0.875424
# epoch:481 loss:0.598912 accu:0.714844 |xentropy_loss:1.928831 xentropy_loss:0.910266
# epoch:482 loss:0.603999 accu:0.644531 |xentropy_loss:1.890619 xentropy_loss:0.889001
# epoch:483 loss:0.561389 accu:0.761719 |xentropy_loss:1.988544 xentropy_loss:0.933038
# epoch:484 loss:0.582107 accu:0.718750 |xentropy_loss:2.028922 xentropy_loss:0.926443
# epoch:485 loss:0.638113 accu:0.617188 |xentropy_loss:1.887819 xentropy_loss:0.911793
# epoch:486 loss:0.629455 accu:0.613281 |xentropy_loss:1.957039 xentropy_loss:0.898482
# epoch:487 loss:0.624703 accu:0.636719 |xentropy_loss:1.849120 xentropy_loss:0.903467
# epoch:488 loss:0.619098 accu:0.621094 |xentropy_loss:1.849611 xentropy_loss:0.869150
# epoch:489 loss:0.625080 accu:0.656250 |xentropy_loss:1.910570 xentropy_loss:0.904956
# epoch:490 loss:0.596700 accu:0.691406 |xentropy_loss:1.912276 xentropy_loss:0.880074
# epoch:491 loss:0.592133 accu:0.679688 |xentropy_loss:2.078534 xentropy_loss:0.934971
# epoch:492 loss:0.565884 accu:0.765625 |xentropy_loss:2.032598 xentropy_loss:0.915268
# epoch:493 loss:0.592179 accu:0.695312 |xentropy_loss:2.033780 xentropy_loss:0.902224
# epoch:494 loss:0.623048 accu:0.601562 |xentropy_loss:2.013474 xentropy_loss:0.893886
# epoch:495 loss:0.629241 accu:0.625000 |xentropy_loss:1.911215 xentropy_loss:0.891370
# epoch:496 loss:0.642836 accu:0.617188 |xentropy_loss:1.831945 xentropy_loss:0.911713
# epoch:497 loss:0.642234 accu:0.593750 |xentropy_loss:1.977957 xentropy_loss:0.912208
# epoch:498 loss:0.674939 accu:0.546875 |xentropy_loss:2.060112 xentropy_loss:0.947183
# epoch:499 loss:0.618465 accu:0.679688 |xentropy_loss:2.078186 xentropy_loss:0.955268
# epoch:500 loss:0.650282 accu:0.601562 |xentropy_loss:1.869868 xentropy_loss:0.888724
# epoch:501 loss:0.613286 accu:0.671875 |xentropy_loss:1.941945 xentropy_loss:0.897439
# epoch:502 loss:0.639119 accu:0.617188 |xentropy_loss:1.936593 xentropy_loss:0.919075
# epoch:503 loss:0.662177 accu:0.601562 |xentropy_loss:1.969491 xentropy_loss:0.923278
# epoch:504 loss:0.641444 accu:0.632812 |xentropy_loss:1.958510 xentropy_loss:0.916890
# epoch:505 loss:0.643115 accu:0.613281 |xentropy_loss:1.941753 xentropy_loss:0.912803
# epoch:506 loss:0.633272 accu:0.628906 |xentropy_loss:1.909359 xentropy_loss:0.895321
# epoch:507 loss:0.634574 accu:0.597656 |xentropy_loss:2.021181 xentropy_loss:0.943746
# epoch:508 loss:0.654888 accu:0.582031 |xentropy_loss:1.945230 xentropy_loss:0.874258
# epoch:509 loss:0.662618 accu:0.593750 |xentropy_loss:1.881788 xentropy_loss:0.862791
# epoch:510 loss:0.656065 accu:0.593750 |xentropy_loss:1.732987 xentropy_loss:0.819321
# epoch:511 loss:0.631516 accu:0.621094 |xentropy_loss:1.894045 xentropy_loss:0.861562
# epoch:512 loss:0.644772 accu:0.574219 |xentropy_loss:1.852741 xentropy_loss:0.870616
# epoch:513 loss:0.631823 accu:0.613281 |xentropy_loss:1.987958 xentropy_loss:0.902863
# epoch:514 loss:0.608173 accu:0.664062 |xentropy_loss:2.007433 xentropy_loss:0.952542
# epoch:515 loss:0.617020 accu:0.687500 |xentropy_loss:1.873475 xentropy_loss:0.898233
# epoch:516 loss:0.623621 accu:0.632812 |xentropy_loss:1.838357 xentropy_loss:0.873822
# epoch:517 loss:0.623945 accu:0.648438 |xentropy_loss:1.789168 xentropy_loss:0.847978
# epoch:518 loss:0.611868 accu:0.660156 |xentropy_loss:1.880858 xentropy_loss:0.872947
# epoch:519 loss:0.633763 accu:0.648438 |xentropy_loss:1.984246 xentropy_loss:0.932991
# epoch:520 loss:0.643786 accu:0.621094 |xentropy_loss:2.001791 xentropy_loss:0.906593
# epoch:521 loss:0.624515 accu:0.613281 |xentropy_loss:1.870446 xentropy_loss:0.898093
# epoch:522 loss:0.618799 accu:0.636719 |xentropy_loss:1.891249 xentropy_loss:0.883260
# epoch:523 loss:0.630104 accu:0.617188 |xentropy_loss:1.896801 xentropy_loss:0.883897
# epoch:524 loss:0.604336 accu:0.667969 |xentropy_loss:1.903025 xentropy_loss:0.896458
# epoch:525 loss:0.609053 accu:0.652344 |xentropy_loss:1.886354 xentropy_loss:0.894365
# epoch:526 loss:0.601700 accu:0.699219 |xentropy_loss:1.915840 xentropy_loss:0.911749
# epoch:527 loss:0.610480 accu:0.667969 |xentropy_loss:1.881483 xentropy_loss:0.884813
# epoch:528 loss:0.603420 accu:0.664062 |xentropy_loss:1.906878 xentropy_loss:0.899271
# epoch:529 loss:0.620778 accu:0.640625 |xentropy_loss:1.877947 xentropy_loss:0.880408
# epoch:530 loss:0.598354 accu:0.652344 |xentropy_loss:1.948793 xentropy_loss:0.911705
# epoch:531 loss:0.601556 accu:0.648438 |xentropy_loss:1.919935 xentropy_loss:0.908469
# epoch:532 loss:0.613964 accu:0.640625 |xentropy_loss:1.921704 xentropy_loss:0.900769
# epoch:533 loss:0.569579 accu:0.750000 |xentropy_loss:1.966994 xentropy_loss:0.909782
# epoch:534 loss:0.603914 accu:0.695312 |xentropy_loss:1.982335 xentropy_loss:0.961737
# epoch:535 loss:0.633539 accu:0.617188 |xentropy_loss:1.875042 xentropy_loss:0.887912
# epoch:536 loss:0.603502 accu:0.707031 |xentropy_loss:1.908390 xentropy_loss:0.914713
# epoch:537 loss:0.633209 accu:0.632812 |xentropy_loss:1.814605 xentropy_loss:0.873790
# epoch:538 loss:0.586115 accu:0.687500 |xentropy_loss:1.866556 xentropy_loss:0.889959
# epoch:539 loss:0.627016 accu:0.644531 |xentropy_loss:1.868917 xentropy_loss:0.898428
# epoch:540 loss:0.630107 accu:0.617188 |xentropy_loss:1.870085 xentropy_loss:0.878000
# epoch:541 loss:0.621070 accu:0.664062 |xentropy_loss:1.888410 xentropy_loss:0.895294
# epoch:542 loss:0.603006 accu:0.675781 |xentropy_loss:1.864904 xentropy_loss:0.918791
# epoch:543 loss:0.607314 accu:0.679688 |xentropy_loss:1.928410 xentropy_loss:0.964938
# epoch:544 loss:0.630866 accu:0.652344 |xentropy_loss:1.888246 xentropy_loss:0.936260
# epoch:545 loss:0.636829 accu:0.609375 |xentropy_loss:1.920631 xentropy_loss:0.895679
# epoch:546 loss:0.623464 accu:0.628906 |xentropy_loss:1.899721 xentropy_loss:0.902316
# epoch:547 loss:0.630425 accu:0.582031 |xentropy_loss:1.893564 xentropy_loss:0.871506
# epoch:548 loss:0.618009 accu:0.644531 |xentropy_loss:1.879122 xentropy_loss:0.909080
# epoch:549 loss:0.612580 accu:0.671875 |xentropy_loss:1.894344 xentropy_loss:0.876480
# epoch:550 loss:0.615505 accu:0.679688 |xentropy_loss:1.874390 xentropy_loss:0.869545
# epoch:551 loss:0.647911 accu:0.609375 |xentropy_loss:1.849730 xentropy_loss:0.897557
# epoch:552 loss:0.606343 accu:0.679688 |xentropy_loss:1.880280 xentropy_loss:0.919156
# epoch:553 loss:0.662369 accu:0.562500 |xentropy_loss:1.840082 xentropy_loss:0.904559
# epoch:554 loss:0.617846 accu:0.648438 |xentropy_loss:1.943750 xentropy_loss:0.905580
# epoch:555 loss:0.638933 accu:0.640625 |xentropy_loss:1.922532 xentropy_loss:0.918324
# epoch:556 loss:0.656927 accu:0.593750 |xentropy_loss:1.960329 xentropy_loss:0.934858
# epoch:557 loss:0.625573 accu:0.640625 |xentropy_loss:1.917586 xentropy_loss:0.905487
# epoch:558 loss:0.639065 accu:0.644531 |xentropy_loss:1.977002 xentropy_loss:0.896167
# epoch:559 loss:0.666996 accu:0.582031 |xentropy_loss:1.870193 xentropy_loss:0.855168
# epoch:560 loss:0.636500 accu:0.617188 |xentropy_loss:1.866590 xentropy_loss:0.906434
# epoch:561 loss:0.638932 accu:0.582031 |xentropy_loss:2.011080 xentropy_loss:0.927295
# ...
# epoch:813 loss:0.581276 accu:0.726562 |xentropy_loss:2.018954 xentropy_loss:0.941011
# epoch:814 loss:0.598162 accu:0.691406 |xentropy_loss:1.947081 xentropy_loss:0.917320
# epoch:815 loss:0.563887 accu:0.761719 |xentropy_loss:1.986135 xentropy_loss:0.905659
# epoch:816 loss:0.572383 accu:0.707031 |xentropy_loss:1.976225 xentropy_loss:0.916046
# epoch:817 loss:0.600564 accu:0.703125 |xentropy_loss:1.989987 xentropy_loss:0.979355
# epoch:818 loss:0.609793 accu:0.679688 |xentropy_loss:2.016102 xentropy_loss:0.942683
# epoch:819 loss:0.590000 accu:0.726562 |xentropy_loss:1.999869 xentropy_loss:0.953099
# epoch:820 loss:0.600843 accu:0.699219 |xentropy_loss:1.915758 xentropy_loss:0.947928
# epoch:821 loss:0.580810 accu:0.718750 |xentropy_loss:1.960096 xentropy_loss:0.960898
# epoch:822 loss:0.579515 accu:0.707031 |xentropy_loss:1.963282 xentropy_loss:0.921499
# epoch:823 loss:0.583136 accu:0.714844 |xentropy_loss:1.979606 xentropy_loss:0.923614
# epoch:824 loss:0.588469 accu:0.695312 |xentropy_loss:1.963869 xentropy_loss:0.961055
# epoch:825 loss:0.569568 accu:0.738281 |xentropy_loss:1.969367 xentropy_loss:0.928963
# epoch:826 loss:0.581962 accu:0.726562 |xentropy_loss:1.932653 xentropy_loss:0.944939
# epoch:827 loss:0.587848 accu:0.730469 |xentropy_loss:1.948834 xentropy_loss:0.959510
# epoch:828 loss:0.593067 accu:0.687500 |xentropy_loss:2.024486 xentropy_loss:0.983384
# epoch:829 loss:0.598043 accu:0.699219 |xentropy_loss:1.944533 xentropy_loss:0.939631
# epoch:830 loss:0.590172 accu:0.675781 |xentropy_loss:1.947895 xentropy_loss:0.925936
# epoch:831 loss:0.610357 accu:0.687500 |xentropy_loss:1.954456 xentropy_loss:0.888977
# epoch:832 loss:0.597236 accu:0.718750 |xentropy_loss:1.934268 xentropy_loss:0.886224
# epoch:833 loss:0.616709 accu:0.683594 |xentropy_loss:1.886162 xentropy_loss:0.886461
# epoch:834 loss:0.599626 accu:0.675781 |xentropy_loss:1.910496 xentropy_loss:0.914141
# epoch:835 loss:0.574655 accu:0.757812 |xentropy_loss:2.067476 xentropy_loss:0.973394
# epoch:836 loss:0.582925 accu:0.722656 |xentropy_loss:1.988681 xentropy_loss:0.924787
# epoch:837 loss:0.575661 accu:0.742188 |xentropy_loss:1.973560 xentropy_loss:0.931061
# epoch:838 loss:0.610876 accu:0.699219 |xentropy_loss:1.940154 xentropy_loss:0.905682
# epoch:839 loss:0.624377 accu:0.671875 |xentropy_loss:1.924730 xentropy_loss:0.883450
# epoch:840 loss:0.601973 accu:0.679688 |xentropy_loss:1.916898 xentropy_loss:0.922374
# epoch:841 loss:0.576903 accu:0.710938 |xentropy_loss:2.069654 xentropy_loss:0.976863
# epoch:842 loss:0.601764 accu:0.699219 |xentropy_loss:2.025291 xentropy_loss:0.973024
# epoch:843 loss:0.611117 accu:0.625000 |xentropy_loss:1.954333 xentropy_loss:0.925730
# epoch:844 loss:0.603566 accu:0.671875 |xentropy_loss:1.954082 xentropy_loss:0.911514
# epoch:845 loss:0.594958 accu:0.726562 |xentropy_loss:2.061746 xentropy_loss:0.945757
# epoch:846 loss:0.615553 accu:0.699219 |xentropy_loss:1.964969 xentropy_loss:0.918274
# epoch:847 loss:0.625079 accu:0.640625 |xentropy_loss:1.972673 xentropy_loss:0.881129
# epoch:848 loss:0.631174 accu:0.636719 |xentropy_loss:1.877084 xentropy_loss:0.890379
# epoch:849 loss:0.600173 accu:0.667969 |xentropy_loss:1.901751 xentropy_loss:0.894338
# epoch:850 loss:0.612273 accu:0.683594 |xentropy_loss:1.903763 xentropy_loss:0.910161
# epoch:851 loss:0.592164 accu:0.695312 |xentropy_loss:1.993881 xentropy_loss:0.936125
# epoch:852 loss:0.597500 accu:0.699219 |xentropy_loss:1.974058 xentropy_loss:0.923762
# epoch:853 loss:0.622335 accu:0.667969 |xentropy_loss:1.945429 xentropy_loss:0.940185
# epoch:854 loss:0.610905 accu:0.671875 |xentropy_loss:1.982738 xentropy_loss:0.934436
# epoch:855 loss:0.618362 accu:0.640625 |xentropy_loss:1.922621 xentropy_loss:0.926243
# epoch:856 loss:0.611382 accu:0.628906 |xentropy_loss:2.018137 xentropy_loss:0.948018
# epoch:857 loss:0.574879 accu:0.734375 |xentropy_loss:2.105968 xentropy_loss:0.967624
# epoch:858 loss:0.621776 accu:0.648438 |xentropy_loss:2.040409 xentropy_loss:0.958995
# epoch:859 loss:0.598267 accu:0.710938 |xentropy_loss:2.029343 xentropy_loss:0.989295
# epoch:860 loss:0.589694 accu:0.707031 |xentropy_loss:1.932086 xentropy_loss:0.892880
# epoch:861 loss:0.615890 accu:0.667969 |xentropy_loss:1.930562 xentropy_loss:0.911718
# epoch:862 loss:0.642259 accu:0.625000 |xentropy_loss:1.863306 xentropy_loss:0.868094
# epoch:863 loss:0.611751 accu:0.687500 |xentropy_loss:1.988153 xentropy_loss:0.910919
# epoch:864 loss:0.610217 accu:0.660156 |xentropy_loss:1.986079 xentropy_loss:0.892137
# epoch:865 loss:0.613815 accu:0.683594 |xentropy_loss:2.011685 xentropy_loss:0.917063
# epoch:866 loss:0.606535 accu:0.695312 |xentropy_loss:1.925088 xentropy_loss:0.910627
# epoch:867 loss:0.600605 accu:0.671875 |xentropy_loss:2.096311 xentropy_loss:0.960238
# epoch:868 loss:0.626303 accu:0.675781 |xentropy_loss:2.041753 xentropy_loss:0.938042
# epoch:869 loss:0.592964 accu:0.714844 |xentropy_loss:1.968465 xentropy_loss:0.935720
# epoch:870 loss:0.660828 accu:0.613281 |xentropy_loss:1.863526 xentropy_loss:0.910492
# epoch:871 loss:0.630932 accu:0.609375 |xentropy_loss:1.898430 xentropy_loss:0.894173
# epoch:872 loss:0.627677 accu:0.613281 |xentropy_loss:1.986332 xentropy_loss:0.962545
# epoch:873 loss:0.592324 accu:0.703125 |xentropy_loss:2.080980 xentropy_loss:0.978253
# epoch:874 loss:0.620638 accu:0.636719 |xentropy_loss:2.022874 xentropy_loss:0.983391
# epoch:875 loss:0.623495 accu:0.656250 |xentropy_loss:1.996627 xentropy_loss:0.943004
# epoch:876 loss:0.624428 accu:0.621094 |xentropy_loss:1.971572 xentropy_loss:0.924195
# epoch:877 loss:0.621068 accu:0.652344 |xentropy_loss:2.058465 xentropy_loss:0.913657
# epoch:878 loss:0.607706 accu:0.675781 |xentropy_loss:2.008148 xentropy_loss:0.946446
# epoch:879 loss:0.610402 accu:0.683594 |xentropy_loss:1.978076 xentropy_loss:0.944840
# epoch:880 loss:0.630860 accu:0.644531 |xentropy_loss:1.890208 xentropy_loss:0.854969
# epoch:881 loss:0.609124 accu:0.656250 |xentropy_loss:2.060407 xentropy_loss:0.959753
# epoch:882 loss:0.637244 accu:0.593750 |xentropy_loss:1.956878 xentropy_loss:0.950539
# epoch:883 loss:0.593153 accu:0.734375 |xentropy_loss:1.936827 xentropy_loss:0.918054
# epoch:884 loss:0.608090 accu:0.667969 |xentropy_loss:1.911023 xentropy_loss:0.900248
# epoch:885 loss:0.566513 accu:0.753906 |xentropy_loss:1.970241 xentropy_loss:0.934464
# epoch:886 loss:0.600370 accu:0.703125 |xentropy_loss:2.002383 xentropy_loss:0.936506
# epoch:887 loss:0.583304 accu:0.710938 |xentropy_loss:1.981318 xentropy_loss:0.921270
# epoch:888 loss:0.624461 accu:0.660156 |xentropy_loss:1.935240 xentropy_loss:0.912200
# epoch:889 loss:0.600364 accu:0.683594 |xentropy_loss:1.942893 xentropy_loss:0.913903
# epoch:890 loss:0.574213 accu:0.730469 |xentropy_loss:2.041776 xentropy_loss:0.918479
# epoch:891 loss:0.615938 accu:0.679688 |xentropy_loss:1.955660 xentropy_loss:0.896429
# epoch:892 loss:0.615126 accu:0.683594 |xentropy_loss:1.936420 xentropy_loss:0.909281
# epoch:893 loss:0.605184 accu:0.667969 |xentropy_loss:1.959207 xentropy_loss:0.910894
# epoch:894 loss:0.583385 accu:0.726562 |xentropy_loss:2.005828 xentropy_loss:0.944428
# epoch:895 loss:0.613052 accu:0.644531 |xentropy_loss:1.943654 xentropy_loss:0.915650
# epoch:896 loss:0.612492 accu:0.687500 |xentropy_loss:1.938342 xentropy_loss:0.909330
# epoch:897 loss:0.594919 accu:0.726562 |xentropy_loss:1.989702 xentropy_loss:0.949748
# epoch:898 loss:0.611651 accu:0.660156 |xentropy_loss:1.962593 xentropy_loss:0.947331
# epoch:899 loss:0.611071 accu:0.703125 |xentropy_loss:2.012404 xentropy_loss:0.908788
# epoch:900 loss:0.593941 accu:0.699219 |xentropy_loss:1.990344 xentropy_loss:0.915930
# epoch:901 loss:0.581686 accu:0.734375 |xentropy_loss:1.976059 xentropy_loss:0.952673
# epoch:902 loss:0.608582 accu:0.687500 |xentropy_loss:1.999272 xentropy_loss:0.966502
# epoch:903 loss:0.610407 accu:0.683594 |xentropy_loss:2.024820 xentropy_loss:0.983756
# epoch:904 loss:0.583788 accu:0.730469 |xentropy_loss:2.015879 xentropy_loss:0.995236
# epoch:905 loss:0.601274 accu:0.707031 |xentropy_loss:1.977930 xentropy_loss:0.971003
# epoch:906 loss:0.602616 accu:0.714844 |xentropy_loss:1.966646 xentropy_loss:0.948185
# epoch:907 loss:0.579406 accu:0.707031 |xentropy_loss:2.052119 xentropy_loss:0.941313
# epoch:908 loss:0.597949 accu:0.730469 |xentropy_loss:1.967826 xentropy_loss:0.917869
# epoch:909 loss:0.603791 accu:0.699219 |xentropy_loss:1.895253 xentropy_loss:0.875898
# epoch:910 loss:0.596907 accu:0.687500 |xentropy_loss:1.942404 xentropy_loss:0.925287
# epoch:911 loss:0.596554 accu:0.671875 |xentropy_loss:2.028066 xentropy_loss:0.982608
# epoch:912 loss:0.641980 accu:0.628906 |xentropy_loss:1.982925 xentropy_loss:0.942877
# epoch:913 loss:0.604023 accu:0.687500 |xentropy_loss:2.017041 xentropy_loss:0.948832
# epoch:914 loss:0.635902 accu:0.625000 |xentropy_loss:1.962657 xentropy_loss:0.922602
# epoch:915 loss:0.587129 accu:0.730469 |xentropy_loss:2.037935 xentropy_loss:0.978535
# epoch:916 loss:0.589463 accu:0.722656 |xentropy_loss:1.951775 xentropy_loss:0.910389
# epoch:917 loss:0.620602 accu:0.664062 |xentropy_loss:1.930680 xentropy_loss:0.918454
# epoch:918 loss:0.602988 accu:0.703125 |xentropy_loss:1.908727 xentropy_loss:0.911465
# epoch:919 loss:0.575364 accu:0.746094 |xentropy_loss:1.980572 xentropy_loss:0.951756
# epoch:920 loss:0.612079 accu:0.656250 |xentropy_loss:1.991858 xentropy_loss:0.954198
# epoch:921 loss:0.592588 accu:0.710938 |xentropy_loss:2.026980 xentropy_loss:0.958524
# epoch:922 loss:0.598192 accu:0.699219 |xentropy_loss:1.981587 xentropy_loss:0.950908
# epoch:923 loss:0.606290 accu:0.664062 |xentropy_loss:1.934265 xentropy_loss:0.910144
# epoch:924 loss:0.614833 accu:0.660156 |xentropy_loss:1.964778 xentropy_loss:0.933568
# epoch:925 loss:0.591894 accu:0.679688 |xentropy_loss:1.950781 xentropy_loss:0.933082
# epoch:926 loss:0.601672 accu:0.691406 |xentropy_loss:1.958258 xentropy_loss:0.906748
# epoch:927 loss:0.595023 accu:0.679688 |xentropy_loss:1.972497 xentropy_loss:0.945929
# epoch:928 loss:0.607649 accu:0.687500 |xentropy_loss:2.026533 xentropy_loss:0.972323
# epoch:929 loss:0.587339 accu:0.730469 |xentropy_loss:1.998305 xentropy_loss:0.975541
# epoch:930 loss:0.606797 accu:0.710938 |xentropy_loss:1.992631 xentropy_loss:0.940884
# epoch:931 loss:0.585454 accu:0.726562 |xentropy_loss:1.979315 xentropy_loss:0.963354
# epoch:932 loss:0.586292 accu:0.714844 |xentropy_loss:1.955023 xentropy_loss:0.945054
# epoch:933 loss:0.612695 accu:0.687500 |xentropy_loss:1.916525 xentropy_loss:0.926447
# epoch:934 loss:0.586303 accu:0.707031 |xentropy_loss:1.980483 xentropy_loss:0.938417
# epoch:935 loss:0.579325 accu:0.718750 |xentropy_loss:2.028624 xentropy_loss:0.971247
# epoch:936 loss:0.575570 accu:0.734375 |xentropy_loss:2.051798 xentropy_loss:0.985916
# epoch:937 loss:0.590762 accu:0.707031 |xentropy_loss:2.085495 xentropy_loss:0.989187
# epoch:938 loss:0.611565 accu:0.722656 |xentropy_loss:1.930726 xentropy_loss:0.948601
# epoch:939 loss:0.607547 accu:0.675781 |xentropy_loss:1.969762 xentropy_loss:0.967834
# epoch:940 loss:0.606147 accu:0.687500 |xentropy_loss:1.938272 xentropy_loss:0.952174
# epoch:941 loss:0.582470 accu:0.714844 |xentropy_loss:1.923348 xentropy_loss:0.923994
# epoch:942 loss:0.595098 accu:0.722656 |xentropy_loss:1.999176 xentropy_loss:1.001787
# epoch:943 loss:0.582619 accu:0.718750 |xentropy_loss:2.036204 xentropy_loss:0.952425
# epoch:944 loss:0.577593 accu:0.687500 |xentropy_loss:1.942401 xentropy_loss:0.950780
# epoch:945 loss:0.578297 accu:0.703125 |xentropy_loss:1.962424 xentropy_loss:0.938027
# epoch:946 loss:0.597055 accu:0.671875 |xentropy_loss:1.928864 xentropy_loss:0.937439
# epoch:947 loss:0.583741 accu:0.742188 |xentropy_loss:2.025562 xentropy_loss:0.961725
# epoch:948 loss:0.620564 accu:0.617188 |xentropy_loss:2.041894 xentropy_loss:0.995512
# epoch:949 loss:0.630028 accu:0.632812 |xentropy_loss:1.962633 xentropy_loss:0.952568
# epoch:950 loss:0.605670 accu:0.679688 |xentropy_loss:1.962311 xentropy_loss:0.914056
# epoch:951 loss:0.592749 accu:0.726562 |xentropy_loss:1.966726 xentropy_loss:0.898987
# epoch:952 loss:0.599679 accu:0.699219 |xentropy_loss:1.935512 xentropy_loss:0.924909
# epoch:953 loss:0.603180 accu:0.648438 |xentropy_loss:1.947405 xentropy_loss:0.935536
# epoch:954 loss:0.597600 accu:0.687500 |xentropy_loss:2.007504 xentropy_loss:0.976377
# epoch:955 loss:0.571823 accu:0.750000 |xentropy_loss:1.981006 xentropy_loss:0.946141
# epoch:956 loss:0.568687 accu:0.734375 |xentropy_loss:1.960047 xentropy_loss:0.939279
# epoch:957 loss:0.587702 accu:0.718750 |xentropy_loss:1.993415 xentropy_loss:0.989086
# epoch:958 loss:0.602814 accu:0.656250 |xentropy_loss:2.006747 xentropy_loss:0.948386
# epoch:959 loss:0.605722 accu:0.675781 |xentropy_loss:1.994728 xentropy_loss:0.930057
# epoch:960 loss:0.585990 accu:0.699219 |xentropy_loss:2.110198 xentropy_loss:0.994647
# epoch:961 loss:0.584017 accu:0.710938 |xentropy_loss:2.139428 xentropy_loss:0.994398
# epoch:962 loss:0.603159 accu:0.687500 |xentropy_loss:1.951896 xentropy_loss:0.934283
# epoch:963 loss:0.604777 accu:0.695312 |xentropy_loss:1.922303 xentropy_loss:0.925856
# epoch:964 loss:0.575285 accu:0.738281 |xentropy_loss:1.989588 xentropy_loss:0.954585
# epoch:965 loss:0.594260 accu:0.703125 |xentropy_loss:1.954905 xentropy_loss:0.934353
# epoch:966 loss:0.591972 accu:0.695312 |xentropy_loss:1.959465 xentropy_loss:0.932024
# epoch:967 loss:0.594422 accu:0.714844 |xentropy_loss:1.974983 xentropy_loss:0.911525
# epoch:968 loss:0.585891 accu:0.695312 |xentropy_loss:2.048475 xentropy_loss:0.937730
# epoch:969 loss:0.579571 accu:0.718750 |xentropy_loss:2.032950 xentropy_loss:0.946059
# epoch:970 loss:0.630329 accu:0.652344 |xentropy_loss:1.964351 xentropy_loss:0.916849
# epoch:971 loss:0.602752 accu:0.644531 |xentropy_loss:2.042295 xentropy_loss:0.988642
# epoch:972 loss:0.606476 accu:0.683594 |xentropy_loss:1.967594 xentropy_loss:0.959230
# epoch:973 loss:0.612478 accu:0.691406 |xentropy_loss:1.925326 xentropy_loss:0.949795
# epoch:974 loss:0.591843 accu:0.683594 |xentropy_loss:2.013958 xentropy_loss:0.958425
# epoch:975 loss:0.625659 accu:0.683594 |xentropy_loss:1.956680 xentropy_loss:0.915270
# epoch:976 loss:0.622180 accu:0.675781 |xentropy_loss:1.948910 xentropy_loss:0.912861
# epoch:977 loss:0.592888 accu:0.707031 |xentropy_loss:1.954931 xentropy_loss:0.947493
# epoch:978 loss:0.602138 accu:0.671875 |xentropy_loss:1.929649 xentropy_loss:0.935838
# epoch:979 loss:0.606484 accu:0.675781 |xentropy_loss:1.879621 xentropy_loss:0.889604
# epoch:980 loss:0.593964 accu:0.675781 |xentropy_loss:1.937498 xentropy_loss:0.922347
# epoch:981 loss:0.646646 accu:0.636719 |xentropy_loss:1.944887 xentropy_loss:0.946669
# epoch:982 loss:0.647130 accu:0.652344 |xentropy_loss:1.901919 xentropy_loss:0.905182
# epoch:983 loss:0.610558 accu:0.656250 |xentropy_loss:1.940135 xentropy_loss:0.901907
# epoch:984 loss:0.580643 accu:0.714844 |xentropy_loss:2.089261 xentropy_loss:0.963832
# epoch:985 loss:0.612949 accu:0.687500 |xentropy_loss:1.988178 xentropy_loss:0.913464
# epoch:986 loss:0.600894 accu:0.671875 |xentropy_loss:1.965943 xentropy_loss:0.924462
# epoch:987 loss:0.577012 accu:0.707031 |xentropy_loss:2.027293 xentropy_loss:0.935209
# epoch:988 loss:0.603039 accu:0.675781 |xentropy_loss:2.027238 xentropy_loss:0.928113
# epoch:989 loss:0.643293 accu:0.609375 |xentropy_loss:1.935342 xentropy_loss:0.891398
# epoch:990 loss:0.598536 accu:0.730469 |xentropy_loss:1.995770 xentropy_loss:0.955933
# epoch:991 loss:0.579953 accu:0.738281 |xentropy_loss:1.984336 xentropy_loss:0.930300
# epoch:992 loss:0.589002 accu:0.683594 |xentropy_loss:1.993337 xentropy_loss:0.933008
# epoch:993 loss:0.592889 accu:0.714844 |xentropy_loss:2.048237 xentropy_loss:0.985425
# epoch:994 loss:0.617800 accu:0.687500 |xentropy_loss:2.029313 xentropy_loss:0.974242
# epoch:995 loss:0.592882 accu:0.742188 |xentropy_loss:2.006134 xentropy_loss:0.955498
# epoch:996 loss:0.599188 accu:0.703125 |xentropy_loss:2.030894 xentropy_loss:0.990010
# epoch:997 loss:0.590956 accu:0.742188 |xentropy_loss:2.035609 xentropy_loss:0.995095
# epoch:998 loss:0.594396 accu:0.718750 |xentropy_loss:1.995718 xentropy_loss:0.920927
# epoch:999 loss:0.571217 accu:0.765625 |xentropy_loss:1.990280 xentropy_loss:0.919793
# epoch:1000 loss:0.608237 accu:0.675781 |xentropy_loss:1.915204 xentropy_loss:0.901680

# %%
X_A.shape
# Out:
# (30000, 784)

# %%
real_labels.shape
# Out:
# (64, 1)

# %%
gc.collect()

# %%
gc.collect()
