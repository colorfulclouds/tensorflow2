# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
s = pd.Series([1,3,5, np.nan , 6 , 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101' , periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),
                 index = dates , columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.498505  1.020003 -0.362398 -0.953510
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757
# 2013-01-03  0.586892  1.912363  1.194461  1.416578
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481
# 2013-01-06 -1.495202  0.888356 -0.122101 -0.814170

# %%
df2 = pd.DataFrame({'A':1.,
                   'B':pd.Timestamp('20130102'),
                   'C':pd.Series(1,index=list(range(4)) , dtype='float32'),
                   'D':np.array([3]*4 , dtype='int32'),
                   'E':pd.Categorical(['test','train','test','train']),
                   'F':'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.498505  1.020003 -0.362398 -0.953510
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757
# 2013-01-03  0.586892  1.912363  1.194461  1.416578
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481
# 2013-01-06 -1.495202  0.888356 -0.122101 -0.814170

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-0.49850533,  1.02000325, -0.36239827, -0.95350976],
#        [-1.10062437,  0.03378181,  0.42863164,  0.87175732],
#        [ 0.58689204,  1.91236327,  1.19446088,  1.416578  ],
#        [-0.40767448, -0.47380044, -0.84407098,  0.14987842],
#        [ 0.34307845, -0.58636974,  0.39362732,  0.32348117],
#        [-1.49520196,  0.88835631, -0.12210079, -0.81417013]])

# %%
df.describe() #简单的统计特征
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.428673  0.465722  0.114692  0.165669
# std    0.802657  0.975171  0.713467  0.927484
# min   -1.495202 -0.586370 -0.844071 -0.953510
# 25%   -0.950095 -0.346905 -0.302324 -0.573158
# 50%   -0.453090  0.461069  0.135763  0.236680
# 75%    0.155390  0.987092  0.419881  0.734688
# max    0.586892  1.912363  1.194461  1.416578

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -0.498505   -1.100624    0.586892   -0.407674    0.343078   -1.495202
# B    1.020003    0.033782    1.912363   -0.473800   -0.586370    0.888356
# C   -0.362398    0.428632    1.194461   -0.844071    0.393627   -0.122101
# D   -0.953510    0.871757    1.416578    0.149878    0.323481   -0.814170

# %%
df.sort_index(axis=1 , ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -0.953510 -0.362398  1.020003 -0.498505
# 2013-01-02  0.871757  0.428632  0.033782 -1.100624
# 2013-01-03  1.416578  1.194461  1.912363  0.586892
# 2013-01-04  0.149878 -0.844071 -0.473800 -0.407674
# 2013-01-05  0.323481  0.393627 -0.586370  0.343078
# 2013-01-06 -0.814170 -0.122101  0.888356 -1.495202

# %%
df.sort_index(axis=0 , ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-06 -1.495202  0.888356 -0.122101 -0.814170
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878
# 2013-01-03  0.586892  1.912363  1.194461  1.416578
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757
# 2013-01-01 -0.498505  1.020003 -0.362398 -0.953510

# %%
df.sort_values(by = 'B') #根据column B 的数据进行排序
# Out:
#                    A         B         C         D
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757
# 2013-01-06 -1.495202  0.888356 -0.122101 -0.814170
# 2013-01-01 -0.498505  1.020003 -0.362398 -0.953510
# 2013-01-03  0.586892  1.912363  1.194461  1.416578

# %% [markdown]
# # selection

# %%
df['A'] #column A
# Out:
# 2013-01-01   -0.498505
# 2013-01-02   -1.100624
# 2013-01-03    0.586892
# 2013-01-04   -0.407674
# 2013-01-05    0.343078
# 2013-01-06   -1.495202
# Freq: D, Name: A, dtype: float64

# %%
df[0:3] #row integer index
# Out:
#                    A         B         C         D
# 2013-01-01 -0.498505  1.020003 -0.362398 -0.953510
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757
# 2013-01-03  0.586892  1.912363  1.194461  1.416578

# %%
df['20130102':'20130104'] #包括区间的两端
# Out:
#                    A         B         C         D
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757
# 2013-01-03  0.586892  1.912363  1.194461  1.416578
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878

# %%
df.loc[dates[0]] #label 进行访问
# Out:
# A   -0.498505
# B    1.020003
# C   -0.362398
# D   -0.953510
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[: , ['A','B']]
# Out:
#                    A         B
# 2013-01-01 -0.498505  1.020003
# 2013-01-02 -1.100624  0.033782
# 2013-01-03  0.586892  1.912363
# 2013-01-04 -0.407674 -0.473800
# 2013-01-05  0.343078 -0.586370
# 2013-01-06 -1.495202  0.888356

# %%
df.loc['20130102':'20130104' , ['A','B']] #loc包含区间的两端
# Out:
#                    A         B
# 2013-01-02 -1.100624  0.033782
# 2013-01-03  0.586892  1.912363
# 2013-01-04 -0.407674 -0.473800

# %%
df.loc['20130102' , ['A','B']]
# Out:
# A   -1.100624
# B    0.033782
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0] , 'A']
# Out:
# -0.49850533316114914

# %%
df.at[dates[0] , 'A'] #和上面的作用是一样的
# Out:
# -0.49850533316114914

# %% [markdown]
# # selection by position

# %%
#iloc函数 都是通过integer index 进行访问 一般是row
#loc函数 是通过label index进行访问 一般是row
df.iloc[3]
# Out:
# A   -0.407674
# B   -0.473800
# C   -0.844071
# D    0.149878
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5 , 0:2] #区域性 进行访问
# Out:
#                    A        B
# 2013-01-04 -0.407674 -0.47380
# 2013-01-05  0.343078 -0.58637

# %%
df.iloc[[1,2,4] , [0 , 2]] #访问指定的行 列 的元素
# Out:
#                    A         C
# 2013-01-02 -1.100624  0.428632
# 2013-01-03  0.586892  1.194461
# 2013-01-05  0.343078  0.393627

# %%
df.iloc[1:3 , :]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757
# 2013-01-03  0.586892  1.912363  1.194461  1.416578

# %%
df.iloc[: , 1:3]
# Out:
#                    B         C
# 2013-01-01  1.020003 -0.362398
# 2013-01-02  0.033782  0.428632
# 2013-01-03  1.912363  1.194461
# 2013-01-04 -0.473800 -0.844071
# 2013-01-05 -0.586370  0.393627
# 2013-01-06  0.888356 -0.122101

# %%
df.iloc[1 , 1] #integer index
# Out:
# 0.033781813100804255

# %% [markdown]
# # boolean indexing

# %%
#利用一个boolean的数组进行访问
df[df.A > 0] #column A > 0 进行显示
# Out:
#                    A         B         C         D
# 2013-01-03  0.586892  1.912363  1.194461  1.416578
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  1.020003       NaN       NaN
# 2013-01-02       NaN  0.033782  0.428632  0.871757
# 2013-01-03  0.586892  1.912363  1.194461  1.416578
# 2013-01-04       NaN       NaN       NaN  0.149878
# 2013-01-05  0.343078       NaN  0.393627  0.323481
# 2013-01-06       NaN  0.888356       NaN       NaN

# %%
df2 = df.copy()
df2
# Out:
#                    A         B         C         D
# 2013-01-01 -0.498505  1.020003 -0.362398 -0.953510
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757
# 2013-01-03  0.586892  1.912363  1.194461  1.416578
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481
# 2013-01-06 -1.495202  0.888356 -0.122101 -0.814170

# %%
df2['E'] = ['one' , 'one' , 'two' , 'three' , 'four' , 'three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.498505  1.020003 -0.362398 -0.953510    one
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757    one
# 2013-01-03  0.586892  1.912363  1.194461  1.416578    two
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878  three
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481   four
# 2013-01-06 -1.495202  0.888356 -0.122101 -0.814170  three

# %%
df2[df2['E'].isin(['two' , 'four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.586892  1.912363  1.194461  1.416578   two
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481  four

# %%
s1 = pd.Series([1,2,3,4,5,6] , index = pd.date_range('20130102' , periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F']=s1 #添加新的column时 按照index进行对应添加 对应不上的是NaN
df
# Out:
#                    A         B         C         D    F
# 2013-01-01 -0.498505  1.020003 -0.362398 -0.953510  NaN
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757  1.0
# 2013-01-03  0.586892  1.912363  1.194461  1.416578  2.0
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878  3.0
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481  4.0
# 2013-01-06 -1.495202  0.888356 -0.122101 -0.814170  5.0

# %%
df.at[dates[0] , 'A'] = 0
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  1.020003 -0.362398 -0.953510  NaN
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757  1.0
# 2013-01-03  0.586892  1.912363  1.194461  1.416578  2.0
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878  3.0
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481  4.0
# 2013-01-06 -1.495202  0.888356 -0.122101 -0.814170  5.0

# %%
df.iat[0 , 1] = 0 #与上面的作用是一样的 iat 是integer index的使用方法
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000  0.000000 -0.362398 -0.953510  NaN
# 2013-01-02 -1.100624  0.033782  0.428632  0.871757  1.0
# 2013-01-03  0.586892  1.912363  1.194461  1.416578  2.0
# 2013-01-04 -0.407674 -0.473800 -0.844071  0.149878  3.0
# 2013-01-05  0.343078 -0.586370  0.393627  0.323481  4.0
# 2013-01-06 -1.495202  0.888356 -0.122101 -0.814170  5.0

# %%
df.loc[:,'D'] = np.array([5]*len(df))
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.362398  5  NaN
# 2013-01-02 -1.100624  0.033782  0.428632  5  1.0
# 2013-01-03  0.586892  1.912363  1.194461  5  2.0
# 2013-01-04 -0.407674 -0.473800 -0.844071  5  3.0
# 2013-01-05  0.343078 -0.586370  0.393627  5  4.0
# 2013-01-06 -1.495202  0.888356 -0.122101  5  5.0

# %%
df2 = df.copy()
df2[df2>0] = -df2 #正数全部取反
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.362398 -5  NaN
# 2013-01-02 -1.100624 -0.033782 -0.428632 -5 -1.0
# 2013-01-03 -0.586892 -1.912363 -1.194461 -5 -2.0
# 2013-01-04 -0.407674 -0.473800 -0.844071 -5 -3.0
# 2013-01-05 -0.343078 -0.586370 -0.393627 -5 -4.0
# 2013-01-06 -1.495202 -0.888356 -0.122101 -5 -5.0

# %% [markdown]
# # missing data

# %%
#index 包括两种 一种是row index 一种是column index
#index 有两种索引方式 一种是label 一种是integer
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.362398  5  NaN
# 2013-01-02 -1.100624  0.033782  0.428632  5  1.0
# 2013-01-03  0.586892  1.912363  1.194461  5  2.0
# 2013-01-04 -0.407674 -0.473800 -0.844071  5  3.0
# 2013-01-05  0.343078 -0.586370  0.393627  5  4.0
# 2013-01-06 -1.495202  0.888356 -0.122101  5  5.0

# %%
df1 = df.reindex(index=dates[0:4] , columns=list(df.columns)+['E'])
df1
# Out:
#                    A         B         C  D    F   E
# 2013-01-01  0.000000  0.000000 -0.362398  5  NaN NaN
# 2013-01-02 -1.100624  0.033782  0.428632  5  1.0 NaN
# 2013-01-03  0.586892  1.912363  1.194461  5  2.0 NaN
# 2013-01-04 -0.407674 -0.473800 -0.844071  5  3.0 NaN

# %%
df1.loc[dates[0]:dates[1] , 'E']
# Out:
# 2013-01-01   NaN
# 2013-01-02   NaN
# Freq: D, Name: E, dtype: float64

# %%
df1.loc[dates[0]:dates[1] , 'E'] = 1 #重新设置值
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.362398  5  NaN  1.0
# 2013-01-02 -1.100624  0.033782  0.428632  5  1.0  1.0
# 2013-01-03  0.586892  1.912363  1.194461  5  2.0  NaN
# 2013-01-04 -0.407674 -0.473800 -0.844071  5  3.0  NaN

# %%
df1.dropna(how='any') #将含有NaN的row直接删除
# Out:
#                    A         B         C  D    F    E
# 2013-01-02 -1.100624  0.033782  0.428632  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.362398  5  5.0  1.0
# 2013-01-02 -1.100624  0.033782  0.428632  5  1.0  1.0
# 2013-01-03  0.586892  1.912363  1.194461  5  2.0  5.0
# 2013-01-04 -0.407674 -0.473800 -0.844071  5  3.0  5.0

# %%
pd.isna(df1) #isna函数不存在
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-e6f1028dcf7b> in <module>()
# ----> 1 pd.isna(df1)
#
# AttributeError: module 'pandas' has no attribute 'isna'

# %% [markdown]
# # operation

# %%
#特征描述时 会扔点缺失值
#默认统计是按column进行统计
df.mean()
# Out:
# A   -0.345588
# B    0.295722
# C    0.114692
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1) #横向统计
# Out:
# 2013-01-01    1.159400
# 2013-01-02    1.072358
# 2013-01-03    2.138743
# 2013-01-04    1.254891
# 2013-01-05    1.830067
# 2013-01-06    1.854211
# Freq: D, dtype: float64

# %%
#pandas 也有广播机制
s = pd.Series([1,3,5,np.nan , 6,8] , index = dates).shift(2) #移位 2
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s , axis = 'index') #默认按column进行计算
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -0.413108  0.912363  0.194461  4.0  1.0
# 2013-01-04 -3.407674 -3.473800 -3.844071  2.0  0.0
# 2013-01-05 -4.656922 -5.586370 -4.606373  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# # apply

# %%
a=np.array([1,2,3])
np.cumsum(a , axis=0)
# Out:
# array([1, 3, 6], dtype=int32)

# %%
df.apply(np.cumsum) #cumsum 进行累加计算
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -0.362398   5   NaN
# 2013-01-02 -1.100624  0.033782  0.066233  10   1.0
# 2013-01-03 -0.513732  1.946145  1.260694  15   3.0
# 2013-01-04 -0.921407  1.472345  0.416623  20   6.0
# 2013-01-05 -0.578328  0.885975  0.810251  25  10.0
# 2013-01-06 -2.073530  1.774331  0.688150  30  15.0

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.362398  5  NaN
# 2013-01-02 -1.100624  0.033782  0.428632  5  1.0
# 2013-01-03  0.586892  1.912363  1.194461  5  2.0
# 2013-01-04 -0.407674 -0.473800 -0.844071  5  3.0
# 2013-01-05  0.343078 -0.586370  0.393627  5  4.0
# 2013-01-06 -1.495202  0.888356 -0.122101  5  5.0

# %%
df.apply(lambda x: x.max() - x.min()) #还是针对column进行作用的
#apply 参数是函数对象
# Out:
# A    2.082094
# B    2.498733
# C    2.038532
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# # histogramming
# # 统计学直方图

# %%
s = pd.Series(np.random.randint(0,7 , size=10))
s
# Out:
# 0    5
# 1    0
# 2    5
# 3    3
# 4    3
# 5    6
# 6    2
# 7    0
# 8    6
# 9    5
# dtype: int32

# %%
s.value_counts() #统计每个value出现了多少次
# Out:
# 5    3
# 6    2
# 3    2
# 0    2
# 2    1
# dtype: int64

# %%
s = pd.Series(['A','B','C','Aaba',np.nan,'CABA','dog','cat'])
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4     NaN
# 5    CABA
# 6     dog
# 7     cat
# dtype: object

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4     NaN
# 5    caba
# 6     dog
# 7     cat
# dtype: object

# %% [markdown]
# # merge

# %%
df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0 -1.128416 -0.728747 -0.510844  1.444184
# 1  0.257076  1.630052 -0.754395  0.877769
# 2  0.779604 -1.684873  0.279170 -0.292806
# 3  1.442483  0.522887 -1.881714  1.198938
# 4  0.508082  0.090637  0.856729  0.175774
# 5  0.048889 -0.483904  1.553435  0.229506
# 6 -0.022471  0.067152  0.335519 -0.373122
# 7 -0.549228 -0.300522  2.113757  0.054120
# 8  0.461320  0.556718 -0.516568  0.573297
# 9  0.282192 -0.359625  0.184594  0.196534

# %%
pieces = [df[:3] , df[3:7] , df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -1.128416 -0.728747 -0.510844  1.444184
#  1  0.257076  1.630052 -0.754395  0.877769
#  2  0.779604 -1.684873  0.279170 -0.292806,
#            0         1         2         3
#  3  1.442483  0.522887 -1.881714  1.198938
#  4  0.508082  0.090637  0.856729  0.175774
#  5  0.048889 -0.483904  1.553435  0.229506
#  6 -0.022471  0.067152  0.335519 -0.373122,
#            0         1         2         3
#  7 -0.549228 -0.300522  2.113757  0.054120
#  8  0.461320  0.556718 -0.516568  0.573297
#  9  0.282192 -0.359625  0.184594  0.196534]

# %%
#pieces的成员是一些dataframe对象 将它们连接起来
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -1.128416 -0.728747 -0.510844  1.444184
# 1  0.257076  1.630052 -0.754395  0.877769
# 2  0.779604 -1.684873  0.279170 -0.292806
# 3  1.442483  0.522887 -1.881714  1.198938
# 4  0.508082  0.090637  0.856729  0.175774
# 5  0.048889 -0.483904  1.553435  0.229506
# 6 -0.022471  0.067152  0.335519 -0.373122
# 7 -0.549228 -0.300522  2.113757  0.054120
# 8  0.461320  0.556718 -0.516568  0.573297
# 9  0.282192 -0.359625  0.184594  0.196534

# %%
#join 是 数据库风格的merge
left = pd.DataFrame({'key':['foo','foo'],
                    'lval':[1,2]})

right = pd.DataFrame({'key':['foo','foo'],
                     'rval':[4,5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left , right ,on='key') #这里有和无on效果一样
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key':['foo','bar'],'lval':[1,2]})
right = pd.DataFrame({'key':['foo','bar'],'rval':[4,5]})

left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right , on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# # append

# %%
df = pd.DataFrame(np.random.randn(8,4) , columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0 -0.594874 -2.512008  1.375170  0.680096
# 1 -0.596871 -1.201073 -2.407136  0.691800
# 2  0.001010 -0.675918  0.714018 -0.069568
# 3  1.124396 -0.807913  0.378678  0.402739
# 4 -1.084540  0.366512 -0.587212 -0.584496
# 5  0.192479 -0.613899  2.047825  0.433652
# 6 -0.422268  0.925965 -0.936659  0.935487
# 7  0.363595  2.886922 -0.465516 -2.031281

# %%
s = df.iloc[3] #integer index 3
s
# Out:
# A    1.124396
# B   -0.807913
# C    0.378678
# D    0.402739
# Name: 3, dtype: float64

# %%
df.append(s )#, ignore_index=True)
#ignore_index 为True 就是使用新的index
# Out:
#           A         B         C         D
# 0 -0.594874 -2.512008  1.375170  0.680096
# 1 -0.596871 -1.201073 -2.407136  0.691800
# 2  0.001010 -0.675918  0.714018 -0.069568
# 3  1.124396 -0.807913  0.378678  0.402739
# 4 -1.084540  0.366512 -0.587212 -0.584496
# 5  0.192479 -0.613899  2.047825  0.433652
# 6 -0.422268  0.925965 -0.936659  0.935487
# 7  0.363595  2.886922 -0.465516 -2.031281
# 3  1.124396 -0.807913  0.378678  0.402739

# %% [markdown]
# # grouping

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                              'foo', 'bar', 'foo', 'foo'],
                       'B' : ['one', 'one', 'two', 'three',
                              'two', 'two', 'one', 'three'],
                       'C' : np.random.randn(8),
                       'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one  0.452384 -2.255594
# 1  bar    one  0.754090  0.693344
# 2  foo    two -2.260909  0.156692
# 3  bar  three -1.103666  1.120935
# 4  foo    two -0.740788 -1.542792
# 5  bar    two  0.548184  0.538402
# 6  foo    one -0.350706  0.452384
# 7  foo  three  0.323681  0.094068

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.198609  2.352681
# foo -2.576338 -3.095242

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.754090  0.693344
#     three -1.103666  1.120935
#     two    0.548184  0.538402
# foo one    0.101678 -1.803210
#     three  0.323681  0.094068
#     two   -3.001697 -1.386100

# %% [markdown]
# # reshaping

# %%
#stack
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz','foo', 'foo', 'qux', 'qux'],
                    ['one', 'two', 'one', 'two','one', 'two', 'one', 'two']]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples , names=['first','second'])
index
# Out:
# MultiIndex(levels=[['bar', 'baz', 'foo', 'qux'], ['one', 'two']],
#            labels=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 0, 1, 0, 1, 0, 1]],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8,2),index=index,columns=['A','B'])
df
# Out:
#                      A         B
# first second
# bar   one     0.995856 -1.596376
#       two    -0.821981  0.373402
# baz   one    -1.077320  0.842590
#       two    -0.085086  0.036859
# foo   one     0.557977 -0.250202
#       two     0.718362  0.692193
# qux   one     0.412102 -0.375349
#       two     0.650139  1.160365

# %%
df2 = df[:4] #
df2
# Out:
#                      A         B
# first second
# bar   one     0.995856 -1.596376
#       two    -0.821981  0.373402
# baz   one    -1.077320  0.842590
#       two    -0.085086  0.036859

# %%
#stack函数 将dataframe的columns进行压缩
stacked = df2.stack()
stacked
#原来的df2只有两个level row index
#stack函数作用后 变成了3个level row index
# Out:
# first  second
# bar    one     A    0.995856
#                B   -1.596376
#        two     A   -0.821981
#                B    0.373402
# baz    one     A   -1.077320
#                B    0.842590
#        two     A   -0.085086
#                B    0.036859
# dtype: float64

# %%
#unstack就是stack的反运算
stacked.unstack()
#2个level level_0:first level_1:second
# Out:
#                      A         B
# first second
# bar   one     0.995856 -1.596376
#       two    -0.821981  0.373402
# baz   one    -1.077320  0.842590
#       two    -0.085086  0.036859

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.995856 -0.821981
#       B -1.596376  0.373402
# baz   A -1.077320 -0.085086
#       B  0.842590  0.036859

# %% [markdown]
# # pivot table

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                       'B' : ['A', 'B', 'C'] * 4,
                       'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                       'D' : np.random.randn(12),
                       'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -2.075771  1.483924
# 1     one  B  foo -0.567483  1.580171
# 2     two  C  foo  0.528039 -1.054739
# 3   three  A  bar  0.325588 -0.290643
# 4     one  B  bar -1.445555 -0.447482
# 5     one  C  bar -0.233339  0.308462
# 6     two  A  foo  0.588177 -0.750323
# 7   three  B  foo -2.283113 -1.789960
# 8     one  C  foo -0.612137 -1.248535
# 9     one  A  bar  0.545034 -0.138404
# 10    two  B  bar  0.672529 -1.369824
# 11  three  C  bar  0.768922 -0.716072

# %%
ff = pd.pivot_table(df , values='D' , index=['A','B'] , columns=['C'])
ff
# Out:
# C             bar       foo
# A     B
# one   A  0.545034 -2.075771
#       B -1.445555 -0.567483
#       C -0.233339 -0.612137
# three A  0.325588       NaN
#       B       NaN -2.283113
#       C  0.768922       NaN
# two   A       NaN  0.588177
#       B  0.672529       NaN
#       C       NaN  0.528039

# %%
ff.index
# Out:
# MultiIndex(levels=[['one', 'three', 'two'], ['A', 'B', 'C']],
#            labels=[[0, 0, 0, 1, 1, 1, 2, 2, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2]],
#            names=['A', 'B'])

# %%
ff.columns #column的名字叫 C
# Out:
# Index(['bar', 'foo'], dtype='object', name='C')

# %% [markdown]
# # time series

# %%
rng = pd.date_range('1/1/2012' , periods=100 , freq='S')
#freq控制的是周期的单元
rng
# Out:
# DatetimeIndex(['2012-01-01 00:00:00', '2012-01-01 00:00:01',
#                '2012-01-01 00:00:02', '2012-01-01 00:00:03',
#                '2012-01-01 00:00:04', '2012-01-01 00:00:05',
#                '2012-01-01 00:00:06', '2012-01-01 00:00:07',
#                '2012-01-01 00:00:08', '2012-01-01 00:00:09',
#                '2012-01-01 00:00:10', '2012-01-01 00:00:11',
#                '2012-01-01 00:00:12', '2012-01-01 00:00:13',
#                '2012-01-01 00:00:14', '2012-01-01 00:00:15',
#                '2012-01-01 00:00:16', '2012-01-01 00:00:17',
#                '2012-01-01 00:00:18', '2012-01-01 00:00:19',
#                '2012-01-01 00:00:20', '2012-01-01 00:00:21',
#                '2012-01-01 00:00:22', '2012-01-01 00:00:23',
#                '2012-01-01 00:00:24', '2012-01-01 00:00:25',
#                '2012-01-01 00:00:26', '2012-01-01 00:00:27',
#                '2012-01-01 00:00:28', '2012-01-01 00:00:29',
# ...

# %%
ts = pd.Series(np.random.randint(0 , 500 , len(rng)) , index=rng)
ts
# Out:
# 2012-01-01 00:00:00    223
# 2012-01-01 00:00:01     11
# 2012-01-01 00:00:02    157
# 2012-01-01 00:00:03    481
# 2012-01-01 00:00:04     81
# 2012-01-01 00:00:05    425
# 2012-01-01 00:00:06    423
# 2012-01-01 00:00:07    180
# 2012-01-01 00:00:08     57
# 2012-01-01 00:00:09    156
# 2012-01-01 00:00:10    339
# 2012-01-01 00:00:11    440
# 2012-01-01 00:00:12    385
# 2012-01-01 00:00:13    207
# 2012-01-01 00:00:14    217
# 2012-01-01 00:00:15    482
# 2012-01-01 00:00:16    399
# 2012-01-01 00:00:17    368
# 2012-01-01 00:00:18    468
# 2012-01-01 00:00:19    480
# 2012-01-01 00:00:20     40
# 2012-01-01 00:00:21    172
# 2012-01-01 00:00:22    426
# 2012-01-01 00:00:23     23
# 2012-01-01 00:00:24    169
# 2012-01-01 00:00:25    300
# 2012-01-01 00:00:26    280
# 2012-01-01 00:00:27     53
# 2012-01-01 00:00:28    386
# 2012-01-01 00:00:29    139
#                       ...
# 2012-01-01 00:01:10    152
# 2012-01-01 00:01:11    477
# 2012-01-01 00:01:12     40
# ...

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    24603
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00' , periods=5 , freq='D')
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)) , rng)
ts
# Out:
# 2012-03-06    1.215489
# 2012-03-07    0.508978
# 2012-03-08   -0.397280
# 2012-03-09    0.974491
# 2012-03-10   -0.322687
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    1.215489
# 2012-03-07 00:00:00+00:00    0.508978
# 2012-03-08 00:00:00+00:00   -0.397280
# 2012-03-09 00:00:00+00:00    0.974491
# 2012-03-10 00:00:00+00:00   -0.322687
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    1.215489
# 2012-03-06 19:00:00-05:00    0.508978
# 2012-03-07 19:00:00-05:00   -0.397280
# 2012-03-08 19:00:00-05:00    0.974491
# 2012-03-09 19:00:00-05:00   -0.322687
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012' , periods=5 , freq='M')
ts = pd.Series(np.random.randn(len(rng)) , index = rng)
ts
# Out:
# 2012-01-31   -0.825793
# 2012-02-29   -0.527222
# 2012-03-31   -0.600476
# 2012-04-30    0.007145
# 2012-05-31    1.316798
# Freq: M, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-01   -0.825793
# 2012-02   -0.527222
# 2012-03   -0.600476
# 2012-04    0.007145
# 2012-05    1.316798
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -0.825793
# 2012-02-01   -0.527222
# 2012-03-01   -0.600476
# 2012-04-01    0.007145
# 2012-05-01    1.316798
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1' , '2000Q4' , freq='Q-NOV')
prng
# Out:
# PeriodIndex(['1990Q1', '1990Q2', '1990Q3', '1990Q4', '1991Q1', '1991Q2',
#              '1991Q3', '1991Q4', '1992Q1', '1992Q2', '1992Q3', '1992Q4',
#              '1993Q1', '1993Q2', '1993Q3', '1993Q4', '1994Q1', '1994Q2',
#              '1994Q3', '1994Q4', '1995Q1', '1995Q2', '1995Q3', '1995Q4',
#              '1996Q1', '1996Q2', '1996Q3', '1996Q4', '1997Q1', '1997Q2',
#              '1997Q3', '1997Q4', '1998Q1', '1998Q2', '1998Q3', '1998Q4',
#              '1999Q1', '1999Q2', '1999Q3', '1999Q4', '2000Q1', '2000Q2',
#              '2000Q3', '2000Q4'],
#             dtype='period[Q-NOV]', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)) , prng)
ts.head()
# Out:
# 1990Q1   -0.733968
# 1990Q2   -1.293106
# 1990Q3   -0.205222
# 1990Q4    0.055219
# 1991Q1    0.065805
# Freq: Q-NOV, dtype: float64

# %%
ts.index = (prng.asfreq('M','e') + 1).asfreq('H','s')+9
ts.head()
# Out:
# 1990-03-01 09:00   -0.733968
# 1990-06-01 09:00   -1.293106
# 1990-09-01 09:00   -0.205222
# 1990-12-01 09:00    0.055219
# 1991-03-01 09:00    0.065805
# Freq: H, dtype: float64

# %% [markdown]
# # categorical

# %%
df = pd.DataFrame({'id':[1,2,3,4,5,6],
                  'raw_grade':['a','b','b','a','a','e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df['grade'] = df['raw_grade'].astype('category')
df['grade'] #将元素类型变为 category
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df['grade'].cat.categories = ['very good' , 'good' , 'very bad']

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df['grade'] = df['grade'].cat.set_categories(['very bad' , 'bad' , 'medium' , 'good' , 'very good'])
df['grade']
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df.sort_values(by='grade') #排序是按照 category 不是按照字典排序
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby('grade').size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# # plotting

# %%
ts = pd.Series(np.random.randn(1000) ,
              index = pd.date_range('1/1/2000',
              periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000 , 4) , index = ts.index,
                 columns=['A','B','C','D'])

df = df.cumsum()

plt.figure()
df.plot()
plt.legend(loc='best')

# %% [markdown]
# # getting data in and out

# %%
df.to_csv('foo.csv') #写入文件

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-01-01  -0.275510  -1.604590  -0.016232  -0.013008
# 1    2000-01-02  -0.295853  -1.836106   1.837767  -0.675996
# 2    2000-01-03  -0.838191  -2.159690   1.649179  -2.029665
# 3    2000-01-04  -0.811856  -3.068830   3.503493  -4.028204
# 4    2000-01-05  -0.888820  -3.139324   3.329057  -6.284901
# 5    2000-01-06  -1.789507  -1.989135   2.932750  -7.073115
# 6    2000-01-07  -2.154222   0.380633   3.685005  -7.067248
# 7    2000-01-08  -2.515837  -1.060332   2.583710  -4.997942
# 8    2000-01-09  -2.798953  -0.465508   2.547062  -4.724121
# 9    2000-01-10  -1.049692  -0.082855   2.447197  -4.549859
# 10   2000-01-11   0.348893   0.581044   2.023998  -3.665294
# 11   2000-01-12  -0.092555   1.354626   0.003465  -3.197280
# 12   2000-01-13  -2.090294   1.732451   0.228346  -4.984268
# 13   2000-01-14  -1.104145   2.391618   0.518171  -7.097361
# 14   2000-01-15  -0.479093   4.409222   0.037052  -7.099943
# ...

# %%
# HDF5格式数据
df.to_hdf('foo.h5' , 'df')

# %%
pd.read_hdf('foo.h5' , 'df')
# Out:
#                     A          B          C          D
# 2000-01-01  -0.275510  -1.604590  -0.016232  -0.013008
# 2000-01-02  -0.295853  -1.836106   1.837767  -0.675996
# 2000-01-03  -0.838191  -2.159690   1.649179  -2.029665
# 2000-01-04  -0.811856  -3.068830   3.503493  -4.028204
# 2000-01-05  -0.888820  -3.139324   3.329057  -6.284901
# 2000-01-06  -1.789507  -1.989135   2.932750  -7.073115
# 2000-01-07  -2.154222   0.380633   3.685005  -7.067248
# 2000-01-08  -2.515837  -1.060332   2.583710  -4.997942
# 2000-01-09  -2.798953  -0.465508   2.547062  -4.724121
# 2000-01-10  -1.049692  -0.082855   2.447197  -4.549859
# 2000-01-11   0.348893   0.581044   2.023998  -3.665294
# 2000-01-12  -0.092555   1.354626   0.003465  -3.197280
# 2000-01-13  -2.090294   1.732451   0.228346  -4.984268
# 2000-01-14  -1.104145   2.391618   0.518171  -7.097361
# 2000-01-15  -0.479093   4.409222   0.037052  -7.099943
# 2000-01-16   1.032244   4.761752   0.496412  -6.933799
# ...

# %%
#excel文件
df.to_excel('foo.xlsx' , sheet_name='Sheet1')

# %%
pd.read_excel('foo.xlsx','Sheet1' , index_col=None , na_values=['NA'])
# Out:
#                     A          B          C          D
# 2000-01-01  -0.275510  -1.604590  -0.016232  -0.013008
# 2000-01-02  -0.295853  -1.836106   1.837767  -0.675996
# 2000-01-03  -0.838191  -2.159690   1.649179  -2.029665
# 2000-01-04  -0.811856  -3.068830   3.503493  -4.028204
# 2000-01-05  -0.888820  -3.139324   3.329057  -6.284901
# 2000-01-06  -1.789507  -1.989135   2.932750  -7.073115
# 2000-01-07  -2.154222   0.380633   3.685005  -7.067248
# 2000-01-08  -2.515837  -1.060332   2.583710  -4.997942
# 2000-01-09  -2.798953  -0.465508   2.547062  -4.724121
# 2000-01-10  -1.049692  -0.082855   2.447197  -4.549859
# 2000-01-11   0.348893   0.581044   2.023998  -3.665294
# 2000-01-12  -0.092555   1.354626   0.003465  -3.197280
# 2000-01-13  -2.090294   1.732451   0.228346  -4.984268
# 2000-01-14  -1.104145   2.391618   0.518171  -7.097361
# 2000-01-15  -0.479093   4.409222   0.037052  -7.099943
# 2000-01-16   1.032244   4.761752   0.496412  -6.933799
# ...

# %%
#数组的逻辑真值是不能够确定的
if pd.Series([False , True , False]):
    print('haha True!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-8d9593f6280c> in <module>()
#       1 #数组的逻辑真值是不能够确定的
# ----> 2 if pd.Series([False , True , False]):
#       3     print('haha True!')
#
# I:\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#     951         raise ValueError("The truth value of a {0} is ambiguous. "
#     952                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 953                          .format(self.__class__.__name__))
#     954
#     955     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
